# %%
import json
import umls_api
import os
import yaml
from tqdm import tqdm
import pandas as pd

# %%
with open("config.yaml", "r") as stream:
    try:
        PARAM = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# %%
umls_token = PARAM["umls_token"]

# %%
hpo_condition = {}
msh_condition = {}

msh_name = {}
hpo_name = {}

conditions = pd.read_csv("neo4j/conditions.tsv", sep="\t")



for i, row in tqdm(conditions.iterrows()):


    condition = row["name"]
    umls = row["UMLS"]
    
    if str(row["HPO"]) != "nan":
        hpos = str(row["HPO"]).split("|")

        for hpo in hpos:
            h = hpo.split("/")[1]
            if h not in hpo_condition:
                hpo_condition[h] = []
            hpo_condition[h].append(umls)

            hpo_name[hpo] = condition

    if str(row["MSH"]) != "nan":
        mshs = str(row["MSH"]).split("|")
    
        for msh in mshs:
            m = msh.split("/")[1]
            if m not in msh_condition:
                msh_condition[m] = []
            msh_condition[m].append(umls)

            msh_name[msh] = condition

print (len(hpo_name))
# Out:
# 279it [00:00, 15635.75it/s]
# 144

# %%
hpo_condition
# Out:
# {'HP:0002725': ['UMLS/C0024141'],
#  'HP:0003765': ['UMLS/C0033860'],
#  'HP:0000822': ['UMLS/C0020538'],
#  'HP:0002013': ['UMLS/C0042963'],
#  'HP:0011123': ['UMLS/C0011603'],
#  'HP:0006510': ['UMLS/C0024117'],
#  'HP:0012384': ['UMLS/C0035455'],
#  'HP:0002099': ['UMLS/C0004096'],
#  'HP:0033678': ['UMLS/C0948089'],
#  'HP:0002204': ['UMLS/C0034065'],
#  'HP:0001250': ['UMLS/C0014544', 'UMLS/C0036572'],
#  'HP:0007302': ['UMLS/C0005586'],
#  'HP:0100651': ['UMLS/C0011854'],
#  'HP:0000716': ['UMLS/C0011581'],
#  'HP:0005406': ['UMLS/C1835686'],
#  'HP:0002621': ['UMLS/C0004153'],
#  'HP:0002635': ['UMLS/C0004153'],
#  'HP:0020110': ['UMLS/C0016658'],
#  'HP:0000939': ['UMLS/C0029456'],
#  'HP:0012452': ['UMLS/C0035258'],
#  'HP:0002511': ['UMLS/C0002395'],
#  'HP:0005978': ['UMLS/C0011860'],
#  'HP:0002076': ['UMLS/C0149931'],
#  'HP:0001635': ['UMLS/C0018802', 'UMLS/C0018801'],
#  'HP:0100787': ['UMLS/C0033578'],
#  'HP:0025428': ['UMLS/C0006266'],
#  'HP:0001370': ['UMLS/C0003873'],
#  'HP:0100582': ['UMLS/C0027430'],
#  'HP:0011947': ['UMLS/C0035243'],
#  'HP:0000388': ['UMLS/C0029882'],
#  'HP:0002090': ['UMLS/C0032285'],
#  'HP:0012387': ['UMLS/C0006277'],
#  'HP:0000246': ['UMLS/C0037199'],
#  'HP:0001907': ['UMLS/C0040038'],
#  'HP:0100753': ['UMLS/C0036341'],
#  'HP:0009830': ['UMLS/C0031117'],
#  'HP:0000141': ['UMLS/C0002453'],
#  'HP:0002018': ['UMLS/C0027497'],
#  'HP:0410133': ['UMLS/C0578870'],
#  'HP:0001047': ['UMLS/C0011615'],
#  'HP:0000360': ['UMLS/C0040264'],
#  'HP:0000722': ['UMLS/C0028768'],
#  'HP:0033676': ['UMLS/C0038436'],
#  'HP:0008711': ['UMLS/C1704272'],
#  'HP:0002664': ['UMLS/C0027651', 'UMLS/C0006826'],
#  'HP:0005584': ['UMLS/C0007134'],
#  'HP:0100806': ['UMLS/C0036690'],
#  'HP:0100834': ['UMLS/C0009404'],
#  'HP:0001712': ['UMLS/C0149721'],
#  'HP:0012594': ['UMLS/C0730345'],
#  'HP:0000135': ['UMLS/C0020619'],
#  'HP:0007378': ['UMLS/C0017185'],
#  'HP:0001051': ['UMLS/C0036508'],
#  'HP:0012539': ['UMLS/C0024305'],
#  'HP:0005550': ['UMLS/C0023434'],
#  'HP:0000020': ['UMLS/C0042024'],
#  'HP:0002037': ['UMLS/C0021390'],
#  'HP:0003119': ['UMLS/C0242339'],
#  'HP:0002578': ['UMLS/C0152020'],
#  'HP:0012531': ['UMLS/C0030193'],
#  'HP:0001513': ['UMLS/C0028754'],
#  'HP:0012735': ['UMLS/C0010200'],
#  'HP:0002326': ['UMLS/C0007787'],
#  'HP:0001297': ['UMLS/C0038454'],
#  'HP:0004326': ['UMLS/C0006625'],
#  'HP:0012876': ['UMLS/C0033038'],
#  'HP:0002758': ['UMLS/C0029408'],
#  'HP:0005110': ['UMLS/C0004238'],
#  'HP:0001626': ['UMLS/C0007222'],
#  'HP:0011675': ['UMLS/C0003811'],
#  'HP:0100280': ['UMLS/C0010346'],
#  'HP:0030358': ['UMLS/C0007131'],
#  'HP:0001596': ['UMLS/C0002170'],
#  'HP:0002293': ['UMLS/C0002170'],
#  'HP:0002583': ['UMLS/C0009319'],
#  'HP:0033125': ['UMLS/C0024301'],
#  'HP:0100615': ['UMLS/C0919267', 'UMLS/C1140680'],
#  'HP:0000819': ['UMLS/C0011849'],
#  'HP:0012108': ['UMLS/C0017612'],
#  'HP:0012126': ['UMLS/C0024623'],
#  'HP:0012324': ['UMLS/C0023470'],
#  'HP:0006775': ['UMLS/C0026764'],
#  'HP:0002863': ['UMLS/C3463824'],
#  'HP:0002861': ['UMLS/C0025202'],
#  'HP:0100242': ['UMLS/C1261473'],
#  'HP:0000726': ['UMLS/C0497327'],
#  'HP:0001903': ['UMLS/C0002871'],
#  'HP:0031609': ['UMLS/C1536085'],
#  'HP:0033345': ['UMLS/C0027796'],
#  'HP:0000975': ['UMLS/C0020458'],
#  'HP:0007879': ['UMLS/C0009766'],
#  'HP:0002069': ['UMLS/C0494475'],
#  'HP:0032677': ['UMLS/C0494475'],
#  'HP:0001406': ['UMLS/C0008372'],
#  'HP:0000938': ['UMLS/C0029453'],
#  'HP:0001402': ['UMLS/C2239176'],
#  'HP:0007018': ['UMLS/C1263846'],
#  'HP:0011024': ['UMLS/C0017178'],
#  'HP:0000479': ['UMLS/C0035309'],
#  'HP:0000488': ['UMLS/C0035309'],
#  'HP:0011891': ['UMLS/C0032797'],
#  'HP:0003193': ['UMLS/C2607914'],
#  'HP:0001677': ['UMLS/C1956346'],
#  'HP:0011034': ['UMLS/C0002726'],
#  'HP:0002110': ['UMLS/C0006267'],
#  'HP:0004808': ['UMLS/C0023467'],
#  'HP:0001973': ['UMLS/C0398650'],
#  'HP:0000951': ['UMLS/C0037274'],
#  'HP:0100598': ['UMLS/C0034063'],
#  'HP:0001396': ['UMLS/C0008370'],
#  'HP:0007359': ['UMLS/C0751495'],
#  'HP:0002633': ['UMLS/C0042384'],
#  'HP:0002960': ['UMLS/C0004364'],
#  'HP:0002092': ['UMLS/C2973725'],
#  'HP:0020172': ['UMLS/C0041755'],
#  'HP:0001945': ['UMLS/C0015967'],
#  'HP:0005526': ['UMLS/C0023448'],
#  'HP:0000964': ['UMLS/C0013595'],
#  'HP:0000976': ['UMLS/C0013595'],
#  'HP:0100495': ['UMLS/C0024899'],
#  'HP:0025524': ['UMLS/C4476828'],
#  'HP:0033327': ['UMLS/C0406322'],
#  'HP:0006744': ['UMLS/C0206686'],
#  'HP:0030127': ['UMLS/C0014175'],
#  'HP:0005681': ['UMLS/C3495559'],
#  'HP:0002019': ['UMLS/C0009806'],
#  'HP:0001257': ['UMLS/C0026838'],
#  'HP:0020101': ['UMLS/C1262313'],
#  'HP:0033677': ['UMLS/C0035222'],
#  'HP:0005506': ['UMLS/C0023473'],
#  'HP:0032242': ['UMLS/C0206708'],
#  'HP:0007269': ['UMLS/C0026847'],
#  'HP:0006721': ['UMLS/C0023449'],
#  'HP:0100634': ['UMLS/C0206754'],
#  'HP:0000608': ['UMLS/C0024437'],
#  'HP:0100570': ['UMLS/C0007095'],
#  'HP:0001025': ['UMLS/C0042109'],
#  'HP:0001733': ['UMLS/C0030305'],
#  'HP:0001287': ['UMLS/C0025289'],
#  'HP:0030731': ['UMLS/C0007097'],
#  'HP:0003124': ['UMLS/C0020443'],
#  'HP:0500049': ['UMLS/C0035344'],
#  'HP:0033726': ['UMLS/C0024143'],
#  'HP:0011459': ['UMLS/C0152018']}

# %%
msh_condition
# Out:
# {'D000152': ['UMLS/C0001144'],
#  'D008180': ['UMLS/C0024141'],
#  'D011565': ['UMLS/C0033860'],
#  'D006973': ['UMLS/C0020538'],
#  'D014839': ['UMLS/C0042963'],
#  'D003872': ['UMLS/C0011603'],
#  'D029424': ['UMLS/C0024117'],
#  'D012220': ['UMLS/C0035455'],
#  'D001249': ['UMLS/C0004096'],
#  'D054058': ['UMLS/C0948089'],
#  'D011655': ['UMLS/C0034065'],
#  'D013927': ['UMLS/C0040053'],
#  'D019964': ['UMLS/C0525045'],
#  'D004827': ['UMLS/C0014544', 'UMLS/C0236018'],
#  'D001714': ['UMLS/C0005586'],
#  'D015228': ['UMLS/C0020557'],
#  'D003922': ['UMLS/C0011854'],
#  'D003866': ['UMLS/C0011581', 'UMLS/C0041696'],
#  'D001424': ['UMLS/C0004623'],
#  'D050197': ['UMLS/C0004153'],
#  'D050723': ['UMLS/C0016658'],
#  'D010024': ['UMLS/C0029456'],
#  'D010300': ['UMLS/C0030567'],
#  'D012148': ['UMLS/C0035258'],
#  'D000544': ['UMLS/C0002395'],
#  'D003924': ['UMLS/C0011860'],
#  'D008881': ['UMLS/C0149931'],
#  'D012893': ['UMLS/C0851578'],
#  'D030361': ['UMLS/C0343641'],
#  'D013290': ['UMLS/C0038395'],
#  'D014917': ['UMLS/C0043167'],
#  'D004165': ['UMLS/C0012546'],
#  'D006509': ['UMLS/C0019163'],
#  'D011051': ['UMLS/C0032371'],
#  'D013742': ['UMLS/C0039614'],
#  'D019741': ['UMLS/C0121772'],
#  'D009345': ['UMLS/C0027575'],
#  'D008457': ['UMLS/C0025007'],
#  'D009107': ['UMLS/C0026780'],
#  'D012409': ['UMLS/C0035920'],
#  'D002644': ['UMLS/C0008049'],
#  'D007251': ['UMLS/C0021400'],
#  'D012400': ['UMLS/C0035869'],
#  'D012640': ['UMLS/C0036572', 'UMLS/C0494475', 'UMLS/C0751495'],
#  'D051474': ['UMLS/C0032768'],
#  'D008288': ['UMLS/C0024530'],
#  'D001523': ['UMLS/C0004936'],
#  'D006333': ['UMLS/C0018802', 'UMLS/C0018801'],
#  'D011471': ['UMLS/C0033578', 'UMLS/C0376358'],
#  'D011470': ['UMLS/C2937421', 'UMLS/C1704272'],
#  'D001986': ['UMLS/C0006266'],
#  'D009103': ['UMLS/C0026769'],
#  'D003929': ['UMLS/C0011882', 'UMLS/C0751074'],
#  'D001172': ['UMLS/C0003873'],
#  'D016535': ['UMLS/C0085129'],
#  'D015658': ['UMLS/C0019693'],
#  'D009298': ['UMLS/C0027430'],
#  'D006506': ['UMLS/C0019159'],
#  'D012141': ['UMLS/C0035243'],
#  'D010033': ['UMLS/C0029882'],
#  'D011014': ['UMLS/C0032285'],
#  'D017714': ['UMLS/C0206171'],
#  'D013296': ['UMLS/C0038410'],
#  'D001991': ['UMLS/C0006277'],
#  'D012852': ['UMLS/C0037199'],
#  'D012223': ['UMLS/C0035460'],
#  'D013923': ['UMLS/C0040038'],
#  'D004830': ['UMLS/C0014549'],
#  'D004828': ['UMLS/C0014547'],
#  'D012559': ['UMLS/C0036341'],
#  'D000568': ['UMLS/C0002453'],
#  'D005356': ['UMLS/C0016053'],
#  'D006558': ['UMLS/C0019342'],
#  'D006561': ['UMLS/C0019348'],
#  'D006560': ['UMLS/C0019345'],
#  'D006566': ['UMLS/C0019372'],
#  'D001008': ['UMLS/C0003469'],
#  'D009325': ['UMLS/C0027497'],
#  'D008589': ['UMLS/C0025303'],
#  'D000080223': ['UMLS/C0578870'],
#  'D003876': ['UMLS/C0011615'],
#  'D014012': ['UMLS/C0040264'],
#  'D010698': ['UMLS/C0349231'],
#  'D009771': ['UMLS/C0028768'],
#  'D016584': ['UMLS/C0030319'],
#  'D013313': ['UMLS/C0038436'],
#  'D011293': ['UMLS/C0033046'],
#  'D009980': ['UMLS/C0029347'],
#  'D009181': ['UMLS/C0026946'],
#  'D009369': ['UMLS/C0027651', 'UMLS/C0006826'],
#  'D002292': ['UMLS/C0007134'],
#  'D018805': ['UMLS/C0036690'],
#  'D009133': ['UMLS/C0026846'],
#  'D015179': ['UMLS/C0009404'],
#  'D017379': ['UMLS/C0149721'],
#  'D003930': ['UMLS/C0011884'],
#  'D007006': ['UMLS/C0020619'],
#  'D005770': ['UMLS/C0017185'],
#  'D012628': ['UMLS/C0036508'],
#  'D007169': ['UMLS/C0021099'],
#  'D008228': ['UMLS/C0024305'],
#  'D015451': ['UMLS/C0023434'],
#  'D014549': ['UMLS/C0042024'],
#  'D014947': ['UMLS/C3263723', 'UMLS/C0043250'],
#  'D015212': ['UMLS/C0021390'],
#  'D050171': ['UMLS/C0242339'],
#  'D018589': ['UMLS/C0152020'],
#  'D010146': ['UMLS/C0030193'],
#  'D007249': ['UMLS/C0021368'],
#  'D009765': ['UMLS/C0028754'],
#  'D003371': ['UMLS/C0010200'],
#  'D006526': ['UMLS/C0019196'],
#  'D002546': ['UMLS/C0007787'],
#  'D020521': ['UMLS/C0038454'],
#  'D002100': ['UMLS/C0006625'],
#  'D061686': ['UMLS/C0033038'],
#  'D024821': ['UMLS/C0524620'],
#  'D015663': ['UMLS/C0029458'],
#  'D010003': ['UMLS/C0029408'],
#  'D001281': ['UMLS/C0004238'],
#  'D002318': ['UMLS/C0007222'],
#  'D001145': ['UMLS/C0003811'],
#  'D003424': ['UMLS/C0010346'],
#  'D003072': ['UMLS/C0009241'],
#  'D003250': ['UMLS/C0009813'],
#  'D002289': ['UMLS/C0007131'],
#  'D000505': ['UMLS/C0002170'],
#  'D003092': ['UMLS/C0009319'],
#  'D014456': ['UMLS/C0041582'],
#  'D008224': ['UMLS/C0024301'],
#  'D010051': ['UMLS/C0919267', 'UMLS/C1140680'],
#  'D065768': ['UMLS/C0238111'],
#  'D003920': ['UMLS/C0011849'],
#  'D057765': ['UMLS/C0341106'],
#  'D020953': ['UMLS/C0752341'],
#  'D009091': ['UMLS/C0026718'],
#  'D005902': ['UMLS/C0017612'],
#  'D009798': ['UMLS/C0028840'],
#  'D013274': ['UMLS/C0024623'],
#  'D007951': ['UMLS/C0023470'],
#  'D009101': ['UMLS/C0026764'],
#  'D009190': ['UMLS/C3463824'],
#  'D008545': ['UMLS/C0025202'],
#  'D004194': ['UMLS/C0012634'],
#  'D012509': ['UMLS/C1261473'],
#  'D003704': ['UMLS/C0497327'],
#  'D015535': ['UMLS/C0003872'],
#  'D012120': ['UMLS/C0035204'],
#  'D014435': ['UMLS/C0041466'],
#  'D000740': ['UMLS/C0002871'],
#  'D014652': ['UMLS/C0042373'],
#  'D006816': ['UMLS/C0020179'],
#  'D007752': ['UMLS/C0022876'],
#  'D003550': ['UMLS/C0010674'],
#  'D057092': ['UMLS/C1536085'],
#  'D009437': ['UMLS/C0027796'],
#  'D006945': ['UMLS/C0020458'],
#  'D001943': ['UMLS/C0006142'],
#  'D003233': ['UMLS/C0009766'],
#  'D006562': ['UMLS/C0019360'],
#  'D017681': ['UMLS/C1540912'],
#  'D005490': ['UMLS/C0016397'],
#  'D002780': ['UMLS/C0008372'],
#  'D001851': ['UMLS/C0029453'],
#  'D006528': ['UMLS/C2239176'],
#  'D001289': ['UMLS/C1263846'],
#  'D005767': ['UMLS/C0017178'],
#  'D012164': ['UMLS/C0035309'],
#  'D006473': ['UMLS/C0032797'],
#  'D065631': ['UMLS/C2607914'],
#  'D013167': ['UMLS/C0038013'],
#  'D003324': ['UMLS/C1956346'],
#  'D000686': ['UMLS/C0002726'],
#  'D018357': ['UMLS/C0035235'],
#  'D014376': ['UMLS/C0041296'],
#  'D001987': ['UMLS/C0006267'],
#  'D014570': ['UMLS/C0042075'],
#  'D053201': ['UMLS/C0268849'],
#  'D012764': ['UMLS/C0036960'],
#  'D015470': ['UMLS/C0023467'],
#  'D013203': ['UMLS/C0038160'],
#  'D054990': ['UMLS/C1800706'],
#  'D058365': ['UMLS/C1609535'],
#  'D016553': ['UMLS/C0398650'],
#  'D012871': ['UMLS/C0037274'],
#  'D006069': ['UMLS/C0018081'],
#  'D000163': ['UMLS/C0001175'],
#  'D012595': ['UMLS/C0036421'],
#  'D011654': ['UMLS/C0034063'],
#  'D002779': ['UMLS/C0008370'],
#  'D006976': ['UMLS/C0020542'],
#  'D009362': ['UMLS/C0027627'],
#  'D003015': ['UMLS/C0343386'],
#  'D043183': ['UMLS/C0022104'],
#  'D014657': ['UMLS/C0042384'],
#  'D001327': ['UMLS/C0004364'],
#  'D004405': ['UMLS/C1527298'],
#  'D014777': ['UMLS/C0042769'],
#  'D000081029': ['UMLS/C2973725'],
#  'D064420': ['UMLS/C0041755'],
#  'D005334': ['UMLS/C0015967'],
#  'D007945': ['UMLS/C0023448'],
#  'D013292': ['UMLS/C0579233'],
#  'D018288': ['UMLS/C0262584'],
#  'D020522': ['UMLS/C0334634'],
#  'D004485': ['UMLS/C0013595'],
#  'D008415': ['UMLS/C0024899'],
#  'D018268': ['UMLS/C0206686'],
#  'D004715': ['UMLS/C0014175'],
#  'D001171': ['UMLS/C3495559'],
#  'D005211': ['UMLS/C0015652'],
#  'D014123': ['UMLS/C0040558'],
#  'D003928': ['UMLS/C0011881'],
#  'D003248': ['UMLS/C0009806'],
#  'D009128': ['UMLS/C0026838'],
#  'D000072742': ['UMLS/C1262313'],
#  'D014077': ['UMLS/C0040436'],
#  'D055728': ['UMLS/C0001815'],
#  'D000270': ['UMLS/C0001519'],
#  'D012128': ['UMLS/C0035222'],
#  'D018290': ['UMLS/C0206708'],
#  'D009157': ['UMLS/C0026896'],
#  'D003807': ['UMLS/C0011432'],
#  'D009134': ['UMLS/C0026847'],
#  'D064726': ['UMLS/C3539878'],
#  'D018358': ['UMLS/C0206754'],
#  'D008268': ['UMLS/C0024437'],
#  'D006009': ['UMLS/C0017921'],
#  'D000755': ['UMLS/C0002895'],
#  'D002276': ['UMLS/C0007095'],
#  'D014581': ['UMLS/C0042109'],
#  'D003781': ['UMLS/C0011397'],
#  'D010195': ['UMLS/C0030305'],
#  'D008581': ['UMLS/C0025289'],
#  'D002277': ['UMLS/C0007097'],
#  'D025241': ['UMLS/C0949690'],
#  'D006937': ['UMLS/C0020443'],
#  'D012178': ['UMLS/C0035344'],
#  'D008181': ['UMLS/C0024143'],
#  'D006086': ['UMLS/C0018133']}

# %%
hpo_from_to = []

umls_to_hpo = set()


print (len(hpo_condition))
for hpo in tqdm(hpo_condition):

    results = umls_api.recursive_get_parent_HPO(hpo, umls_token)

    for r in results:
        hpo_from_to.append((r[0], r[1]))

        if r[1] not in hpo_condition:
            hpo_name[f"HPO/{r[1]}"] = r[2]

    for u in hpo_condition[hpo]:
        umls_to_hpo.add((u, hpo))

print (len(hpo_name))
# Out:
# 144
# 100%|██████████| 144/144 [06:33<00:00,  2.73s/it]
# 405

# %%
umls_to_hpo
# Out:
# {('UMLS/C0002170', 'HP:0001596'),
#  ('UMLS/C0002170', 'HP:0002293'),
#  ('UMLS/C0002395', 'HP:0002511'),
#  ('UMLS/C0002453', 'HP:0000141'),
#  ('UMLS/C0002726', 'HP:0011034'),
#  ('UMLS/C0002871', 'HP:0001903'),
#  ('UMLS/C0003811', 'HP:0011675'),
#  ('UMLS/C0003873', 'HP:0001370'),
#  ('UMLS/C0004096', 'HP:0002099'),
#  ('UMLS/C0004153', 'HP:0002621'),
#  ('UMLS/C0004153', 'HP:0002635'),
#  ('UMLS/C0004238', 'HP:0005110'),
#  ('UMLS/C0004364', 'HP:0002960'),
#  ('UMLS/C0005586', 'HP:0007302'),
#  ('UMLS/C0006266', 'HP:0025428'),
#  ('UMLS/C0006267', 'HP:0002110'),
#  ('UMLS/C0006277', 'HP:0012387'),
#  ('UMLS/C0006625', 'HP:0004326'),
#  ('UMLS/C0006826', 'HP:0002664'),
#  ('UMLS/C0007095', 'HP:0100570'),
#  ('UMLS/C0007097', 'HP:0030731'),
#  ('UMLS/C0007131', 'HP:0030358'),
#  ('UMLS/C0007134', 'HP:0005584'),
#  ('UMLS/C0007222', 'HP:0001626'),
#  ('UMLS/C0007787', 'HP:0002326'),
#  ('UMLS/C0008370', 'HP:0001396'),
#  ('UMLS/C0008372', 'HP:0001406'),
#  ('UMLS/C0009319', 'HP:0002583'),
#  ('UMLS/C0009404', 'HP:0100834'),
#  ('UMLS/C0009766', 'HP:0007879'),
#  ('UMLS/C0009806', 'HP:0002019'),
#  ('UMLS/C0010200', 'HP:0012735'),
#  ('UMLS/C0010346', 'HP:0100280'),
#  ('UMLS/C0011581', 'HP:0000716'),
#  ('UMLS/C0011603', 'HP:0011123'),
#  ('UMLS/C0011615', 'HP:0001047'),
#  ('UMLS/C0011849', 'HP:0000819'),
#  ('UMLS/C0011854', 'HP:0100651'),
#  ('UMLS/C0011860', 'HP:0005978'),
#  ('UMLS/C0013595', 'HP:0000964'),
#  ('UMLS/C0013595', 'HP:0000976'),
#  ('UMLS/C0014175', 'HP:0030127'),
#  ('UMLS/C0014544', 'HP:0001250'),
#  ('UMLS/C0015967', 'HP:0001945'),
#  ('UMLS/C0016658', 'HP:0020110'),
#  ('UMLS/C0017178', 'HP:0011024'),
#  ('UMLS/C0017185', 'HP:0007378'),
#  ('UMLS/C0017612', 'HP:0012108'),
#  ('UMLS/C0018801', 'HP:0001635'),
#  ('UMLS/C0018802', 'HP:0001635'),
#  ('UMLS/C0020443', 'HP:0003124'),
#  ('UMLS/C0020458', 'HP:0000975'),
#  ('UMLS/C0020538', 'HP:0000822'),
#  ('UMLS/C0020619', 'HP:0000135'),
#  ('UMLS/C0021390', 'HP:0002037'),
#  ('UMLS/C0023434', 'HP:0005550'),
#  ('UMLS/C0023448', 'HP:0005526'),
#  ('UMLS/C0023449', 'HP:0006721'),
#  ('UMLS/C0023467', 'HP:0004808'),
#  ('UMLS/C0023470', 'HP:0012324'),
#  ('UMLS/C0023473', 'HP:0005506'),
#  ('UMLS/C0024117', 'HP:0006510'),
#  ('UMLS/C0024141', 'HP:0002725'),
#  ('UMLS/C0024143', 'HP:0033726'),
#  ('UMLS/C0024301', 'HP:0033125'),
#  ('UMLS/C0024305', 'HP:0012539'),
#  ('UMLS/C0024437', 'HP:0000608'),
#  ('UMLS/C0024623', 'HP:0012126'),
#  ('UMLS/C0024899', 'HP:0100495'),
#  ('UMLS/C0025202', 'HP:0002861'),
#  ('UMLS/C0025289', 'HP:0001287'),
#  ('UMLS/C0026764', 'HP:0006775'),
#  ('UMLS/C0026838', 'HP:0001257'),
#  ('UMLS/C0026847', 'HP:0007269'),
#  ('UMLS/C0027430', 'HP:0100582'),
#  ('UMLS/C0027497', 'HP:0002018'),
#  ('UMLS/C0027651', 'HP:0002664'),
#  ('UMLS/C0027796', 'HP:0033345'),
#  ('UMLS/C0028754', 'HP:0001513'),
#  ('UMLS/C0028768', 'HP:0000722'),
#  ('UMLS/C0029408', 'HP:0002758'),
#  ('UMLS/C0029453', 'HP:0000938'),
#  ('UMLS/C0029456', 'HP:0000939'),
#  ('UMLS/C0029882', 'HP:0000388'),
#  ('UMLS/C0030193', 'HP:0012531'),
#  ('UMLS/C0030305', 'HP:0001733'),
#  ('UMLS/C0031117', 'HP:0009830'),
#  ('UMLS/C0032285', 'HP:0002090'),
#  ('UMLS/C0032797', 'HP:0011891'),
#  ('UMLS/C0033038', 'HP:0012876'),
#  ('UMLS/C0033578', 'HP:0100787'),
#  ('UMLS/C0033860', 'HP:0003765'),
#  ('UMLS/C0034063', 'HP:0100598'),
#  ('UMLS/C0034065', 'HP:0002204'),
#  ('UMLS/C0035222', 'HP:0033677'),
#  ('UMLS/C0035243', 'HP:0011947'),
#  ('UMLS/C0035258', 'HP:0012452'),
#  ('UMLS/C0035309', 'HP:0000479'),
#  ('UMLS/C0035309', 'HP:0000488'),
#  ('UMLS/C0035344', 'HP:0500049'),
#  ('UMLS/C0035455', 'HP:0012384'),
#  ('UMLS/C0036341', 'HP:0100753'),
#  ('UMLS/C0036508', 'HP:0001051'),
#  ('UMLS/C0036572', 'HP:0001250'),
#  ('UMLS/C0036690', 'HP:0100806'),
#  ('UMLS/C0037199', 'HP:0000246'),
#  ('UMLS/C0037274', 'HP:0000951'),
#  ('UMLS/C0038436', 'HP:0033676'),
#  ('UMLS/C0038454', 'HP:0001297'),
#  ('UMLS/C0040038', 'HP:0001907'),
#  ('UMLS/C0040264', 'HP:0000360'),
#  ('UMLS/C0041755', 'HP:0020172'),
#  ('UMLS/C0042024', 'HP:0000020'),
#  ('UMLS/C0042109', 'HP:0001025'),
#  ('UMLS/C0042384', 'HP:0002633'),
#  ('UMLS/C0042963', 'HP:0002013'),
#  ('UMLS/C0149721', 'HP:0001712'),
#  ('UMLS/C0149931', 'HP:0002076'),
#  ('UMLS/C0152018', 'HP:0011459'),
#  ('UMLS/C0152020', 'HP:0002578'),
#  ('UMLS/C0206686', 'HP:0006744'),
#  ('UMLS/C0206708', 'HP:0032242'),
#  ('UMLS/C0206754', 'HP:0100634'),
#  ('UMLS/C0242339', 'HP:0003119'),
#  ('UMLS/C0398650', 'HP:0001973'),
#  ('UMLS/C0406322', 'HP:0033327'),
#  ('UMLS/C0494475', 'HP:0002069'),
#  ('UMLS/C0494475', 'HP:0032677'),
#  ('UMLS/C0497327', 'HP:0000726'),
#  ('UMLS/C0578870', 'HP:0410133'),
#  ('UMLS/C0730345', 'HP:0012594'),
#  ('UMLS/C0751495', 'HP:0007359'),
#  ('UMLS/C0919267', 'HP:0100615'),
#  ('UMLS/C0948089', 'HP:0033678'),
#  ('UMLS/C1140680', 'HP:0100615'),
#  ('UMLS/C1261473', 'HP:0100242'),
#  ('UMLS/C1262313', 'HP:0020101'),
#  ('UMLS/C1263846', 'HP:0007018'),
#  ('UMLS/C1536085', 'HP:0031609'),
#  ('UMLS/C1704272', 'HP:0008711'),
#  ('UMLS/C1835686', 'HP:0005406'),
#  ('UMLS/C1956346', 'HP:0001677'),
#  ('UMLS/C2239176', 'HP:0001402'),
#  ('UMLS/C2607914', 'HP:0003193'),
#  ('UMLS/C2973725', 'HP:0002092'),
#  ('UMLS/C3463824', 'HP:0002863'),
#  ('UMLS/C3495559', 'HP:0005681'),
#  ('UMLS/C4476828', 'HP:0025524')}

# %%
content = "from\tto\n"

for h in hpo_from_to:
    content += f"HPO/{h[0]}" + "\t" + f"HPO/{h[1]}" + "\n"


with open("neo4j/hpo_is_a.tsv", "w") as f:
    f.write(content)

# %%
content = "from\tto\n"

for h in umls_to_hpo:
    content += h[0] + "\t" + f"HPO/{h[1]}" + "\n"


with open("neo4j/condition_is_hpo.tsv", "w") as f:
    f.write(content)

# %%
content = "HPO\tname\n"
for h in hpo_name:
    content += h + "\t" + hpo_name[h] + "\n"

with open("neo4j/condition_hpo_name.tsv", "w") as f:
    f.write(content)

# %%
msh_condition
# Out:
# {'D000152': ['UMLS/C0001144'],
#  'D008180': ['UMLS/C0024141'],
#  'D011565': ['UMLS/C0033860'],
#  'D006973': ['UMLS/C0020538'],
#  'D014839': ['UMLS/C0042963'],
#  'D003872': ['UMLS/C0011603'],
#  'D029424': ['UMLS/C0024117'],
#  'D012220': ['UMLS/C0035455'],
#  'D001249': ['UMLS/C0004096'],
#  'D054058': ['UMLS/C0948089'],
#  'D011655': ['UMLS/C0034065'],
#  'D013927': ['UMLS/C0040053'],
#  'D019964': ['UMLS/C0525045'],
#  'D004827': ['UMLS/C0014544', 'UMLS/C0236018'],
#  'D001714': ['UMLS/C0005586'],
#  'D015228': ['UMLS/C0020557'],
#  'D003922': ['UMLS/C0011854'],
#  'D003866': ['UMLS/C0011581', 'UMLS/C0041696'],
#  'D001424': ['UMLS/C0004623'],
#  'D050197': ['UMLS/C0004153'],
#  'D050723': ['UMLS/C0016658'],
#  'D010024': ['UMLS/C0029456'],
#  'D010300': ['UMLS/C0030567'],
#  'D012148': ['UMLS/C0035258'],
#  'D000544': ['UMLS/C0002395'],
#  'D003924': ['UMLS/C0011860'],
#  'D008881': ['UMLS/C0149931'],
#  'D012893': ['UMLS/C0851578'],
#  'D030361': ['UMLS/C0343641'],
#  'D013290': ['UMLS/C0038395'],
#  'D014917': ['UMLS/C0043167'],
#  'D004165': ['UMLS/C0012546'],
#  'D006509': ['UMLS/C0019163'],
#  'D011051': ['UMLS/C0032371'],
#  'D013742': ['UMLS/C0039614'],
#  'D019741': ['UMLS/C0121772'],
#  'D009345': ['UMLS/C0027575'],
#  'D008457': ['UMLS/C0025007'],
#  'D009107': ['UMLS/C0026780'],
#  'D012409': ['UMLS/C0035920'],
#  'D002644': ['UMLS/C0008049'],
#  'D007251': ['UMLS/C0021400'],
#  'D012400': ['UMLS/C0035869'],
#  'D012640': ['UMLS/C0036572', 'UMLS/C0494475', 'UMLS/C0751495'],
#  'D051474': ['UMLS/C0032768'],
#  'D008288': ['UMLS/C0024530'],
#  'D001523': ['UMLS/C0004936'],
#  'D006333': ['UMLS/C0018802', 'UMLS/C0018801'],
#  'D011471': ['UMLS/C0033578', 'UMLS/C0376358'],
#  'D011470': ['UMLS/C2937421', 'UMLS/C1704272'],
#  'D001986': ['UMLS/C0006266'],
#  'D009103': ['UMLS/C0026769'],
#  'D003929': ['UMLS/C0011882', 'UMLS/C0751074'],
#  'D001172': ['UMLS/C0003873'],
#  'D016535': ['UMLS/C0085129'],
#  'D015658': ['UMLS/C0019693'],
#  'D009298': ['UMLS/C0027430'],
#  'D006506': ['UMLS/C0019159'],
#  'D012141': ['UMLS/C0035243'],
#  'D010033': ['UMLS/C0029882'],
#  'D011014': ['UMLS/C0032285'],
#  'D017714': ['UMLS/C0206171'],
#  'D013296': ['UMLS/C0038410'],
#  'D001991': ['UMLS/C0006277'],
#  'D012852': ['UMLS/C0037199'],
#  'D012223': ['UMLS/C0035460'],
#  'D013923': ['UMLS/C0040038'],
#  'D004830': ['UMLS/C0014549'],
#  'D004828': ['UMLS/C0014547'],
#  'D012559': ['UMLS/C0036341'],
#  'D000568': ['UMLS/C0002453'],
#  'D005356': ['UMLS/C0016053'],
#  'D006558': ['UMLS/C0019342'],
#  'D006561': ['UMLS/C0019348'],
#  'D006560': ['UMLS/C0019345'],
#  'D006566': ['UMLS/C0019372'],
#  'D001008': ['UMLS/C0003469'],
#  'D009325': ['UMLS/C0027497'],
#  'D008589': ['UMLS/C0025303'],
#  'D000080223': ['UMLS/C0578870'],
#  'D003876': ['UMLS/C0011615'],
#  'D014012': ['UMLS/C0040264'],
#  'D010698': ['UMLS/C0349231'],
#  'D009771': ['UMLS/C0028768'],
#  'D016584': ['UMLS/C0030319'],
#  'D013313': ['UMLS/C0038436'],
#  'D011293': ['UMLS/C0033046'],
#  'D009980': ['UMLS/C0029347'],
#  'D009181': ['UMLS/C0026946'],
#  'D009369': ['UMLS/C0027651', 'UMLS/C0006826'],
#  'D002292': ['UMLS/C0007134'],
#  'D018805': ['UMLS/C0036690'],
#  'D009133': ['UMLS/C0026846'],
#  'D015179': ['UMLS/C0009404'],
#  'D017379': ['UMLS/C0149721'],
#  'D003930': ['UMLS/C0011884'],
#  'D007006': ['UMLS/C0020619'],
#  'D005770': ['UMLS/C0017185'],
#  'D012628': ['UMLS/C0036508'],
#  'D007169': ['UMLS/C0021099'],
#  'D008228': ['UMLS/C0024305'],
#  'D015451': ['UMLS/C0023434'],
#  'D014549': ['UMLS/C0042024'],
#  'D014947': ['UMLS/C3263723', 'UMLS/C0043250'],
#  'D015212': ['UMLS/C0021390'],
#  'D050171': ['UMLS/C0242339'],
#  'D018589': ['UMLS/C0152020'],
#  'D010146': ['UMLS/C0030193'],
#  'D007249': ['UMLS/C0021368'],
#  'D009765': ['UMLS/C0028754'],
#  'D003371': ['UMLS/C0010200'],
#  'D006526': ['UMLS/C0019196'],
#  'D002546': ['UMLS/C0007787'],
#  'D020521': ['UMLS/C0038454'],
#  'D002100': ['UMLS/C0006625'],
#  'D061686': ['UMLS/C0033038'],
#  'D024821': ['UMLS/C0524620'],
#  'D015663': ['UMLS/C0029458'],
#  'D010003': ['UMLS/C0029408'],
#  'D001281': ['UMLS/C0004238'],
#  'D002318': ['UMLS/C0007222'],
#  'D001145': ['UMLS/C0003811'],
#  'D003424': ['UMLS/C0010346'],
#  'D003072': ['UMLS/C0009241'],
#  'D003250': ['UMLS/C0009813'],
#  'D002289': ['UMLS/C0007131'],
#  'D000505': ['UMLS/C0002170'],
#  'D003092': ['UMLS/C0009319'],
#  'D014456': ['UMLS/C0041582'],
#  'D008224': ['UMLS/C0024301'],
#  'D010051': ['UMLS/C0919267', 'UMLS/C1140680'],
#  'D065768': ['UMLS/C0238111'],
#  'D003920': ['UMLS/C0011849'],
#  'D057765': ['UMLS/C0341106'],
#  'D020953': ['UMLS/C0752341'],
#  'D009091': ['UMLS/C0026718'],
#  'D005902': ['UMLS/C0017612'],
#  'D009798': ['UMLS/C0028840'],
#  'D013274': ['UMLS/C0024623'],
#  'D007951': ['UMLS/C0023470'],
#  'D009101': ['UMLS/C0026764'],
#  'D009190': ['UMLS/C3463824'],
#  'D008545': ['UMLS/C0025202'],
#  'D004194': ['UMLS/C0012634'],
#  'D012509': ['UMLS/C1261473'],
#  'D003704': ['UMLS/C0497327'],
#  'D015535': ['UMLS/C0003872'],
#  'D012120': ['UMLS/C0035204'],
#  'D014435': ['UMLS/C0041466'],
#  'D000740': ['UMLS/C0002871'],
#  'D014652': ['UMLS/C0042373'],
#  'D006816': ['UMLS/C0020179'],
#  'D007752': ['UMLS/C0022876'],
#  'D003550': ['UMLS/C0010674'],
#  'D057092': ['UMLS/C1536085'],
#  'D009437': ['UMLS/C0027796'],
#  'D006945': ['UMLS/C0020458'],
#  'D001943': ['UMLS/C0006142'],
#  'D003233': ['UMLS/C0009766'],
#  'D006562': ['UMLS/C0019360'],
#  'D017681': ['UMLS/C1540912'],
#  'D005490': ['UMLS/C0016397'],
#  'D002780': ['UMLS/C0008372'],
#  'D001851': ['UMLS/C0029453'],
#  'D006528': ['UMLS/C2239176'],
#  'D001289': ['UMLS/C1263846'],
#  'D005767': ['UMLS/C0017178'],
#  'D012164': ['UMLS/C0035309'],
#  'D006473': ['UMLS/C0032797'],
#  'D065631': ['UMLS/C2607914'],
#  'D013167': ['UMLS/C0038013'],
#  'D003324': ['UMLS/C1956346'],
#  'D000686': ['UMLS/C0002726'],
#  'D018357': ['UMLS/C0035235'],
#  'D014376': ['UMLS/C0041296'],
#  'D001987': ['UMLS/C0006267'],
#  'D014570': ['UMLS/C0042075'],
#  'D053201': ['UMLS/C0268849'],
#  'D012764': ['UMLS/C0036960'],
#  'D015470': ['UMLS/C0023467'],
#  'D013203': ['UMLS/C0038160'],
#  'D054990': ['UMLS/C1800706'],
#  'D058365': ['UMLS/C1609535'],
#  'D016553': ['UMLS/C0398650'],
#  'D012871': ['UMLS/C0037274'],
#  'D006069': ['UMLS/C0018081'],
#  'D000163': ['UMLS/C0001175'],
#  'D012595': ['UMLS/C0036421'],
#  'D011654': ['UMLS/C0034063'],
#  'D002779': ['UMLS/C0008370'],
#  'D006976': ['UMLS/C0020542'],
#  'D009362': ['UMLS/C0027627'],
#  'D003015': ['UMLS/C0343386'],
#  'D043183': ['UMLS/C0022104'],
#  'D014657': ['UMLS/C0042384'],
#  'D001327': ['UMLS/C0004364'],
#  'D004405': ['UMLS/C1527298'],
#  'D014777': ['UMLS/C0042769'],
#  'D000081029': ['UMLS/C2973725'],
#  'D064420': ['UMLS/C0041755'],
#  'D005334': ['UMLS/C0015967'],
#  'D007945': ['UMLS/C0023448'],
#  'D013292': ['UMLS/C0579233'],
#  'D018288': ['UMLS/C0262584'],
#  'D020522': ['UMLS/C0334634'],
#  'D004485': ['UMLS/C0013595'],
#  'D008415': ['UMLS/C0024899'],
#  'D018268': ['UMLS/C0206686'],
#  'D004715': ['UMLS/C0014175'],
#  'D001171': ['UMLS/C3495559'],
#  'D005211': ['UMLS/C0015652'],
#  'D014123': ['UMLS/C0040558'],
#  'D003928': ['UMLS/C0011881'],
#  'D003248': ['UMLS/C0009806'],
#  'D009128': ['UMLS/C0026838'],
#  'D000072742': ['UMLS/C1262313'],
#  'D014077': ['UMLS/C0040436'],
#  'D055728': ['UMLS/C0001815'],
#  'D000270': ['UMLS/C0001519'],
#  'D012128': ['UMLS/C0035222'],
#  'D018290': ['UMLS/C0206708'],
#  'D009157': ['UMLS/C0026896'],
#  'D003807': ['UMLS/C0011432'],
#  'D009134': ['UMLS/C0026847'],
#  'D064726': ['UMLS/C3539878'],
#  'D018358': ['UMLS/C0206754'],
#  'D008268': ['UMLS/C0024437'],
#  'D006009': ['UMLS/C0017921'],
#  'D000755': ['UMLS/C0002895'],
#  'D002276': ['UMLS/C0007095'],
#  'D014581': ['UMLS/C0042109'],
#  'D003781': ['UMLS/C0011397'],
#  'D010195': ['UMLS/C0030305'],
#  'D008581': ['UMLS/C0025289'],
#  'D002277': ['UMLS/C0007097'],
#  'D025241': ['UMLS/C0949690'],
#  'D006937': ['UMLS/C0020443'],
#  'D012178': ['UMLS/C0035344'],
#  'D008181': ['UMLS/C0024143'],
#  'D006086': ['UMLS/C0018133']}

# %%
print (len(msh_condition))

msh_treated = {}

umls_to_msh_condition = set()

for msh_id in tqdm(msh_condition):

    #print (msh_id)
    results = umls_api.get_all_items("MSH", msh_id, "includeAdditionalRelationLabels=may_be_prevented_by", umls_token)

    if msh_id not in msh_treated:
        msh_treated[msh_id] = set()
    for r in results:
        msh_treated[msh_id].add(r[1])
    
    for u in msh_condition[msh_id]:
        umls_to_msh_condition.add((u, msh_id))
# Out:
# 240
# 100%|██████████| 240/240 [04:21<00:00,  1.09s/it]

# %%
content = "MSH\tmay_be_treated_by\n"
for m in msh_treated:
    content += f"MSH/{m}" + "\t" + "|".join(msh_treated[m]) + "\n"

with open("neo4j/msh_may_be_treated_by.tsv", "w") as f:
    f.write(content)

# %%
msh_condition
# Out:
# {'D000152': ['UMLS/C0001144'],
#  'D008180': ['UMLS/C0024141'],
#  'D011565': ['UMLS/C0033860'],
#  'D006973': ['UMLS/C0020538'],
#  'D014839': ['UMLS/C0042963'],
#  'D003872': ['UMLS/C0011603'],
#  'D029424': ['UMLS/C0024117'],
#  'D012220': ['UMLS/C0035455'],
#  'D001249': ['UMLS/C0004096'],
#  'D054058': ['UMLS/C0948089'],
#  'D011655': ['UMLS/C0034065'],
#  'D013927': ['UMLS/C0040053'],
#  'D019964': ['UMLS/C0525045'],
#  'D004827': ['UMLS/C0014544', 'UMLS/C0236018'],
#  'D001714': ['UMLS/C0005586'],
#  'D015228': ['UMLS/C0020557'],
#  'D003922': ['UMLS/C0011854'],
#  'D003866': ['UMLS/C0011581', 'UMLS/C0041696'],
#  'D001424': ['UMLS/C0004623'],
#  'D050197': ['UMLS/C0004153'],
#  'D050723': ['UMLS/C0016658'],
#  'D010024': ['UMLS/C0029456'],
#  'D010300': ['UMLS/C0030567'],
#  'D012148': ['UMLS/C0035258'],
#  'D000544': ['UMLS/C0002395'],
#  'D003924': ['UMLS/C0011860'],
#  'D008881': ['UMLS/C0149931'],
#  'D012893': ['UMLS/C0851578'],
#  'D030361': ['UMLS/C0343641'],
#  'D013290': ['UMLS/C0038395'],
#  'D014917': ['UMLS/C0043167'],
#  'D004165': ['UMLS/C0012546'],
#  'D006509': ['UMLS/C0019163'],
#  'D011051': ['UMLS/C0032371'],
#  'D013742': ['UMLS/C0039614'],
#  'D019741': ['UMLS/C0121772'],
#  'D009345': ['UMLS/C0027575'],
#  'D008457': ['UMLS/C0025007'],
#  'D009107': ['UMLS/C0026780'],
#  'D012409': ['UMLS/C0035920'],
#  'D002644': ['UMLS/C0008049'],
#  'D007251': ['UMLS/C0021400'],
#  'D012400': ['UMLS/C0035869'],
#  'D012640': ['UMLS/C0036572', 'UMLS/C0494475', 'UMLS/C0751495'],
#  'D051474': ['UMLS/C0032768'],
#  'D008288': ['UMLS/C0024530'],
#  'D001523': ['UMLS/C0004936'],
#  'D006333': ['UMLS/C0018802', 'UMLS/C0018801'],
#  'D011471': ['UMLS/C0033578', 'UMLS/C0376358'],
#  'D011470': ['UMLS/C2937421', 'UMLS/C1704272'],
#  'D001986': ['UMLS/C0006266'],
#  'D009103': ['UMLS/C0026769'],
#  'D003929': ['UMLS/C0011882', 'UMLS/C0751074'],
#  'D001172': ['UMLS/C0003873'],
#  'D016535': ['UMLS/C0085129'],
#  'D015658': ['UMLS/C0019693'],
#  'D009298': ['UMLS/C0027430'],
#  'D006506': ['UMLS/C0019159'],
#  'D012141': ['UMLS/C0035243'],
#  'D010033': ['UMLS/C0029882'],
#  'D011014': ['UMLS/C0032285'],
#  'D017714': ['UMLS/C0206171'],
#  'D013296': ['UMLS/C0038410'],
#  'D001991': ['UMLS/C0006277'],
#  'D012852': ['UMLS/C0037199'],
#  'D012223': ['UMLS/C0035460'],
#  'D013923': ['UMLS/C0040038'],
#  'D004830': ['UMLS/C0014549'],
#  'D004828': ['UMLS/C0014547'],
#  'D012559': ['UMLS/C0036341'],
#  'D000568': ['UMLS/C0002453'],
#  'D005356': ['UMLS/C0016053'],
#  'D006558': ['UMLS/C0019342'],
#  'D006561': ['UMLS/C0019348'],
#  'D006560': ['UMLS/C0019345'],
#  'D006566': ['UMLS/C0019372'],
#  'D001008': ['UMLS/C0003469'],
#  'D009325': ['UMLS/C0027497'],
#  'D008589': ['UMLS/C0025303'],
#  'D000080223': ['UMLS/C0578870'],
#  'D003876': ['UMLS/C0011615'],
#  'D014012': ['UMLS/C0040264'],
#  'D010698': ['UMLS/C0349231'],
#  'D009771': ['UMLS/C0028768'],
#  'D016584': ['UMLS/C0030319'],
#  'D013313': ['UMLS/C0038436'],
#  'D011293': ['UMLS/C0033046'],
#  'D009980': ['UMLS/C0029347'],
#  'D009181': ['UMLS/C0026946'],
#  'D009369': ['UMLS/C0027651', 'UMLS/C0006826'],
#  'D002292': ['UMLS/C0007134'],
#  'D018805': ['UMLS/C0036690'],
#  'D009133': ['UMLS/C0026846'],
#  'D015179': ['UMLS/C0009404'],
#  'D017379': ['UMLS/C0149721'],
#  'D003930': ['UMLS/C0011884'],
#  'D007006': ['UMLS/C0020619'],
#  'D005770': ['UMLS/C0017185'],
#  'D012628': ['UMLS/C0036508'],
#  'D007169': ['UMLS/C0021099'],
#  'D008228': ['UMLS/C0024305'],
#  'D015451': ['UMLS/C0023434'],
#  'D014549': ['UMLS/C0042024'],
#  'D014947': ['UMLS/C3263723', 'UMLS/C0043250'],
#  'D015212': ['UMLS/C0021390'],
#  'D050171': ['UMLS/C0242339'],
#  'D018589': ['UMLS/C0152020'],
#  'D010146': ['UMLS/C0030193'],
#  'D007249': ['UMLS/C0021368'],
#  'D009765': ['UMLS/C0028754'],
#  'D003371': ['UMLS/C0010200'],
#  'D006526': ['UMLS/C0019196'],
#  'D002546': ['UMLS/C0007787'],
#  'D020521': ['UMLS/C0038454'],
#  'D002100': ['UMLS/C0006625'],
#  'D061686': ['UMLS/C0033038'],
#  'D024821': ['UMLS/C0524620'],
#  'D015663': ['UMLS/C0029458'],
#  'D010003': ['UMLS/C0029408'],
#  'D001281': ['UMLS/C0004238'],
#  'D002318': ['UMLS/C0007222'],
#  'D001145': ['UMLS/C0003811'],
#  'D003424': ['UMLS/C0010346'],
#  'D003072': ['UMLS/C0009241'],
#  'D003250': ['UMLS/C0009813'],
#  'D002289': ['UMLS/C0007131'],
#  'D000505': ['UMLS/C0002170'],
#  'D003092': ['UMLS/C0009319'],
#  'D014456': ['UMLS/C0041582'],
#  'D008224': ['UMLS/C0024301'],
#  'D010051': ['UMLS/C0919267', 'UMLS/C1140680'],
#  'D065768': ['UMLS/C0238111'],
#  'D003920': ['UMLS/C0011849'],
#  'D057765': ['UMLS/C0341106'],
#  'D020953': ['UMLS/C0752341'],
#  'D009091': ['UMLS/C0026718'],
#  'D005902': ['UMLS/C0017612'],
#  'D009798': ['UMLS/C0028840'],
#  'D013274': ['UMLS/C0024623'],
#  'D007951': ['UMLS/C0023470'],
#  'D009101': ['UMLS/C0026764'],
#  'D009190': ['UMLS/C3463824'],
#  'D008545': ['UMLS/C0025202'],
#  'D004194': ['UMLS/C0012634'],
#  'D012509': ['UMLS/C1261473'],
#  'D003704': ['UMLS/C0497327'],
#  'D015535': ['UMLS/C0003872'],
#  'D012120': ['UMLS/C0035204'],
#  'D014435': ['UMLS/C0041466'],
#  'D000740': ['UMLS/C0002871'],
#  'D014652': ['UMLS/C0042373'],
#  'D006816': ['UMLS/C0020179'],
#  'D007752': ['UMLS/C0022876'],
#  'D003550': ['UMLS/C0010674'],
#  'D057092': ['UMLS/C1536085'],
#  'D009437': ['UMLS/C0027796'],
#  'D006945': ['UMLS/C0020458'],
#  'D001943': ['UMLS/C0006142'],
#  'D003233': ['UMLS/C0009766'],
#  'D006562': ['UMLS/C0019360'],
#  'D017681': ['UMLS/C1540912'],
#  'D005490': ['UMLS/C0016397'],
#  'D002780': ['UMLS/C0008372'],
#  'D001851': ['UMLS/C0029453'],
#  'D006528': ['UMLS/C2239176'],
#  'D001289': ['UMLS/C1263846'],
#  'D005767': ['UMLS/C0017178'],
#  'D012164': ['UMLS/C0035309'],
#  'D006473': ['UMLS/C0032797'],
#  'D065631': ['UMLS/C2607914'],
#  'D013167': ['UMLS/C0038013'],
#  'D003324': ['UMLS/C1956346'],
#  'D000686': ['UMLS/C0002726'],
#  'D018357': ['UMLS/C0035235'],
#  'D014376': ['UMLS/C0041296'],
#  'D001987': ['UMLS/C0006267'],
#  'D014570': ['UMLS/C0042075'],
#  'D053201': ['UMLS/C0268849'],
#  'D012764': ['UMLS/C0036960'],
#  'D015470': ['UMLS/C0023467'],
#  'D013203': ['UMLS/C0038160'],
#  'D054990': ['UMLS/C1800706'],
#  'D058365': ['UMLS/C1609535'],
#  'D016553': ['UMLS/C0398650'],
#  'D012871': ['UMLS/C0037274'],
#  'D006069': ['UMLS/C0018081'],
#  'D000163': ['UMLS/C0001175'],
#  'D012595': ['UMLS/C0036421'],
#  'D011654': ['UMLS/C0034063'],
#  'D002779': ['UMLS/C0008370'],
#  'D006976': ['UMLS/C0020542'],
#  'D009362': ['UMLS/C0027627'],
#  'D003015': ['UMLS/C0343386'],
#  'D043183': ['UMLS/C0022104'],
#  'D014657': ['UMLS/C0042384'],
#  'D001327': ['UMLS/C0004364'],
#  'D004405': ['UMLS/C1527298'],
#  'D014777': ['UMLS/C0042769'],
#  'D000081029': ['UMLS/C2973725'],
#  'D064420': ['UMLS/C0041755'],
#  'D005334': ['UMLS/C0015967'],
#  'D007945': ['UMLS/C0023448'],
#  'D013292': ['UMLS/C0579233'],
#  'D018288': ['UMLS/C0262584'],
#  'D020522': ['UMLS/C0334634'],
#  'D004485': ['UMLS/C0013595'],
#  'D008415': ['UMLS/C0024899'],
#  'D018268': ['UMLS/C0206686'],
#  'D004715': ['UMLS/C0014175'],
#  'D001171': ['UMLS/C3495559'],
#  'D005211': ['UMLS/C0015652'],
#  'D014123': ['UMLS/C0040558'],
#  'D003928': ['UMLS/C0011881'],
#  'D003248': ['UMLS/C0009806'],
#  'D009128': ['UMLS/C0026838'],
#  'D000072742': ['UMLS/C1262313'],
#  'D014077': ['UMLS/C0040436'],
#  'D055728': ['UMLS/C0001815'],
#  'D000270': ['UMLS/C0001519'],
#  'D012128': ['UMLS/C0035222'],
#  'D018290': ['UMLS/C0206708'],
#  'D009157': ['UMLS/C0026896'],
#  'D003807': ['UMLS/C0011432'],
#  'D009134': ['UMLS/C0026847'],
#  'D064726': ['UMLS/C3539878'],
#  'D018358': ['UMLS/C0206754'],
#  'D008268': ['UMLS/C0024437'],
#  'D006009': ['UMLS/C0017921'],
#  'D000755': ['UMLS/C0002895'],
#  'D002276': ['UMLS/C0007095'],
#  'D014581': ['UMLS/C0042109'],
#  'D003781': ['UMLS/C0011397'],
#  'D010195': ['UMLS/C0030305'],
#  'D008581': ['UMLS/C0025289'],
#  'D002277': ['UMLS/C0007097'],
#  'D025241': ['UMLS/C0949690'],
#  'D006937': ['UMLS/C0020443'],
#  'D012178': ['UMLS/C0035344'],
#  'D008181': ['UMLS/C0024143'],
#  'D006086': ['UMLS/C0018133']}

# %%
content = "from\tto\n"

for h in umls_to_msh_condition:
    content += h[0] + "\t" + f"MSH/{h[1]}" + "\n"


with open("neo4j/condition_is_msh.tsv", "w") as f:
    f.write(content)

# %%
content = "MSH\tname\n"
for m in msh_name:
    content += m + "\t" + msh_name[m] + "\n"

with open("neo4j/condition_msh_name.tsv", "w") as f:
    f.write(content)

# %%
msh_medicine = {}

conditions = pd.read_csv("neo4j/medicines.tsv", sep="\t")

msh_name_medicine = {}
for i, row in tqdm(conditions.iterrows()):

    umls = row["UMLS"]

    if str(row["MSH"]) != "nan":
        mshs = str(row["MSH"]).split("|")
    
        for msh in mshs:
            m = msh.split("/")[1]
            if m not in msh_medicine:
                msh_medicine[m] = []
            msh_medicine[m].append(umls)

            msh_name_medicine[m] = row["name"]
# Out:
# 254it [00:00, 15527.67it/s]

# %%
msh_mapped_to = {}
valid_gsk = {}

content = "name\tUMLS\tMSH\tHPO\tRXNORM\tother_name\n"

gsk_is_a = set()

lines = open("cryptic_medicines.txt").readlines()

for line in tqdm(lines):
    gsk = line.strip()
    umls = umls_api.search(gsk, umls_token)

    if umls != "" and umls != None:
        msh = umls_api.get_MSH(umls, umls_token)
        name = ""
        
        if msh != "" and msh != None:
            msh_name_medicine[msh] = gsk

            name = umls_api.get_name(msh, umls_token)
            is_mapped_to = umls_api.get_all_items("MSH", msh, "includeAdditionalRelationLabels=mapped_to", umls_token)

            if msh not in msh_mapped_to:
                msh_mapped_to[msh] = []
            for m in is_mapped_to:
                msh_mapped_to[msh].append(m[0])
                msh_name_medicine[m[0]] = m[1]
            
            gsk_is_a.add((f"UMLS/{umls}", f"MSH/{msh}"))
        
        else:
            msh = ""


        content += f"{gsk}\tUMLS/{umls}\tMSH/{msh}\t\t\t{name}\n"

        valid_gsk[gsk] = umls
   
with open("neo4j/medicines_cryptic.tsv", "w") as f:
    f.write(content)

content = "from\tto\n"
with open("neo4j/gsk_is_a.tsv", "w") as f:
    for g in gsk_is_a:
        content += g[0] + "\t" + g[1] + "\n"
    f.write(content)
# Out:
# 100%|██████████| 196/196 [07:06<00:00,  2.18s/it]

# %%
trial_cryptic_drugs = pd.read_csv("trial_cryptic_drugs.tsv", sep="\t")

content = "from\tto\n"

for i, row in tqdm(trial_cryptic_drugs.iterrows()):
    gsk = row["to"]
    trial = row["from"]

    if gsk in valid_gsk:
        content += f"{trial}\tUMLS/{valid_gsk[gsk]}\n"


with open("neo4j/trial_cryptic_drugs.tsv", "w") as f:
    f.write(content)
# Out:
# 370it [00:00, 6411.16it/s]

# %%
msh_mapped_to
# Out:
# {'C549469': ['D013450', 'D000634'],
#  'C581038': ['D013256'],
#  'C512301': ['D014508', 'D011759'],
#  'C000625977': ['D007211', 'D010069'],
#  'C576936': ['D013449', 'D000420'],
#  'D000077185': [],
#  'C000593393': ['D001549', 'D008782'],
#  'C558853': ['D010793', 'D010880', 'D010793', 'D010880'],
#  'C558852': ['D009281', 'D010880', 'D009281', 'D010880'],
#  'C562323': ['D001549', 'D011759'],
#  'C561922': ['D001549'],
#  'C000608195': ['D061067'],
#  'C587902': ['D010069', 'D008698'],
#  'C583947': ['D006877', 'D019086'],
#  'C557997': ['D053961'],
#  'C000604998': ['D011761'],
#  'C568078': ['D007189', 'D014230'],
#  'C587791': ['D007093', 'D011804'],
#  'C000594852': ['D011993'],
#  'C584220': ['D001552'],
#  'C588298': ['D001897', 'D013449'],
#  'C000604188': ['D014970'],
#  'C000590132': ['D061067'],
#  'C561573': ['D001562', 'D013876'],
#  'C000594007': ['D053961', 'D010080'],
#  'C582664': ['D061067'],
#  'C409004': ['D013440'],
#  'C545367': ['D014230', 'D000241'],
#  'C000602898': ['D010649', 'D010880'],
#  'C557781': ['D001572', 'D013844'],
#  'C568644': ['D001562'],
#  'C584556': ['D010880', 'D000081'],
#  'C000595241': ['D002219', 'D014633'],
#  'C528328': ['D010069'],
#  'C000600809': ['D006877', 'D000631', 'D006877', 'D000631'],
#  'C000629862': ['D061067'],
#  'C000603511': ['D010880', 'D000225'],
#  'C000590928': ['D013844', 'D010069'],
#  'C000705473': ['D061067'],
#  'C000605830': ['D000911'],
#  'C584201': ['D003514', 'D014227'],
#  'C000615596': ['D010647', 'D011744'],
#  'C000709571': ['D002264', 'D011759'],
#  'C000627232': ['D007211'],
#  'C000626978': ['D061067'],
#  'C000627739': ['D007093', 'D009025'],
#  'C000718753': ['D001572'],
#  'C000622373': ['D061067'],
#  'C540176': ['D000655'],
#  'C000632156': ['D011725', 'D010880'],
#  'C000628558': ['D002087', 'D009287', 'D011720', 'D011759'],
#  'C000654586': ['D011714', 'D000096926'],
#  'C000708951': ['D014230', 'D010077'],
#  'C000656065': ['D001562', 'D013141'],
#  'C000629546': ['D053978'],
#  'C000707549': ['D014230'],
#  'C000709851': ['D007211', 'D011743'],
#  'C000603799': ['D007191', 'D013449'],
#  'C556153': ['D007252'],
#  'C559041': ['D007074', 'D051496', 'D011993'],
#  'C000706131': ['D014280'],
#  'C000602008': ['D003521', 'D001565'],
#  'C577920': ['D007211', 'D011728'],
#  'C000708087': ['D007093', 'D013450'],
#  'C000633847': ['D009930'],
#  'C000719587': ['D009930'],
#  'C000626035': ['D000911'],
#  'C000712933': ['D006017'],
#  'C000615784': ['D011720', 'D011743'],
#  'C000631066': ['D011725'],
#  'C000723722': ['D014315'],
#  'C560077': ['D011728', 'D011744'],
#  'C000719547': ['D017780'],
#  'C000628578': ['D010078']}

# %%
msh_name_medicine
# Out:
# {'C511911': 'belimumab',
#  'C055085': 'calcipotriene',
#  'C466951': 'benzoyl peroxide / clindamycin',
#  'D000077261': 'carvedilol',
#  'D002990': 'clobetasol',
#  'C523187': 'fluticasone furoate',
#  'D000068298': 'fluticasone',
#  'D000068297': 'Fluticasone Propionate, Salmeterol Xinafoate Drug Combination',
#  'D000077425': 'fondaparinux sodium',
#  'D000077213': 'lamotrigine',
#  'C550701': 'otelixizumab',
#  'D017374': 'paroxetine',
#  'C508887': 'retapamulin',
#  'C101866': 'ezogabine',
#  'C000592856': 'rilapladib',
#  'C561716': 'ronacaleret',
#  'C046649': 'ropinirole',
#  'D000077154': 'rosiglitazone',
#  'C000611385': 'naproxen / sumatriptan',
#  'C086827': 'tazarotene',
#  'C534550': 'vestipitant',
#  'C510352': 'human papillomavirus vaccine, L1 type 16, 18',
#  'D022242': 'Polyvalent pneumococcal vaccine',
#  'D004166': 'diphtheria antitoxin',
#  'D013745': 'tetanus toxoid vaccine, inactivated',
#  'D011055': 'Oral Poliovirus Vaccine',
#  'C044237': 'Haemophilus influenzae type b polysaccharide vaccine',
#  'C092872': 'streptococcal polysaccharide-tetanus toxoid conjugate vaccine',
#  'D009108': 'Mumps Vaccine',
#  'D012411': 'Rubella virus vaccine',
#  'D019433': 'Chickenpox Vaccine',
#  'D000946': 'Antigens, Fungal',
#  'D007252': 'Influenza Vaccines',
#  'D014612': 'Vaccines',
#  'D022243': 'Rotavirus Vaccines',
#  'D053243': 'zanamivir',
#  'D000068538': 'dutasteride',
#  'C550468': 'vilanterol',
#  'D000068299': 'salmeterol',
#  'C106538': 'abacavir',
#  'C492871': 'abacavir / lamivudine',
#  'D019259': 'lamivudine',
#  'D015215': 'zidovudine',
#  'C562325': 'dolutegravir',
#  'C426859': 'fosamprenavir',
#  'D000077592': 'maraviroc',
#  'D017762': 'nadroparin',
#  'D022362': 'Hepatitis A Vaccines',
#  'D000420': 'Albuterol',
#  'C534611': 'albiglutide',
#  'D019980': 'amoxicillin / clavulanate',
#  'D017706': 'lisinopril',
#  'C433226': 'Twinrix',
#  'D018170': 'sumatriptan',
#  'D000077483': 'valacyclovir',
#  'C493155': 'RTS,S-AS02A vaccine',
#  'D016642': 'bupropion',
#  'D000069444': 'omalizumab',
#  'C433247': 'Cilomilast',
#  'C551147': 'denagliptin',
#  'D008687': 'metformin',
#  'C520025': 'mirabegron',
#  'D000069464': 'solifenacin succinate',
#  'D000077409': 'tamsulosin',
#  'D014614': 'Vaccines, Recombinant',
#  'C057619': 'glimepiride',
#  'C106783': 'naratriptan',
#  'D000077332': 'artesunate',
#  'C007030': 'chlorproguanil',
#  'D003622': 'dapsone',
#  'C572941': 'ipragliflozin',
#  'D000077551': 'micafungin',
#  'C430916': 'regadenoson',
#  'D016559': 'tacrolimus',
#  'C544831': 'Foretinib',
#  'D022301': 'Herpes Simplex Virus Vaccines',
#  'D008458': 'Measles Vaccine',
#  'D022401': 'Meningococcal vaccine',
#  'C529040': 'darapladib',
#  'D000077557': 'ibandronic acid',
#  'D007654': 'ketoconazole',
#  'D017311': 'amlodipine',
#  'D019808': 'losartan',
#  'C040738': 'cefuroxime axetil',
#  'C574213': 'dilmapimod',
#  'C581856': 'refanezumab',
#  'D000077430': 'nabumetone',
#  'D011405': 'propafenone',
#  'C531958': 'lenvatinib',
#  'D004077': 'digoxin',
#  'C583420': 'Vercirnon',
#  'D000077185': 'Srt501',
#  'D000069347': 'erlotinib',
#  'C434107': 'mepolizumab',
#  'D019821': 'simvastatin',
#  'D000077208': 'remifentanil',
#  'C555450': 'secukinumab',
#  'C588122': 'batefenterol',
#  'C047340': 'levocabastine',
#  'C542124': 'raxibacumab',
#  'D004656': 'enalapril',
#  'D000068718': 'rosuvastatin',
#  'C508735': 'isavuconazonium sulfate',
#  'C111827': 'brinzolamide',
#  'D000068338': 'everolimus',
#  'C510790': 'indacaterol',
#  'D006024': 'Glycopyrronium Bromide',
#  'C498826': 'nilotinib',
#  'D000078330': 'oxcarbazepine',
#  'C000717211': 'sacubitril',
#  'D000068756': 'valsartan',
#  'D000069557': 'travoprost',
#  'D000068876': 'fingolimod',
#  'D000068836': 'rivastigmine',
#  'D000077767': 'panobinostat',
#  'D002434': 'cefadroxil',
#  'C561454': 'omipalisib',
#  'C586847': 'ceritinib',
#  'C561627': 'dabrafenib',
#  'C520809': 'eltrombopag',
#  'D000077341': 'lapatinib',
#  'C516667': 'pazopanib',
#  'C560077': 'Gsk1120212',
#  'D000077211': 'zoledronic acid',
#  'D000077556': 'alitretinoin',
#  'C581951': 'danirixin',
#  'C000611924': 'fluticasone furoate-vilanterol trifenatate',
#  'C000612856': 'gepotidacin',
#  'C000599718': 'Daprodustat',
#  'C522194': 'Retosiban',
#  'C541863': 'Camicinal',
#  'C571185': 'epelsiban',
#  'C543534': 'Losmapimod',
#  'C093875': 'montelukast',
#  'D000069605': 'olopatadine hydrochloride',
#  'C081643': 'candesartan',
#  'C077793': 'candesartan cilexetil',
#  'C000629641': 'Nemiralisib',
#  'C509706': 'relacatib',
#  'C055852': 'tafenoquine',
#  'C414203': 'nepafenac',
#  'C551441': 'perampanel',
#  'C053001': 'adefovir',
#  'C571829': 'tapinarof',
#  'D001241': 'aspirin',
#  'D008774': 'methylphenidate',
#  'D000068582': 'certolizumab pegol',
#  'D064750': 'rabeprazole',
#  'D000077270': 'exenatide',
#  'C507357': 'mapatumumab',
#  'D010121': 'oxytocin',
#  'C490954': 'eribulin mesylate',
#  'C079703': 'rufinamide',
#  'D004275': 'DNA, Ribosomal',
#  'D061485': 'nicotine polacrilex',
#  'C000599766': 'Otilimab',
#  'D000077289': 'letrozole',
#  'D009538': 'nicotine',
#  'D022681': 'Infanrix',
#  'C064764': 'PENTA natural heparin pentassacharide',
#  'D011464': 'epoprostenol',
#  'D000077239': 'meloxicam',
#  'C106716': 'Talnetant',
#  'D000077732': 'fidaxomicin',
#  'D000068698': 'tenofovir disoproxil fumarate',
#  'D000068696': 'rilpivirine',
#  'D002939': 'ciprofloxacin',
#  'D000068877': 'imatinib',
#  'D000077265': 'donepezil',
#  'C541220': 'canakinumab',
#  'C527517': 'ofatumumab',
#  'C059539': 'midostaurin',
#  'D020682': 'cefixime',
#  'C000627869': 'naquotinib',
#  'D016729': 'leuprolide acetate',
#  'C551528': 'Linsitinib',
#  'C578989': 'siponimod',
#  'D000077682': 'triclabendazole',
#  'D011739': 'pyrimethamine',
#  'C540278': 'enzalutamide',
#  'C523483': 'linaclotide',
#  'D019274': 'onabotulinumtoxinA',
#  'C472067': 'levocetirizine',
#  'D000068656': 'mometasone furoate',
#  'D000068759': 'formoterol fumarate',
#  'C584914': 'cabotegravir',
#  'D012254': 'ribavirin',
#  'C540383': 'ruxolitinib',
#  'C120489': 'oligofructose',
#  'D010368': 'Pectins',
#  'C000596550': 'lanadelumab',
#  'C573971': 'umeclidinium',
#  'D000077588': 'deferasirox',
#  'C585539': 'alpelisib',
#  'C000604875': 'fevipiprant',
#  'C554645': 'molibresib',
#  'D022541': 'Streptococcal Vaccines',
#  'C000710948': 'onasemnogene abeparvovec-xioi',
#  'C058381': 'pneumococcal polysaccharide, type 37',
#  'D018073': 'Haemophilus Vaccines',
#  'D018074': 'Vaccines, Conjugate',
#  'D015282': 'octreotide',
#  'C000622091': 'brolucizumab',
#  'C000614139': 'crizanlizumab',
#  'D002266': 'carboxymethylcellulose sodium',
#  'D009536': 'niacinamide',
#  'D000961': 'Antilymphocyte Serum',
#  'D000077597': 'vildagliptin',
#  'D000077432': 'tapentadol',
#  'C499715': 'alisporivir',
#  'D006118': 'griseofulvin',
#  'C000604315': 'fremanezumab',
#  'D000068717': 'glatiramer acetate',
#  'C515492': 'reslizumab',
#  'C585830': 'Inclisiran',
#  'C428744': 'Licarbazepine',
#  'D000069287': 'capecitabine',
#  'D000069579': 'ranibizumab',
#  'D000077594': 'nivolumab',
#  'C549469': 'Gsk256066',
#  'D013450': 'Sulfones',
#  'D000634': 'Aminoquinolines',
#  'C581038': 'Gw870086',
#  'D013256': 'Steroids',
#  'C512301': 'Sb705498',
#  'D014508': 'Urea',
#  'D011759': 'Pyrrolidines',
#  'C000625977': 'Gsk2018682',
#  'D007211': 'Indoles',
#  'D010069': 'Oxadiazoles',
#  'C576936': 'Gw597901',
#  'D013449': 'Sulfonamides',
#  'C000593393': 'Gw766994',
#  'D001549': 'Benzamides',
#  'D008782': 'Methylurea Compounds',
#  'C558853': 'Gsk1004723',
#  'D010793': 'Phthalazines',
#  'D010880': 'Piperidines',
#  'C558852': 'Gsk835726',
#  'D009281': 'Naphthalenes',
#  'C562323': 'Gsk1018921',
#  'C561922': 'Gsk931145',
#  'C000608195': 'Gsk1070806',
#  'D061067': 'Antibodies, Monoclonal, Humanized',
#  'C587902': 'Gsk1292263',
#  'D008698': 'Mesylates',
#  'C583947': 'Gsk1322322',
#  'D006877': 'Hydroxamic Acids',
#  'D019086': 'Bridged Bicyclo Compounds, Heterocyclic',
#  'C557997': 'Gsk1360707',
#  'D053961': 'Azabicyclo Compounds',
#  'C000604998': 'Gsk1482160',
#  'D011761': 'Pyrrolidonecarboxylic Acid',
#  'C568078': 'Gsk1521498',
#  'D007189': 'Indans',
#  'D014230': 'Triazoles',
#  'C587791': 'Gsk163090',
#  'D007093': 'Imidazoles',
#  'D011804': 'Quinolines',
#  'C000594852': 'Gsk2374697',
#  'D011993': 'Recombinant Fusion Proteins',
#  'C584220': 'Gsk239512',
#  'D001552': 'Benzazepines',
#  'C588298': 'Gsk2485852',
#  'D001897': 'Boronic Acids',
#  'C000604188': 'Gsk256073',
#  'D014970': 'Xanthines',
#  'C000590132': 'Gsk315234',
#  'C561573': 'Gsk461364',
#  'D001562': 'Benzimidazoles',
#  'D013876': 'Thiophenes',
#  'C000594007': 'Gsk598809',
#  'D010080': 'Oxazoles',
#  'C582664': 'Gsk679586',
#  'C409004': 'Gw274150',
#  'D013440': 'Sulfides',
#  'C545367': 'Gw328267',
#  'D000241': 'Adenosine',
#  'C000602898': 'Gw559090',
#  'D010649': 'Phenylalanine',
#  'C557781': 'Sb649868',
#  'D001572': 'Benzofurans',
#  'D013844': 'Thiazoles',
#  'C568644': 'Gsk1034702',
#  'C584556': 'Gsk424887',
#  'D000081': 'Acetamides',
#  'C000595241': 'Gsk2336805',
#  'D002219': 'Carbamates',
#  'D014633': 'Valine',
#  'C528328': 'Gsk690693',
#  'C000600809': 'Gsk2256098',
#  'D000631': 'Aminopyridines',
#  'C000629862': 'Gsk1995057',
#  'C000603511': 'Gsk2245035',
#  'D000225': 'Adenine',
#  'C000590928': 'Gsk356278',
#  'C000705473': 'Gsk2618960',
#  'C000605830': 'Gsk2862277',
#  'D000911': 'Antibodies, Monoclonal',
#  'C584201': 'Gsk2256294',
#  'D003514': 'Cyclohexylamines',
#  'D014227': 'Triazines',
#  'C000615596': 'Gsk2647544',
#  'D010647': 'Phenyl Ethers',
#  'D011744': 'Pyrimidinones',
#  'C000709571': 'Gsk2315698',
#  'D002264': 'Carboxylic Acids',
#  'C000627232': 'Gsk2881078',
#  'C000626978': 'Gsk3050002',
#  'C000627739': 'Gsk2636771',
#  'D009025': 'Morpholines',
#  'C000718753': 'Gsk2878175',
#  'C000622373': 'Gsk2849330',
#  'C540176': 'Gsk369796',
#  'D000655': 'Amodiaquine',
#  'C000632156': 'Asp8477',
#  'D011725': 'Pyridines',
#  'C000628558': 'Gsk3008348',
#  'D002087': 'Butyrates',
#  'D009287': 'Naphthyridines',
#  'D011720': 'Pyrazoles',
#  'C000654586': 'Gsk2981278',
#  'D011714': 'Pyrans',
#  'D000096926': 'Benzenesulfonamides',
#  'C000708951': 'Gsk2982772',
#  'D010077': 'Oxazepines',
#  'C000656065': 'Gsk2798745',
#  'D013141': 'Spiro Compounds',
#  'C000629546': 'Gsk2838232',
#  'D053978': 'Pentacyclic Triterpenes',
#  'C000707549': 'Gsk1940029',
#  'C000709851': 'Gsk3008356',
#  'D011743': 'Pyrimidines',
#  'C000603799': 'Gsk2292767',
#  'D007191': 'Indazoles',
#  'C556153': 'Gsk1557484a',
#  'C559041': 'Gsk3052230',
#  'D007074': 'Immunoglobulin G',
#  'D051496': 'Receptor, Fibroblast Growth Factor, Type 1',
#  'C000706131': 'Gsk2981710',
#  'D014280': 'Triglycerides',
#  'C000602008': 'Gsk2879552',
#  'D003521': 'Cyclopropanes',
#  'D001565': 'Benzoates',
#  'C577920': 'Gsk2816126',
#  'D011728': 'Pyridones',
#  'C000708087': 'Asp1707',
#  'C000633847': 'Asp8232',
#  'D009930': 'Organic Chemicals',
#  'C000719587': 'Asp3652',
#  'C000626035': 'Cfz533',
#  'C000712933': 'Gsk1795091',
#  'D006017': 'Glycolipids',
#  'C000615784': 'Asp5878',
#  'C000631066': 'Gsk2646264',
#  'C000723722': 'Gsk3640254',
#  'D014315': 'Triterpenes',
#  'C000719547': 'Sb257049',
#  'D017780': 'Malaria Vaccines',
#  'C000628578': 'Cnp520',
#  'D010078': 'Oxazines'}

# %%
print (len(msh_medicine))

msh_isa = {}


umls_to_msh_medicine = set()

for msh_id in tqdm(msh_medicine):

    #print (msh_id)
    results = umls_api.get_all_items("MSH", msh_id, "includeAdditionalRelationLabels=isa", umls_token)

    if msh_id not in msh_isa:
        msh_isa[msh_id] = []
    for r in results:
        msh_isa[msh_id].append(r[0])

        msh_name_medicine[r[0]] = r[1]


    results = umls_api.get_all_items("MSH", msh_id, "includeAdditionalRelationLabels=mapped_to", umls_token)

    if msh_id not in msh_mapped_to:
        msh_mapped_to[msh_id] = []
    for r in results:
        msh_mapped_to[msh_id].append(r[0])

        msh_name_medicine[r[0]] = r[1]
    
    for u in msh_medicine[msh_id]:
        umls_to_msh_medicine.add((u, msh_id))
# Out:
# 219
# 100%|██████████| 219/219 [06:37<00:00,  1.82s/it]

# %%
edge_content = "from\tto\n"

for m in msh_isa:
    for is_a in msh_isa[m]:
        edge_content += f"MSH/{m}" + "\t" + f"MSH/{is_a}" + "\n"

#print (edge_content)

# with open("neo4j/medicine_msh_name.tsv", "w") as f:
#     f.write(node_content)

with open("neo4j/medicine_msh_is_a.tsv", "w") as f:
    f.write(edge_content)


edge_content = "from\tto\n"

for m in msh_mapped_to:
    for mapped_to in msh_mapped_to[m]:
        edge_content += f"MSH/{m}" + "\t" + f"MSH/{mapped_to}" + "\n"

with open("neo4j/medicine_msh_mapped_to.tsv", "w") as f:
    f.write(edge_content)


node_content = "MSH\tname\n"

for msh in msh_name_medicine:
    node_content += f"MSH/{msh}" + "\t" + msh_name_medicine[msh] + "\n"

with open("neo4j/medicine_msh_name.tsv", "w") as f:
    f.write(node_content)

# %%
content = "from\tto\n"

for h in umls_to_msh_medicine:
    content += h[0] + "\t" + f"MSH/{h[1]}" + "\n"


with open("neo4j/medicine_is_msh.tsv", "w") as f:
    f.write(content)
