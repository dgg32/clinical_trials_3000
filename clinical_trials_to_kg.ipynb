# %%
import pandas as pd
import numpy as np
import re
import json
import healthcare_nlp

from subprocess import check_output
from io import BytesIO

# %%
clinical_trials = pd.read_csv('clinical_study_data_request_com_all_sponsor.tsv', sep="\t")

# %%
output_folder = "neo4j"

# %%
clinical_trials.head()
# Out:
#    Posting ID Sponsor                                        Study Title  \
# 0           1     GSK  U0289-401: An Evaluator Blinded, 8 Week, Split...
# 1           3     GSK  GSK1550188, A randomised, single-blind, placeb...
# 2           4     GSK  A Multicenter, Randomized, Double-Blind, Phase...
# 3           8     GSK  Two-week Study to Determine and Compare the To...
# 4           9     GSK  A single-blind, randomized, comparative split-...
#
#        Medicine or Vaccine (generic name) Sponsor Identification Number  \
# 0         benzoyl peroxide/salicylic acid                     STF114550
# 1                               belimumab                     BEL114243
# 2             calcipotriol, calcipotriene                     STF114741
# 3  benzoyl peroxide/clindamycin phosphate                     STF114546
# 4  benzoyl peroxide/clindamycin phosphate                     STF114547
#
#               Medical Condition    Phase  \
# 0                 Acne Vulgaris  Phase 4
# 1  Systemic Lupus Erythematosus  Phase 1
# 2                     Psoriasis  Phase 3
# 3                 Acne Vulgaris  Phase 4
# 4                 Acne Vulgaris  Phase 4
#
#                       Link to Sponsor Study Registry  \
# 0  https://www.gsk-studyregister.com/en/trial-det...
# 1  https://www.gsk-studyregister.com/en/trial-det...
# 2  https://www.gsk-studyregister.com/en/trial-det...
# 3  https://www.gsk-studyregister.com/en/trial-det...
# 4  https://www.gsk-studyregister.com/en/trial-det...
#
#   Link to study details on ClinicalTrials.gov (if available)  \
# 0         http://clinicaltrials.gov/show/NCT01706250
# 1         http://clinicaltrials.gov/show/NCT01381536
# 2         http://clinicaltrials.gov/show/NCT00688519
# 3         http://clinicaltrials.gov/show/NCT01015638
# 4         http://clinicaltrials.gov/show/NCT00964223
#
#   Link to study details on EudraCT (if available) Analysis-ready dataset  \
# 0                                             NaN                      N
# 1                                             NaN                      N
# 2                                             NaN                      Y
# 3                                             NaN                      N
# 4                                             NaN                      Y
#
#   Annotated case report form Clinical study report Dataset specifications  \
# 0                          Y                     Y                      Y
# 1                          Y                     Y                      Y
# 2                          Y                     Y                      Y
# 3                          N                     Y                      Y
# 4                          Y                     Y                      Y
#
#   Protocol with any amendments Raw dataset Reporting and analysis plan  \
# 0                            N           Y                           N
# 1                            N           Y                           Y
# 2                            Y           Y                           Y
# 3                            Y           Y                           N
# 4                            Y           N                           Y
#
#   Additional Information about the data and documents available for this study  \
# 0  An analysis-ready dataset and a reporting and ...
# 1  An analysis-ready dataset is not available for...
# 2                                                NaN
# 3  An analysis-ready dataset and reporting and an...
# 4     A raw dataset is not available for this study.
#
#   Date Added to this Site
# 0              1-Aug-2015
# 1              1-Jul-2015
# 2              1-Jul-2015
# 3              1-Aug-2014
# 4              1-Aug-2014

# %%
len(clinical_trials["Medicine or Vaccine (generic name)"].unique())
# Out:
# 485

# %%
len(clinical_trials["Medical Condition"].unique())
# Out:
# 402

# %%
condition_abnornaml_list_mapping = {"Alzheimers disease": "Alzheimer's disease",
                                    "Dementia with parkinson’s disease": "Parkinson's disease dementia", 
                                    "Dementia with lewy bodies": "Dementia",
                                    "Renal cell carcinoma (rcc)": "Renal cell carcinoma",
                                    "Influenza, human": "Influenza",
                                    "Healthy subjects": "",
                                    "Healthy volunteers": "",
                                    "Anklyosing spondylitis": "Ankylosing spondylitis",
                                    "Antifungal agents": "",
                                    "Partial-onset seizures": "Partial onset seizures",
                                    "Relapse-remitting multiple sclerosis": "Multiple sclerosis",
                                    "Relapsing remitting multiple sclerosis": "Multiple sclerosis",
                                    "Relapsing multiple sclerosis": "Multiple sclerosis",
                                    "Relapsing-remitting multiple sclerosis": "Multiple sclerosis",
                                    "Skin care": "",
                                    "Solid tumors": "Solid tumours",
                                    "Aids": "AIDS",
                                    "Nutritional status": "",					
                                    "Nutritional supplement": "",
                                    "Arthritis, rheumatoid": "Rheumatoid arthritis",
                                    "Myocardial perfusion imaging": "",
                                    "Neoplasms, breast": "Breast neoplasms",
                                    "Neoplasms, ovarian": "Ovarian neoplasms",
                                    "Fasciolasis": "Fascioliasis",
                                    "Neoplasms, colorectal": "Colorectal Neoplasms",
                                    "Neoplasms, gastrointestinal tract": "Gastrointestinal Neoplasms",
                                    "Herpes simplex": "Herpes simplex infection",
                                    "Pulmonary disease, chronic obstructive": "Chronic Obstructive Airway Disease",
                                    "Skin diseases": "Dermatologic disorders",
                                    "Skin infections, bacterial": "Bacterial skin infections",
                                    "Infection, human immunodeficiency virus": "Human immunodeficiency virus infection",
                                    "Infection, human immunodeficiency virus i": "Human immunodeficiency virus infection",
                                    "Infections, bacterial": "Bacterial infections",
                                    "Infections, herpesviridae": "Herpesviridae infections",
                                    "Infections, human immunodeficiency virus and herpesviridae": "Human immunodeficiency virus infection and herpesviridae infections",
                                    "Infections, meningococcal": "Meningococcal infections",
                                    "Infections, papillomavirus": "Papillomavirus infections",
                                    "Infections, respiratory syncytial virus": "Respiratory syncytial virus infections",
                                    "Infections, respiratory tract": "Respiratory tract infections",
                                    "Infections, rotavirus": "Rotavirus infections",
                                    "Infections, staphylococcal": "Staphylococcal infections",
                                    "Infections, streptococcal": "Streptococcal infections",
                                    "Dermatitis, atopic": "Atopic dermatitis",
                                    "Dermatitis, chronic": "Chronic dermatitis",
                                    "Dermatitis, seborrheic": "Seborrheic dermatitis",
                                    "Embolism, pulmonary": "Pulmonary embolism",
                                    "Epilepsy, tonic-clonic": "Tonic-clonic epilepsy",
                                    "Epilepsy, partial": "Partial epilepsy",
                                    "Scleroderma, systemic": "Systemic scleroderma",
                                    "Sinusitis, acute": "Acute sinusitis",
                                    "Spondylitis, ankylosing": "Ankylosing spondylitis",
                                    "Lymphoma, follicular": "Follicular lymphoma",
                                    "Lymphoma, mantle-cell": "Mantle-cell lymphoma",
                                    "Lymphoma, non-hodgkin": "Non-hodgkin lymphoma",
                                    "Diabetes mellitus, type 1": "Type 1 diabetes mellitus",
                                    "Diabetes mellitus, type 2": "Type 2 diabetes mellitus",
                                    "Fibrillation, atrial": "Atrial fibrillation",
                                    "Cholestasis, intrahepatic": "Intrahepatic cholestasis",
                                    "Atrophy, geographic": "Geographic atrophy",
                                    "Atrophy, muscular": "Muscular atrophy",
                                    "Carcinoma, hepatocellular": "Hepatocellular carcinoma",
                                    "Carcinoma, midline": "Midline carcinoma",
                                    "Carcinoma, renal cell": "Renal cell carcinoma",
                                    "Carcinoma, small cell": "Small cell carcinoma",
                                    "Cancer, advanced gastric": "Advanced gastric cancer",
                                    "Cancer, breast": "Breast cancer",
                                    "Hypertrophy, left ventricular": "Left ventricular hypertrophy",
                                    "Metastases, brain": "Brain metastases",
                                    "Neoplasms, prostate": "Prostate neoplasms",
                                    "Oedema, pulmonary": "Pulmonary edema",
                                    "Osteoporosis, male": "Male osteoporosis",
                                    "Osteoporosis, postmenopausal": "Postmenopausal osteoporosis",
                                    "Pain, neuropathic": "Neuropathic pain",
                                    "Psoriasis, nail": "Nail psoriasis",
                                    "Psoriasis, palmoplantar": "Palmoplantar psoriasis",
                                    "Retinopathy, diabetic": "Diabetic retinopathy",
                                    "Sarcoma, soft tissue": "Soft tissue sarcoma",
                                    "Spasticity, post-stroke": "Post-stroke spasticity",
                                    "Rhinitis, vasomotor": "Vasomotor rhinitis",
                                    "Polyps, nasal": "Nasal polyps",
                                    "Oesophagitis, eosinophilic": "Eosinophilic esophagitis",
                                    "Neuropathy, diabetic": "Diabetic neuropathy",
                                    "Neuralgia, postherpetic": "Postherpetic neuralgia",
                                    "Lung cancer, non-small cell": "Non-small cell lung cancer",
                                    "Lung injury, acute": "Acute lung injury",
                                    "Hypertension, pulmonary": "Pulmonary hypertension",
                                    "Hyperreactivity, bronchial": "Bronchial hyperreactivity",
                                    "Dysentery, bacillary": "Bacillary dysentery",
                                    "Depressive disorder, major": "Major depressive disorder",
                                    "Arrhythmia, cardiac": "Cardiac arrhythmia",
                                    "Constriction, bronchial": "Bronchial constriction",
                                    "Heart failure, congestive": "Congestive heart failure",
                                    "Heart failure, congestive and microalbuminuria": "Congestive heart failure and microalbuminuria heart failure",
                                    "Leukaemia, lymphocytic, chronic": "Chronic lymphocytic leukaemia",
                                    "Leukaemia, myelocytic, acute": "Acute myelocytic leukaemia",
                                    "Influenza a virus, h1n1 subtype": "H1N1 subtype influenza A virus",
                                    "Ischaemic attack, transient": "Transient ischaemic attack",
                                    "Bronchitis, chronic": "Chronic bronchitis",
                                    "Multiple sclerosis, relapsing-remitting": "Relapsing-remitting multiple sclerosis",
                                    "Nausea and vomiting, postoperative": "Postoperative nausea and vomiting",
                                    "Nausea and vomiting, chemotherapy-induced": "Chemotherapy-induced nausea and vomiting",
                                    "Neoplasms, head and neck": "Head neoplasms and neck neoplasms",
                                    "Obstetric labour, premature": "Premature obstetric labour",
                                    }

# %%
conditions = []

for combination in clinical_trials["Medical Condition"].unique():
    for x in combination.split("; "):
        x = x.strip().lower().capitalize()
        if x in condition_abnornaml_list_mapping:
            if condition_abnornaml_list_mapping[x] != "":
                conditions.append(condition_abnornaml_list_mapping[x])
        elif "transplant" in x:
            pass
        else:
            conditions.append(x)

conditions = sorted(list(set(conditions)))

content = ""
for c in conditions:
    content += c + "\n"

with open("conditions.txt", "w") as f:
    f.write(content)

# %% [markdown]
# Here, we need to head to gcp and do some ner.

# %%
condition_corrections = {
    "Measles": [{"preferredTerms": "Measles", "entityids": "UMLS/C0025007", "HPO": [], "MSH": ["MSH/D008457"], "RXNORM": []}],
    "Measles, mumps, rubella": [{"preferredTerms": "Measles", "entityids": "UMLS/C0025007", "HPO": [], "MSH": ["MSH/D008457"], "RXNORM": []}, {"preferredTerms": "Mumps", "entityids": "UMLS/C0026780", "HPO": [], "MSH": ["MSH/D009107"], "RXNORM": []}, {"preferredTerms": "Rubella", "entityids": "UMLS/C0035920", "HPO": [], "MSH": ["MSH/D012409"], "RXNORM": []}],
    "Tetanus": [{"preferredTerms": "Tetanus", "entityids": "UMLS/C0039614", "HPO": [], "MSH": ["MSH/D013742"], "RXNORM": []}],
    "Tuberculosis": [{"preferredTerms": "Tuberculosis", "entityids": "UMLS/C0041296", "HPO": [], "MSH": ["MSH/D014376"], "RXNORM": []}],
    "Fascioliasis": [{"preferredTerms": "Fascioliasis", "entityids": "UMLS/C0015652", "HPO": [], "MSH": ["MSH/D005211"], "RXNORM": []}],
    "Neoplasms": [{"preferredTerms": "Neoplasms", "entityids": "UMLS/C0027651", "HPO": ["HPO/HP:0002664"], "MSH": ["MSH/D009369"], "RXNORM": []}],
    "Mumps": [{"preferredTerms": "Mumps", "entityids": "UMLS/C0026780", "HPO": [], "MSH": ["MSH/D009107"], "RXNORM": []}]
}

# %%
len("Chronic Obstructive Airway Disease".strip())
# Out:
# 34

# %%
offset_text = []

begin = 0
with open('conditions.txt') as f:
    for line in f.readlines():
        line = line.strip()
        end = begin + len(line) + 1 ## +1 for the ; character
        offset_text.append((begin, end, line))

        begin = end

# %%
offset_text
# Out:
# [(0, 5, 'AIDS'),
#  (5, 25, 'Acellular pertussis'),
#  (25, 39, 'Acne vulgaris'),
#  (39, 63, 'Acute coronary syndrome'),
#  (63, 81, 'Acute lung injury'),
#  (81, 108, 'Acute myelocytic leukaemia'),
#  (108, 131, 'Acute myeloid leukemia'),
#  (131, 147, 'Acute sinusitis'),
#  (147, 172, 'Adrenocortical carcinoma'),
#  (172, 195, 'Advanced breast cancer'),
#  (195, 219, 'Advanced gastric cancer'),
#  (219, 230, 'Alcoholism'),
#  (230, 254, 'Allergic conjunctivitis'),
#  (254, 263, 'Alopecia'),
#  (263, 283, "Alzheimer's disease"),
#  (283, 295, 'Amyloidosis'),
#  (295, 303, 'Anaemia'),
#  (303, 313, 'Analgesia'),
#  (313, 336, 'Ankylosing spondylitis'),
#  (336, 354, 'Anxiety disorders'),
#  (354, 361, 'Asthma'),
#  (361, 381, 'Asthma and rhinitis'),
#  (381, 397, 'Atherosclerosis'),
#  (397, 415, 'Atopic dermatitis'),
#  (415, 435, 'Atrial fibrillation'),
#  (435, 483, 'Attention deficit hyperactivity disorder (adhd)'),
#  (483, 503, 'Autoimmune diseases'),
#  (503,
#   633,
#   'B-cell acute lymphoblastic leukemia, relapsed b-cell acute lymphoblastic leukemia, refractory b-cell acute lymphoblastic leukemia'),
#  (633, 653, 'Bacillary dysentery'),
#  (653, 674, 'Bacterial infections'),
#  (674, 700, 'Bacterial skin infections'),
#  (700, 717, 'Bipolar disorder'),
#  (717, 736, 'Bipolar i disorder'),
#  (736, 749, 'Bladder pain'),
#  (749, 766, 'Brain metastases'),
#  (766, 780, 'Breast cancer'),
#  (780, 797, 'Breast neoplasms'),
#  (797, 820, 'Bronchial constriction'),
#  (820, 846, 'Bronchial hyperreactivity'),
#  (846, 861, 'Bronchiectasis'),
#  (861, 874, 'Bronchospasm'),
#  (874, 883, 'Cachexia'),
#  (883, 890, 'Cancer'),
#  (890, 907, 'Cancer|neoplasms'),
#  (907, 923, 'Carcinoid tumor'),
#  (923, 942, 'Cardiac arrhythmia'),
#  (942, 965, 'Cardiovascular disease'),
#  (965, 974, 'Cataract'),
#  (974, 999, 'Cerebrovascular accident'),
#  (999, 1034, 'Cervical intraepithelial neoplasia'),
#  (1034, 1075, 'Chemotherapy-induced nausea and vomiting'),
#  (1075, 1087, 'Cholestasis'),
#  (1087, 1122, 'Chronic Obstructive Airway Disease'),
#  (1122, 1141, 'Chronic bronchitis'),
#  (1141, 1162, 'Chronic constipation'),
#  (1162, 1181, 'Chronic dermatitis'),
#  (1181, 1216, 'Chronic idiopathic urticaria (ciu)'),
#  (1216, 1246, 'Chronic lymphocytic leukaemia'),
#  (1246, 1281, 'Chronic lymphocytic leukemia (cll)'),
#  (1281, 1310, 'Chronic myelogenous leukemia'),
#  (1310, 1341, 'Chronic myeloid leukemia (cml)'),
#  (1341, 1386, 'Chronic obstructive pulmonary disease (copd)'),
#  (1386, 1411, 'Chronic plaque psoriasis'),
#  (1411, 1443, 'Clostridium difficile infection'),
#  (1443, 1463, 'Cognitive disorders'),
#  (1463, 1483, 'Colitis, ulcerative'),
#  (1483, 1504, 'Colorectal Neoplasms'),
#  (1504, 1529, 'Congestive heart failure'),
#  (1529, 1589, 'Congestive heart failure and microalbuminuria heart failure'),
#  (1589, 1613, 'Coronary artery disease'),
#  (1613, 1667, 'Corticosteroid refractory acute graft vs host disease'),
#  (1667, 1673, 'Cough'),
#  (1673, 1689, "Crohn's disease"),
#  (1689, 1705, 'Cystic fibrosis'),
#  (1705, 1714, 'Dementia'),
#  (1714, 1733, 'Dentin sensitivity'),
#  (1733, 1751, 'Denture retention'),
#  (1751, 1771, 'Depressive disorder'),
#  (1771, 1813, 'Depressive disorder and anxiety disorders'),
#  (1813, 1836, 'Dermatologic disorders'),
#  (1836, 1854, 'Diabetes mellitus'),
#  (1854, 1878, 'Diabetic kidney disease'),
#  (1878, 1901, 'Diabetic macular edema'),
#  (1901, 1927, 'Diabetic neuropathic pain'),
#  (1927, 1947, 'Diabetic neuropathy'),
#  (1947, 1968, 'Diabetic retinopathy'),
#  (1968, 1979, 'Diphtheria'),
#  (1979, 2027, 'Drug-related side effects and adverse reactions'),
#  (2027, 2042, 'Dyslipidaemias'),
#  (2042, 2049, 'Eczema'),
#  (2049, 2065, 'Embryo transfer'),
#  (2065, 2079, 'Endometriosis'),
#  (2079, 2099, 'Eosinophilic asthma'),
#  (2099, 2124, 'Eosinophilic esophagitis'),
#  (2124, 2133, 'Epilepsy'),
#  (2133, 2160, 'Episodic migraine headache'),
#  (2160, 2178, 'Esophageal cancer'),
#  (2178, 2191, 'Fascioliasis'),
#  (2191, 2222, 'Fibromyalgia syndrome, primary'),
#  (2222, 2246, 'Focal infection, dental'),
#  (2246, 2266, 'Follicular lymphoma'),
#  (2266, 2283, 'Fracture healing'),
#  (2283, 2310, 'Gastrointestinal Neoplasms'),
#  (2310, 2336, 'Gastrointestinal diseases'),
#  (2336, 2362, 'Gastrointestinal motility'),
#  (2362, 2376, 'Gastroparesis'),
#  (2376, 2395, 'Geographic atrophy'),
#  (2395, 2405, 'Gonorrhea'),
#  (2405, 2436, 'H1N1 subtype influenza A virus'),
#  (2436, 2466, 'Haemophilus influenzae type b'),
#  (2466, 2500, 'Head neoplasms and neck neoplasms'),
#  (2500, 2514, 'Heart failure'),
#  (2514, 2561, 'Heart failure with preserved ejection fraction'),
#  (2561, 2590, 'Heart failure, chronic (chf)'),
#  (2590, 2602, 'Hepatitis a'),
#  (2602, 2614, 'Hepatitis b'),
#  (2614, 2635, 'Hepatitis b, chronic'),
#  (2635, 2647, 'Hepatitis c'),
#  (2647, 2668, 'Hepatitis c, chronic'),
#  (2668, 2693, 'Hepatocellular carcinoma'),
#  (2693, 2724, 'Hepatocellular carcinoma (hcc)'),
#  (2724, 2763, 'Her2-negative metastatic breast cancer'),
#  (2763,
#   2847,
#   'Her2/neu over-expressing locally advanced breast cancer or metastatic breast cancer'),
#  (2847, 2874, 'Hereditary periodic fevers'),
#  (2874, 2891, 'Herpes genitalis'),
#  (2891, 2907, 'Herpes labialis'),
#  (2907, 2932, 'Herpes simplex infection'),
#  (2932, 2946, 'Herpes zoster'),
#  (2946, 2971, 'Herpesviridae infections'),
#  (2971, 2984, 'Hip fracture'),
#  (2984, 2999, 'Hiv infections'),
#  (2999, 3038, 'Human immunodeficiency virus infection'),
#  (3038,
#   3106,
#   'Human immunodeficiency virus infection and herpesviridae infections'),
#  (3106, 3125, 'Huntington disease'),
#  (3125, 3146, 'Hypercholesterolemia'),
#  (3146, 3173, 'Hypereosinophilic syndrome'),
#  (3173, 3187, 'Hyperhidrosis'),
#  (3187, 3200, 'Hypertension'),
#  (3200, 3221, 'Hypertriglyceridemia'),
#  (3221, 3240, 'Hypogonadism, male'),
#  (3240, 3270, 'Idiopathic pulmonary fibrosis'),
#  (3270, 3306, 'Idiopathic thrombocytopenic purpura'),
#  (3306, 3315, 'Impetigo'),
#  (3315, 3343, 'Inflammatory bowel diseases'),
#  (3343, 3353, 'Influenza'),
#  (3353, 3372, 'Insulin resistance'),
#  (3372, 3397, 'Intrahepatic cholestasis'),
#  (3397, 3444, 'Invasive aspergillosis / invasive mucormycosis'),
#  (3444, 3465, 'Invasive candidiasis'),
#  (3465, 3491, 'Invasive fungal infection'),
#  (3491, 3518, 'Invasive fungal infections'),
#  (3518, 3543, 'Irritable bowel syndrome'),
#  (3543, 3602, 'Juvenile psoriatic arthritis, enthesitis-related arthritis'),
#  (3602, 3631, 'Left ventricular hypertrophy'),
#  (3631, 3655, 'Lennox-gastaut syndrome'),
#  (3655, 3670, 'Liver diseases'),
#  (3670, 3730, 'Lower urinary tract symptoms / benign prostatic hyperplasia'),
#  (3730, 3790, 'Lung injury, acute and respiratory distress syndrome, adult'),
#  (3790, 3821, 'Lupus erythematosus, cutaneous'),
#  (3821, 3837, 'Lupus nephritis'),
#  (3837, 3863, 'Major depressive disorder'),
#  (3863, 3871, 'Malaria'),
#  (3871, 3891, 'Malaria, falciparum'),
#  (3891, 3906, 'Malaria, vivax'),
#  (3906, 3924, 'Male osteoporosis'),
#  (3924, 3945, 'Mantle-cell lymphoma'),
#  (3945, 3958, 'Mastocytosis'),
#  (3958, 3966, 'Measles'),
#  (3966, 3990, 'Measles, mumps, rubella'),
#  (3990, 3999, 'Melanoma'),
#  (3999, 4025, 'Meningitis, meningococcal'),
#  (4025, 4047, 'Meningococcal disease'),
#  (4047, 4072, 'Meningococcal infections'),
#  (4072, 4089, 'Mental disorders'),
#  (4089, 4110, 'Metabolic syndrome x'),
#  (4110, 4135, 'Metastatic breast cancer'),
#  (4135, 4155, 'Metastatic melanoma'),
#  (4155, 4187, 'Metastatic renal cell carcinoma'),
#  (4187, 4228, 'Metastatic triple-negative breast cancer'),
#  (4228, 4246, 'Midline carcinoma'),
#  (4246, 4255, 'Migraine'),
#  (4255, 4274, 'Migraine disorders'),
#  (4274, 4319, 'Migraine disorders and premenstrual syndrome'),
#  (4319, 4342, 'Migraine, without aura'),
#  (4342, 4376, 'Mild asthma and allergic rhinitis'),
#  (4376, 4406, 'Moderate to severe acute pain'),
#  (4406, 4451, 'Moderate to severe acute post-operative pain'),
#  (4451, 4500, 'Moderate to severe chronic plaque-type psoriasis'),
#  (4500, 4535, 'Moderate to severe scalp psoriasis'),
#  (4535, 4550, 'Mood disorders'),
#  (4550, 4572, 'Multiple myeloma (mm)'),
#  (4572, 4591, 'Multiple sclerosis'),
#  (4591, 4597, 'Mumps'),
#  (4597, 4612, 'Muscle atrophy'),
#  (4612, 4629, 'Muscular atrophy'),
#  (4629, 4647, 'Myasthenia gravis'),
#  (4647, 4655, 'Mycoses'),
#  (4655, 4686, 'Myelodysplastic syndrome (mds)'),
#  (4686, 4700, 'Myelofibrosis'),
#  (4700, 4715, 'Nail psoriasis'),
#  (4715, 4728, 'Nasal polyps'),
#  (4728, 4751, 'Neisseria meningitidis'),
#  (4751, 4761, 'Neoplasms'),
#  (4761, 4786, 'Neoplasms|lung neoplasms'),
#  (4786, 4831, 'Neovascular age-related macular degeneration'),
#  (4831, 4859, 'Neuroendocrine tumors (net)'),
#  (4859, 4892, 'Neurogenic detrusor overactivity'),
#  (4892, 4909, 'Neuropathic pain'),
#  (4909, 4930, 'Non-hodgkin lymphoma'),
#  (4930, 4965, 'Non-radiographic spondyloarthritis'),
#  (4965, 4992, 'Non-small cell lung cancer'),
#  (4992, 5030, 'Non-small cell lung carcinoma (nsclc)'),
#  (5030, 5038, 'Obesity'),
#  (5038, 5068, 'Obsessive-compulsive disorder'),
#  (5068, 5122, 'Obsessive-compulsive disorder and depressive disorder'),
#  (5122, 5142, 'Ocular hypertension'),
#  (5142, 5162, 'Open-angle glaucoma'),
#  (5162, 5177, 'Osteoarthritis'),
#  (5177, 5188, 'Osteopenia'),
#  (5188, 5201, 'Osteoporosis'),
#  (5201, 5214, 'Otitis media'),
#  (5214, 5229, 'Ovarian cancer'),
#  (5229, 5247, 'Ovarian neoplasms'),
#  (5247, 5306, 'Ovarian neoplasms|neoplasms|solid tumor|hepatic impairment'),
#  (5306, 5325, 'Pain, inflammatory'),
#  (5325, 5348, 'Palmoplantar psoriasis'),
#  (5348, 5387, 'Pancreatic neuroendocrine tumor (pnet)'),
#  (5387, 5419, 'Pancreatitis, acute necrotizing'),
#  (5419, 5434, 'Panic disorder'),
#  (5434, 5460, 'Papillomavirus infections'),
#  (5460, 5478, 'Parkinson disease'),
#  (5478, 5507, "Parkinson's disease dementia"),
#  (5507, 5524, 'Partial epilepsy'),
#  (5524, 5547, 'Partial onset seizures'),
#  (5547, 5575, 'Peripheral neuropathic pain'),
#  (5575, 5599, 'Peripheral neuropathies'),
#  (5599, 5617, 'Persistent asthma'),
#  (5617, 5627, 'Pertussis'),
#  (5627,
#   5699,
#   'Philadelphia chromosome positive acute lymphoblastic leukemia (ph+ all)'),
#  (5699, 5716, 'Plaque psoriasis'),
#  (5716, 5746, 'Pneumonia, community-acquired'),
#  (5746, 5760, 'Poliomyelitis'),
#  (5760, 5806, 'Post-polycythemia vera myelofibrosis (ppv-mf)'),
#  (5806, 5829, 'Post-stroke spasticity'),
#  (5829, 5860, 'Post-traumatic stress disorder'),
#  (5860, 5883, 'Postherpetic neuralgia'),
#  (5883, 5912, 'Postherpetic neuralgia (phn)'),
#  (5912, 5940, 'Postmenopausal osteoporosis'),
#  (5940, 5974, 'Postoperative nausea and vomiting'),
#  (5974, 5996, 'Postpartum hemorrhage'),
#  (5996, 6018, 'Premature ejaculation'),
#  (6018, 6045, 'Premature obstetric labour'),
#  (6045, 6067, 'Premenstrual syndrome'),
#  (6067, 6083, 'Prostate cancer'),
#  (6083, 6102, 'Prostate neoplasms'),
#  (6102, 6124, 'Prostatic hyperplasia'),
#  (6124, 6134, 'Psoriasis'),
#  (6134, 6154, 'Psoriatic arthritis'),
#  (6154, 6186, 'Pulmonary arterial hypertension'),
#  (6186, 6202, 'Pulmonary edema'),
#  (6202, 6221, 'Pulmonary embolism'),
#  (6221, 6244, 'Pulmonary hypertension'),
#  (6244, 6272, 'Refractory partial seizures'),
#  (6272, 6311, 'Relapsing-remitting multiple sclerosis'),
#  (6311, 6332, 'Renal cell carcinoma'),
#  (6332, 6354, 'Respiratory disorders'),
#  (6354, 6393, 'Respiratory syncytial virus infections'),
#  (6393, 6422, 'Respiratory tract infections'),
#  (6422, 6445, 'Restless legs syndrome'),
#  (6445, 6462, 'Retinal diseases'),
#  (6462, 6489, 'Retinopathy of prematurity'),
#  (6489, 6510, 'Rheumatoid arthritis'),
#  (6510, 6519, 'Rhinitis'),
#  (6519, 6549, 'Rhinitis, allergic, perennial'),
#  (6549, 6592, 'Rhinitis, allergic, perennial and seasonal'),
#  (6592, 6621, 'Rhinitis, allergic, seasonal'),
#  (6621, 6642, 'Rotavirus infections'),
#  (6642, 6650, 'Rubella'),
#  (6650, 6664, 'Schizophrenia'),
#  (6664, 6686, 'Seborrheic dermatitis'),
#  (6686, 6732, 'Secondary prevention of thromboembolic events'),
#  (6732, 6774, 'Seizure disorder generalized tonic clonic'),
#  (6774, 6791, 'Seizure, absence'),
#  (6791, 6800, 'Seizures'),
#  (6800, 6807, 'Sepsis'),
#  (6807, 6833, 'Shigella sonnei infection'),
#  (6833, 6853, 'Sickle cell disease'),
#  (6853, 6863, 'Sinusitis'),
#  (6863, 6883, "Sjoegren's syndrome"),
#  (6883, 6899, 'Sleep disorders'),
#  (6899, 6942, 'Sleep initiation and maintenance disorders'),
#  (6942, 6972, 'Sma - spinal muscular atrophy'),
#  (6972, 6993, 'Small cell carcinoma'),
#  (6993, 7011, 'Smoking cessation'),
#  (7011, 7025, 'Social phobia'),
#  (7025, 7045, 'Soft tissue sarcoma'),
#  (7045, 7085, 'Solid tumor cancer with bone metastases'),
#  (7085, 7099, 'Solid tumours'),
#  (7099, 7117, 'Spondyloarthritis'),
#  (7117, 7143, 'Staphylococcal infections'),
#  (7143, 7168, 'Streptococcal infections'),
#  (7168, 7193, 'Streptococcus agalactiae'),
#  (7193, 7218, 'Streptococcus pneumoniae'),
#  (7218, 7239, 'Substance dependence'),
#  (7239, 7285, 'Systemic juvenile idiopathic arthritis (sjia)'),
#  (7285, 7314, 'Systemic lupus erythematosus'),
#  (7314, 7335, 'Systemic scleroderma'),
#  (7335, 7351, 'Tendon injuries'),
#  (7351, 7359, 'Tetanus'),
#  (7359, 7403, 'Therapeutic treatment of inhalation anthrax'),
#  (7403, 7419, 'Thromboembolism'),
#  (7419, 7438, 'Thrombosis, venous'),
#  (7438, 7453, 'Thyroid cancer'),
#  (7453, 7462, 'Tinnitus'),
#  (7462, 7483, 'Tobacco use disorder'),
#  (7483, 7505, 'Tonic-clonic epilepsy'),
#  (7505, 7519, 'Tooth erosion'),
#  (7519, 7533, 'Toxoplasmosis'),
#  (7533, 7560, 'Transient ischaemic attack'),
#  (7560, 7584, 'Transplantation, kidney'),
#  (7584, 7607, 'Transplantation, liver'),
#  (7607, 7630, 'Transplantation, organ'),
#  (7630, 7643, 'Tuberculosis'),
#  (7643, 7696, 'Tumors characterized by genetic abnormalities of alk'),
#  (7696, 7721, 'Type 1 diabetes mellitus'),
#  (7721, 7737, 'Type 2 diabetes'),
#  (7737, 7762, 'Type 2 diabetes mellitus'),
#  (7762, 7776, 'Typhoid fever'),
#  (7776, 7805, 'Ulcers, duodenal and gastric'),
#  (7805, 7825, 'Uncontrolled asthma'),
#  (7825, 7853, 'Urinary bladder, overactive'),
#  (7853, 7874, 'Urinary incontinence'),
#  (7874, 7892, 'Urologic diseases'),
#  (7892, 7902, 'Urticaria'),
#  (7902, 7912, 'Varicella'),
#  (7912, 7941, 'Vascular disease, peripheral'),
#  (7941, 7952, 'Vasculitis'),
#  (7952, 7971, 'Vasomotor rhinitis'),
#  (7971, 7986, 'Virus diseases'),
#  (7986, 7995, 'Vomiting'),
#  (7995, 8038, 'Wet age related macular degeneration (amd)'),
#  (8038, 8059, 'Whole cell pertussis'),
#  (8059, 8073, 'Wound healing')]

# %%
gcp_token = check_output(["gcloud", "auth", "print-access-token"], encoding='UTF-8').strip()

# %%
#test_text = ";".join([x[2] for x in offset_text])

test_text = ""
content = ""

for x in offset_text:

    if len(test_text) + len(x[2]) < 10000:

        test_text += x[2] + ";"

    else:
        test_text = test_text[:-1]

        result = healthcare_nlp.get_healthcare_json(test_text, gcp_token)

        json_form = json.loads(result)
        
        temp = healthcare_nlp.get_json(json_form, "PROBLEM", condition_corrections, offset_text)

        content += "\n".join([json.dumps(x) for x in temp]) + "\n"

        test_text = x[2] + ";"


if test_text != "":
    test_text = test_text[:-1]

    result = healthcare_nlp.get_healthcare_json(test_text, gcp_token)

    with open("condition_gcp_raw.json", "w") as f:
        f.write(result)

    json_form = json.loads(result)

    temp = healthcare_nlp.get_json(json_form, "PROBLEM", condition_corrections, offset_text)

    content += "\n".join([json.dumps(x) for x in temp]) + "\n"
# Out:
# {'UMLS/C0001144': {'preferredTerm': 'Acne Vulgaris', 'vocabularyCodes': ['MSH/D000152', 'MTH/NOCODE', 'NCI/C27195']}, 'UMLS/C0001175': {'preferredTerm': 'Acquired Immunodeficiency Syndrome', 'vocabularyCodes': ['LNC/LA10430-9', 'MEDLINEPLUS/1', 'MSH/D000163', 'MTH/NOCODE', 'NCI/C2851']}, 'UMLS/C0001519': {'preferredTerm': 'Adie Syndrome', 'vocabularyCodes': ['MSH/D000270', 'MTH/NOCODE', 'NCI/C34357', 'OMIM/103100']}, 'UMLS/C0001529': {'preferredTerm': 'Adiposis Dolorosa', 'vocabularyCodes': ['MSH/D000274', 'NCI/C84540', 'OMIM/103200']}, 'UMLS/C0001617': {'preferredTerm': 'Adrenal Cortex Hormones', 'vocabularyCodes': ['LNC/LP31653-6', 'MEDLINEPLUS/4557', 'MSH/D000305', 'MTH/NOCODE', 'NCI/C211', 'NCI/C2322', 'VANDF/4021625']}, 'UMLS/C0001683': {'preferredTerm': 'Advance Directives', 'vocabularyCodes': ['LNC/LP133261-0', 'LNC/LP74455-4', 'LNC/MTHU021127', 'LNC/MTHU047657', 'MEDLINEPLUS/4151', 'MSH/D016223', 'MTH/NOCODE', 'NCI/C93142']}, 'UMLS/C0001815': {'preferredTerm': 'Primary Myelofibrosis', 'vocabularyCodes': ['ICD9CM/238.76', 'MSH/D055728', 'MTH/NOCODE', 'NCI/C2862']}, 'UMLS/C0001962': {'preferredTerm': 'ethanol', 'vocabularyCodes': ['LNC/LA28139-6', 'LNC/LP14348-4', 'LNC/MTHU001345', 'MEDLINEPLUS/1558', 'MSH/D000431', 'MTH/NOCODE', 'NCI/C2190', 'RXNORM/448', 'VANDF/4017424', 'VANDF/4017736']}, 'UMLS/C0001973': {'preferredTerm': 'Alcoholic Intoxication, Chronic', 'vocabularyCodes': ['HPO/HP:0030955', 'ICD9CM/303', 'LNC/LA20350-7', 'LNC/LA6152-8', 'MEDLINEPLUS/120', 'MSH/D000437', 'MTH/035', 'MTH/NOCODE', 'NCI/C93040', 'OMIM/103780']}, 'UMLS/C0002170': {'preferredTerm': 'Alopecia', 'vocabularyCodes': ['HPO/HP:0001596', 'HPO/HP:0002293', 'ICD9CM/704.0', 'ICD9CM/704.00', 'MEDLINEPLUS/5282', 'MSH/D000505', 'MTH/U001676', 'NCI/C50575', 'OMIM/MTHU036685', 'OMIM/MTHU036686', 'OMIM/MTHU042127']}, 'UMLS/C0002395': {'preferredTerm': "Alzheimer's Disease", 'vocabularyCodes': ['HPO/HP:0002511', 'ICD9CM/331.0', 'LNC/LA22313-3', 'LNC/LP74474-5', 'LNC/MTHU020798', 'MEDLINEPLUS/22', 'MSH/D000544', 'MTH/NOCODE', 'NCI/C2866', 'OMIM/104300', 'OMIM/516000', 'OMIM/MTHU004582']}, 'UMLS/C0002453': {'preferredTerm': 'Amenorrhea', 'vocabularyCodes': ['HPO/HP:0000141', 'ICD9CM/626.0', 'MSH/D000568', 'MTH/NOCODE', 'NCI/C61443', 'OMIM/MTHU012513']}, 'UMLS/C0002726': {'preferredTerm': 'Amyloidosis', 'vocabularyCodes': ['HPO/HP:0011034', 'ICD9CM/277.3', 'ICD9CM/277.30', 'LNC/LP209029-0', 'MEDLINEPLUS/5273', 'MSH/D000686', 'MTH/NOCODE', 'NCI/C2868']}, 'UMLS/C0002771': {'preferredTerm': 'Analgesics', 'vocabularyCodes': ['LNC/LP134119-9', 'LNC/LP31483-8', 'LNC/MTHU015955', 'MEDLINEPLUS/4059', 'MSH/D000700', 'MTH/NOCODE', 'NCI/C241', 'NCI/C29631', 'VANDF/4021580']}, 'UMLS/C0002871': {'preferredTerm': 'Anemia', 'vocabularyCodes': ['HPO/HP:0001903', 'ICD9CM/285.9', 'LNC/LA18969-8', 'LNC/LP74477-8', 'LNC/MTHU020823', 'MEDLINEPLUS/139', 'MSH/D000740', 'MTH/NOCODE', 'MTH/U000161', 'MTH/U000164', 'NCI/C2869', 'OMIM/MTHU002606']}, 'UMLS/C0002895': {'preferredTerm': 'Anemia, Sickle Cell', 'vocabularyCodes': ['ICD9CM/282.6', 'ICD9CM/282.60', 'LNC/LP56775-7', 'LNC/MTHU021603', 'MEDLINEPLUS/402', 'MSH/D000755', 'MTH/NOCODE', 'NCI/C34383', 'OMIM/141900', 'OMIM/603903', 'OMIM/MTHU054349']}, 'UMLS/C0003469': {'preferredTerm': 'Anxiety Disorders', 'vocabularyCodes': ['LNC/LA27866-5', 'LNC/LP74483-6', 'LNC/MTHU020812', 'MSH/D001008', 'MTH/058', 'MTH/NOCODE', 'NCI/C2878', 'OMIM/MTHU004077', 'OMIM/MTHU053021']}, 'UMLS/C0003564': {'preferredTerm': 'Aphonia', 'vocabularyCodes': ['HPO/HP:0001686', 'ICD9CM/784.41', 'MSH/D001044', 'MTH/NOCODE', 'NCI/C79539', 'OMIM/MTHU037052']}, 'UMLS/C0003811': {'preferredTerm': 'Cardiac Arrhythmia', 'vocabularyCodes': ['HPO/HP:0011675', 'ICD9CM/427', 'ICD9CM/427.9', 'LNC/LA15419-7', 'LNC/LA7414-1', 'LNC/LA9536-9', 'LNC/LP188713-4', 'LNC/LP74586-6', 'LNC/MTHU020785', 'LNC/MTHU050325', 'MEDLINEPLUS/147', 'MSH/D001145', 'MTH/153', 'MTH/271', 'MTH/549', 'MTH/NOCODE', 'NCI/C2881', 'OMIM/MTHU001654', 'OMIM/MTHU006699', 'OMIM/MTHU010895', 'OMIM/MTHU01 ...
# {'content': 'AIDS', 'beginOffset': 0} [{'entityId': 'UMLS/C0001175'}, {'entityId': 'UMLS/C0021588'}] 0.8268852829933167
# {'content': 'Acellular pertussis', 'beginOffset': 5} [{'entityId': 'UMLS/C0043167'}] 0.9864320755004883
# {'content': 'Acne vulgaris', 'beginOffset': 25} [{'entityId': 'UMLS/C0001144'}] 0.9524648189544678
# {'content': 'Acute coronary syndrome', 'beginOffset': 39} [{'entityId': 'UMLS/C0948089'}] 0.8969781994819641
# {'content': 'injury', 'beginOffset': 74} [{'entityId': 'UMLS/C3263723'}] 0.9750198721885681
# {'content': 'Acute myelocytic leukaemia', 'beginOffset': 81} [{'entityId': 'UMLS/C0023467'}] 0.7757142782211304
# {'content': 'Acute myeloid leukemia', 'beginOffset': 108} [{'entityId': 'UMLS/C0023467'}] 0.7337126135826111
# {'content': 'sinusitis', 'beginOffset': 137} [{'entityId': 'UMLS/C0037199'}] 0.8450464010238647
# {'content': 'Adrenocortical carcinoma', 'beginOffset': 147} [{'entityId': 'UMLS/C0206686'}] 0.9685287475585938
# {'content': 'cancer', 'beginOffset': 188} [{'entityId': 'UMLS/C0006826'}] 0.9889470934867859
# {'content': 'gastric cancer', 'beginOffset': 204} [{'entityId': 'UMLS/C0024623'}, {'entityId': 'UMLS/C0699791'}] 0.8236435055732727
# {'content': 'Allergic conjunctivitis', 'beginOffset': 230} [{'entityId': 'UMLS/C0009766'}] 0.8901834487915039
# {'content': 'Alopecia', 'beginOffset': 254} [{'entityId': 'UMLS/C0002170'}] 0.9771223068237305
# {'content': "Alzheimer's disease", 'beginOffset': 263} [{'entityId': 'UMLS/C0002395'}] 0.9931473731994629
# {'content': 'Amyloidosis', 'beginOffset': 283} [{'entityId': 'UMLS/C0002726'}] 0.9884583353996277
# {'content': 'Anaemia', 'beginOffset': 295} [{'entityId': 'UMLS/C0002871'}] 0.9939550161361694
# {'content': 'Ankylosing spondylitis', 'beginOffset': 313} [{'entityId': 'UMLS/C0038013'}] 0.9925868511199951
# {'content': 'Anxiety disorders', 'beginOffset': 336} [{'entityId': 'UMLS/C0003469'}] 0.9397355318069458
# {'content': 'Asthma', 'beginOffset': 354} [{'entityId': 'UMLS/C0004096'}] 0.9966434240341187
# {'content': 'Asthma', 'beginOffset': 361} [{'entityId': 'UMLS/C0004096'}] 0.9977861642837524
# {'content': 'rhinitis', 'beginOffset': 372} [{'entityId': 'UMLS/C0035455'}] 0.9962188601493835
# {'content': 'Atherosclerosis', 'beginOffset': 381} [{'entityId': 'UMLS/C0004153'}] 0.983167290687561
# {'content': 'Atopic dermatitis', 'beginOffset': 397} [{'entityId': 'UMLS/C0011615'}, {'entityId': 'UMLS/C0013595'}] 0.9893900156021118
# {'content': 'Atrial fibrillation', 'beginOffset': 415} [{'entityId': 'UMLS/C0004238'}] 0.9940417408943176
# {'content': 'Attention deficit hyperactivity disorder', 'beginOffset': 435} [{'entityId': 'UMLS/C1263846'}] 0.9803110361099243
# {'content': 'Autoimmune diseases', 'beginOffset': 483} [{'entityId': 'UMLS/C0004364'}] 0.9555047154426575
# {'content': 'B-cell acute lymphoblastic leukemia', 'beginOffset': 503} [{'entityId': 'UMLS/C1292769'}] 0.8035414814949036
# {'content': 'relapsed b-cell acute lymphoblastic leukemia', 'beginOffset': 540} [{'entityId': 'UMLS/C1292769'}] 0.6659447550773621
# {'content': 'lymphoblastic leukemia', 'beginOffset': 610} [{'entityId': 'UMLS/C0023449'}, {'entityId': 'UMLS/C1961102'}] 0.9728643298149109
# {'content': 'Bacillary dysentery', 'beginOffset': 633} [{'entityId': 'UMLS/C1527298'}] 0.41238632798194885
# {'content': 'Bacterial infections', 'beginOffset': 653} [{'entityId': 'UMLS/C0004623'}] 0.9273865222930908
# {'content': 'Bacterial skin infections', 'beginOffset': 674} [{'entityId': 'UMLS/C1835686'}] 0.7767043709754944
# {'content': 'Bipolar disorder', 'beginOffset': 700} [{'entityId': 'UMLS/C0005586'}] 0.9799374341964722
# {'content': 'Bipolar i disorder', 'beginOffset': 717} [{'entityId': 'UMLS/C0236780'}] 0.9882224202156067
# {'content': 'pain', 'beginOffset': 744} [{'entityId': 'UMLS/C0030193'}] 0.986057460308075
# {'content': 'metastases', 'beginOffset': 755} [{'entityId': 'UMLS/C0027627'}, {'entityId': 'UMLS/C4255448'}] 0.9874024391174316
# {'content': 'cancer', 'beginOffset': 773} [{'entityId': 'UMLS/C0006826'}] 0.9905269145965576
# {'content': 'neoplasms', 'beginOffset': 787} [{'entityId': 'UMLS/C0027651'}] 0.8981393575668335
# {'content': 'Bronchial constriction', 'beginOffset': 797} [{'entityId': 'UMLS/C0009813'}, {'entityId': 'UMLS/C1444778'}] 0.8222478032112122
# {'content': 'Bronchial hyperreactivity', 'beginOffset': 820} [{'entityId': 'UMLS/C0085129'}] 0.8039790987968445
# {'content': 'Bronchiectasis', 'beginOffset': 846} [{'entityId': 'UMLS/C0006267'}] 0.9905588030815125
# {'content': 'Bronchospasm', 'beginOffset': 861} [{'entityId': 'UMLS/C0006266'}] 0.9421064257621765
# {'content': 'Cachexia', 'beginOffset': 874} [{'entityId': 'UMLS/C0006625'}] 0.9958348274230957
# {'content': 'Cancer', 'beginOffset': 883} [{'entityId': 'UMLS/C0006826'}] 0.9650756120681763
# {'content': 'Cancer', 'beginOffset': 890} [{'entityId': 'UMLS/C0006826'}] 0.8890804052352905
# {'content': 'neoplasms', 'beginOffset': 897} [{'entityId': 'UMLS/C0027651'}] 0.6877548694610596
# {'content': 'Carcinoid tumor', 'beginOffset': 907} [{'entityId': 'UMLS/C0007095'}] 0.7944874167442322
# {'content': 'Cardiac arrhythmia', 'beginOffset': 923} [{'entityId': 'UMLS/C0003811'}] 0.969698965549469
# {'content': 'Cardiovascular disease', 'beginOffset': 942} [{'entityId': 'UMLS/C0007222'}] 0.9349859356880188
# {'content': 'Cataract', 'beginOffset': 965} [{'entityId': 'UMLS/C0521707'}] 0.9816972613334656
# {'content': 'Cerebrovascular accident', 'beginOffset': 974} [{'entityId': 'UMLS/C0038454'}] 0.9647518992424011
# {'content': 'Cervical intraepithelial neoplasia', 'beginOffset': 999} [{'entityId': 'UMLS/C0206708'}] 0.9753516912460327
# {'content': 'Chemotherapy-induced nausea', 'beginOffset': 1034} [{'entityId': 'UMLS/C4687664'}] 0.6881038546562195
# {'content': 'vomiting', 'beginOffset': 1066} [{'entityId': 'UMLS/C0042963'}] 0.9961848258972168
# {'content': 'Cholestasis', 'beginOffset': 1075} [{'entityId': 'UMLS/C0008370'}] 0.9960980415344238
# {'content': 'Chronic Obstructive Airway Disease', 'beginOffset': 1087} [{'entityId': 'UMLS/C0024117'}] 0.8820010423660278
# {'content': 'bronchitis', 'beginOffset': 1130} [{'entityId': 'UMLS/C0006277'}] 0.9939728379249573
# {'content': 'constipation', 'beginOffset': 1149} [{'entityId': 'UMLS/C0009806'}] 0.9960134625434875
# {'content': 'dermatitis', 'beginOffset': 1170} [{'entityId': 'UMLS/C0011603'}] 0.9959018230438232
# {'content': 'idiopathic urticaria', 'beginOffset': 1189} [{'entityId': 'UMLS/C0157741'}] 0.9478525519371033
# {'content': 'ciu', 'beginOffset': 1211} [{'entityId': 'UMLS/C0578870'}] 0.7667137384414673
# {'content': 'lymphocytic leukaemia', 'beginOffset': 1224} [{'entityId': 'UMLS/C0023434'}, {'entityId': 'UMLS/C0023449'}] 0.9789646863937378
# {'content': 'lymphocytic leukemia', 'beginOffset': 1254} [{'entityId': 'UMLS/C0023448'}] 0.9827724695205688
# {'content': 'myelogenous leukemia', 'beginOffset': 1289} [{'entityId': 'UMLS/C0023470'}] 0.9877031445503235
# {'content': 'Chronic myeloid leukemia', 'beginOffset': 1310} [{'entityId': 'UMLS/C0023473'}, {'entityId': 'UMLS/C0279543'}, {'entityId': 'UMLS/C1292771'}] 0.6233974695205688
# {'content': 'Chronic obstructive pulmonary disease', 'beginOffset': 1341} [{'entityId': 'UMLS/C0024117'}] 0.9509403109550476
# {'content': 'copd', 'beginOffset': 1380} [{'entityId': 'UMLS/C0024117'}] 0.7997470498085022
# {'content': 'plaque psoriasis', 'beginOffset': 1394} [{'entityId': 'UMLS/C0033860'}] 0.9715630412101746
# {'content': 'Clostridium difficile infection', 'beginOffset': 1411} [{'entityId': 'UMLS/C0343386'}] 0.9351624846458435
# {'content': 'Cognitive disorders', 'beginOffset': 1443} [{'entityId': 'UMLS/C0009241'}] 0.9379746913909912
# {'content': 'Colitis', 'beginOffset': 1463} [{'entityId': 'UMLS/C0009319'}] 0.9645317196846008
# {'content': 'ulcerative', 'beginOffset': 1472} [{'entityId': 'UMLS/C0041582'}] 0.4455707371234894
# {'content': 'Colorectal Neoplasms', 'beginOffset': 1483} [{'entityId': 'UMLS/C0009404'}] 0.48142167925834656
# {'content': 'Congestive heart failure', 'beginOffset': 1504} [{'entityId': 'UMLS/C0018802'}] 0.9912593364715576
# {'content': 'Congestive heart failure', 'beginOffset': 1529} [{'entityId': 'UMLS/C0018802'}] 0.990882396697998
# {'content': 'microalbuminuria', 'beginOffset': 1558} [{'entityId': 'UMLS/C0730345'}] 0.9660503268241882
# {'content': 'heart failure', 'beginOffset': 1575} [{'entityId': 'UMLS/C0018801'}, {'entityId': 'UMLS/C0018802'}] 0.9746724963188171
# {'content': 'Coronary artery disease', 'beginOffset': 1589} [{'entityId': 'UMLS/C1956346'}] 0.9908908605575562
# {'content': 'host disease', 'beginOffset': 1654} [{'entityId': 'UMLS/C0018133'}] 0.6238856315612793
# {'content': 'Cough', 'beginOffset': 1667} [{'entityId': 'UMLS/C0010200'}] 0.9673538208007812
# {'content': "Crohn's disease", 'beginOffset': 1673} [{'entityId': 'UMLS/C0010346'}] 0.9868972301483154
# {'content': 'Cystic fibrosis', 'beginOffset': 1689} [{'entityId': 'UMLS/C0010674'}] 0.9911090135574341
# {'content': 'Dementia', 'beginOffset': 1705} [{'entityId': 'UMLS/C0497327'}] 0.9959971308708191
# {'content': 'Dentin sensitivity', 'beginOffset': 1714} [{'entityId': 'UMLS/C0011432'}] 0.8164581060409546
# {'content': 'Denture retention', 'beginOffset': 1733} [{'entityId': 'UMLS/C0011397'}] 0.9765986204147339
# {'content': 'Depressive disorder', 'beginOffset': 1751} [{'entityId': 'UMLS/C0011581'}] 0.9915759563446045
# {'content': 'Depressive disorder', 'beginOffset': 1771} [{'entityId': 'UMLS/C0011581'}] 0.9908232092857361
# {'content': 'anxiety disorders', 'beginOffset': 1795} [{'entityId': 'UMLS/C0003469'}] 0.9686433672904968
# {'content': 'Dermatologic disorders', 'beginOffset': 1813} [{'entityId': 'UMLS/C0037274'}] 0.9649987816810608
# {'content': 'Diabetes mellitus', 'beginOffset': 1836} [{'entityId': 'UMLS/C0011849'}] 0.9893444180488586
# {'content': 'Diabetic kidney disease', 'beginOffset': 1854} [{'entityId': 'UMLS/C0011881'}] 0.9941562414169312
# {'content': 'Diabetic macular edema', 'beginOffset': 1878} [{'entityId': 'UMLS/C0730285'}] 0.9621250629425049
# {'content': 'Diabetic neuropathic pain', 'beginOffset': 1901} [{'entityId': 'UMLS/C0751074'}] 0.9744822978973389
# {'content': 'Diabetic neuropathy', 'beginOffset': 1927} [{'entityId': 'UMLS/C0011882'}] 0.9903542399406433
# {'content': 'Diabetic retinopathy', 'beginOffset': 1947} [{'entityId': 'UMLS/C0011884'}] 0.9928548336029053
# {'content': 'Diphtheria', 'beginOffset': 1968} [{'entityId': 'UMLS/C0012546'}, {'entityId': 'UMLS/C1440557'}] 0.991320013999939
# {'content': 'Drug-related side effects', 'beginOffset': 1979} [{'entityId': 'UMLS/C0041755'}] 0.7673635482788086
# {'content': 'adverse reactions', 'beginOffset': 2009} [{'entityId': 'UMLS/C0559546'}] 0.8235226273536682
# {'content': 'Dyslipidaemias', 'beginOffset': 2027} [{'entityId': 'UMLS/C0242339'}] 0.9971308708190918
# {'content': 'Eczema', 'beginOffset': 2042} [{'entityId': 'UMLS/C0013595'}] 0.996532678604126
# {'content': 'Endometriosis', 'beginOffset': 2065} [{'entityId': 'UMLS/C0014175'}] 0.9362920522689819
# {'content': 'Eosinophilic asthma', 'beginOffset': 2079} [{'entityId': 'UMLS/C0004096'}] 0.9712786078453064
# {'content': 'Eosinophilic esophagitis', 'beginOffset': 2099} [{'entityId': 'UMLS/C0341106'}, {'entityId': 'UMLS/C4703646'}] 0.9676379561424255
# {'content': 'Epilepsy', 'beginOffset': 2124} [{'entityId': 'UMLS/C0014544'}] 0.9969423413276672
# {'content': 'Episodic migraine headache', 'beginOffset': 2133} [{'entityId': 'UMLS/C0149931'}] 0.8857117295265198
# {'content': 'Esophageal cancer', 'beginOffset': 2160} [{'entityId': 'UMLS/C0152018'}, {'entityId': 'UMLS/C0546837'}] 0.9763160347938538
# {'content': 'Fascioliasis', 'beginOffset': 2178} [{'entityId': 'UMLS/C0015652'}] 0.9361693263053894
# {'content': 'Fibromyalgia syndrome', 'beginOffset': 2191} [{'entityId': 'UMLS/C0016053'}] 0.9818029403686523
# {'content': 'Focal infection', 'beginOffset': 2222} [{'entityId': 'UMLS/C0016397'}] 0.9212414622306824
# {'content': 'Follicular lymphoma', 'beginOffset': 2246} [{'entityId': 'UMLS/C0024301'}] 0.8644776344299316
# {'content': 'Fracture', 'beginOffset': 2266} [{'entityId': 'UMLS/C0016658'}, {'entityId': 'UMLS/C4554413'}] 0.8804707527160645
# {'content': 'Gastrointestinal Neoplasms', 'beginOffset': 2283} [{'entityId': 'UMLS/C0017185'}] 0.7323068380355835
# {'content': 'Gastrointestinal diseases', 'beginOffset': 2310} [{'entityId': 'UMLS/C0017178'}] 0.917179524898529
# {'content': 'Gastroparesis', 'beginOffset': 2362} [{'entityId': 'UMLS/C0152020'}] 0.973270058631897
# {'content': 'Geographic atrophy', 'beginOffset': 2376} [{'entityId': 'UMLS/C1536085'}] 0.7979090809822083
# {'content': 'Gonorrhea', 'beginOffset': 2395} [{'entityId': 'UMLS/C0018081'}] 0.9525274634361267
# {'content': 'influenza A virus', 'beginOffset': 2418} [{'entityId': 'UMLS/C0029347'}] 0.802370548248291
# {'content': 'Haemophilus influenzae type b', 'beginOffset': 2436} [{'entityId': 'UMLS/C0121772'}] 0.5382435917854309
# {'content': 'neoplasms', 'beginOffset': 2471} [{'entityId': 'UMLS/C0027651'}] 0.9157379269599915
# {'content': 'neoplasms', 'beginOffset': 2490} [{'entityId': 'UMLS/C0027651'}] 0.8002112507820129
# {'content': 'Heart failure', 'beginOffset': 2500} [{'entityId': 'UMLS/C0018801'}, {'entityId': 'UMLS/C0018802'}] 0.8687694668769836
# {'content': 'Heart failure', 'beginOffset': 2514} [{'entityId': 'UMLS/C0018801'}, {'entityId': 'UMLS/C0018802'}] 0.8086141347885132
# {'content': 'Heart failure', 'beginOffset': 2561} [{'entityId': 'UMLS/C0018801'}, {'entityId': 'UMLS/C0018802'}] 0.8861265182495117
# {'content': 'Hepatitis a', 'beginOffset': 2590} [{'entityId': 'UMLS/C0019159'}] 0.6002692580223083
# {'content': 'Hepatitis b', 'beginOffset': 2602} [{'entityId': 'UMLS/C0019163'}] 0.598939836025238
# {'content': 'Hepatitis b', 'beginOffset': 2614} [{'entityId': 'UMLS/C0019163'}] 0.6732063889503479
# {'content': 'Hepatitis c', 'beginOffset': 2635} [{'entityId': 'UMLS/C0019196'}, {'entityId': 'UMLS/C0220847'}] 0.7183271050453186
# {'content': 'Hepatitis c', 'beginOffset': 2647} [{'entityId': 'UMLS/C0019196'}, {'entityId': 'UMLS/C0220847'}] 0.7536868453025818
# {'content': 'Hepatocellular carcinoma', 'beginOffset': 2668} [{'entityId': 'UMLS/C2239176'}] 0.9276757836341858
# {'content': 'Hepatocellular carcinoma', 'beginOffset': 2693} [{'entityId': 'UMLS/C2239176'}] 0.8636860251426697
# {'content': 'metastatic', 'beginOffset': 2738} [{'entityId': 'UMLS/C0027627'}, {'entityId': 'UMLS/C4255448'}] 0.8018231987953186
# {'content': 'cancer', 'beginOffset': 2756} [{'entityId': 'UMLS/C0006826'}] 0.9762915968894958
# {'content': 'cancer', 'beginOffset': 2812} [{'entityId': 'UMLS/C0006826'}] 0.9928540587425232
# {'content': 'metastatic', 'beginOffset': 2822} [{'entityId': 'UMLS/C0027627'}, {'entityId': 'UMLS/C4255448'}] 0.9273154735565186
# {'content': 'cancer', 'beginOffset': 2840} [{'entityId': 'UMLS/C0006826'}] 0.9821457266807556
# {'content': 'fevers', 'beginOffset': 2867} [{'entityId': 'UMLS/C0015967'}, {'entityId': 'UMLS/C0424755'}] 0.9289571642875671
# {'content': 'Herpes genitalis', 'beginOffset': 2874} [{'entityId': 'UMLS/C0019342'}] 0.8132097721099854
# {'content': 'Herpes labialis', 'beginOffset': 2891} [{'entityId': 'UMLS/C0019345'}] 0.822712779045105
# {'content': 'Herpes simplex infection', 'beginOffset': 2907} [{'entityId': 'UMLS/C0019348'}] 0.5909348130226135
# {'content': 'Herpes zoster', 'beginOffset': 2932} [{'entityId': 'UMLS/C0019360'}] 0.808921754360199
# {'content': 'Herpesviridae infections', 'beginOffset': 2946} [{'entityId': 'UMLS/C0019372'}] 0.8500008583068848
# {'content': 'fracture', 'beginOffset': 2975} [{'entityId': 'UMLS/C0016658'}, {'entityId': 'UMLS/C4554413'}] 0.9869711399078369
# {'content': 'Hiv infections', 'beginOffset': 2984} [{'entityId': 'UMLS/C0019693'}] 0.5865998268127441
# {'content': 'Human immunodeficiency virus infection', 'beginOffset': 2999} [{'entityId': 'UMLS/C0019693'}] 0.9167234301567078
# {'content': 'Human immunodeficiency virus infection', 'beginOffset': 3038} [{'entityId': 'UMLS/C0019693'}] 0.884145975112915
# {'content': 'herpesviridae infections', 'beginOffset': 3081} [{'entityId': 'UMLS/C0019372'}] 0.8905613422393799
# {'content': 'Huntington disease', 'beginOffset': 3106} [{'entityId': 'UMLS/C0020179'}] 0.8780145645141602
# {'content': 'Hypercholesterolemia', 'beginOffset': 3125} [{'entityId': 'UMLS/C0020443'}, {'entityId': 'UMLS/C1522133'}] 0.9774051308631897
# {'content': 'Hypereosinophilic syndrome', 'beginOffset': 3146} [{'entityId': 'UMLS/C1540912'}] 0.992617130279541
# {'content': 'Hyperhidrosis', 'beginOffset': 3173} [{'entityId': 'UMLS/C0020458'}] 0.9949760437011719
# {'content': 'Hypertension', 'beginOffset': 3187} [{'entityId': 'UMLS/C0020538'}] 0.9934890866279602
# {'content': 'Hypertriglyceridemia', 'beginOffset': 3200} [{'entityId': 'UMLS/C0020557'}, {'entityId': 'UMLS/C0813230'}, {'entityId': 'UMLS/C1522137'}] 0.9969286918640137
# {'content': 'Hypogonadism', 'beginOffset': 3221} [{'entityId': 'UMLS/C0020619'}] 0.9847612380981445
# {'content': 'Idiopathic pulmonary fibrosis', 'beginOffset': 3240} [{'entityId': 'UMLS/C1800706'}] 0.9152165055274963
# {'content': 'Idiopathic thrombocytopenic purpura', 'beginOffset': 3270} [{'entityId': 'UMLS/C0398650'}] 0.8626502156257629
# {'content': 'Impetigo', 'beginOffset': 3306} [{'entityId': 'UMLS/C0021099'}] 0.7328082323074341
# {'content': 'Inflammatory bowel diseases', 'beginOffset': 3315} [{'entityId': 'UMLS/C0021390'}] 0.9713078737258911
# {'content': 'Influenza', 'beginOffset': 3343} [{'entityId': 'UMLS/C0021400'}] 0.830482006072998
# {'content': 'Intrahepatic cholestasis', 'beginOffset': 3372} [{'entityId': 'UMLS/C0008372'}] 0.9800817370414734
# {'content': 'Invasive aspergillosis', 'beginOffset': 3397} [{'entityId': 'UMLS/C0752341'}] 0.6659131646156311
# {'content': 'invasive mucormycosis', 'beginOffset': 3422} [{'entityId': 'UMLS/C0026718'}, {'entityId': 'UMLS/C0043541'}] 0.8910754323005676
# {'content': 'Invasive candidiasis', 'beginOffset': 3444} [{'entityId': 'UMLS/C1609535'}] 0.7844728231430054
# {'content': 'Invasive fungal infection', 'beginOffset': 3465} [{'entityId': 'UMLS/C1262313'}] 0.7614210844039917
# {'content': 'fungal infections', 'beginOffset': 3500} [{'entityId': 'UMLS/C0026946'}] 0.9022456407546997
# {'content': 'Irritable bowel syndrome', 'beginOffset': 3518} [{'entityId': 'UMLS/C0022104'}] 0.9871119856834412
# {'content': 'psoriatic arthritis', 'beginOffset': 3552} [{'entityId': 'UMLS/C0003872'}] 0.971450686454773
# {'content': 'enthesitis-related arthritis', 'beginOffset': 3573} [{'entityId': 'UMLS/C3495919'}] 0.43448585271835327
# {'content': 'Left ventricular hypertrophy', 'beginOffset': 3602} [{'entityId': 'UMLS/C0149721'}] 0.891594409942627
# {'content': 'Lennox-gastaut syndrome', 'beginOffset': 3631} [{'entityId': 'UMLS/C0238111'}] 0.9572522640228271
# {'content': 'diseases', 'beginOffset': 3661} [{'entityId': 'UMLS/C0012634'}] 0.9017323851585388
# {'content': 'symptoms', 'beginOffset': 3690} [{'entityId': 'UMLS/C1457887'}] 0.9637441039085388
# {'content': 'benign prostatic hyperplasia', 'beginOffset': 3701} [{'entityId': 'UMLS/C1704272'}] 0.900392472743988
# {'content': 'injury', 'beginOffset': 3735} [{'entityId': 'UMLS/C3263723'}] 0.9745020866394043
# {'content': 'acute and respiratory distress syndrome', 'beginOffset': 3743} [{'entityId': 'UMLS/C0035222'}, {'entityId': 'UMLS/C0748355'}] 0.7811457514762878
# {'content': 'erythematosus', 'beginOffset': 3796} [{'entityId': 'UMLS/C0409974'}] 0.9212146997451782
# {'content': 'Lupus nephritis', 'beginOffset': 3821} [{'entityId': 'UMLS/C0024143'}] 0.44207435846328735
# {'content': 'Major depressive disorder', 'beginOffset': 3837} [{'entityId': 'UMLS/C0041696'}, {'entityId': 'UMLS/C1269683'}] 0.9883425235748291
# {'content': 'Malaria', 'beginOffset': 3863} [{'entityId': 'UMLS/C0024530'}] 0.553978681564331
# {'content': 'Malaria', 'beginOffset': 3871} [{'entityId': 'UMLS/C0024530'}] 0.6866275668144226
# {'content': 'Malaria', 'beginOffset': 3891} [{'entityId': 'UMLS/C0024530'}] 0.6662589311599731
# {'content': 'osteoporosis', 'beginOffset': 3911} [{'entityId': 'UMLS/C0029456'}] 0.9918076395988464
# {'content': 'Mantle-cell lymphoma', 'beginOffset': 3924} [{'entityId': 'UMLS/C0334634'}, {'entityId': 'UMLS/C4721414'}] 0.9200451970100403
# {'content': 'Mastocytosis', 'beginOffset': 3945} [{'entityId': 'UMLS/C0024899'}] 0.9620988965034485
# {'content': 'Melanoma', 'beginOffset': 3990} [{'entityId': 'UMLS/C0025202'}] 0.7782315611839294
# {'content': 'Meningitis', 'beginOffset': 3999} [{'entityId': 'UMLS/C0025289'}] 0.8247768878936768
# {'content': 'Meningococcal disease', 'beginOffset': 4025} [{'entityId': 'UMLS/C0025303'}] 0.9314436912536621
# {'content': 'Meningococcal infections', 'beginOffset': 4047} [{'entityId': 'UMLS/C0025303'}] 0.9432958364486694
# {'content': 'Mental disorders', 'beginOffset': 4072} [{'entityId': 'UMLS/C0004936'}] 0.9237347841262817
# {'content': 'Metabolic syndrome', 'beginOffset': 4089} [{'entityId': 'UMLS/C0524620'}] 0.9919957518577576
# {'content': 'Metastatic breast cancer', 'beginOffset': 4110} [{'entityId': 'UMLS/C0006142'}, {'entityId': 'UMLS/C0678222'}] 0.9020739197731018
# {'content': 'Metastatic melanoma', 'beginOffset': 4135} [{'entityId': 'UMLS/C0278883'}] 0.9949387907981873
# {'content': 'Metastatic renal cell carcinoma', 'beginOffset': 4155} [{'entityId': 'UMLS/C4721698'}] 0.9814730286598206
# {'content': 'Metastatic triple-negative breast cancer', 'beginOffset': 4187} [{'entityId': 'UMLS/C3539878'}, {'entityId': 'UMLS/C4722518'}] 0.6682186722755432
# {'content': 'carcinoma', 'beginOffset': 4236} [{'entityId': 'UMLS/C0007097'}] 0.9593484997749329
# {'content': 'Migraine', 'beginOffset': 4246} [{'entityId': 'UMLS/C0149931'}] 0.8796797394752502
# {'content': 'Migraine disorders', 'beginOffset': 4255} [{'entityId': 'UMLS/C0149931'}] 0.9552887678146362
# {'content': 'Migraine disorders', 'beginOffset': 4274} [{'entityId': 'UMLS/C0149931'}] 0.9575244188308716
# {'content': 'premenstrual syndrome', 'beginOffset': 4297} [{'entityId': 'UMLS/C0033046'}] 0.9231985211372375
# {'content': 'Migraine', 'beginOffset': 4319} [{'entityId': 'UMLS/C0149931'}] 0.64593905210495
# {'content': 'aura', 'beginOffset': 4337} [{'entityId': 'UMLS/C0236018'}] 0.4625031650066376
# {'content': 'asthma', 'beginOffset': 4347} [{'entityId': 'UMLS/C0004096'}] 0.9986290335655212
# {'content': 'allergic rhinitis', 'beginOffset': 4358} [{'entityId': 'UMLS/C2607914'}] 0.9397331476211548
# {'content': 'pain', 'beginOffset': 4401} [{'entityId': 'UMLS/C0030193'}] 0.9873444437980652
# {'content': 'pain', 'beginOffset': 4446} [{'entityId': 'UMLS/C0030193'}] 0.9703664779663086
# {'content': 'plaque-type psoriasis', 'beginOffset': 4478} [{'entityId': 'UMLS/C0033860'}] 0.8958398699760437
# {'content': 'psoriasis', 'beginOffset': 4525} [{'entityId': 'UMLS/C0033860'}] 0.9865208864212036
# {'content': 'Mood disorders', 'beginOffset': 4535} [{'entityId': 'UMLS/C0525045'}] 0.8608165383338928
# {'content': 'Multiple myeloma', 'beginOffset': 4550} [{'entityId': 'UMLS/C0026764'}] 0.8833471536636353
# {'content': 'Multiple sclerosis', 'beginOffset': 4572} [{'entityId': 'UMLS/C0026769'}] 0.8620213270187378
# {'content': 'Mumps', 'beginOffset': 4591} [{'entityId': 'UMLS/C0026780'}] 0.8318957686424255
# {'content': 'Muscle atrophy', 'beginOffset': 4597} [{'entityId': 'UMLS/C0026846'}, {'entityId': 'UMLS/C0541794'}] 0.6547409296035767
# {'content': 'Muscular atrophy', 'beginOffset': 4612} [{'entityId': 'UMLS/C0026846'}, {'entityId': 'UMLS/C0541794'}] 0.8752750158309937
# {'content': 'Myasthenia gravis', 'beginOffset': 4629} [{'entityId': 'UMLS/C0026896'}] 0.9233260154724121
# {'content': 'Mycoses', 'beginOffset': 4647} [{'entityId': 'UMLS/C0026946'}] 0.5824843049049377
# {'content': 'Myelodysplastic syndrome', 'beginOffset': 4655} [{'entityId': 'UMLS/C3463824'}] 0.9747663736343384
# {'content': 'Myelofibrosis', 'beginOffset': 4686} [{'entityId': 'UMLS/C0001815'}, {'entityId': 'UMLS/C0026987'}] 0.993747889995575
# {'content': 'Nail psoriasis', 'beginOffset': 4700} [{'entityId': 'UMLS/C0406322'}] 0.6177182793617249
# {'content': 'Nasal polyps', 'beginOffset': 4715} [{'entityId': 'UMLS/C0027430'}] 0.8690685629844666
# {'content': 'Neisseria meningitidis', 'beginOffset': 4728} [{'entityId': 'UMLS/C0027575'}] 0.5951697826385498
# {'content': 'neoplasms', 'beginOffset': 4776} [{'entityId': 'UMLS/C0027651'}] 0.8848332166671753
# {'content': 'macular degeneration', 'beginOffset': 4810} [{'entityId': 'UMLS/C0024437'}, {'entityId': 'UMLS/C0242383'}] 0.9036199450492859
# {'content': 'Neuroendocrine tumors', 'beginOffset': 4831} [{'entityId': 'UMLS/C0206754'}] 0.6792221665382385
# {'content': 'Neurogenic detrusor overactivity', 'beginOffset': 4859} [{'entityId': 'UMLS/C0268849'}] 0.8432719111442566
# {'content': 'Neuropathic pain', 'beginOffset': 4892} [{'entityId': 'UMLS/C0027796'}, {'entityId': 'UMLS/C1850383'}, {'entityId': 'UMLS/C3714625'}] 0.9489580988883972
# {'content': 'Non-hodgkin lymphoma', 'beginOffset': 4909} [{'entityId': 'UMLS/C0024305'}, {'entityId': 'UMLS/C4721532'}] 0.8642305135726929
# {'content': 'Non-radiographic spondyloarthritis', 'beginOffset': 4930} [{'entityId': 'UMLS/C0949690'}] 0.7314884662628174
# {'content': 'Non-small cell lung cancer', 'beginOffset': 4965} [{'entityId': 'UMLS/C0007131'}] 0.9820082187652588
# {'content': 'Non-small cell lung carcinoma', 'beginOffset': 4992} [{'entityId': 'UMLS/C0007131'}] 0.9674504995346069
# {'content': 'Obesity', 'beginOffset': 5030} [{'entityId': 'UMLS/C0028754'}, {'entityId': 'UMLS/C4759928'}] 0.9863045811653137
# {'content': 'Obsessive-compulsive disorder', 'beginOffset': 5038} [{'entityId': 'UMLS/C0028768'}] 0.8810147643089294
# {'content': 'Obsessive-compulsive disorder', 'beginOffset': 5068} [{'entityId': 'UMLS/C0028768'}] 0.8836283087730408
# {'content': 'depressive disorder', 'beginOffset': 5102} [{'entityId': 'UMLS/C0011581'}] 0.9851469397544861
# {'content': 'Ocular hypertension', 'beginOffset': 5122} [{'entityId': 'UMLS/C0028840'}, {'entityId': 'UMLS/C0234708'}] 0.9381330609321594
# {'content': 'Open-angle glaucoma', 'beginOffset': 5142} [{'entityId': 'UMLS/C0017612'}] 0.6590943336486816
# {'content': 'Osteoarthritis', 'beginOffset': 5162} [{'entityId': 'UMLS/C0029408'}] 0.9938689470291138
# {'content': 'Osteopenia', 'beginOffset': 5177} [{'entityId': 'UMLS/C0029453'}] 0.9969764947891235
# {'content': 'Osteoporosis', 'beginOffset': 5188} [{'entityId': 'UMLS/C0029456'}] 0.9978060126304626
# {'content': 'Otitis media', 'beginOffset': 5201} [{'entityId': 'UMLS/C0029882'}] 0.69643634557724
# {'content': 'Ovarian cancer', 'beginOffset': 5214} [{'entityId': 'UMLS/C1140680'}] 0.93442702293396
# {'content': 'Ovarian neoplasms', 'beginOffset': 5229} [{'entityId': 'UMLS/C0919267'}] 0.9034325480461121
# {'content': 'Ovarian neoplasms', 'beginOffset': 5247} [{'entityId': 'UMLS/C0919267'}] 0.8743011355400085
# {'content': 'neoplasms', 'beginOffset': 5265} [{'entityId': 'UMLS/C0027651'}] 0.4671545922756195
# {'content': 'solid tumor', 'beginOffset': 5275} [{'entityId': 'UMLS/C0280100'}] 0.5071318745613098
# {'content': 'hepatic impairment', 'beginOffset': 5287} [{'entityId': 'UMLS/C0948807'}] 0.9173752069473267
# {'content': 'Pain', 'beginOffset': 5306} [{'entityId': 'UMLS/C0030193'}] 0.9554914236068726
# {'content': 'inflammatory', 'beginOffset': 5312} [{'entityId': 'UMLS/C0021368'}] 0.9035119414329529
# {'content': 'Palmoplantar psoriasis', 'beginOffset': 5325} [{'entityId': 'UMLS/C4476828'}] 0.8877323865890503
# {'content': 'Pancreatic neuroendocrine tumor', 'beginOffset': 5348} [{'entityId': 'UMLS/C1337011'}] 0.8724398612976074
# {'content': 'Pancreatitis', 'beginOffset': 5387} [{'entityId': 'UMLS/C0030305'}] 0.9975430965423584
# {'content': 'necrotizing', 'beginOffset': 5407} [{'entityId': 'UMLS/C0021386'}, {'entityId': 'UMLS/C0027547'}, {'entityId': 'UMLS/C0037033'}, {'entityId': 'UMLS/C0234905'}, {'entityId': 'UMLS/C0235849'}] 0.8260169625282288
# {'content': 'Panic disorder', 'beginOffset': 5419} [{'entityId': 'UMLS/C0030319'}] 0.9936596751213074
# {'content': 'Papillomavirus infections', 'beginOffset': 5434} [{'entityId': 'UMLS/C0343641'}, {'entityId': 'UMLS/C0950124'}] 0.924296498298645
# {'content': 'Parkinson disease', 'beginOffset': 5460} [{'entityId': 'UMLS/C0030567'}, {'entityId': 'UMLS/C0242422'}] 0.9798182249069214
# {'content': "Parkinson's disease", 'beginOffset': 5478} [{'entityId': 'UMLS/C0030567'}] 0.9884582757949829
# {'content': 'dementia', 'beginOffset': 5498} [{'entityId': 'UMLS/C0497327'}] 0.9742258787155151
# {'content': 'Partial epilepsy', 'beginOffset': 5507} [{'entityId': 'UMLS/C0014547'}] 0.9747902154922485
# {'content': 'seizures', 'beginOffset': 5538} [{'entityId': 'UMLS/C0036572'}] 0.9748932123184204
# {'content': 'Peripheral neuropathic pain', 'beginOffset': 5547} [{'entityId': 'UMLS/C0027796'}, {'entityId': 'UMLS/C1850383'}, {'entityId': 'UMLS/C3714625'}] 0.9672938585281372
# {'content': 'Peripheral neuropathies', 'beginOffset': 5575} [{'entityId': 'UMLS/C0031117'}, {'entityId': 'UMLS/C4721453'}] 0.9523459076881409
# {'content': 'asthma', 'beginOffset': 5610} [{'entityId': 'UMLS/C0004096'}] 0.9781376719474792
# {'content': 'Pertussis', 'beginOffset': 5617} [{'entityId': 'UMLS/C0043167'}] 0.9696192145347595
# {'content': 'lymphoblastic leukemia', 'beginOffset': 5666} [{'entityId': 'UMLS/C0023449'}, {'entityId': 'UMLS/C1961102'}] 0.9761307835578918
# {'content': 'Plaque psoriasis', 'beginOffset': 5699} [{'entityId': 'UMLS/C0033860'}] 0.9187738299369812
# {'content': 'Pneumonia', 'beginOffset': 5716} [{'entityId': 'UMLS/C0032285'}] 0.8787767887115479
# {'content': 'community-acquired', 'beginOffset': 5727} [{'entityId': 'UMLS/C0206171'}, {'entityId': 'UMLS/C0694549'}] 0.5394260287284851
# {'content': 'Poliomyelitis', 'beginOffset': 5746} [{'entityId': 'UMLS/C0032371'}] 0.9956294298171997
# {'content': 'Post-polycythemia vera', 'beginOffset': 5760} [{'entityId': 'UMLS/C3805232'}] 0.6049031019210815
# {'content': 'myelofibrosis', 'beginOffset': 5783} [{'entityId': 'UMLS/C0001815'}, {'entityId': 'UMLS/C0026987'}] 0.9569092988967896
# {'content': 'Post-stroke spasticity', 'beginOffset': 5806} [{'entityId': 'UMLS/C0026838'}, {'entityId': 'UMLS/C0443306'}] 0.6428912878036499
# {'content': 'Post-traumatic stress disorder', 'beginOffset': 5829} [{'entityId': 'UMLS/C0038436'}] 0.9729318022727966
# {'content': 'Postherpetic neuralgia', 'beginOffset': 5860} [{'entityId': 'UMLS/C0032768'}] 0.918319046497345
# {'content': 'Postherpetic neuralgia', 'beginOffset': 5883} [{'entityId': 'UMLS/C0032768'}] 0.89091956615448
# {'content': 'phn', 'beginOffset': 5907} [{'entityId': 'UMLS/C0032768'}, {'entityId': 'UMLS/C3714958'}] 0.6377429366111755
# {'content': 'Postmenopausal osteoporosis', 'beginOffset': 5912} [{'entityId': 'UMLS/C0029458'}] 0.9678832292556763
# {'content': 'nausea', 'beginOffset': 5954} [{'entityId': 'UMLS/C0027497'}] 0.9676934480667114
# {'content': 'vomiting', 'beginOffset': 5965} [{'entityId': 'UMLS/C0042963'}] 0.975249707698822
# {'content': 'Postpartum hemorrhage', 'beginOffset': 5974} [{'entityId': 'UMLS/C0032797'}] 0.8291302919387817
# {'content': 'Premature ejaculation', 'beginOffset': 5996} [{'entityId': 'UMLS/C0033038'}] 0.8886998295783997
# {'content': 'Premature obstetric labour', 'beginOffset': 6018} [{'entityId': 'UMLS/C0022876'}] 0.7883340716362
# {'content': 'Premenstrual syndrome', 'beginOffset': 6045} [{'entityId': 'UMLS/C0033046'}] 0.9513306617736816
# {'content': 'cancer', 'beginOffset': 6076} [{'entityId': 'UMLS/C0006826'}] 0.9787277579307556
# {'content': 'Prostate neoplasms', 'beginOffset': 6083} [{'entityId': 'UMLS/C0033578'}] 0.5896082520484924
# {'content': 'Prostatic hyperplasia', 'beginOffset': 6102} [{'entityId': 'UMLS/C2937421'}] 0.9845764636993408
# {'content': 'Psoriasis', 'beginOffset': 6124} [{'entityId': 'UMLS/C0033860'}] 0.9937877655029297
# {'content': 'Psoriatic arthritis', 'beginOffset': 6134} [{'entityId': 'UMLS/C0003872'}] 0.9894298315048218
# {'content': 'Pulmonary arterial hypertension', 'beginOffset': 6154} [{'entityId': 'UMLS/C2973725'}, {'entityId': 'UMLS/C3203102'}] 0.9668148756027222
# {'content': 'Pulmonary edema', 'beginOffset': 6186} [{'entityId': 'UMLS/C0034063'}] 0.9390358924865723
# {'content': 'Pulmonary embolism', 'beginOffset': 6202} [{'entityId': 'UMLS/C0034065'}] 0.9707973003387451
# {'content': 'Pulmonary hypertension', 'beginOffset': 6221} [{'entityId': 'UMLS/C0020542'}] 0.9675173759460449
# {'content': 'partial seizures', 'beginOffset': 6255} [{'entityId': 'UMLS/C0751495'}] 0.8045617938041687
# {'content': 'multiple sclerosis', 'beginOffset': 6292} [{'entityId': 'UMLS/C0026769'}] 0.8914839029312134
# {'content': 'Renal cell carcinoma', 'beginOffset': 6311} [{'entityId': 'UMLS/C0007134'}] 0.9649246335029602
# {'content': 'Respiratory disorders', 'beginOffset': 6332} [{'entityId': 'UMLS/C0035204'}] 0.9615957140922546
# {'content': 'Respiratory syncytial virus infections', 'beginOffset': 6354} [{'entityId': 'UMLS/C0035235'}] 0.9763550162315369
# {'content': 'Respiratory tract infections', 'beginOffset': 6393} [{'entityId': 'UMLS/C0035243'}] 0.8086764216423035
# {'content': 'Restless legs syndrome', 'beginOffset': 6422} [{'entityId': 'UMLS/C0035258'}] 0.9633795022964478
# {'content': 'Retinal diseases', 'beginOffset': 6445} [{'entityId': 'UMLS/C0035309'}] 0.9018057584762573
# {'content': 'Retinopathy of prematurity', 'beginOffset': 6462} [{'entityId': 'UMLS/C0035344'}] 0.7919114828109741
# {'content': 'Rheumatoid arthritis', 'beginOffset': 6489} [{'entityId': 'UMLS/C0003873'}, {'entityId': 'UMLS/C0035436'}, {'entityId': 'UMLS/C5445125'}] 0.9818464517593384
# {'content': 'Rhinitis', 'beginOffset': 6510} [{'entityId': 'UMLS/C0035455'}] 0.9667232632637024
# {'content': 'Rhinitis', 'beginOffset': 6519} [{'entityId': 'UMLS/C0035455'}] 0.9460899829864502
# {'content': 'Rhinitis', 'beginOffset': 6549} [{'entityId': 'UMLS/C0035455'}] 0.942690908908844
# {'content': 'Rhinitis', 'beginOffset': 6592} [{'entityId': 'UMLS/C0035455'}] 0.937796413898468
# {'content': 'Rotavirus infections', 'beginOffset': 6621} [{'entityId': 'UMLS/C0035869'}] 0.8005362153053284
# {'content': 'Rubella', 'beginOffset': 6642} [{'entityId': 'UMLS/C0035920'}] 0.8262667655944824
# {'content': 'Schizophrenia', 'beginOffset': 6650} [{'entityId': 'UMLS/C0036341'}] 0.993815541267395
# {'content': 'Seborrheic dermatitis', 'beginOffset': 6664} [{'entityId': 'UMLS/C0036508'}] 0.9915899634361267
# {'content': 'thromboembolic events', 'beginOffset': 6710} [{'entityId': 'UMLS/C0040038'}] 0.8149985671043396
# {'content': 'Seizure disorder', 'beginOffset': 6732} [{'entityId': 'UMLS/C0014544'}] 0.9751774668693542
# {'content': 'generalized tonic clonic', 'beginOffset': 6749} [{'entityId': 'UMLS/C0494475'}] 0.7016390562057495
# {'content': 'Seizure', 'beginOffset': 6774} [{'entityId': 'UMLS/C0036572'}] 0.9038147926330566
# {'content': 'absence', 'beginOffset': 6783} [{'entityId': 'UMLS/C0002453'}, {'entityId': 'UMLS/C0003564'}, {'entityId': 'UMLS/C0014553'}, {'entityId': 'UMLS/C0220763'}, {'entityId': 'UMLS/C0231300'}] 0.45462605357170105
# {'content': 'Seizures', 'beginOffset': 6791} [{'entityId': 'UMLS/C0036572'}] 0.9812065958976746
# {'content': 'Sepsis', 'beginOffset': 6800} [{'entityId': 'UMLS/C0036690'}, {'entityId': 'UMLS/C0243026'}] 0.9965318441390991
# {'content': 'Shigella sonnei infection', 'beginOffset': 6807} [{'entityId': 'UMLS/C0036960'}, {'entityId': 'UMLS/C0302361'}] 0.6170640587806702
# {'content': 'Sickle cell disease', 'beginOffset': 6833} [{'entityId': 'UMLS/C0002895'}] 0.9886397123336792
# {'content': 'Sinusitis', 'beginOffset': 6853} [{'entityId': 'UMLS/C0037199'}] 0.9588559865951538
# {'content': "Sjoegren's syndrome", 'beginOffset': 6863} [{'entityId': 'UMLS/C0001519'}, {'entityId': 'UMLS/C0001529'}, {'entityId': 'UMLS/C0004352'}, {'entityId': 'UMLS/C0004763'}, {'entityId': 'UMLS/C0004775'}] 0.9706593751907349
# {'content': 'Sleep disorders', 'beginOffset': 6883} [{'entityId': 'UMLS/C0851578'}] 0.8923417925834656
# {'content': 'Sma', 'beginOffset': 6942} [{'entityId': 'UMLS/C0026847'}] 0.881077229976654
# {'content': 'spinal muscular atrophy', 'beginOffset': 6948} [{'entityId': 'UMLS/C0026847'}] 0.8080576062202454
# {'content': 'Small cell carcinoma', 'beginOffset': 6972} [{'entityId': 'UMLS/C0262584'}] 0.9117063283920288
# {'content': 'phobia', 'beginOffset': 7018} [{'entityId': 'UMLS/C0349231'}] 0.8035679459571838
# {'content': 'sarcoma', 'beginOffset': 7037} [{'entityId': 'UMLS/C1261473'}] 0.9807146787643433
# {'content': 'tumor cancer', 'beginOffset': 7051} [{'entityId': 'UMLS/C0006826'}] 0.8603386878967285
# {'content': 'metastases', 'beginOffset': 7074} [{'entityId': 'UMLS/C0027627'}, {'entityId': 'UMLS/C4255448'}] 0.9746105074882507
# {'content': 'tumours', 'beginOffset': 7091} [{'entityId': 'UMLS/C0027651'}] 0.8833367228507996
# {'content': 'Spondyloarthritis', 'beginOffset': 7099} [{'entityId': 'UMLS/C0949690'}] 0.9935289025306702
# {'content': 'Staphylococcal infections', 'beginOffset': 7117} [{'entityId': 'UMLS/C0038160'}] 0.8457990288734436
# {'content': 'Streptococcal infections', 'beginOffset': 7143} [{'entityId': 'UMLS/C0038395'}] 0.8146320581436157
# {'content': 'Streptococcus agalactiae', 'beginOffset': 7168} [{'entityId': 'UMLS/C0579233'}] 0.9180136919021606
# {'content': 'Streptococcus pneumoniae', 'beginOffset': 7193} [{'entityId': 'UMLS/C0038410'}] 0.8696264028549194
# {'content': 'juvenile idiopathic arthritis', 'beginOffset': 7248} [{'entityId': 'UMLS/C3495559'}] 0.7724481225013733
# {'content': 'sjia', 'beginOffset': 7279} [{'entityId': 'UMLS/C1384600'}] 0.8077211976051331
# {'content': 'Systemic lupus erythematosus', 'beginOffset': 7285} [{'entityId': 'UMLS/C0024141'}] 0.8074948787689209
# {'content': 'Systemic scleroderma', 'beginOffset': 7314} [{'entityId': 'UMLS/C0036421'}] 0.781898558139801
# {'content': 'injuries', 'beginOffset': 7342} [{'entityId': 'UMLS/C3263723'}] 0.9260378479957581
# {'content': 'Thromboembolism', 'beginOffset': 7403} [{'entityId': 'UMLS/C0040038'}] 0.7950782775878906
# {'content': 'Thrombosis', 'beginOffset': 7419} [{'entityId': 'UMLS/C0040053'}, {'entityId': 'UMLS/C0087086'}, {'entityId': 'UMLS/C0302148'}, {'entityId': 'UMLS/C1654047'}] 0.9905001521110535
# {'content': 'cancer', 'beginOffset': 7446} [{'entityId': 'UMLS/C0006826'}] 0.9876419305801392
# {'content': 'Tinnitus', 'beginOffset': 7453} [{'entityId': 'UMLS/C0040264'}] 0.901023268699646
# {'content': 'Tonic-clonic epilepsy', 'beginOffset': 7483} [{'entityId': 'UMLS/C0014549'}] 0.8496320843696594
# {'content': 'Tooth erosion', 'beginOffset': 7505} [{'entityId': 'UMLS/C0040436'}] 0.7058492302894592
# {'content': 'Toxoplasmosis', 'beginOffset': 7519} [{'entityId': 'UMLS/C0040558'}] 0.9701510667800903
# {'content': 'Transient ischaemic attack', 'beginOffset': 7533} [{'entityId': 'UMLS/C0007787'}] 0.9630174040794373
# {'content': 'Tumors', 'beginOffset': 7643} [{'entityId': 'UMLS/C0027651'}, {'entityId': 'UMLS/C3273930'}] 0.8472809791564941
# {'content': 'genetic abnormalities', 'beginOffset': 7667} [{'entityId': 'UMLS/C0262496'}, {'entityId': 'UMLS/C1704257'}] 0.6918132901191711
# {'content': 'Type 1 diabetes mellitus', 'beginOffset': 7696} [{'entityId': 'UMLS/C0011854'}] 0.988521158695221
# {'content': 'Type 2 diabetes', 'beginOffset': 7721} [{'entityId': 'UMLS/C0011860'}] 0.9923480153083801
# {'content': 'Type 2 diabetes mellitus', 'beginOffset': 7737} [{'entityId': 'UMLS/C0011860'}] 0.9885426163673401
# {'content': 'Typhoid fever', 'beginOffset': 7762} [{'entityId': 'UMLS/C0041466'}] 0.7342177033424377
# {'content': 'Ulcers', 'beginOffset': 7776} [{'entityId': 'UMLS/C0041582'}, {'entityId': 'UMLS/C3887532'}] 0.9558594822883606
# {'content': 'asthma', 'beginOffset': 7818} [{'entityId': 'UMLS/C0004096'}] 0.9779005646705627
# {'content': 'Urinary incontinence', 'beginOffset': 7853} [{'entityId': 'UMLS/C0042024'}] 0.9727580547332764
# {'content': 'Urologic diseases', 'beginOffset': 7874} [{'entityId': 'UMLS/C0042075'}] 0.96513432264328
# {'content': 'Urticaria', 'beginOffset': 7892} [{'entityId': 'UMLS/C0042109'}] 0.8621531128883362
# {'content': 'Varicella', 'beginOffset': 7902} [{'entityId': 'UMLS/C0008049'}, {'entityId': 'UMLS/C0042338'}] 0.7675464749336243
# {'content': 'Vascular disease', 'beginOffset': 7912} [{'entityId': 'UMLS/C0042373'}] 0.9384188652038574
# {'content': 'Vasculitis', 'beginOffset': 7941} [{'entityId': 'UMLS/C0042384'}] 0.9525485038757324
# {'content': 'Vasomotor rhinitis', 'beginOffset': 7952} [{'entityId': 'UMLS/C0035460'}] 0.7778730392456055
# {'content': 'Virus diseases', 'beginOffset': 7971} [{'entityId': 'UMLS/C0042769'}] 0.7899982333183289
# {'content': 'Vomiting', 'beginOffset': 7986} [{'entityId': 'UMLS/C0042963'}] 0.6651278734207153
# {'content': 'macular degeneration', 'beginOffset': 8011} [{'entityId': 'UMLS/C0024437'}, {'entityId': 'UMLS/C0242383'}] 0.9337819218635559
# {'content': 'amd', 'beginOffset': 8033} [{'entityId': 'UMLS/C0017921'}, {'entityId': 'UMLS/C0242383'}] 0.4136495590209961
# {'content': 'Whole cell pertussis', 'beginOffset': 8038} [{'entityId': 'UMLS/C0043167'}] 0.8755202293395996
# {'content': 'Wound', 'beginOffset': 8059} [{'entityId': 'UMLS/C0043250'}, {'entityId': 'UMLS/C3263723'}] 0.7082890868186951

# %%
test_text
# Out:
# "AIDS;Acellular pertussis;Acne vulgaris;Acute coronary syndrome;Acute lung injury;Acute myelocytic leukaemia;Acute myeloid leukemia;Acute sinusitis;Adrenocortical carcinoma;Advanced breast cancer;Advanced gastric cancer;Alcoholism;Allergic conjunctivitis;Alopecia;Alzheimer's disease;Amyloidosis;Anaemia;Analgesia;Ankylosing spondylitis;Anxiety disorders;Asthma;Asthma and rhinitis;Atherosclerosis;Atopic dermatitis;Atrial fibrillation;Attention deficit hyperactivity disorder (adhd);Autoimmune diseases;B-cell acute lymphoblastic leukemia, relapsed b-cell acute lymphoblastic leukemia, refractory b-cell acute lymphoblastic leukemia;Bacillary dysentery;Bacterial infections;Bacterial skin infections;Bipolar disorder;Bipolar i disorder;Bladder pain;Brain metastases;Breast cancer;Breast neoplasms;Bronchial constriction;Bronchial hyperreactivity;Bronchiectasis;Bronchospasm;Cachexia;Cancer;Cancer|neoplasms;Carcinoid tumor;Cardiac arrhythmia;Cardiovascular disease;Cataract;Cerebrovascular accident;Cervical intraepithelial neoplasia;Chemotherapy-induced nausea and vomiting;Cholestasis;Chronic Obstructive Airway Disease;Chronic bronchitis;Chronic constipation;Chronic dermatitis;Chronic idiopathic urticaria (ciu);Chronic lymphocytic leukaemia;Chronic lymphocytic leukemia (cll);Chronic myelogenous leukemia;Chronic myeloid leukemia (cml);Chronic obstructive pulmonary disease (copd);Chronic plaque psoriasis;Clostridium difficile infection;Cognitive disorders;Colitis, ulcerative;Colorectal Neoplasms;Congestive heart failure;Congestive heart failure and microalbuminuria heart failure;Coronary artery disease;Corticosteroid refractory acute graft vs host disease;Cough;Crohn's disease;Cystic fibrosis;Dementia;Dentin sensitivity;Denture retention;Depressive disorder;Depressive disorder and anxiety disorders;Dermatologic disorders;Diabetes mellitus;Diabetic kidney disease;Diabetic macular edema;Diabetic neuropathic pain;Diabetic neuropathy;Diabetic retinopathy;Diphtheria;Drug-related side effects and adverse reactions;Dyslipidaemias;Eczema;Embryo transfer;Endometriosis;Eosinophilic asthma;Eosinophilic esophagitis;Epilepsy;Episodic migraine headache;Esophageal cancer;Fascioliasis;Fibromyalgia syndrome, primary;Focal infection, dental;Follicular lymphoma;Fracture healing;Gastrointestinal Neoplasms;Gastrointestinal diseases;Gastrointestinal motility;Gastroparesis;Geographic atrophy;Gonorrhea;H1N1 subtype influenza A virus;Haemophilus influenzae type b;Head neoplasms and neck neoplasms;Heart failure;Heart failure with preserved ejection fraction;Heart failure, chronic (chf);Hepatitis a;Hepatitis b;Hepatitis b, chronic;Hepatitis c;Hepatitis c, chronic;Hepatocellular carcinoma;Hepatocellular carcinoma (hcc);Her2-negative metastatic breast cancer;Her2/neu over-expressing locally advanced breast cancer or metastatic breast cancer;Hereditary periodic fevers;Herpes genitalis;Herpes labialis;Herpes simplex infection;Herpes zoster;Herpesviridae infections;Hip fracture;Hiv infections;Human immunodeficiency virus infection;Human immunodeficiency virus infection and herpesviridae infections;Huntington disease;Hypercholesterolemia;Hypereosinophilic syndrome;Hyperhidrosis;Hypertension;Hypertriglyceridemia;Hypogonadism, male;Idiopathic pulmonary fibrosis;Idiopathic thrombocytopenic purpura;Impetigo;Inflammatory bowel diseases;Influenza;Insulin resistance;Intrahepatic cholestasis;Invasive aspergillosis / invasive mucormycosis;Invasive candidiasis;Invasive fungal infection;Invasive fungal infections;Irritable bowel syndrome;Juvenile psoriatic arthritis, enthesitis-related arthritis;Left ventricular hypertrophy;Lennox-gastaut syndrome;Liver diseases;Lower urinary tract symptoms / benign prostatic hyperplasia;Lung injury, acute and respiratory distress syndrome, adult;Lupus erythematosus, cutaneous;Lupus nephritis;Major depressive disorder;Malaria;Malaria, falciparum;Malaria, vivax;Male osteoporosis;Mantle-cell lymphoma;Mastocytosis;Measles;Measles, mumps, rubella;Melanoma; ...

# %%
test_text[5161:5169]
# Out:
# ';Osteoar'

# %%
offset_text
# Out:
# [(0, 5, 'AIDS'),
#  (5, 25, 'Acellular pertussis'),
#  (25, 39, 'Acne vulgaris'),
#  (39, 63, 'Acute coronary syndrome'),
#  (63, 81, 'Acute lung injury'),
#  (81, 108, 'Acute myelocytic leukaemia'),
#  (108, 131, 'Acute myeloid leukemia'),
#  (131, 147, 'Acute sinusitis'),
#  (147, 172, 'Adrenocortical carcinoma'),
#  (172, 195, 'Advanced breast cancer'),
#  (195, 219, 'Advanced gastric cancer'),
#  (219, 230, 'Alcoholism'),
#  (230, 254, 'Allergic conjunctivitis'),
#  (254, 263, 'Alopecia'),
#  (263, 283, "Alzheimer's disease"),
#  (283, 295, 'Amyloidosis'),
#  (295, 303, 'Anaemia'),
#  (303, 313, 'Analgesia'),
#  (313, 336, 'Ankylosing spondylitis'),
#  (336, 354, 'Anxiety disorders'),
#  (354, 361, 'Asthma'),
#  (361, 381, 'Asthma and rhinitis'),
#  (381, 397, 'Atherosclerosis'),
#  (397, 415, 'Atopic dermatitis'),
#  (415, 435, 'Atrial fibrillation'),
#  (435, 483, 'Attention deficit hyperactivity disorder (adhd)'),
#  (483, 503, 'Autoimmune diseases'),
#  (503,
#   633,
#   'B-cell acute lymphoblastic leukemia, relapsed b-cell acute lymphoblastic leukemia, refractory b-cell acute lymphoblastic leukemia'),
#  (633, 653, 'Bacillary dysentery'),
#  (653, 674, 'Bacterial infections'),
#  (674, 700, 'Bacterial skin infections'),
#  (700, 717, 'Bipolar disorder'),
#  (717, 736, 'Bipolar i disorder'),
#  (736, 749, 'Bladder pain'),
#  (749, 766, 'Brain metastases'),
#  (766, 780, 'Breast cancer'),
#  (780, 797, 'Breast neoplasms'),
#  (797, 820, 'Bronchial constriction'),
#  (820, 846, 'Bronchial hyperreactivity'),
#  (846, 861, 'Bronchiectasis'),
#  (861, 874, 'Bronchospasm'),
#  (874, 883, 'Cachexia'),
#  (883, 890, 'Cancer'),
#  (890, 907, 'Cancer|neoplasms'),
#  (907, 923, 'Carcinoid tumor'),
#  (923, 942, 'Cardiac arrhythmia'),
#  (942, 965, 'Cardiovascular disease'),
#  (965, 974, 'Cataract'),
#  (974, 999, 'Cerebrovascular accident'),
#  (999, 1034, 'Cervical intraepithelial neoplasia'),
#  (1034, 1075, 'Chemotherapy-induced nausea and vomiting'),
#  (1075, 1087, 'Cholestasis'),
#  (1087, 1122, 'Chronic Obstructive Airway Disease'),
#  (1122, 1141, 'Chronic bronchitis'),
#  (1141, 1162, 'Chronic constipation'),
#  (1162, 1181, 'Chronic dermatitis'),
#  (1181, 1216, 'Chronic idiopathic urticaria (ciu)'),
#  (1216, 1246, 'Chronic lymphocytic leukaemia'),
#  (1246, 1281, 'Chronic lymphocytic leukemia (cll)'),
#  (1281, 1310, 'Chronic myelogenous leukemia'),
#  (1310, 1341, 'Chronic myeloid leukemia (cml)'),
#  (1341, 1386, 'Chronic obstructive pulmonary disease (copd)'),
#  (1386, 1411, 'Chronic plaque psoriasis'),
#  (1411, 1443, 'Clostridium difficile infection'),
#  (1443, 1463, 'Cognitive disorders'),
#  (1463, 1483, 'Colitis, ulcerative'),
#  (1483, 1504, 'Colorectal Neoplasms'),
#  (1504, 1529, 'Congestive heart failure'),
#  (1529, 1589, 'Congestive heart failure and microalbuminuria heart failure'),
#  (1589, 1613, 'Coronary artery disease'),
#  (1613, 1667, 'Corticosteroid refractory acute graft vs host disease'),
#  (1667, 1673, 'Cough'),
#  (1673, 1689, "Crohn's disease"),
#  (1689, 1705, 'Cystic fibrosis'),
#  (1705, 1714, 'Dementia'),
#  (1714, 1733, 'Dentin sensitivity'),
#  (1733, 1751, 'Denture retention'),
#  (1751, 1771, 'Depressive disorder'),
#  (1771, 1813, 'Depressive disorder and anxiety disorders'),
#  (1813, 1836, 'Dermatologic disorders'),
#  (1836, 1854, 'Diabetes mellitus'),
#  (1854, 1878, 'Diabetic kidney disease'),
#  (1878, 1901, 'Diabetic macular edema'),
#  (1901, 1927, 'Diabetic neuropathic pain'),
#  (1927, 1947, 'Diabetic neuropathy'),
#  (1947, 1968, 'Diabetic retinopathy'),
#  (1968, 1979, 'Diphtheria'),
#  (1979, 2027, 'Drug-related side effects and adverse reactions'),
#  (2027, 2042, 'Dyslipidaemias'),
#  (2042, 2049, 'Eczema'),
#  (2049, 2065, 'Embryo transfer'),
#  (2065, 2079, 'Endometriosis'),
#  (2079, 2099, 'Eosinophilic asthma'),
#  (2099, 2124, 'Eosinophilic esophagitis'),
#  (2124, 2133, 'Epilepsy'),
#  (2133, 2160, 'Episodic migraine headache'),
#  (2160, 2178, 'Esophageal cancer'),
#  (2178, 2191, 'Fascioliasis'),
#  (2191, 2222, 'Fibromyalgia syndrome, primary'),
#  (2222, 2246, 'Focal infection, dental'),
#  (2246, 2266, 'Follicular lymphoma'),
#  (2266, 2283, 'Fracture healing'),
#  (2283, 2310, 'Gastrointestinal Neoplasms'),
#  (2310, 2336, 'Gastrointestinal diseases'),
#  (2336, 2362, 'Gastrointestinal motility'),
#  (2362, 2376, 'Gastroparesis'),
#  (2376, 2395, 'Geographic atrophy'),
#  (2395, 2405, 'Gonorrhea'),
#  (2405, 2436, 'H1N1 subtype influenza A virus'),
#  (2436, 2466, 'Haemophilus influenzae type b'),
#  (2466, 2500, 'Head neoplasms and neck neoplasms'),
#  (2500, 2514, 'Heart failure'),
#  (2514, 2561, 'Heart failure with preserved ejection fraction'),
#  (2561, 2590, 'Heart failure, chronic (chf)'),
#  (2590, 2602, 'Hepatitis a'),
#  (2602, 2614, 'Hepatitis b'),
#  (2614, 2635, 'Hepatitis b, chronic'),
#  (2635, 2647, 'Hepatitis c'),
#  (2647, 2668, 'Hepatitis c, chronic'),
#  (2668, 2693, 'Hepatocellular carcinoma'),
#  (2693, 2724, 'Hepatocellular carcinoma (hcc)'),
#  (2724, 2763, 'Her2-negative metastatic breast cancer'),
#  (2763,
#   2847,
#   'Her2/neu over-expressing locally advanced breast cancer or metastatic breast cancer'),
#  (2847, 2874, 'Hereditary periodic fevers'),
#  (2874, 2891, 'Herpes genitalis'),
#  (2891, 2907, 'Herpes labialis'),
#  (2907, 2932, 'Herpes simplex infection'),
#  (2932, 2946, 'Herpes zoster'),
#  (2946, 2971, 'Herpesviridae infections'),
#  (2971, 2984, 'Hip fracture'),
#  (2984, 2999, 'Hiv infections'),
#  (2999, 3038, 'Human immunodeficiency virus infection'),
#  (3038,
#   3106,
#   'Human immunodeficiency virus infection and herpesviridae infections'),
#  (3106, 3125, 'Huntington disease'),
#  (3125, 3146, 'Hypercholesterolemia'),
#  (3146, 3173, 'Hypereosinophilic syndrome'),
#  (3173, 3187, 'Hyperhidrosis'),
#  (3187, 3200, 'Hypertension'),
#  (3200, 3221, 'Hypertriglyceridemia'),
#  (3221, 3240, 'Hypogonadism, male'),
#  (3240, 3270, 'Idiopathic pulmonary fibrosis'),
#  (3270, 3306, 'Idiopathic thrombocytopenic purpura'),
#  (3306, 3315, 'Impetigo'),
#  (3315, 3343, 'Inflammatory bowel diseases'),
#  (3343, 3353, 'Influenza'),
#  (3353, 3372, 'Insulin resistance'),
#  (3372, 3397, 'Intrahepatic cholestasis'),
#  (3397, 3444, 'Invasive aspergillosis / invasive mucormycosis'),
#  (3444, 3465, 'Invasive candidiasis'),
#  (3465, 3491, 'Invasive fungal infection'),
#  (3491, 3518, 'Invasive fungal infections'),
#  (3518, 3543, 'Irritable bowel syndrome'),
#  (3543, 3602, 'Juvenile psoriatic arthritis, enthesitis-related arthritis'),
#  (3602, 3631, 'Left ventricular hypertrophy'),
#  (3631, 3655, 'Lennox-gastaut syndrome'),
#  (3655, 3670, 'Liver diseases'),
#  (3670, 3730, 'Lower urinary tract symptoms / benign prostatic hyperplasia'),
#  (3730, 3790, 'Lung injury, acute and respiratory distress syndrome, adult'),
#  (3790, 3821, 'Lupus erythematosus, cutaneous'),
#  (3821, 3837, 'Lupus nephritis'),
#  (3837, 3863, 'Major depressive disorder'),
#  (3863, 3871, 'Malaria'),
#  (3871, 3891, 'Malaria, falciparum'),
#  (3891, 3906, 'Malaria, vivax'),
#  (3906, 3924, 'Male osteoporosis'),
#  (3924, 3945, 'Mantle-cell lymphoma'),
#  (3945, 3958, 'Mastocytosis'),
#  (3958, 3966, 'Measles'),
#  (3966, 3990, 'Measles, mumps, rubella'),
#  (3990, 3999, 'Melanoma'),
#  (3999, 4025, 'Meningitis, meningococcal'),
#  (4025, 4047, 'Meningococcal disease'),
#  (4047, 4072, 'Meningococcal infections'),
#  (4072, 4089, 'Mental disorders'),
#  (4089, 4110, 'Metabolic syndrome x'),
#  (4110, 4135, 'Metastatic breast cancer'),
#  (4135, 4155, 'Metastatic melanoma'),
#  (4155, 4187, 'Metastatic renal cell carcinoma'),
#  (4187, 4228, 'Metastatic triple-negative breast cancer'),
#  (4228, 4246, 'Midline carcinoma'),
#  (4246, 4255, 'Migraine'),
#  (4255, 4274, 'Migraine disorders'),
#  (4274, 4319, 'Migraine disorders and premenstrual syndrome'),
#  (4319, 4342, 'Migraine, without aura'),
#  (4342, 4376, 'Mild asthma and allergic rhinitis'),
#  (4376, 4406, 'Moderate to severe acute pain'),
#  (4406, 4451, 'Moderate to severe acute post-operative pain'),
#  (4451, 4500, 'Moderate to severe chronic plaque-type psoriasis'),
#  (4500, 4535, 'Moderate to severe scalp psoriasis'),
#  (4535, 4550, 'Mood disorders'),
#  (4550, 4572, 'Multiple myeloma (mm)'),
#  (4572, 4591, 'Multiple sclerosis'),
#  (4591, 4597, 'Mumps'),
#  (4597, 4612, 'Muscle atrophy'),
#  (4612, 4629, 'Muscular atrophy'),
#  (4629, 4647, 'Myasthenia gravis'),
#  (4647, 4655, 'Mycoses'),
#  (4655, 4686, 'Myelodysplastic syndrome (mds)'),
#  (4686, 4700, 'Myelofibrosis'),
#  (4700, 4715, 'Nail psoriasis'),
#  (4715, 4728, 'Nasal polyps'),
#  (4728, 4751, 'Neisseria meningitidis'),
#  (4751, 4761, 'Neoplasms'),
#  (4761, 4786, 'Neoplasms|lung neoplasms'),
#  (4786, 4831, 'Neovascular age-related macular degeneration'),
#  (4831, 4859, 'Neuroendocrine tumors (net)'),
#  (4859, 4892, 'Neurogenic detrusor overactivity'),
#  (4892, 4909, 'Neuropathic pain'),
#  (4909, 4930, 'Non-hodgkin lymphoma'),
#  (4930, 4965, 'Non-radiographic spondyloarthritis'),
#  (4965, 4992, 'Non-small cell lung cancer'),
#  (4992, 5030, 'Non-small cell lung carcinoma (nsclc)'),
#  (5030, 5038, 'Obesity'),
#  (5038, 5068, 'Obsessive-compulsive disorder'),
#  (5068, 5122, 'Obsessive-compulsive disorder and depressive disorder'),
#  (5122, 5142, 'Ocular hypertension'),
#  (5142, 5162, 'Open-angle glaucoma'),
#  (5162, 5177, 'Osteoarthritis'),
#  (5177, 5188, 'Osteopenia'),
#  (5188, 5201, 'Osteoporosis'),
#  (5201, 5214, 'Otitis media'),
#  (5214, 5229, 'Ovarian cancer'),
#  (5229, 5247, 'Ovarian neoplasms'),
#  (5247, 5306, 'Ovarian neoplasms|neoplasms|solid tumor|hepatic impairment'),
#  (5306, 5325, 'Pain, inflammatory'),
#  (5325, 5348, 'Palmoplantar psoriasis'),
#  (5348, 5387, 'Pancreatic neuroendocrine tumor (pnet)'),
#  (5387, 5419, 'Pancreatitis, acute necrotizing'),
#  (5419, 5434, 'Panic disorder'),
#  (5434, 5460, 'Papillomavirus infections'),
#  (5460, 5478, 'Parkinson disease'),
#  (5478, 5507, "Parkinson's disease dementia"),
#  (5507, 5524, 'Partial epilepsy'),
#  (5524, 5547, 'Partial onset seizures'),
#  (5547, 5575, 'Peripheral neuropathic pain'),
#  (5575, 5599, 'Peripheral neuropathies'),
#  (5599, 5617, 'Persistent asthma'),
#  (5617, 5627, 'Pertussis'),
#  (5627,
#   5699,
#   'Philadelphia chromosome positive acute lymphoblastic leukemia (ph+ all)'),
#  (5699, 5716, 'Plaque psoriasis'),
#  (5716, 5746, 'Pneumonia, community-acquired'),
#  (5746, 5760, 'Poliomyelitis'),
#  (5760, 5806, 'Post-polycythemia vera myelofibrosis (ppv-mf)'),
#  (5806, 5829, 'Post-stroke spasticity'),
#  (5829, 5860, 'Post-traumatic stress disorder'),
#  (5860, 5883, 'Postherpetic neuralgia'),
#  (5883, 5912, 'Postherpetic neuralgia (phn)'),
#  (5912, 5940, 'Postmenopausal osteoporosis'),
#  (5940, 5974, 'Postoperative nausea and vomiting'),
#  (5974, 5996, 'Postpartum hemorrhage'),
#  (5996, 6018, 'Premature ejaculation'),
#  (6018, 6045, 'Premature obstetric labour'),
#  (6045, 6067, 'Premenstrual syndrome'),
#  (6067, 6083, 'Prostate cancer'),
#  (6083, 6102, 'Prostate neoplasms'),
#  (6102, 6124, 'Prostatic hyperplasia'),
#  (6124, 6134, 'Psoriasis'),
#  (6134, 6154, 'Psoriatic arthritis'),
#  (6154, 6186, 'Pulmonary arterial hypertension'),
#  (6186, 6202, 'Pulmonary edema'),
#  (6202, 6221, 'Pulmonary embolism'),
#  (6221, 6244, 'Pulmonary hypertension'),
#  (6244, 6272, 'Refractory partial seizures'),
#  (6272, 6311, 'Relapsing-remitting multiple sclerosis'),
#  (6311, 6332, 'Renal cell carcinoma'),
#  (6332, 6354, 'Respiratory disorders'),
#  (6354, 6393, 'Respiratory syncytial virus infections'),
#  (6393, 6422, 'Respiratory tract infections'),
#  (6422, 6445, 'Restless legs syndrome'),
#  (6445, 6462, 'Retinal diseases'),
#  (6462, 6489, 'Retinopathy of prematurity'),
#  (6489, 6510, 'Rheumatoid arthritis'),
#  (6510, 6519, 'Rhinitis'),
#  (6519, 6549, 'Rhinitis, allergic, perennial'),
#  (6549, 6592, 'Rhinitis, allergic, perennial and seasonal'),
#  (6592, 6621, 'Rhinitis, allergic, seasonal'),
#  (6621, 6642, 'Rotavirus infections'),
#  (6642, 6650, 'Rubella'),
#  (6650, 6664, 'Schizophrenia'),
#  (6664, 6686, 'Seborrheic dermatitis'),
#  (6686, 6732, 'Secondary prevention of thromboembolic events'),
#  (6732, 6774, 'Seizure disorder generalized tonic clonic'),
#  (6774, 6791, 'Seizure, absence'),
#  (6791, 6800, 'Seizures'),
#  (6800, 6807, 'Sepsis'),
#  (6807, 6833, 'Shigella sonnei infection'),
#  (6833, 6853, 'Sickle cell disease'),
#  (6853, 6863, 'Sinusitis'),
#  (6863, 6883, "Sjoegren's syndrome"),
#  (6883, 6899, 'Sleep disorders'),
#  (6899, 6942, 'Sleep initiation and maintenance disorders'),
#  (6942, 6972, 'Sma - spinal muscular atrophy'),
#  (6972, 6993, 'Small cell carcinoma'),
#  (6993, 7011, 'Smoking cessation'),
#  (7011, 7025, 'Social phobia'),
#  (7025, 7045, 'Soft tissue sarcoma'),
#  (7045, 7085, 'Solid tumor cancer with bone metastases'),
#  (7085, 7099, 'Solid tumours'),
#  (7099, 7117, 'Spondyloarthritis'),
#  (7117, 7143, 'Staphylococcal infections'),
#  (7143, 7168, 'Streptococcal infections'),
#  (7168, 7193, 'Streptococcus agalactiae'),
#  (7193, 7218, 'Streptococcus pneumoniae'),
#  (7218, 7239, 'Substance dependence'),
#  (7239, 7285, 'Systemic juvenile idiopathic arthritis (sjia)'),
#  (7285, 7314, 'Systemic lupus erythematosus'),
#  (7314, 7335, 'Systemic scleroderma'),
#  (7335, 7351, 'Tendon injuries'),
#  (7351, 7359, 'Tetanus'),
#  (7359, 7403, 'Therapeutic treatment of inhalation anthrax'),
#  (7403, 7419, 'Thromboembolism'),
#  (7419, 7438, 'Thrombosis, venous'),
#  (7438, 7453, 'Thyroid cancer'),
#  (7453, 7462, 'Tinnitus'),
#  (7462, 7483, 'Tobacco use disorder'),
#  (7483, 7505, 'Tonic-clonic epilepsy'),
#  (7505, 7519, 'Tooth erosion'),
#  (7519, 7533, 'Toxoplasmosis'),
#  (7533, 7560, 'Transient ischaemic attack'),
#  (7560, 7584, 'Transplantation, kidney'),
#  (7584, 7607, 'Transplantation, liver'),
#  (7607, 7630, 'Transplantation, organ'),
#  (7630, 7643, 'Tuberculosis'),
#  (7643, 7696, 'Tumors characterized by genetic abnormalities of alk'),
#  (7696, 7721, 'Type 1 diabetes mellitus'),
#  (7721, 7737, 'Type 2 diabetes'),
#  (7737, 7762, 'Type 2 diabetes mellitus'),
#  (7762, 7776, 'Typhoid fever'),
#  (7776, 7805, 'Ulcers, duodenal and gastric'),
#  (7805, 7825, 'Uncontrolled asthma'),
#  (7825, 7853, 'Urinary bladder, overactive'),
#  (7853, 7874, 'Urinary incontinence'),
#  (7874, 7892, 'Urologic diseases'),
#  (7892, 7902, 'Urticaria'),
#  (7902, 7912, 'Varicella'),
#  (7912, 7941, 'Vascular disease, peripheral'),
#  (7941, 7952, 'Vasculitis'),
#  (7952, 7971, 'Vasomotor rhinitis'),
#  (7971, 7986, 'Virus diseases'),
#  (7986, 7995, 'Vomiting'),
#  (7995, 8038, 'Wet age related macular degeneration (amd)'),
#  (8038, 8059, 'Whole cell pertussis'),
#  (8059, 8073, 'Wound healing')]

# %% [markdown]
# GCP healthcare NLP requires at least 10 characters

# %%
with open('condition_gcp_ner.jsonl', 'w') as f:
    f.write(content)

# %%
condition_gcp_nlp = {}

with open('condition_gcp_ner.jsonl', 'r') as json_file:
    for line in json_file.readlines():
        obj = json.loads(line)
        condition_gcp_nlp[list(obj.keys())[0]] = list(obj.values())[0]

condition_gcp_nlp
# Out:
# {'AIDS': [{'preferredTerms': 'Acquired Immunodeficiency Syndrome',
#    'entityids': 'UMLS/C0001175',
#    'HPO': [],
#    'MSH': ['MSH/D000163'],
#    'RXNORM': []}],
#  'Acellular pertussis': [{'preferredTerms': 'Pertussis',
#    'entityids': 'UMLS/C0043167',
#    'HPO': [],
#    'MSH': ['MSH/D014917'],
#    'RXNORM': []}],
#  'Acne vulgaris': [{'preferredTerms': 'Acne Vulgaris',
#    'entityids': 'UMLS/C0001144',
#    'HPO': [],
#    'MSH': ['MSH/D000152'],
#    'RXNORM': []}],
#  'Acute coronary syndrome': [{'preferredTerms': 'Acute Coronary Syndrome',
#    'entityids': 'UMLS/C0948089',
#    'HPO': ['HPO/HP:0033678'],
#    'MSH': ['MSH/D054058'],
#    'RXNORM': []}],
#  'Acute lung injury': [{'preferredTerms': 'Traumatic injury',
#    'entityids': 'UMLS/C3263723',
#    'HPO': [],
#    'MSH': ['MSH/D014947'],
#    'RXNORM': []}],
#  'Acute myelocytic leukaemia': [{'preferredTerms': 'Leukemia, Myelocytic, Acute',
#    'entityids': 'UMLS/C0023467',
#    'HPO': ['HPO/HP:0004808'],
#    'MSH': ['MSH/D015470'],
#    'RXNORM': []}],
#  'Acute myeloid leukemia': [{'preferredTerms': 'Leukemia, Myelocytic, Acute',
#    'entityids': 'UMLS/C0023467',
#    'HPO': ['HPO/HP:0004808'],
#    'MSH': ['MSH/D015470'],
#    'RXNORM': []}],
#  'Acute sinusitis': [{'preferredTerms': 'Sinusitis',
#    'entityids': 'UMLS/C0037199',
#    'HPO': ['HPO/HP:0000246'],
#    'MSH': ['MSH/D012852'],
#    'RXNORM': []}],
#  'Adrenocortical carcinoma': [{'preferredTerms': 'Adrenocortical carcinoma',
#    'entityids': 'UMLS/C0206686',
#    'HPO': ['HPO/HP:0006744'],
#    'MSH': ['MSH/D018268'],
#    'RXNORM': []}],
#  'Advanced breast cancer': [{'preferredTerms': 'Malignant Neoplasms',
#    'entityids': 'UMLS/C0006826',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Advanced gastric cancer': [{'preferredTerms': 'Malignant neoplasm of stomach',
#    'entityids': 'UMLS/C0024623',
#    'HPO': ['HPO/HP:0012126'],
#    'MSH': ['MSH/D013274'],
#    'RXNORM': []}],
#  'Alcoholism': [{}],
#  'Allergic conjunctivitis': [{'preferredTerms': 'Allergic Conjunctivitis',
#    'entityids': 'UMLS/C0009766',
#    'HPO': ['HPO/HP:0007879'],
#    'MSH': ['MSH/D003233'],
#    'RXNORM': []}],
#  'Alopecia': [{'preferredTerms': 'Alopecia',
#    'entityids': 'UMLS/C0002170',
#    'HPO': ['HPO/HP:0001596', 'HPO/HP:0002293'],
#    'MSH': ['MSH/D000505'],
#    'RXNORM': []}],
#  "Alzheimer's disease": [{'preferredTerms': "Alzheimer's Disease",
#    'entityids': 'UMLS/C0002395',
#    'HPO': ['HPO/HP:0002511'],
#    'MSH': ['MSH/D000544'],
#    'RXNORM': []}],
#  'Amyloidosis': [{'preferredTerms': 'Amyloidosis',
#    'entityids': 'UMLS/C0002726',
#    'HPO': ['HPO/HP:0011034'],
#    'MSH': ['MSH/D000686'],
#    'RXNORM': []}],
#  'Anaemia': [{'preferredTerms': 'Anemia',
#    'entityids': 'UMLS/C0002871',
#    'HPO': ['HPO/HP:0001903'],
#    'MSH': ['MSH/D000740'],
#    'RXNORM': []}],
#  'Analgesia': [{}],
#  'Ankylosing spondylitis': [{'preferredTerms': 'Ankylosing spondylitis',
#    'entityids': 'UMLS/C0038013',
#    'HPO': [],
#    'MSH': ['MSH/D013167'],
#    'RXNORM': []}],
#  'Anxiety disorders': [{'preferredTerms': 'Anxiety Disorders',
#    'entityids': 'UMLS/C0003469',
#    'HPO': [],
#    'MSH': ['MSH/D001008'],
#    'RXNORM': []}],
#  'Asthma': [{'preferredTerms': 'Asthma',
#    'entityids': 'UMLS/C0004096',
#    'HPO': ['HPO/HP:0002099'],
#    'MSH': ['MSH/D001249'],
#    'RXNORM': []}],
#  'Asthma and rhinitis': [{'preferredTerms': 'Asthma',
#    'entityids': 'UMLS/C0004096',
#    'HPO': ['HPO/HP:0002099'],
#    'MSH': ['MSH/D001249'],
#    'RXNORM': []},
#   {'preferredTerms': 'Rhinitis',
#    'entityids': 'UMLS/C0035455',
#    'HPO': ['HPO/HP:0012384'],
#    'MSH': ['MSH/D012220'],
#    'RXNORM': []}],
#  'Atherosclerosis': [{'preferredTerms': 'Atherosclerosis',
#    'entityids': 'UMLS/C0004153',
#    'HPO': ['HPO/HP:0002621', 'HPO/HP:0002635'],
#    'MSH': ['MSH/D050197'],
#    'RXNORM': []}],
#  'Atopic dermatitis': [{'preferredTerms': 'Dermatitis, Atopic',
#    'entityids': 'UMLS/C0011615',
#    'HPO': ['HPO/HP:0001047'],
#    'MSH': ['MSH/D003876'],
#    'RXNORM': []}],
#  'Atrial fibrillation': [{'preferredTerms': 'Atrial Fibrillation',
#    'entityids': 'UMLS/C0004238',
#    'HPO': ['HPO/HP:0005110'],
#    'MSH': ['MSH/D001281'],
#    'RXNORM': []}],
#  'Attention deficit hyperactivity disorder (adhd)': [{'preferredTerms': 'Attention deficit hyperactivity disorder',
#    'entityids': 'UMLS/C1263846',
#    'HPO': ['HPO/HP:0007018'],
#    'MSH': ['MSH/D001289'],
#    'RXNORM': []}],
#  'Autoimmune diseases': [{'preferredTerms': 'Autoimmune Diseases',
#    'entityids': 'UMLS/C0004364',
#    'HPO': ['HPO/HP:0002960'],
#    'MSH': ['MSH/D001327'],
#    'RXNORM': []}],
#  'B-cell acute lymphoblastic leukemia, relapsed b-cell acute lymphoblastic leukemia, refractory b-cell acute lymphoblastic leukemia': [{'preferredTerms': 'Precursor B-cell lymphoblastic leukemia',
#    'entityids': 'UMLS/C1292769',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []},
#   {'preferredTerms': 'Acute lymphocytic leukemia',
#    'entityids': 'UMLS/C0023449',
#    'HPO': ['HPO/HP:0006721'],
#    'MSH': [],
#    'RXNORM': []}],
#  'Bacillary dysentery': [{'preferredTerms': 'Dysentery, Bacillary',
#    'entityids': 'UMLS/C1527298',
#    'HPO': [],
#    'MSH': ['MSH/D004405'],
#    'RXNORM': []}],
#  'Bacterial infections': [{'preferredTerms': 'Bacterial Infections',
#    'entityids': 'UMLS/C0004623',
#    'HPO': [],
#    'MSH': ['MSH/D001424'],
#    'RXNORM': []}],
#  'Bacterial skin infections': [{'preferredTerms': 'Recurrent bacterial skin infections',
#    'entityids': 'UMLS/C1835686',
#    'HPO': ['HPO/HP:0005406'],
#    'MSH': [],
#    'RXNORM': []}],
#  'Bipolar disorder': [{'preferredTerms': 'Bipolar Disorder',
#    'entityids': 'UMLS/C0005586',
#    'HPO': ['HPO/HP:0007302'],
#    'MSH': ['MSH/D001714'],
#    'RXNORM': []}],
#  'Bipolar i disorder': [{'preferredTerms': 'Mixed bipolar I disorder',
#    'entityids': 'UMLS/C0236780',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Bladder pain': [{'preferredTerms': 'Pain',
#    'entityids': 'UMLS/C0030193',
#    'HPO': ['HPO/HP:0012531'],
#    'MSH': ['MSH/D010146'],
#    'RXNORM': []}],
#  'Brain metastases': [{'preferredTerms': 'Neoplasm Metastasis',
#    'entityids': 'UMLS/C0027627',
#    'HPO': [],
#    'MSH': ['MSH/D009362'],
#    'RXNORM': []}],
#  'Breast cancer': [{'preferredTerms': 'Malignant Neoplasms',
#    'entityids': 'UMLS/C0006826',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Breast neoplasms': [{'preferredTerms': 'Neoplasms',
#    'entityids': 'UMLS/C0027651',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Bronchial constriction': [{'preferredTerms': 'Constriction procedure',
#    'entityids': 'UMLS/C0009813',
#    'HPO': [],
#    'MSH': ['MSH/D003250'],
#    'RXNORM': []}],
#  'Bronchial hyperreactivity': [{'preferredTerms': 'Bronchial Hyperreactivity',
#    'entityids': 'UMLS/C0085129',
#    'HPO': [],
#    'MSH': ['MSH/D016535'],
#    'RXNORM': []}],
#  'Bronchiectasis': [{'preferredTerms': 'Bronchiectasis',
#    'entityids': 'UMLS/C0006267',
#    'HPO': ['HPO/HP:0002110'],
#    'MSH': ['MSH/D001987'],
#    'RXNORM': []}],
#  'Bronchospasm': [{'preferredTerms': 'Bronchospasm',
#    'entityids': 'UMLS/C0006266',
#    'HPO': ['HPO/HP:0025428'],
#    'MSH': ['MSH/D001986'],
#    'RXNORM': []}],
#  'Cachexia': [{'preferredTerms': 'Cachexia',
#    'entityids': 'UMLS/C0006625',
#    'HPO': ['HPO/HP:0004326'],
#    'MSH': ['MSH/D002100'],
#    'RXNORM': []}],
#  'Cancer': [{'preferredTerms': 'Malignant Neoplasms',
#    'entityids': 'UMLS/C0006826',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Cancer|neoplasms': [{'preferredTerms': 'Malignant Neoplasms',
#    'entityids': 'UMLS/C0006826',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []},
#   {'preferredTerms': 'Neoplasms',
#    'entityids': 'UMLS/C0027651',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Carcinoid tumor': [{'preferredTerms': 'Carcinoid Tumor',
#    'entityids': 'UMLS/C0007095',
#    'HPO': ['HPO/HP:0100570'],
#    'MSH': ['MSH/D002276'],
#    'RXNORM': []}],
#  'Cardiac arrhythmia': [{'preferredTerms': 'Cardiac Arrhythmia',
#    'entityids': 'UMLS/C0003811',
#    'HPO': ['HPO/HP:0011675'],
#    'MSH': ['MSH/D001145'],
#    'RXNORM': []}],
#  'Cardiovascular disease': [{'preferredTerms': 'Cardiovascular Diseases',
#    'entityids': 'UMLS/C0007222',
#    'HPO': ['HPO/HP:0001626'],
#    'MSH': ['MSH/D002318'],
#    'RXNORM': []}],
#  'Cataract': [{'preferredTerms': 'Bilateral cataracts (disorder)',
#    'entityids': 'UMLS/C0521707',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Cerebrovascular accident': [{'preferredTerms': 'Cerebrovascular accident',
#    'entityids': 'UMLS/C0038454',
#    'HPO': ['HPO/HP:0001297'],
#    'MSH': ['MSH/D020521'],
#    'RXNORM': []}],
#  'Cervical intraepithelial neoplasia': [{'preferredTerms': 'Cervical Intraepithelial Neoplasia',
#    'entityids': 'UMLS/C0206708',
#    'HPO': ['HPO/HP:0032242'],
#    'MSH': ['MSH/D018290'],
#    'RXNORM': []}],
#  'Chemotherapy-induced nausea and vomiting': [{'preferredTerms': 'Refractory Chemotherapy-Induced Nausea and Vomiting',
#    'entityids': 'UMLS/C4687664',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []},
#   {'preferredTerms': 'Vomiting',
#    'entityids': 'UMLS/C0042963',
#    'HPO': ['HPO/HP:0002013'],
#    'MSH': ['MSH/D014839'],
#    'RXNORM': []}],
#  'Cholestasis': [{'preferredTerms': 'Cholestasis',
#    'entityids': 'UMLS/C0008370',
#    'HPO': ['HPO/HP:0001396'],
#    'MSH': ['MSH/D002779'],
#    'RXNORM': []}],
#  'Chronic Obstructive Airway Disease': [{'preferredTerms': 'Chronic Obstructive Airway Disease',
#    'entityids': 'UMLS/C0024117',
#    'HPO': ['HPO/HP:0006510'],
#    'MSH': ['MSH/D029424'],
#    'RXNORM': []}],
#  'Chronic bronchitis': [{'preferredTerms': 'Bronchitis',
#    'entityids': 'UMLS/C0006277',
#    'HPO': ['HPO/HP:0012387'],
#    'MSH': ['MSH/D001991'],
#    'RXNORM': []}],
#  'Chronic constipation': [{'preferredTerms': 'Constipation',
#    'entityids': 'UMLS/C0009806',
#    'HPO': ['HPO/HP:0002019'],
#    'MSH': ['MSH/D003248'],
#    'RXNORM': []}],
#  'Chronic dermatitis': [{'preferredTerms': 'Dermatitis',
#    'entityids': 'UMLS/C0011603',
#    'HPO': ['HPO/HP:0011123'],
#    'MSH': ['MSH/D003872'],
#    'RXNORM': []}],
#  'Chronic idiopathic urticaria (ciu)': [{'preferredTerms': 'Idiopathic urticaria',
#    'entityids': 'UMLS/C0157741',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []},
#   {'preferredTerms': 'Chronic Spontaneous Urticaria',
#    'entityids': 'UMLS/C0578870',
#    'HPO': ['HPO/HP:0410133'],
#    'MSH': ['MSH/D000080223'],
#    'RXNORM': []}],
#  'Chronic lymphocytic leukaemia': [{'preferredTerms': 'Chronic Lymphocytic Leukemia',
#    'entityids': 'UMLS/C0023434',
#    'HPO': ['HPO/HP:0005550'],
#    'MSH': ['MSH/D015451'],
#    'RXNORM': []}],
#  'Chronic lymphocytic leukemia (cll)': [{'preferredTerms': 'Lymphoid leukemia',
#    'entityids': 'UMLS/C0023448',
#    'HPO': ['HPO/HP:0005526'],
#    'MSH': ['MSH/D007945'],
#    'RXNORM': []}],
#  'Chronic myelogenous leukemia': [{'preferredTerms': 'Myeloid Leukemia',
#    'entityids': 'UMLS/C0023470',
#    'HPO': ['HPO/HP:0012324'],
#    'MSH': ['MSH/D007951'],
#    'RXNORM': []}],
#  'Chronic myeloid leukemia (cml)': [{'preferredTerms': 'Myeloid Leukemia, Chronic',
#    'entityids': 'UMLS/C0023473',
#    'HPO': ['HPO/HP:0005506'],
#    'MSH': [],
#    'RXNORM': []}],
#  'Chronic obstructive pulmonary disease (copd)': [{'preferredTerms': 'Chronic Obstructive Airway Disease',
#    'entityids': 'UMLS/C0024117',
#    'HPO': ['HPO/HP:0006510'],
#    'MSH': ['MSH/D029424'],
#    'RXNORM': []}],
#  'Chronic plaque psoriasis': [{'preferredTerms': 'Psoriasis',
#    'entityids': 'UMLS/C0033860',
#    'HPO': ['HPO/HP:0003765'],
#    'MSH': ['MSH/D011565'],
#    'RXNORM': []}],
#  'Clostridium difficile infection': [{'preferredTerms': 'Clostridium difficile infection',
#    'entityids': 'UMLS/C0343386',
#    'HPO': [],
#    'MSH': ['MSH/D003015'],
#    'RXNORM': []}],
#  'Cognitive disorders': [{'preferredTerms': 'Cognition Disorders',
#    'entityids': 'UMLS/C0009241',
#    'HPO': [],
#    'MSH': ['MSH/D003072'],
#    'RXNORM': []}],
#  'Colitis, ulcerative': [{'preferredTerms': 'Colitis',
#    'entityids': 'UMLS/C0009319',
#    'HPO': ['HPO/HP:0002583'],
#    'MSH': ['MSH/D003092'],
#    'RXNORM': []},
#   {'preferredTerms': 'Ulcer',
#    'entityids': 'UMLS/C0041582',
#    'HPO': [],
#    'MSH': ['MSH/D014456'],
#    'RXNORM': []}],
#  'Colorectal Neoplasms': [{'preferredTerms': 'Colorectal Neoplasms',
#    'entityids': 'UMLS/C0009404',
#    'HPO': ['HPO/HP:0100834'],
#    'MSH': ['MSH/D015179'],
#    'RXNORM': []}],
#  'Congestive heart failure': [{'preferredTerms': 'Congestive heart failure',
#    'entityids': 'UMLS/C0018802',
#    'HPO': ['HPO/HP:0001635'],
#    'MSH': ['MSH/D006333'],
#    'RXNORM': []}],
#  'Congestive heart failure and microalbuminuria heart failure': [{'preferredTerms': 'Congestive heart failure',
#    'entityids': 'UMLS/C0018802',
#    'HPO': ['HPO/HP:0001635'],
#    'MSH': ['MSH/D006333'],
#    'RXNORM': []},
#   {'preferredTerms': 'Microalbuminuria',
#    'entityids': 'UMLS/C0730345',
#    'HPO': ['HPO/HP:0012594'],
#    'MSH': [],
#    'RXNORM': []},
#   {'preferredTerms': 'Heart failure',
#    'entityids': 'UMLS/C0018801',
#    'HPO': ['HPO/HP:0001635'],
#    'MSH': ['MSH/D006333'],
#    'RXNORM': []}],
#  'Coronary artery disease': [{'preferredTerms': 'Coronary Artery Disease',
#    'entityids': 'UMLS/C1956346',
#    'HPO': ['HPO/HP:0001677'],
#    'MSH': ['MSH/D003324'],
#    'RXNORM': []}],
#  'Corticosteroid refractory acute graft vs host disease': [{'preferredTerms': 'Graft-vs-Host Disease',
#    'entityids': 'UMLS/C0018133',
#    'HPO': [],
#    'MSH': ['MSH/D006086'],
#    'RXNORM': []}],
#  'Cough': [{'preferredTerms': 'Coughing',
#    'entityids': 'UMLS/C0010200',
#    'HPO': ['HPO/HP:0012735'],
#    'MSH': ['MSH/D003371'],
#    'RXNORM': []}],
#  "Crohn's disease": [{'preferredTerms': 'Crohn Disease',
#    'entityids': 'UMLS/C0010346',
#    'HPO': ['HPO/HP:0100280'],
#    'MSH': ['MSH/D003424'],
#    'RXNORM': []}],
#  'Cystic fibrosis': [{'preferredTerms': 'Cystic Fibrosis',
#    'entityids': 'UMLS/C0010674',
#    'HPO': [],
#    'MSH': ['MSH/D003550'],
#    'RXNORM': []}],
#  'Dementia': [{'preferredTerms': 'Dementia',
#    'entityids': 'UMLS/C0497327',
#    'HPO': ['HPO/HP:0000726'],
#    'MSH': ['MSH/D003704'],
#    'RXNORM': []}],
#  'Dentin sensitivity': [{'preferredTerms': 'Dentin Sensitivity',
#    'entityids': 'UMLS/C0011432',
#    'HPO': [],
#    'MSH': ['MSH/D003807'],
#    'RXNORM': []}],
#  'Denture retention': [{'preferredTerms': 'Denture Retention',
#    'entityids': 'UMLS/C0011397',
#    'HPO': [],
#    'MSH': ['MSH/D003781'],
#    'RXNORM': []}],
#  'Depressive disorder': [{'preferredTerms': 'Depressive disorder',
#    'entityids': 'UMLS/C0011581',
#    'HPO': ['HPO/HP:0000716'],
#    'MSH': ['MSH/D003866'],
#    'RXNORM': []}],
#  'Depressive disorder and anxiety disorders': [{'preferredTerms': 'Depressive disorder',
#    'entityids': 'UMLS/C0011581',
#    'HPO': ['HPO/HP:0000716'],
#    'MSH': ['MSH/D003866'],
#    'RXNORM': []},
#   {'preferredTerms': 'Anxiety Disorders',
#    'entityids': 'UMLS/C0003469',
#    'HPO': [],
#    'MSH': ['MSH/D001008'],
#    'RXNORM': []}],
#  'Dermatologic disorders': [{'preferredTerms': 'Dermatologic disorders',
#    'entityids': 'UMLS/C0037274',
#    'HPO': ['HPO/HP:0000951'],
#    'MSH': ['MSH/D012871'],
#    'RXNORM': []}],
#  'Diabetes mellitus': [{'preferredTerms': 'Diabetes Mellitus',
#    'entityids': 'UMLS/C0011849',
#    'HPO': ['HPO/HP:0000819'],
#    'MSH': ['MSH/D003920'],
#    'RXNORM': []}],
#  'Diabetic kidney disease': [{'preferredTerms': 'Diabetic Nephropathy',
#    'entityids': 'UMLS/C0011881',
#    'HPO': [],
#    'MSH': ['MSH/D003928'],
#    'RXNORM': []}],
#  'Diabetic macular edema': [{'preferredTerms': 'Macular edema due to diabetes mellitus',
#    'entityids': 'UMLS/C0730285',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Diabetic neuropathic pain': [{'preferredTerms': 'Diabetic Neuralgia',
#    'entityids': 'UMLS/C0751074',
#    'HPO': [],
#    'MSH': ['MSH/D003929'],
#    'RXNORM': []}],
#  'Diabetic neuropathy': [{'preferredTerms': 'Diabetic Neuropathies',
#    'entityids': 'UMLS/C0011882',
#    'HPO': [],
#    'MSH': ['MSH/D003929'],
#    'RXNORM': []}],
#  'Diabetic retinopathy': [{'preferredTerms': 'Diabetic Retinopathy',
#    'entityids': 'UMLS/C0011884',
#    'HPO': [],
#    'MSH': ['MSH/D003930'],
#    'RXNORM': []}],
#  'Diphtheria': [{'preferredTerms': 'Diphtheria',
#    'entityids': 'UMLS/C0012546',
#    'HPO': [],
#    'MSH': ['MSH/D004165'],
#    'RXNORM': []}],
#  'Drug-related side effects and adverse reactions': [{'preferredTerms': 'Adverse reaction to drug',
#    'entityids': 'UMLS/C0041755',
#    'HPO': ['HPO/HP:0020172'],
#    'MSH': ['MSH/D064420'],
#    'RXNORM': []},
#   {'preferredTerms': 'Adverse reactions',
#    'entityids': 'UMLS/C0559546',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Dyslipidaemias': [{'preferredTerms': 'Dyslipidemias',
#    'entityids': 'UMLS/C0242339',
#    'HPO': ['HPO/HP:0003119'],
#    'MSH': ['MSH/D050171'],
#    'RXNORM': []}],
#  'Eczema': [{'preferredTerms': 'Eczema',
#    'entityids': 'UMLS/C0013595',
#    'HPO': ['HPO/HP:0000964', 'HPO/HP:0000976'],
#    'MSH': ['MSH/D004485'],
#    'RXNORM': []}],
#  'Embryo transfer': [{}],
#  'Endometriosis': [{'preferredTerms': 'Endometriosis',
#    'entityids': 'UMLS/C0014175',
#    'HPO': ['HPO/HP:0030127'],
#    'MSH': ['MSH/D004715'],
#    'RXNORM': []}],
#  'Eosinophilic asthma': [{'preferredTerms': 'Asthma',
#    'entityids': 'UMLS/C0004096',
#    'HPO': ['HPO/HP:0002099'],
#    'MSH': ['MSH/D001249'],
#    'RXNORM': []}],
#  'Eosinophilic esophagitis': [{'preferredTerms': 'Eosinophilic esophagitis',
#    'entityids': 'UMLS/C0341106',
#    'HPO': [],
#    'MSH': ['MSH/D057765'],
#    'RXNORM': []}],
#  'Epilepsy': [{'preferredTerms': 'Epilepsy',
#    'entityids': 'UMLS/C0014544',
#    'HPO': ['HPO/HP:0001250'],
#    'MSH': ['MSH/D004827'],
#    'RXNORM': []}],
#  'Episodic migraine headache': [{'preferredTerms': 'Migraine Disorders',
#    'entityids': 'UMLS/C0149931',
#    'HPO': ['HPO/HP:0002076'],
#    'MSH': ['MSH/D008881'],
#    'RXNORM': []}],
#  'Esophageal cancer': [{'preferredTerms': 'Esophageal carcinoma',
#    'entityids': 'UMLS/C0152018',
#    'HPO': ['HPO/HP:0011459'],
#    'MSH': [],
#    'RXNORM': []}],
#  'Fascioliasis': [{'preferredTerms': 'Fascioliasis',
#    'entityids': 'UMLS/C0015652',
#    'HPO': [],
#    'MSH': ['MSH/D005211'],
#    'RXNORM': []}],
#  'Fibromyalgia syndrome, primary': [{'preferredTerms': 'Fibromyalgia',
#    'entityids': 'UMLS/C0016053',
#    'HPO': [],
#    'MSH': ['MSH/D005356'],
#    'RXNORM': []}],
#  'Focal infection, dental': [{'preferredTerms': 'Focal Infection',
#    'entityids': 'UMLS/C0016397',
#    'HPO': [],
#    'MSH': ['MSH/D005490'],
#    'RXNORM': []}],
#  'Follicular lymphoma': [{'preferredTerms': 'Lymphoma, Follicular',
#    'entityids': 'UMLS/C0024301',
#    'HPO': ['HPO/HP:0033125'],
#    'MSH': ['MSH/D008224'],
#    'RXNORM': []}],
#  'Fracture healing': [{'preferredTerms': 'Fracture',
#    'entityids': 'UMLS/C0016658',
#    'HPO': ['HPO/HP:0020110'],
#    'MSH': ['MSH/D050723'],
#    'RXNORM': []}],
#  'Gastrointestinal Neoplasms': [{'preferredTerms': 'Gastrointestinal Neoplasms',
#    'entityids': 'UMLS/C0017185',
#    'HPO': ['HPO/HP:0007378'],
#    'MSH': ['MSH/D005770'],
#    'RXNORM': []}],
#  'Gastrointestinal diseases': [{'preferredTerms': 'Gastrointestinal Diseases',
#    'entityids': 'UMLS/C0017178',
#    'HPO': ['HPO/HP:0011024'],
#    'MSH': ['MSH/D005767'],
#    'RXNORM': []}],
#  'Gastrointestinal motility': [{}],
#  'Gastroparesis': [{'preferredTerms': 'Gastroparesis',
#    'entityids': 'UMLS/C0152020',
#    'HPO': ['HPO/HP:0002578'],
#    'MSH': ['MSH/D018589'],
#    'RXNORM': []}],
#  'Geographic atrophy': [{'preferredTerms': 'Geographic Atrophy',
#    'entityids': 'UMLS/C1536085',
#    'HPO': ['HPO/HP:0031609'],
#    'MSH': ['MSH/D057092'],
#    'RXNORM': []}],
#  'Gonorrhea': [{'preferredTerms': 'Gonorrhea',
#    'entityids': 'UMLS/C0018081',
#    'HPO': [],
#    'MSH': ['MSH/D006069'],
#    'RXNORM': []}],
#  'H1N1 subtype influenza A virus': [{'preferredTerms': 'influenza A virus',
#    'entityids': 'UMLS/C0029347',
#    'HPO': [],
#    'MSH': ['MSH/D009980'],
#    'RXNORM': ['RXNORM/1312375']}],
#  'Haemophilus influenzae type b': [{'preferredTerms': 'Haemophilus influenzae type b',
#    'entityids': 'UMLS/C0121772',
#    'HPO': [],
#    'MSH': ['MSH/D019741'],
#    'RXNORM': ['RXNORM/50937']}],
#  'Head neoplasms and neck neoplasms': [{'preferredTerms': 'Neoplasms',
#    'entityids': 'UMLS/C0027651',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Heart failure': [{'preferredTerms': 'Heart failure',
#    'entityids': 'UMLS/C0018801',
#    'HPO': ['HPO/HP:0001635'],
#    'MSH': ['MSH/D006333'],
#    'RXNORM': []}],
#  'Heart failure with preserved ejection fraction': [{'preferredTerms': 'Heart failure',
#    'entityids': 'UMLS/C0018801',
#    'HPO': ['HPO/HP:0001635'],
#    'MSH': ['MSH/D006333'],
#    'RXNORM': []}],
#  'Heart failure, chronic (chf)': [{'preferredTerms': 'Heart failure',
#    'entityids': 'UMLS/C0018801',
#    'HPO': ['HPO/HP:0001635'],
#    'MSH': ['MSH/D006333'],
#    'RXNORM': []}],
#  'Hepatitis a': [{'preferredTerms': 'Hepatitis A',
#    'entityids': 'UMLS/C0019159',
#    'HPO': [],
#    'MSH': ['MSH/D006506'],
#    'RXNORM': []}],
#  'Hepatitis b': [{'preferredTerms': 'Hepatitis B',
#    'entityids': 'UMLS/C0019163',
#    'HPO': [],
#    'MSH': ['MSH/D006509'],
#    'RXNORM': []}],
#  'Hepatitis b, chronic': [{'preferredTerms': 'Hepatitis B',
#    'entityids': 'UMLS/C0019163',
#    'HPO': [],
#    'MSH': ['MSH/D006509'],
#    'RXNORM': []}],
#  'Hepatitis c': [{'preferredTerms': 'Hepatitis C',
#    'entityids': 'UMLS/C0019196',
#    'HPO': [],
#    'MSH': ['MSH/D006526'],
#    'RXNORM': []}],
#  'Hepatitis c, chronic': [{'preferredTerms': 'Hepatitis C',
#    'entityids': 'UMLS/C0019196',
#    'HPO': [],
#    'MSH': ['MSH/D006526'],
#    'RXNORM': []}],
#  'Hepatocellular carcinoma': [{'preferredTerms': 'Liver carcinoma',
#    'entityids': 'UMLS/C2239176',
#    'HPO': ['HPO/HP:0001402'],
#    'MSH': ['MSH/D006528'],
#    'RXNORM': []}],
#  'Hepatocellular carcinoma (hcc)': [{'preferredTerms': 'Liver carcinoma',
#    'entityids': 'UMLS/C2239176',
#    'HPO': ['HPO/HP:0001402'],
#    'MSH': ['MSH/D006528'],
#    'RXNORM': []}],
#  'Her2-negative metastatic breast cancer': [{'preferredTerms': 'Neoplasm Metastasis',
#    'entityids': 'UMLS/C0027627',
#    'HPO': [],
#    'MSH': ['MSH/D009362'],
#    'RXNORM': []},
#   {'preferredTerms': 'Malignant Neoplasms',
#    'entityids': 'UMLS/C0006826',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Her2/neu over-expressing locally advanced breast cancer or metastatic breast cancer': [{'preferredTerms': 'Malignant Neoplasms',
#    'entityids': 'UMLS/C0006826',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []},
#   {'preferredTerms': 'Neoplasm Metastasis',
#    'entityids': 'UMLS/C0027627',
#    'HPO': [],
#    'MSH': ['MSH/D009362'],
#    'RXNORM': []}],
#  'Hereditary periodic fevers': [{'preferredTerms': 'Fever',
#    'entityids': 'UMLS/C0015967',
#    'HPO': ['HPO/HP:0001945'],
#    'MSH': ['MSH/D005334'],
#    'RXNORM': []}],
#  'Herpes genitalis': [{'preferredTerms': 'Genital Herpes',
#    'entityids': 'UMLS/C0019342',
#    'HPO': [],
#    'MSH': ['MSH/D006558'],
#    'RXNORM': []}],
#  'Herpes labialis': [{'preferredTerms': 'Herpes Labialis',
#    'entityids': 'UMLS/C0019345',
#    'HPO': [],
#    'MSH': ['MSH/D006560'],
#    'RXNORM': []}],
#  'Herpes simplex infection': [{'preferredTerms': 'Herpes Simplex Infections',
#    'entityids': 'UMLS/C0019348',
#    'HPO': [],
#    'MSH': ['MSH/D006561'],
#    'RXNORM': []}],
#  'Herpes zoster': [{'preferredTerms': 'Herpes zoster disease',
#    'entityids': 'UMLS/C0019360',
#    'HPO': [],
#    'MSH': ['MSH/D006562'],
#    'RXNORM': []}],
#  'Herpesviridae infections': [{'preferredTerms': 'Herpesviridae Infections',
#    'entityids': 'UMLS/C0019372',
#    'HPO': [],
#    'MSH': ['MSH/D006566'],
#    'RXNORM': []}],
#  'Hip fracture': [{'preferredTerms': 'Fracture',
#    'entityids': 'UMLS/C0016658',
#    'HPO': ['HPO/HP:0020110'],
#    'MSH': ['MSH/D050723'],
#    'RXNORM': []}],
#  'Hiv infections': [{'preferredTerms': 'HIV Infections',
#    'entityids': 'UMLS/C0019693',
#    'HPO': [],
#    'MSH': ['MSH/D015658'],
#    'RXNORM': []}],
#  'Human immunodeficiency virus infection': [{'preferredTerms': 'HIV Infections',
#    'entityids': 'UMLS/C0019693',
#    'HPO': [],
#    'MSH': ['MSH/D015658'],
#    'RXNORM': []}],
#  'Human immunodeficiency virus infection and herpesviridae infections': [{'preferredTerms': 'HIV Infections',
#    'entityids': 'UMLS/C0019693',
#    'HPO': [],
#    'MSH': ['MSH/D015658'],
#    'RXNORM': []},
#   {'preferredTerms': 'Herpesviridae Infections',
#    'entityids': 'UMLS/C0019372',
#    'HPO': [],
#    'MSH': ['MSH/D006566'],
#    'RXNORM': []}],
#  'Huntington disease': [{'preferredTerms': 'Huntington Disease',
#    'entityids': 'UMLS/C0020179',
#    'HPO': [],
#    'MSH': ['MSH/D006816'],
#    'RXNORM': []}],
#  'Hypercholesterolemia': [{'preferredTerms': 'Hypercholesterolemia',
#    'entityids': 'UMLS/C0020443',
#    'HPO': ['HPO/HP:0003124'],
#    'MSH': ['MSH/D006937'],
#    'RXNORM': []}],
#  'Hypereosinophilic syndrome': [{'preferredTerms': 'Hypereosinophilic syndrome',
#    'entityids': 'UMLS/C1540912',
#    'HPO': [],
#    'MSH': ['MSH/D017681'],
#    'RXNORM': []}],
#  'Hyperhidrosis': [{'preferredTerms': 'Hyperhidrosis disorder',
#    'entityids': 'UMLS/C0020458',
#    'HPO': ['HPO/HP:0000975'],
#    'MSH': ['MSH/D006945'],
#    'RXNORM': []}],
#  'Hypertension': [{'preferredTerms': 'Hypertensive disease',
#    'entityids': 'UMLS/C0020538',
#    'HPO': ['HPO/HP:0000822'],
#    'MSH': ['MSH/D006973'],
#    'RXNORM': []}],
#  'Hypertriglyceridemia': [{'preferredTerms': 'Hypertriglyceridemia',
#    'entityids': 'UMLS/C0020557',
#    'HPO': [],
#    'MSH': ['MSH/D015228'],
#    'RXNORM': []}],
#  'Hypogonadism, male': [{'preferredTerms': 'Hypogonadism',
#    'entityids': 'UMLS/C0020619',
#    'HPO': ['HPO/HP:0000135'],
#    'MSH': ['MSH/D007006'],
#    'RXNORM': []}],
#  'Idiopathic pulmonary fibrosis': [{'preferredTerms': 'Idiopathic Pulmonary Fibrosis',
#    'entityids': 'UMLS/C1800706',
#    'HPO': [],
#    'MSH': ['MSH/D054990'],
#    'RXNORM': []}],
#  'Idiopathic thrombocytopenic purpura': [{'preferredTerms': 'Immune thrombocytopenic purpura',
#    'entityids': 'UMLS/C0398650',
#    'HPO': ['HPO/HP:0001973'],
#    'MSH': ['MSH/D016553'],
#    'RXNORM': []}],
#  'Impetigo': [{'preferredTerms': 'Impetigo',
#    'entityids': 'UMLS/C0021099',
#    'HPO': [],
#    'MSH': ['MSH/D007169'],
#    'RXNORM': []}],
#  'Inflammatory bowel diseases': [{'preferredTerms': 'Inflammatory Bowel Diseases',
#    'entityids': 'UMLS/C0021390',
#    'HPO': ['HPO/HP:0002037'],
#    'MSH': ['MSH/D015212'],
#    'RXNORM': []}],
#  'Influenza': [{'preferredTerms': 'Influenza',
#    'entityids': 'UMLS/C0021400',
#    'HPO': [],
#    'MSH': ['MSH/D007251'],
#    'RXNORM': []}],
#  'Insulin resistance': [{}],
#  'Intrahepatic cholestasis': [{'preferredTerms': 'Intrahepatic Cholestasis',
#    'entityids': 'UMLS/C0008372',
#    'HPO': ['HPO/HP:0001406'],
#    'MSH': ['MSH/D002780'],
#    'RXNORM': []}],
#  'Invasive aspergillosis / invasive mucormycosis': [{'preferredTerms': 'Aspergillosis, Nervous System Invasive',
#    'entityids': 'UMLS/C0752341',
#    'HPO': [],
#    'MSH': ['MSH/D020953'],
#    'RXNORM': []},
#   {'preferredTerms': 'Mucormycosis',
#    'entityids': 'UMLS/C0026718',
#    'HPO': [],
#    'MSH': ['MSH/D009091'],
#    'RXNORM': []}],
#  'Invasive candidiasis': [{'preferredTerms': 'Invasive Candidiasis',
#    'entityids': 'UMLS/C1609535',
#    'HPO': [],
#    'MSH': ['MSH/D058365'],
#    'RXNORM': []}],
#  'Invasive fungal infection': [{'preferredTerms': 'Invasive Fungal Infections',
#    'entityids': 'UMLS/C1262313',
#    'HPO': ['HPO/HP:0020101'],
#    'MSH': ['MSH/D000072742'],
#    'RXNORM': []}],
#  'Invasive fungal infections': [{'preferredTerms': 'Mycoses',
#    'entityids': 'UMLS/C0026946',
#    'HPO': [],
#    'MSH': ['MSH/D009181'],
#    'RXNORM': []}],
#  'Irritable bowel syndrome': [{'preferredTerms': 'Irritable Bowel Syndrome',
#    'entityids': 'UMLS/C0022104',
#    'HPO': [],
#    'MSH': ['MSH/D043183'],
#    'RXNORM': []}],
#  'Juvenile psoriatic arthritis, enthesitis-related arthritis': [{'preferredTerms': 'Arthritis, Psoriatic',
#    'entityids': 'UMLS/C0003872',
#    'HPO': [],
#    'MSH': ['MSH/D015535'],
#    'RXNORM': []},
#   {'preferredTerms': 'Enthesitis-Related Arthritis',
#    'entityids': 'UMLS/C3495919',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Left ventricular hypertrophy': [{'preferredTerms': 'Left Ventricular Hypertrophy',
#    'entityids': 'UMLS/C0149721',
#    'HPO': ['HPO/HP:0001712'],
#    'MSH': ['MSH/D017379'],
#    'RXNORM': []}],
#  'Lennox-gastaut syndrome': [{'preferredTerms': 'Lennox-Gastaut syndrome',
#    'entityids': 'UMLS/C0238111',
#    'HPO': [],
#    'MSH': ['MSH/D065768'],
#    'RXNORM': []}],
#  'Liver diseases': [{'preferredTerms': 'Disease',
#    'entityids': 'UMLS/C0012634',
#    'HPO': [],
#    'MSH': ['MSH/D004194'],
#    'RXNORM': []}],
#  'Lower urinary tract symptoms / benign prostatic hyperplasia': [{'preferredTerms': 'Symptoms',
#    'entityids': 'UMLS/C1457887',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []},
#   {'preferredTerms': 'Benign Prostatic Hyperplasia',
#    'entityids': 'UMLS/C1704272',
#    'HPO': ['HPO/HP:0008711'],
#    'MSH': ['MSH/D011470'],
#    'RXNORM': []}],
#  'Lung injury, acute and respiratory distress syndrome, adult': [{'preferredTerms': 'Traumatic injury',
#    'entityids': 'UMLS/C3263723',
#    'HPO': [],
#    'MSH': ['MSH/D014947'],
#    'RXNORM': []},
#   {'preferredTerms': 'Respiratory Distress Syndrome, Adult',
#    'entityids': 'UMLS/C0035222',
#    'HPO': ['HPO/HP:0033677'],
#    'MSH': ['MSH/D012128'],
#    'RXNORM': []}],
#  'Lupus erythematosus, cutaneous': [{'preferredTerms': 'Lupus Erythematosus',
#    'entityids': 'UMLS/C0409974',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Lupus nephritis': [{'preferredTerms': 'Lupus Nephritis',
#    'entityids': 'UMLS/C0024143',
#    'HPO': ['HPO/HP:0033726'],
#    'MSH': ['MSH/D008181'],
#    'RXNORM': []}],
#  'Major depressive disorder': [{'preferredTerms': 'Unipolar Depression',
#    'entityids': 'UMLS/C0041696',
#    'HPO': [],
#    'MSH': ['MSH/D003866'],
#    'RXNORM': []}],
#  'Malaria': [{'preferredTerms': 'Malaria',
#    'entityids': 'UMLS/C0024530',
#    'HPO': [],
#    'MSH': ['MSH/D008288'],
#    'RXNORM': []}],
#  'Malaria, falciparum': [{'preferredTerms': 'Malaria',
#    'entityids': 'UMLS/C0024530',
#    'HPO': [],
#    'MSH': ['MSH/D008288'],
#    'RXNORM': []}],
#  'Malaria, vivax': [{'preferredTerms': 'Malaria',
#    'entityids': 'UMLS/C0024530',
#    'HPO': [],
#    'MSH': ['MSH/D008288'],
#    'RXNORM': []}],
#  'Male osteoporosis': [{'preferredTerms': 'Osteoporosis',
#    'entityids': 'UMLS/C0029456',
#    'HPO': ['HPO/HP:0000939'],
#    'MSH': ['MSH/D010024'],
#    'RXNORM': []}],
#  'Mantle-cell lymphoma': [{'preferredTerms': 'Malignant lymphoma, lymphocytic, intermediate differentiation, diffuse',
#    'entityids': 'UMLS/C0334634',
#    'HPO': [],
#    'MSH': ['MSH/D020522'],
#    'RXNORM': []}],
#  'Mastocytosis': [{'preferredTerms': 'Mastocytosis',
#    'entityids': 'UMLS/C0024899',
#    'HPO': ['HPO/HP:0100495'],
#    'MSH': ['MSH/D008415'],
#    'RXNORM': []}],
#  'Measles': [{'preferredTerms': 'Measles',
#    'entityids': 'UMLS/C0025007',
#    'HPO': [],
#    'MSH': ['MSH/D008457'],
#    'RXNORM': []}],
#  'Measles, mumps, rubella': [{'preferredTerms': 'Measles',
#    'entityids': 'UMLS/C0025007',
#    'HPO': [],
#    'MSH': ['MSH/D008457'],
#    'RXNORM': []},
#   {'preferredTerms': 'Mumps',
#    'entityids': 'UMLS/C0026780',
#    'HPO': [],
#    'MSH': ['MSH/D009107'],
#    'RXNORM': []},
#   {'preferredTerms': 'Rubella',
#    'entityids': 'UMLS/C0035920',
#    'HPO': [],
#    'MSH': ['MSH/D012409'],
#    'RXNORM': []}],
#  'Melanoma': [{'preferredTerms': 'melanoma',
#    'entityids': 'UMLS/C0025202',
#    'HPO': ['HPO/HP:0002861'],
#    'MSH': ['MSH/D008545'],
#    'RXNORM': []}],
#  'Meningitis, meningococcal': [{'preferredTerms': 'Meningitis',
#    'entityids': 'UMLS/C0025289',
#    'HPO': ['HPO/HP:0001287'],
#    'MSH': ['MSH/D008581'],
#    'RXNORM': []}],
#  'Meningococcal disease': [{'preferredTerms': 'Meningococcal Infections',
#    'entityids': 'UMLS/C0025303',
#    'HPO': [],
#    'MSH': ['MSH/D008589'],
#    'RXNORM': []}],
#  'Meningococcal infections': [{'preferredTerms': 'Meningococcal Infections',
#    'entityids': 'UMLS/C0025303',
#    'HPO': [],
#    'MSH': ['MSH/D008589'],
#    'RXNORM': []}],
#  'Mental disorders': [{'preferredTerms': 'Mental disorders',
#    'entityids': 'UMLS/C0004936',
#    'HPO': [],
#    'MSH': ['MSH/D001523'],
#    'RXNORM': []}],
#  'Metabolic syndrome x': [{'preferredTerms': 'Metabolic Syndrome X',
#    'entityids': 'UMLS/C0524620',
#    'HPO': [],
#    'MSH': ['MSH/D024821'],
#    'RXNORM': []}],
#  'Metastatic breast cancer': [{'preferredTerms': 'Malignant neoplasm of breast',
#    'entityids': 'UMLS/C0006142',
#    'HPO': [],
#    'MSH': ['MSH/D001943'],
#    'RXNORM': []}],
#  'Metastatic melanoma': [{'preferredTerms': 'Metastatic melanoma',
#    'entityids': 'UMLS/C0278883',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Metastatic renal cell carcinoma': [{'preferredTerms': 'Metastatic Renal Cell Carcinoma',
#    'entityids': 'UMLS/C4721698',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Metastatic triple-negative breast cancer': [{'preferredTerms': 'Triple Negative Breast Neoplasms',
#    'entityids': 'UMLS/C3539878',
#    'HPO': [],
#    'MSH': ['MSH/D064726'],
#    'RXNORM': []}],
#  'Midline carcinoma': [{'preferredTerms': 'Carcinoma',
#    'entityids': 'UMLS/C0007097',
#    'HPO': ['HPO/HP:0030731'],
#    'MSH': ['MSH/D002277'],
#    'RXNORM': []}],
#  'Migraine': [{'preferredTerms': 'Migraine Disorders',
#    'entityids': 'UMLS/C0149931',
#    'HPO': ['HPO/HP:0002076'],
#    'MSH': ['MSH/D008881'],
#    'RXNORM': []}],
#  'Migraine disorders': [{'preferredTerms': 'Migraine Disorders',
#    'entityids': 'UMLS/C0149931',
#    'HPO': ['HPO/HP:0002076'],
#    'MSH': ['MSH/D008881'],
#    'RXNORM': []}],
#  'Migraine disorders and premenstrual syndrome': [{'preferredTerms': 'Migraine Disorders',
#    'entityids': 'UMLS/C0149931',
#    'HPO': ['HPO/HP:0002076'],
#    'MSH': ['MSH/D008881'],
#    'RXNORM': []},
#   {'preferredTerms': 'Premenstrual syndrome',
#    'entityids': 'UMLS/C0033046',
#    'HPO': [],
#    'MSH': ['MSH/D011293'],
#    'RXNORM': []}],
#  'Migraine, without aura': [{'preferredTerms': 'Migraine Disorders',
#    'entityids': 'UMLS/C0149931',
#    'HPO': ['HPO/HP:0002076'],
#    'MSH': ['MSH/D008881'],
#    'RXNORM': []},
#   {'preferredTerms': 'Aura',
#    'entityids': 'UMLS/C0236018',
#    'HPO': [],
#    'MSH': ['MSH/D004827'],
#    'RXNORM': []}],
#  'Mild asthma and allergic rhinitis': [{'preferredTerms': 'Asthma',
#    'entityids': 'UMLS/C0004096',
#    'HPO': ['HPO/HP:0002099'],
#    'MSH': ['MSH/D001249'],
#    'RXNORM': []},
#   {'preferredTerms': 'Allergic rhinitis (disorder)',
#    'entityids': 'UMLS/C2607914',
#    'HPO': ['HPO/HP:0003193'],
#    'MSH': ['MSH/D065631'],
#    'RXNORM': []}],
#  'Moderate to severe acute pain': [{'preferredTerms': 'Pain',
#    'entityids': 'UMLS/C0030193',
#    'HPO': ['HPO/HP:0012531'],
#    'MSH': ['MSH/D010146'],
#    'RXNORM': []}],
#  'Moderate to severe acute post-operative pain': [{'preferredTerms': 'Pain',
#    'entityids': 'UMLS/C0030193',
#    'HPO': ['HPO/HP:0012531'],
#    'MSH': ['MSH/D010146'],
#    'RXNORM': []}],
#  'Moderate to severe chronic plaque-type psoriasis': [{'preferredTerms': 'Psoriasis',
#    'entityids': 'UMLS/C0033860',
#    'HPO': ['HPO/HP:0003765'],
#    'MSH': ['MSH/D011565'],
#    'RXNORM': []}],
#  'Moderate to severe scalp psoriasis': [{'preferredTerms': 'Psoriasis',
#    'entityids': 'UMLS/C0033860',
#    'HPO': ['HPO/HP:0003765'],
#    'MSH': ['MSH/D011565'],
#    'RXNORM': []}],
#  'Mood disorders': [{'preferredTerms': 'Mood Disorders',
#    'entityids': 'UMLS/C0525045',
#    'HPO': [],
#    'MSH': ['MSH/D019964'],
#    'RXNORM': []}],
#  'Multiple myeloma (mm)': [{'preferredTerms': 'Multiple Myeloma',
#    'entityids': 'UMLS/C0026764',
#    'HPO': ['HPO/HP:0006775'],
#    'MSH': ['MSH/D009101'],
#    'RXNORM': []}],
#  'Multiple sclerosis': [{'preferredTerms': 'Multiple Sclerosis',
#    'entityids': 'UMLS/C0026769',
#    'HPO': [],
#    'MSH': ['MSH/D009103'],
#    'RXNORM': []}],
#  'Mumps': [{'preferredTerms': 'Mumps',
#    'entityids': 'UMLS/C0026780',
#    'HPO': [],
#    'MSH': ['MSH/D009107'],
#    'RXNORM': []}],
#  'Muscle atrophy': [{'preferredTerms': 'Muscular Atrophy',
#    'entityids': 'UMLS/C0026846',
#    'HPO': [],
#    'MSH': ['MSH/D009133'],
#    'RXNORM': []}],
#  'Muscular atrophy': [{'preferredTerms': 'Muscular Atrophy',
#    'entityids': 'UMLS/C0026846',
#    'HPO': [],
#    'MSH': ['MSH/D009133'],
#    'RXNORM': []}],
#  'Myasthenia gravis': [{'preferredTerms': 'Myasthenia Gravis',
#    'entityids': 'UMLS/C0026896',
#    'HPO': [],
#    'MSH': ['MSH/D009157'],
#    'RXNORM': []}],
#  'Mycoses': [{'preferredTerms': 'Mycoses',
#    'entityids': 'UMLS/C0026946',
#    'HPO': [],
#    'MSH': ['MSH/D009181'],
#    'RXNORM': []}],
#  'Myelodysplastic syndrome (mds)': [{'preferredTerms': 'MYELODYSPLASTIC SYNDROME',
#    'entityids': 'UMLS/C3463824',
#    'HPO': ['HPO/HP:0002863'],
#    'MSH': ['MSH/D009190'],
#    'RXNORM': []}],
#  'Myelofibrosis': [{'preferredTerms': 'Primary Myelofibrosis',
#    'entityids': 'UMLS/C0001815',
#    'HPO': [],
#    'MSH': ['MSH/D055728'],
#    'RXNORM': []}],
#  'Nail psoriasis': [{'preferredTerms': 'Psoriasis of nail',
#    'entityids': 'UMLS/C0406322',
#    'HPO': ['HPO/HP:0033327'],
#    'MSH': [],
#    'RXNORM': []}],
#  'Nasal polyps': [{'preferredTerms': 'Nasal Polyps',
#    'entityids': 'UMLS/C0027430',
#    'HPO': ['HPO/HP:0100582'],
#    'MSH': ['MSH/D009298'],
#    'RXNORM': []}],
#  'Neisseria meningitidis': [{'preferredTerms': 'Neisseria meningitidis',
#    'entityids': 'UMLS/C0027575',
#    'HPO': [],
#    'MSH': ['MSH/D009345'],
#    'RXNORM': ['RXNORM/7288']}],
#  'Neoplasms': [{'preferredTerms': 'Neoplasms',
#    'entityids': 'UMLS/C0027651',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Neoplasms|lung neoplasms': [{'preferredTerms': 'Neoplasms',
#    'entityids': 'UMLS/C0027651',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Neovascular age-related macular degeneration': [{'preferredTerms': 'Macular degeneration',
#    'entityids': 'UMLS/C0024437',
#    'HPO': ['HPO/HP:0000608'],
#    'MSH': ['MSH/D008268'],
#    'RXNORM': []}],
#  'Neuroendocrine tumors (net)': [{'preferredTerms': 'Neuroendocrine Tumors',
#    'entityids': 'UMLS/C0206754',
#    'HPO': ['HPO/HP:0100634'],
#    'MSH': ['MSH/D018358'],
#    'RXNORM': []}],
#  'Neurogenic detrusor overactivity': [{'preferredTerms': 'Overactive Detrusor',
#    'entityids': 'UMLS/C0268849',
#    'HPO': [],
#    'MSH': ['MSH/D053201'],
#    'RXNORM': []}],
#  'Neuropathic pain': [{'preferredTerms': 'Neuralgia',
#    'entityids': 'UMLS/C0027796',
#    'HPO': ['HPO/HP:0033345'],
#    'MSH': ['MSH/D009437'],
#    'RXNORM': []}],
#  'Non-hodgkin lymphoma': [{'preferredTerms': 'Lymphoma, Non-Hodgkin',
#    'entityids': 'UMLS/C0024305',
#    'HPO': ['HPO/HP:0012539'],
#    'MSH': ['MSH/D008228'],
#    'RXNORM': []}],
#  'Non-radiographic spondyloarthritis': [{'preferredTerms': 'Spondylarthritis',
#    'entityids': 'UMLS/C0949690',
#    'HPO': [],
#    'MSH': ['MSH/D025241'],
#    'RXNORM': []}],
#  'Non-small cell lung cancer': [{'preferredTerms': 'Non-Small Cell Lung Carcinoma',
#    'entityids': 'UMLS/C0007131',
#    'HPO': ['HPO/HP:0030358'],
#    'MSH': ['MSH/D002289'],
#    'RXNORM': []}],
#  'Non-small cell lung carcinoma (nsclc)': [{'preferredTerms': 'Non-Small Cell Lung Carcinoma',
#    'entityids': 'UMLS/C0007131',
#    'HPO': ['HPO/HP:0030358'],
#    'MSH': ['MSH/D002289'],
#    'RXNORM': []}],
#  'Obesity': [{'preferredTerms': 'Obesity',
#    'entityids': 'UMLS/C0028754',
#    'HPO': ['HPO/HP:0001513'],
#    'MSH': ['MSH/D009765'],
#    'RXNORM': []}],
#  'Obsessive-compulsive disorder': [{'preferredTerms': 'Obsessive-Compulsive Disorder',
#    'entityids': 'UMLS/C0028768',
#    'HPO': ['HPO/HP:0000722'],
#    'MSH': ['MSH/D009771'],
#    'RXNORM': []}],
#  'Obsessive-compulsive disorder and depressive disorder': [{'preferredTerms': 'Obsessive-Compulsive Disorder',
#    'entityids': 'UMLS/C0028768',
#    'HPO': ['HPO/HP:0000722'],
#    'MSH': ['MSH/D009771'],
#    'RXNORM': []},
#   {'preferredTerms': 'Depressive disorder',
#    'entityids': 'UMLS/C0011581',
#    'HPO': ['HPO/HP:0000716'],
#    'MSH': ['MSH/D003866'],
#    'RXNORM': []}],
#  'Ocular hypertension': [{'preferredTerms': 'Ocular Hypertension',
#    'entityids': 'UMLS/C0028840',
#    'HPO': [],
#    'MSH': ['MSH/D009798'],
#    'RXNORM': []}],
#  'Open-angle glaucoma': [{'preferredTerms': 'Glaucoma, Open-Angle',
#    'entityids': 'UMLS/C0017612',
#    'HPO': ['HPO/HP:0012108'],
#    'MSH': ['MSH/D005902'],
#    'RXNORM': []}],
#  'Osteoarthritis': [{'preferredTerms': 'Degenerative polyarthritis',
#    'entityids': 'UMLS/C0029408',
#    'HPO': ['HPO/HP:0002758'],
#    'MSH': ['MSH/D010003'],
#    'RXNORM': []}],
#  'Osteopenia': [{'preferredTerms': 'Osteopenia',
#    'entityids': 'UMLS/C0029453',
#    'HPO': ['HPO/HP:0000938'],
#    'MSH': ['MSH/D001851'],
#    'RXNORM': []}],
#  'Osteoporosis': [{'preferredTerms': 'Osteoporosis',
#    'entityids': 'UMLS/C0029456',
#    'HPO': ['HPO/HP:0000939'],
#    'MSH': ['MSH/D010024'],
#    'RXNORM': []}],
#  'Otitis media': [{'preferredTerms': 'Otitis Media',
#    'entityids': 'UMLS/C0029882',
#    'HPO': ['HPO/HP:0000388'],
#    'MSH': ['MSH/D010033'],
#    'RXNORM': []}],
#  'Ovarian cancer': [{'preferredTerms': 'Malignant neoplasm of ovary',
#    'entityids': 'UMLS/C1140680',
#    'HPO': ['HPO/HP:0100615'],
#    'MSH': ['MSH/D010051'],
#    'RXNORM': []}],
#  'Ovarian neoplasms': [{'preferredTerms': 'ovarian neoplasm',
#    'entityids': 'UMLS/C0919267',
#    'HPO': ['HPO/HP:0100615'],
#    'MSH': ['MSH/D010051'],
#    'RXNORM': []}],
#  'Ovarian neoplasms|neoplasms|solid tumor|hepatic impairment': [{'preferredTerms': 'ovarian neoplasm',
#    'entityids': 'UMLS/C0919267',
#    'HPO': ['HPO/HP:0100615'],
#    'MSH': ['MSH/D010051'],
#    'RXNORM': []},
#   {'preferredTerms': 'Neoplasms',
#    'entityids': 'UMLS/C0027651',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []},
#   {'preferredTerms': 'Solid Neoplasm',
#    'entityids': 'UMLS/C0280100',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []},
#   {'preferredTerms': 'Hepatic impairment',
#    'entityids': 'UMLS/C0948807',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Pain, inflammatory': [{'preferredTerms': 'Pain',
#    'entityids': 'UMLS/C0030193',
#    'HPO': ['HPO/HP:0012531'],
#    'MSH': ['MSH/D010146'],
#    'RXNORM': []},
#   {'preferredTerms': 'Inflammation',
#    'entityids': 'UMLS/C0021368',
#    'HPO': [],
#    'MSH': ['MSH/D007249'],
#    'RXNORM': []}],
#  'Palmoplantar psoriasis': [{'preferredTerms': 'Palmoplantar psoriasis',
#    'entityids': 'UMLS/C4476828',
#    'HPO': ['HPO/HP:0025524'],
#    'MSH': [],
#    'RXNORM': []}],
#  'Pancreatic neuroendocrine tumor (pnet)': [{'preferredTerms': 'Well Differentiated Pancreatic Endocrine Tumor',
#    'entityids': 'UMLS/C1337011',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Pancreatitis, acute necrotizing': [{'preferredTerms': 'Pancreatitis',
#    'entityids': 'UMLS/C0030305',
#    'HPO': ['HPO/HP:0001733'],
#    'MSH': ['MSH/D010195'],
#    'RXNORM': []},
#   {'preferredTerms': 'Necrotizing granulomatous inflammation',
#    'entityids': 'UMLS/C0021386',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Panic disorder': [{'preferredTerms': 'Panic Disorder',
#    'entityids': 'UMLS/C0030319',
#    'HPO': [],
#    'MSH': ['MSH/D016584'],
#    'RXNORM': []}],
#  'Papillomavirus infections': [{'preferredTerms': 'Human papilloma virus infection',
#    'entityids': 'UMLS/C0343641',
#    'HPO': [],
#    'MSH': ['MSH/D030361'],
#    'RXNORM': []}],
#  'Parkinson disease': [{'preferredTerms': 'Parkinson Disease',
#    'entityids': 'UMLS/C0030567',
#    'HPO': [],
#    'MSH': ['MSH/D010300'],
#    'RXNORM': []}],
#  "Parkinson's disease dementia": [{'preferredTerms': 'Parkinson Disease',
#    'entityids': 'UMLS/C0030567',
#    'HPO': [],
#    'MSH': ['MSH/D010300'],
#    'RXNORM': []},
#   {'preferredTerms': 'Dementia',
#    'entityids': 'UMLS/C0497327',
#    'HPO': ['HPO/HP:0000726'],
#    'MSH': ['MSH/D003704'],
#    'RXNORM': []}],
#  'Partial epilepsy': [{'preferredTerms': 'Epilepsies, Partial',
#    'entityids': 'UMLS/C0014547',
#    'HPO': [],
#    'MSH': ['MSH/D004828'],
#    'RXNORM': []}],
#  'Partial onset seizures': [{'preferredTerms': 'Seizures',
#    'entityids': 'UMLS/C0036572',
#    'HPO': ['HPO/HP:0001250'],
#    'MSH': ['MSH/D012640'],
#    'RXNORM': []}],
#  'Peripheral neuropathic pain': [{'preferredTerms': 'Neuralgia',
#    'entityids': 'UMLS/C0027796',
#    'HPO': ['HPO/HP:0033345'],
#    'MSH': ['MSH/D009437'],
#    'RXNORM': []}],
#  'Peripheral neuropathies': [{'preferredTerms': 'Peripheral Neuropathy',
#    'entityids': 'UMLS/C0031117',
#    'HPO': ['HPO/HP:0009830'],
#    'MSH': [],
#    'RXNORM': []}],
#  'Persistent asthma': [{'preferredTerms': 'Asthma',
#    'entityids': 'UMLS/C0004096',
#    'HPO': ['HPO/HP:0002099'],
#    'MSH': ['MSH/D001249'],
#    'RXNORM': []}],
#  'Pertussis': [{'preferredTerms': 'Pertussis',
#    'entityids': 'UMLS/C0043167',
#    'HPO': [],
#    'MSH': ['MSH/D014917'],
#    'RXNORM': []}],
#  'Philadelphia chromosome positive acute lymphoblastic leukemia (ph+ all)': [{'preferredTerms': 'Acute lymphocytic leukemia',
#    'entityids': 'UMLS/C0023449',
#    'HPO': ['HPO/HP:0006721'],
#    'MSH': [],
#    'RXNORM': []}],
#  'Plaque psoriasis': [{'preferredTerms': 'Psoriasis',
#    'entityids': 'UMLS/C0033860',
#    'HPO': ['HPO/HP:0003765'],
#    'MSH': ['MSH/D011565'],
#    'RXNORM': []}],
#  'Pneumonia, community-acquired': [{'preferredTerms': 'Pneumonia',
#    'entityids': 'UMLS/C0032285',
#    'HPO': ['HPO/HP:0002090'],
#    'MSH': ['MSH/D011014'],
#    'RXNORM': []},
#   {'preferredTerms': 'Community-Acquired Infections',
#    'entityids': 'UMLS/C0206171',
#    'HPO': [],
#    'MSH': ['MSH/D017714'],
#    'RXNORM': []}],
#  'Poliomyelitis': [{'preferredTerms': 'Poliomyelitis',
#    'entityids': 'UMLS/C0032371',
#    'HPO': [],
#    'MSH': ['MSH/D011051'],
#    'RXNORM': []}],
#  'Post-polycythemia vera myelofibrosis (ppv-mf)': [{'preferredTerms': 'Post-polycythemia vera myelofibrosis',
#    'entityids': 'UMLS/C3805232',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []},
#   {'preferredTerms': 'Primary Myelofibrosis',
#    'entityids': 'UMLS/C0001815',
#    'HPO': [],
#    'MSH': ['MSH/D055728'],
#    'RXNORM': []}],
#  'Post-stroke spasticity': [{'preferredTerms': 'Muscle Spasticity',
#    'entityids': 'UMLS/C0026838',
#    'HPO': ['HPO/HP:0001257'],
#    'MSH': ['MSH/D009128'],
#    'RXNORM': []}],
#  'Post-traumatic stress disorder': [{'preferredTerms': 'Post-Traumatic Stress Disorder',
#    'entityids': 'UMLS/C0038436',
#    'HPO': ['HPO/HP:0033676'],
#    'MSH': ['MSH/D013313'],
#    'RXNORM': []}],
#  'Postherpetic neuralgia': [{'preferredTerms': 'Postherpetic neuralgia',
#    'entityids': 'UMLS/C0032768',
#    'HPO': [],
#    'MSH': ['MSH/D051474'],
#    'RXNORM': []}],
#  'Postherpetic neuralgia (phn)': [{'preferredTerms': 'Postherpetic neuralgia',
#    'entityids': 'UMLS/C0032768',
#    'HPO': [],
#    'MSH': ['MSH/D051474'],
#    'RXNORM': []}],
#  'Postmenopausal osteoporosis': [{'preferredTerms': 'Osteoporosis, Postmenopausal',
#    'entityids': 'UMLS/C0029458',
#    'HPO': [],
#    'MSH': ['MSH/D015663'],
#    'RXNORM': []}],
#  'Postoperative nausea and vomiting': [{'preferredTerms': 'Nausea',
#    'entityids': 'UMLS/C0027497',
#    'HPO': ['HPO/HP:0002018'],
#    'MSH': ['MSH/D009325'],
#    'RXNORM': []},
#   {'preferredTerms': 'Vomiting',
#    'entityids': 'UMLS/C0042963',
#    'HPO': ['HPO/HP:0002013'],
#    'MSH': ['MSH/D014839'],
#    'RXNORM': []}],
#  'Postpartum hemorrhage': [{'preferredTerms': 'Postpartum Hemorrhage',
#    'entityids': 'UMLS/C0032797',
#    'HPO': ['HPO/HP:0011891'],
#    'MSH': ['MSH/D006473'],
#    'RXNORM': []}],
#  'Premature ejaculation': [{'preferredTerms': 'Premature Ejaculation',
#    'entityids': 'UMLS/C0033038',
#    'HPO': ['HPO/HP:0012876'],
#    'MSH': ['MSH/D061686'],
#    'RXNORM': []}],
#  'Premature obstetric labour': [{'preferredTerms': 'Premature Obstetric Labor',
#    'entityids': 'UMLS/C0022876',
#    'HPO': [],
#    'MSH': ['MSH/D007752'],
#    'RXNORM': []}],
#  'Premenstrual syndrome': [{'preferredTerms': 'Premenstrual syndrome',
#    'entityids': 'UMLS/C0033046',
#    'HPO': [],
#    'MSH': ['MSH/D011293'],
#    'RXNORM': []}],
#  'Prostate cancer': [{'preferredTerms': 'Malignant Neoplasms',
#    'entityids': 'UMLS/C0006826',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Prostate neoplasms': [{'preferredTerms': 'Prostatic Neoplasms',
#    'entityids': 'UMLS/C0033578',
#    'HPO': ['HPO/HP:0100787'],
#    'MSH': ['MSH/D011471'],
#    'RXNORM': []}],
#  'Prostatic hyperplasia': [{'preferredTerms': 'Prostatic Hyperplasia',
#    'entityids': 'UMLS/C2937421',
#    'HPO': [],
#    'MSH': ['MSH/D011470'],
#    'RXNORM': []}],
#  'Psoriasis': [{'preferredTerms': 'Psoriasis',
#    'entityids': 'UMLS/C0033860',
#    'HPO': ['HPO/HP:0003765'],
#    'MSH': ['MSH/D011565'],
#    'RXNORM': []}],
#  'Psoriatic arthritis': [{'preferredTerms': 'Arthritis, Psoriatic',
#    'entityids': 'UMLS/C0003872',
#    'HPO': [],
#    'MSH': ['MSH/D015535'],
#    'RXNORM': []}],
#  'Pulmonary arterial hypertension': [{'preferredTerms': 'Pulmonary arterial hypertension',
#    'entityids': 'UMLS/C2973725',
#    'HPO': ['HPO/HP:0002092'],
#    'MSH': ['MSH/D000081029'],
#    'RXNORM': []}],
#  'Pulmonary edema': [{'preferredTerms': 'Pulmonary Edema',
#    'entityids': 'UMLS/C0034063',
#    'HPO': ['HPO/HP:0100598'],
#    'MSH': ['MSH/D011654'],
#    'RXNORM': []}],
#  'Pulmonary embolism': [{'preferredTerms': 'Pulmonary Embolism',
#    'entityids': 'UMLS/C0034065',
#    'HPO': ['HPO/HP:0002204'],
#    'MSH': ['MSH/D011655'],
#    'RXNORM': []}],
#  'Pulmonary hypertension': [{'preferredTerms': 'Pulmonary Hypertension',
#    'entityids': 'UMLS/C0020542',
#    'HPO': [],
#    'MSH': ['MSH/D006976'],
#    'RXNORM': []}],
#  'Refractory partial seizures': [{'preferredTerms': 'Seizures, Focal',
#    'entityids': 'UMLS/C0751495',
#    'HPO': ['HPO/HP:0007359'],
#    'MSH': ['MSH/D012640'],
#    'RXNORM': []}],
#  'Relapsing-remitting multiple sclerosis': [{'preferredTerms': 'Multiple Sclerosis',
#    'entityids': 'UMLS/C0026769',
#    'HPO': [],
#    'MSH': ['MSH/D009103'],
#    'RXNORM': []}],
#  'Renal cell carcinoma': [{'preferredTerms': 'Renal Cell Carcinoma',
#    'entityids': 'UMLS/C0007134',
#    'HPO': ['HPO/HP:0005584'],
#    'MSH': ['MSH/D002292'],
#    'RXNORM': []}],
#  'Respiratory disorders': [{'preferredTerms': 'Respiration Disorders',
#    'entityids': 'UMLS/C0035204',
#    'HPO': [],
#    'MSH': ['MSH/D012120'],
#    'RXNORM': []}],
#  'Respiratory syncytial virus infections': [{'preferredTerms': 'Respiratory Syncytial Virus Infections',
#    'entityids': 'UMLS/C0035235',
#    'HPO': [],
#    'MSH': ['MSH/D018357'],
#    'RXNORM': []}],
#  'Respiratory tract infections': [{'preferredTerms': 'Respiratory Tract Infections',
#    'entityids': 'UMLS/C0035243',
#    'HPO': ['HPO/HP:0011947'],
#    'MSH': ['MSH/D012141'],
#    'RXNORM': []}],
#  'Restless legs syndrome': [{'preferredTerms': 'Restless Legs Syndrome',
#    'entityids': 'UMLS/C0035258',
#    'HPO': ['HPO/HP:0012452'],
#    'MSH': ['MSH/D012148'],
#    'RXNORM': []}],
#  'Retinal diseases': [{'preferredTerms': 'Retinal Diseases',
#    'entityids': 'UMLS/C0035309',
#    'HPO': ['HPO/HP:0000479', 'HPO/HP:0000488'],
#    'MSH': ['MSH/D012164'],
#    'RXNORM': []}],
#  'Retinopathy of prematurity': [{'preferredTerms': 'Retinopathy of Prematurity',
#    'entityids': 'UMLS/C0035344',
#    'HPO': ['HPO/HP:0500049'],
#    'MSH': ['MSH/D012178'],
#    'RXNORM': []}],
#  'Rheumatoid arthritis': [{'preferredTerms': 'Rheumatoid Arthritis',
#    'entityids': 'UMLS/C0003873',
#    'HPO': ['HPO/HP:0001370'],
#    'MSH': ['MSH/D001172'],
#    'RXNORM': []}],
#  'Rhinitis': [{'preferredTerms': 'Rhinitis',
#    'entityids': 'UMLS/C0035455',
#    'HPO': ['HPO/HP:0012384'],
#    'MSH': ['MSH/D012220'],
#    'RXNORM': []}],
#  'Rhinitis, allergic, perennial': [{'preferredTerms': 'Rhinitis',
#    'entityids': 'UMLS/C0035455',
#    'HPO': ['HPO/HP:0012384'],
#    'MSH': ['MSH/D012220'],
#    'RXNORM': []}],
#  'Rhinitis, allergic, perennial and seasonal': [{'preferredTerms': 'Rhinitis',
#    'entityids': 'UMLS/C0035455',
#    'HPO': ['HPO/HP:0012384'],
#    'MSH': ['MSH/D012220'],
#    'RXNORM': []}],
#  'Rhinitis, allergic, seasonal': [{'preferredTerms': 'Rhinitis',
#    'entityids': 'UMLS/C0035455',
#    'HPO': ['HPO/HP:0012384'],
#    'MSH': ['MSH/D012220'],
#    'RXNORM': []}],
#  'Rotavirus infections': [{'preferredTerms': 'Rotavirus Infections',
#    'entityids': 'UMLS/C0035869',
#    'HPO': [],
#    'MSH': ['MSH/D012400'],
#    'RXNORM': []}],
#  'Rubella': [{'preferredTerms': 'Rubella',
#    'entityids': 'UMLS/C0035920',
#    'HPO': [],
#    'MSH': ['MSH/D012409'],
#    'RXNORM': []}],
#  'Schizophrenia': [{'preferredTerms': 'Schizophrenia',
#    'entityids': 'UMLS/C0036341',
#    'HPO': ['HPO/HP:0100753'],
#    'MSH': ['MSH/D012559'],
#    'RXNORM': []}],
#  'Seborrheic dermatitis': [{'preferredTerms': 'Seborrheic dermatitis',
#    'entityids': 'UMLS/C0036508',
#    'HPO': ['HPO/HP:0001051'],
#    'MSH': ['MSH/D012628'],
#    'RXNORM': []}],
#  'Secondary prevention of thromboembolic events': [{'preferredTerms': 'Thromboembolism',
#    'entityids': 'UMLS/C0040038',
#    'HPO': ['HPO/HP:0001907'],
#    'MSH': ['MSH/D013923'],
#    'RXNORM': []}],
#  'Seizure disorder generalized tonic clonic': [{'preferredTerms': 'Epilepsy',
#    'entityids': 'UMLS/C0014544',
#    'HPO': ['HPO/HP:0001250'],
#    'MSH': ['MSH/D004827'],
#    'RXNORM': []},
#   {'preferredTerms': 'Tonic - clonic seizures',
#    'entityids': 'UMLS/C0494475',
#    'HPO': ['HPO/HP:0002069', 'HPO/HP:0032677'],
#    'MSH': ['MSH/D012640'],
#    'RXNORM': []}],
#  'Seizure, absence': [{'preferredTerms': 'Seizures',
#    'entityids': 'UMLS/C0036572',
#    'HPO': ['HPO/HP:0001250'],
#    'MSH': ['MSH/D012640'],
#    'RXNORM': []},
#   {'preferredTerms': 'Amenorrhea',
#    'entityids': 'UMLS/C0002453',
#    'HPO': ['HPO/HP:0000141'],
#    'MSH': ['MSH/D000568'],
#    'RXNORM': []}],
#  'Seizures': [{'preferredTerms': 'Seizures',
#    'entityids': 'UMLS/C0036572',
#    'HPO': ['HPO/HP:0001250'],
#    'MSH': ['MSH/D012640'],
#    'RXNORM': []}],
#  'Sepsis': [{'preferredTerms': 'Septicemia',
#    'entityids': 'UMLS/C0036690',
#    'HPO': ['HPO/HP:0100806'],
#    'MSH': ['MSH/D018805'],
#    'RXNORM': []}],
#  'Shigella sonnei infection': [{'preferredTerms': 'Shigella sonnei',
#    'entityids': 'UMLS/C0036960',
#    'HPO': [],
#    'MSH': ['MSH/D012764'],
#    'RXNORM': ['RXNORM/1491872']}],
#  'Sickle cell disease': [{'preferredTerms': 'Anemia, Sickle Cell',
#    'entityids': 'UMLS/C0002895',
#    'HPO': [],
#    'MSH': ['MSH/D000755'],
#    'RXNORM': []}],
#  'Sinusitis': [{'preferredTerms': 'Sinusitis',
#    'entityids': 'UMLS/C0037199',
#    'HPO': ['HPO/HP:0000246'],
#    'MSH': ['MSH/D012852'],
#    'RXNORM': []}],
#  "Sjoegren's syndrome": [{'preferredTerms': 'Adie Syndrome',
#    'entityids': 'UMLS/C0001519',
#    'HPO': [],
#    'MSH': ['MSH/D000270'],
#    'RXNORM': []}],
#  'Sleep disorders': [{'preferredTerms': 'Sleep Disorders',
#    'entityids': 'UMLS/C0851578',
#    'HPO': [],
#    'MSH': ['MSH/D012893'],
#    'RXNORM': []}],
#  'Sleep initiation and maintenance disorders': [{}],
#  'Sma - spinal muscular atrophy': [{'preferredTerms': 'Spinal Muscular Atrophy',
#    'entityids': 'UMLS/C0026847',
#    'HPO': ['HPO/HP:0007269'],
#    'MSH': ['MSH/D009134'],
#    'RXNORM': []}],
#  'Small cell carcinoma': [{'preferredTerms': 'Carcinoma, Small Cell',
#    'entityids': 'UMLS/C0262584',
#    'HPO': [],
#    'MSH': ['MSH/D018288'],
#    'RXNORM': []}],
#  'Smoking cessation': [{}],
#  'Social phobia': [{'preferredTerms': 'Phobic anxiety disorder',
#    'entityids': 'UMLS/C0349231',
#    'HPO': [],
#    'MSH': ['MSH/D010698'],
#    'RXNORM': []}],
#  'Soft tissue sarcoma': [{'preferredTerms': 'Sarcoma',
#    'entityids': 'UMLS/C1261473',
#    'HPO': ['HPO/HP:0100242'],
#    'MSH': ['MSH/D012509'],
#    'RXNORM': []}],
#  'Solid tumor cancer with bone metastases': [{'preferredTerms': 'Malignant Neoplasms',
#    'entityids': 'UMLS/C0006826',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []},
#   {'preferredTerms': 'Neoplasm Metastasis',
#    'entityids': 'UMLS/C0027627',
#    'HPO': [],
#    'MSH': ['MSH/D009362'],
#    'RXNORM': []}],
#  'Solid tumours': [{'preferredTerms': 'Neoplasms',
#    'entityids': 'UMLS/C0027651',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Spondyloarthritis': [{'preferredTerms': 'Spondylarthritis',
#    'entityids': 'UMLS/C0949690',
#    'HPO': [],
#    'MSH': ['MSH/D025241'],
#    'RXNORM': []}],
#  'Staphylococcal infections': [{'preferredTerms': 'Staphylococcal Infections',
#    'entityids': 'UMLS/C0038160',
#    'HPO': [],
#    'MSH': ['MSH/D013203'],
#    'RXNORM': []}],
#  'Streptococcal infections': [{'preferredTerms': 'Streptococcal Infections',
#    'entityids': 'UMLS/C0038395',
#    'HPO': [],
#    'MSH': ['MSH/D013290'],
#    'RXNORM': []}],
#  'Streptococcus agalactiae': [{'preferredTerms': 'Streptococcus agalactiae',
#    'entityids': 'UMLS/C0579233',
#    'HPO': [],
#    'MSH': ['MSH/D013292'],
#    'RXNORM': ['RXNORM/1363918']}],
#  'Streptococcus pneumoniae': [{'preferredTerms': 'Streptococcus pneumoniae',
#    'entityids': 'UMLS/C0038410',
#    'HPO': [],
#    'MSH': ['MSH/D013296'],
#    'RXNORM': ['RXNORM/1363917']}],
#  'Substance dependence': [{}],
#  'Systemic juvenile idiopathic arthritis (sjia)': [{'preferredTerms': 'Juvenile arthritis',
#    'entityids': 'UMLS/C3495559',
#    'HPO': ['HPO/HP:0005681'],
#    'MSH': ['MSH/D001171'],
#    'RXNORM': []},
#   {'preferredTerms': 'Systemic onset juvenile chronic arthritis',
#    'entityids': 'UMLS/C1384600',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Systemic lupus erythematosus': [{'preferredTerms': 'Lupus Erythematosus, Systemic',
#    'entityids': 'UMLS/C0024141',
#    'HPO': ['HPO/HP:0002725'],
#    'MSH': ['MSH/D008180'],
#    'RXNORM': []}],
#  'Systemic scleroderma': [{'preferredTerms': 'Systemic Scleroderma',
#    'entityids': 'UMLS/C0036421',
#    'HPO': [],
#    'MSH': ['MSH/D012595'],
#    'RXNORM': []}],
#  'Tendon injuries': [{'preferredTerms': 'Traumatic injury',
#    'entityids': 'UMLS/C3263723',
#    'HPO': [],
#    'MSH': ['MSH/D014947'],
#    'RXNORM': []}],
#  'Tetanus': [{'preferredTerms': 'Tetanus',
#    'entityids': 'UMLS/C0039614',
#    'HPO': [],
#    'MSH': ['MSH/D013742'],
#    'RXNORM': []}],
#  'Therapeutic treatment of inhalation anthrax': [{}],
#  'Thromboembolism': [{'preferredTerms': 'Thromboembolism',
#    'entityids': 'UMLS/C0040038',
#    'HPO': ['HPO/HP:0001907'],
#    'MSH': ['MSH/D013923'],
#    'RXNORM': []}],
#  'Thrombosis, venous': [{'preferredTerms': 'Thrombosis',
#    'entityids': 'UMLS/C0040053',
#    'HPO': [],
#    'MSH': ['MSH/D013927'],
#    'RXNORM': []}],
#  'Thyroid cancer': [{'preferredTerms': 'Malignant Neoplasms',
#    'entityids': 'UMLS/C0006826',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []}],
#  'Tinnitus': [{'preferredTerms': 'Tinnitus',
#    'entityids': 'UMLS/C0040264',
#    'HPO': ['HPO/HP:0000360'],
#    'MSH': ['MSH/D014012'],
#    'RXNORM': []}],
#  'Tobacco use disorder': [{}],
#  'Tonic-clonic epilepsy': [{'preferredTerms': 'Tonic-Clonic Epilepsy',
#    'entityids': 'UMLS/C0014549',
#    'HPO': [],
#    'MSH': ['MSH/D004830'],
#    'RXNORM': []}],
#  'Tooth erosion': [{'preferredTerms': 'Tooth Erosion',
#    'entityids': 'UMLS/C0040436',
#    'HPO': [],
#    'MSH': ['MSH/D014077'],
#    'RXNORM': []}],
#  'Toxoplasmosis': [{'preferredTerms': 'Toxoplasmosis',
#    'entityids': 'UMLS/C0040558',
#    'HPO': [],
#    'MSH': ['MSH/D014123'],
#    'RXNORM': []}],
#  'Transient ischaemic attack': [{'preferredTerms': 'Transient Ischemic Attack',
#    'entityids': 'UMLS/C0007787',
#    'HPO': ['HPO/HP:0002326'],
#    'MSH': ['MSH/D002546'],
#    'RXNORM': []}],
#  'Transplantation, kidney': [{}],
#  'Transplantation, liver': [{}],
#  'Transplantation, organ': [{}],
#  'Tuberculosis': [{'preferredTerms': 'Tuberculosis',
#    'entityids': 'UMLS/C0041296',
#    'HPO': [],
#    'MSH': ['MSH/D014376'],
#    'RXNORM': []}],
#  'Tumors characterized by genetic abnormalities of alk': [{'preferredTerms': 'Neoplasms',
#    'entityids': 'UMLS/C0027651',
#    'HPO': ['HPO/HP:0002664'],
#    'MSH': ['MSH/D009369'],
#    'RXNORM': []},
#   {'preferredTerms': 'Molecular Abnormality',
#    'entityids': 'UMLS/C0262496',
#    'HPO': [],
#    'MSH': [],
#    'RXNORM': []}],
#  'Type 1 diabetes mellitus': [{'preferredTerms': 'Diabetes Mellitus, Insulin-Dependent',
#    'entityids': 'UMLS/C0011854',
#    'HPO': ['HPO/HP:0100651'],
#    'MSH': ['MSH/D003922'],
#    'RXNORM': []}],
#  'Type 2 diabetes': [{'preferredTerms': 'Diabetes Mellitus, Non-Insulin-Dependent',
#    'entityids': 'UMLS/C0011860',
#    'HPO': ['HPO/HP:0005978'],
#    'MSH': ['MSH/D003924'],
#    'RXNORM': []}],
#  'Type 2 diabetes mellitus': [{'preferredTerms': 'Diabetes Mellitus, Non-Insulin-Dependent',
#    'entityids': 'UMLS/C0011860',
#    'HPO': ['HPO/HP:0005978'],
#    'MSH': ['MSH/D003924'],
#    'RXNORM': []}],
#  'Typhoid fever': [{'preferredTerms': 'Typhoid Fever',
#    'entityids': 'UMLS/C0041466',
#    'HPO': [],
#    'MSH': ['MSH/D014435'],
#    'RXNORM': []}],
#  'Ulcers, duodenal and gastric': [{'preferredTerms': 'Ulcer',
#    'entityids': 'UMLS/C0041582',
#    'HPO': [],
#    'MSH': ['MSH/D014456'],
#    'RXNORM': []}],
#  'Uncontrolled asthma': [{'preferredTerms': 'Asthma',
#    'entityids': 'UMLS/C0004096',
#    'HPO': ['HPO/HP:0002099'],
#    'MSH': ['MSH/D001249'],
#    'RXNORM': []}],
#  'Urinary bladder, overactive': [{}],
#  'Urinary incontinence': [{'preferredTerms': 'Urinary Incontinence',
#    'entityids': 'UMLS/C0042024',
#    'HPO': ['HPO/HP:0000020'],
#    'MSH': ['MSH/D014549'],
#    'RXNORM': []}],
#  'Urologic diseases': [{'preferredTerms': 'Urologic Diseases',
#    'entityids': 'UMLS/C0042075',
#    'HPO': [],
#    'MSH': ['MSH/D014570'],
#    'RXNORM': []}],
#  'Urticaria': [{'preferredTerms': 'Urticaria',
#    'entityids': 'UMLS/C0042109',
#    'HPO': ['HPO/HP:0001025'],
#    'MSH': ['MSH/D014581'],
#    'RXNORM': []}],
#  'Varicella': [{'preferredTerms': 'Chickenpox',
#    'entityids': 'UMLS/C0008049',
#    'HPO': [],
#    'MSH': ['MSH/D002644'],
#    'RXNORM': []}],
#  'Vascular disease, peripheral': [{'preferredTerms': 'Vascular Diseases',
#    'entityids': 'UMLS/C0042373',
#    'HPO': [],
#    'MSH': ['MSH/D014652'],
#    'RXNORM': []}],
#  'Vasculitis': [{'preferredTerms': 'Vasculitis',
#    'entityids': 'UMLS/C0042384',
#    'HPO': ['HPO/HP:0002633'],
#    'MSH': ['MSH/D014657'],
#    'RXNORM': []}],
#  'Vasomotor rhinitis': [{'preferredTerms': 'Rhinitis, Vasomotor',
#    'entityids': 'UMLS/C0035460',
#    'HPO': [],
#    'MSH': ['MSH/D012223'],
#    'RXNORM': []}],
#  'Virus diseases': [{'preferredTerms': 'Virus Diseases',
#    'entityids': 'UMLS/C0042769',
#    'HPO': [],
#    'MSH': ['MSH/D014777'],
#    'RXNORM': []}],
#  'Vomiting': [{'preferredTerms': 'Vomiting',
#    'entityids': 'UMLS/C0042963',
#    'HPO': ['HPO/HP:0002013'],
#    'MSH': ['MSH/D014839'],
#    'RXNORM': []}],
#  'Wet age related macular degeneration (amd)': [{'preferredTerms': 'Macular degeneration',
#    'entityids': 'UMLS/C0024437',
#    'HPO': ['HPO/HP:0000608'],
#    'MSH': ['MSH/D008268'],
#    'RXNORM': []},
#   {'preferredTerms': 'Glycogen storage disease type II',
#    'entityids': 'UMLS/C0017921',
#    'HPO': [],
#    'MSH': ['MSH/D006009'],
#    'RXNORM': []}],
#  'Whole cell pertussis': [{'preferredTerms': 'Pertussis',
#    'entityids': 'UMLS/C0043167',
#    'HPO': [],
#    'MSH': ['MSH/D014917'],
#    'RXNORM': []}],
#  'Wound healing': [{'preferredTerms': 'Injury wounds',
#    'entityids': 'UMLS/C0043250',
#    'HPO': [],
#    'MSH': ['MSH/D014947'],
#    'RXNORM': []}]}

# %%
trial_conditions = []

condition_nodes = {}

for i, row in clinical_trials.iterrows():
    for x in row["Medical Condition"].split("; "):
        x = x.strip().lower().capitalize()

        query = ""
        if x in condition_abnornaml_list_mapping:
            if condition_abnornaml_list_mapping[x] != "":
                query = condition_abnornaml_list_mapping[x]
        else:
            query = x

        if query in condition_gcp_nlp:
            for entity in condition_gcp_nlp[query]:
                if "entityids" in entity:
                    trial_conditions.append((row["Posting ID"], entity["entityids"]))

                    condition_nodes[entity["entityids"]] = {"name": entity["preferredTerms"], "HPO": entity["HPO"], "MSH": entity["MSH"], "RXNORM": entity["RXNORM"]}

# %%
content = "from\tto\n"
for row in trial_conditions:
    content += f"{row[0]}\t{row[1]}\n"

with open(f"{output_folder}/trial_conditions.tsv", "w") as f:
    f.write(content)

# %%
content = "UMLS\tname\tHPO\tMSH\tRXNORM\n"
for c in condition_nodes:
    content += f"{c}\t{condition_nodes[c]['name']}\t{'|'.join(condition_nodes[c]['HPO'])}\t{'|'.join(condition_nodes[c]['MSH'])}\t{'|'.join(condition_nodes[c]['RXNORM'])}\n"

with open(f"{output_folder}/conditions.tsv", "w") as f:
    f.write(content)

# %%
medicine_abnornaml_list_mapping = {
                                    "Nan": "",
                                    "Lanalumab": "lanadelumab",
                                    "Papzopanib": "pazopanib",
                                    "Indacterol": "indacaterol",
                                    "Seralaxin": "Serelaxin",
                                    "Haemophilus influenzae type b": "Haemophilus influenzae type b vaccine"
                                }

# %%
rx_cryptic_drug = re.compile(r'[A-Za-z]+\d+')

# %%
medicine = []
cryptic_drugs = []


content = ""
for m in clinical_trials["Medicine or Vaccine (generic name)"].unique():
    for x in str(m).split(";"):
        x = x.strip().lower().capitalize()

        if x in medicine_abnornaml_list_mapping:
            if medicine_abnornaml_list_mapping[x] != "":
                medicine.append(medicine_abnornaml_list_mapping[x])
        else:
            if rx_cryptic_drug.match(x) is None:
                medicine.append(x)
            else:
                if "vaccine" in x:
                    medicine.append(x)
                else:
                    for s in x.split("/"):
                        cryptic_drugs.append(s.strip())
                        

medicine = sorted(list(set(medicine)))

content = ""
for c in medicine:
    content += c + "\n"

with open("medicines.txt", "w") as f:
    f.write(content)

content = ""
for c in cryptic_drugs:
    content += c + "\n"

with open("cryptic_medicines.txt", "w") as f:
    f.write(content)

# %%
medicine_corrections = {
    "Benzoyl peroxide/clindamycin": [{"preferredTerms": "benzoyl peroxide / clindamycin", "entityids": "UMLS/C1720375", "HPO": [], "MSH": ["MSH/C466951"], "RXNORM": ["RXNORM/646781"]}],
    "Casopitant": [{"preferredTerms": "casopitant", "entityids": "UMLS/C2347566", "HPO": [], "MSH": [], "RXNORM": []}],
    "Alisporivir": [{"preferredTerms": "alisporivir", "entityids": "UMLS/C1567950", "HPO": [], "MSH": ["MSH/C499715"], "RXNORM": []}],
    "Indacterol": [{"preferredTerms": "Recombinant Interleukin-18", "entityids": "UMLS/C1527127", "HPO": [], "MSH": [], "RXNORM": []}],
    "Iboctadekin": [{"preferredTerms": "Recombinant Interleukin-18", "entityids": "UMLS/C1527127", "HPO": [], "MSH": [], "RXNORM": []}],
    "Human papillomavirus types 16 and 18 vaccine": [{"preferredTerms": "human papillomavirus vaccine, L1 type 16, 18", "entityids": "UMLS/C1721788", "HPO": [], "MSH": ["MSH/C510352"], "RXNORM": []}]
}

# %%
offset_text = []


begin = 0
with open('medicines.txt') as f:
    for line in f.readlines():
        end = begin + len(line)
        offset_text.append((begin, end, line.strip()))

        begin += len(line)

# %%
gcp_token = check_output(["gcloud", "auth", "print-access-token"], encoding='UTF-8').strip()
#test_text = ";".join([x[2] for x in offset_text])

test_text = ""
content = ""

for x in offset_text:

    if len(test_text) + len(x[2]) < 10000:

        test_text += x[2] + ";"

    else:
        test_text = test_text[:-1]

        result = healthcare_nlp.get_healthcare_json(test_text, gcp_token)

        temp = healthcare_nlp.get_json(json_form, "MEDICINE", medicine_corrections, offset_text)

        content += "\n".join([json.dumps(x) for x in temp]) + "\n"

        test_text = x[2] + ";"


if test_text != "":
    test_text = test_text[:-1]

    result = healthcare_nlp.get_healthcare_json(test_text, gcp_token)

    json_form = json.loads(result)

    temp = healthcare_nlp.get_json(json_form, "MEDICINE", medicine_corrections, offset_text)

    content += "\n".join([json.dumps(x) for x in temp]) + "\n"
# Out:
# {'UMLS/C0001927': {'preferredTerm': 'albuterol', 'vocabularyCodes': ['LNC/LP17843-1', 'LNC/MTHU013596', 'MSH/D000420', 'MTH/NOCODE', 'NCI/C215', 'RXNORM/435', 'VANDF/4018796']}, 'UMLS/C0003330': {'preferredTerm': 'Antigens, Fungal', 'vocabularyCodes': ['MSH/D000946']}, 'UMLS/C0003341': {'preferredTerm': 'Antigens, Tumor-Associated, Carbohydrate', 'vocabularyCodes': ['MSH/D015295']}, 'UMLS/C0003372': {'preferredTerm': 'Antilymphocyte Serum', 'vocabularyCodes': ['MSH/D000961', 'MTH/NOCODE', 'NCI/C62577']}, 'UMLS/C0003442': {'preferredTerm': 'lymphocyte immune globulin, anti-thymocyte globulin', 'vocabularyCodes': ['MSH/D000961', 'MTH/NOCODE', 'NCI/C278', 'RXNORM/1011', 'VANDF/4018097', 'VANDF/4022194']}, 'UMLS/C0004057': {'preferredTerm': 'aspirin', 'vocabularyCodes': ['LNC/LA26702-3', 'MSH/D001241', 'MTH/NOCODE', 'MTH/U000319', 'MTH/U000320', 'NCI/C287', 'RXNORM/1191', 'VANDF/4017536']}, 'UMLS/C0005088': {'preferredTerm': 'benzoyl peroxide', 'vocabularyCodes': ['MSH/D001585', 'MTH/NOCODE', 'NCI/C47411', 'RXNORM/1418', 'VANDF/4018562']}, 'UMLS/C0007538': {'preferredTerm': 'cefadroxil', 'vocabularyCodes': ['LNC/LP17101-4', 'LNC/MTHU005578', 'MSH/D002434', 'MTH/NOCODE', 'NCI/C28912', 'RXNORM/2177', 'VANDF/4018151']}, 'UMLS/C0008809': {'preferredTerm': 'ciprofloxacin', 'vocabularyCodes': ['LNC/LP15380-6', 'LNC/MTHU004599', 'MSH/D002939', 'MTH/NOCODE', 'NCI/C375', 'RXNORM/2551', 'VANDF/4019307']}, 'UMLS/C0008947': {'preferredTerm': 'clindamycin', 'vocabularyCodes': ['LNC/LP15427-5', 'LNC/MTHU006899', 'MSH/D002981', 'MTH/NOCODE', 'NCI/C377', 'RXNORM/2582', 'VANDF/4019683']}, 'UMLS/C0008992': {'preferredTerm': 'clobetasol', 'vocabularyCodes': ['MSH/D002990', 'MTH/NOCODE', 'NCI/C65339', 'RXNORM/2590', 'VANDF/4019684']}, 'UMLS/C0010980': {'preferredTerm': 'dapsone', 'vocabularyCodes': ['LNC/LP17991-8', 'LNC/LP32038-9', 'LNC/MTHU024811', 'MSH/D003622', 'MTH/NOCODE', 'NCI/C415', 'RXNORM/3108', 'VANDF/4019264']}, 'UMLS/C0012265': {'preferredTerm': 'digoxin', 'vocabularyCodes': ['LNC/LP14714-7', 'LNC/MTHU001808', 'MSH/D004077', 'MTH/NOCODE', 'MTH/U000251', 'NCI/C28990', 'RXNORM/3407', 'VANDF/4018047']}, 'UMLS/C0012546': {'preferredTerm': 'Diphtheria', 'vocabularyCodes': ['ICD9CM/032', 'ICD9CM/032.9', 'LNC/LA10452-3', 'MEDLINEPLUS/1512', 'MSH/D004165', 'MTH/NOCODE', 'NCI/C34541']}, 'UMLS/C0012547': {'preferredTerm': 'diphtheria antitoxin', 'vocabularyCodes': ['MSH/D004166', 'MTH/NOCODE', 'RXNORM/3510', 'VANDF/4022109']}, 'UMLS/C0012550': {'preferredTerm': 'Diphtheria Toxin', 'vocabularyCodes': ['LNC/LP21127-3', 'MSH/D004167', 'NCI/C444']}, 'UMLS/C0012551': {'preferredTerm': 'diphtheria toxoid vaccine, inactivated', 'vocabularyCodes': ['MSH/D004168', 'MTH/NOCODE', 'NCI/C77707', 'RXNORM/798304', 'VANDF/4017753']}, 'UMLS/C0012933': {'preferredTerm': 'DNA, Ribosomal', 'vocabularyCodes': ['MSH/D004275', 'MTH/NOCODE', 'NCI/C95943']}, 'UMLS/C0014025': {'preferredTerm': 'enalapril', 'vocabularyCodes': ['LNC/LP171394-2', 'MSH/D004656', 'MTH/NOCODE', 'NCI/C62027', 'RXNORM/3827', 'VANDF/4019744']}, 'UMLS/C0015399': {'preferredTerm': 'Eye Drops', 'vocabularyCodes': ['HPO/HP:0000508', 'LNC/LA14707-6', 'MSH/D009883', 'MTH/NOCODE', 'NCI/C91163', 'RXNORM/4230', 'VANDF/4027349']}, 'UMLS/C0017278': {'preferredTerm': 'Gene Products, env', 'vocabularyCodes': ['MSH/D015686', 'MTH/NOCODE', 'NCI/C16610']}, 'UMLS/C0017279': {'preferredTerm': 'Gene Products, gag', 'vocabularyCodes': ['MSH/D015683', 'NCI/C20588']}, 'UMLS/C0017649': {'preferredTerm': 'Globulins', 'vocabularyCodes': ['LNC/LP14885-5', 'LNC/LP32057-9', 'LNC/MTHU002109', 'MSH/D005916', 'MTH/NOCODE', 'NCI/C17125']}, 'UMLS/C0017970': {'preferredTerm': 'glycopyrrolate', 'vocabularyCodes': ['MSH/D006024', 'MTH/NOCODE', 'NCI/C29078', 'RXNORM/4955', 'VANDF/4018421']}, 'UMLS/C0018242': {'preferredTerm': 'griseofulvin', 'vocabularyCodes': ['LNC/LP18091-6', 'LNC/MTHU003374', 'MSH/D006118', 'MTH/NOCODE', 'NCI/C65819', 'RXNORM/5021', 'VANDF/4018217']}, 'UMLS/C0019163': {'preferredTerm': 'Hepatitis B', 'vocabularyCod ...
# {'content': 'pneumococcal polysaccharide', 'beginOffset': 10} [{'entityId': 'UMLS/C0245576'}, {'entityId': 'UMLS/C0305065'}, {'entityId': 'UMLS/C1098021'}, {'entityId': 'UMLS/C1098022'}] 0.5190078020095825
# {'content': 'haemophilus influenzae protein', 'beginOffset': 55} [{'entityId': 'UMLS/C0206514'}, {'entityId': 'UMLS/C0369290'}, {'entityId': 'UMLS/C1566328'}] 0.6549157500267029
# {'content': 'conjugate vaccine', 'beginOffset': 88} [{'entityId': 'UMLS/C0206515'}] 0.6425295472145081
# {'content': 'pneumococcal polysaccharide', 'beginOffset': 116} [{'entityId': 'UMLS/C0245576'}, {'entityId': 'UMLS/C0305065'}, {'entityId': 'UMLS/C1098021'}, {'entityId': 'UMLS/C1098022'}] 0.609725832939148
# {'content': 'haemophilus influenzae protein', 'beginOffset': 161} [{'entityId': 'UMLS/C0206514'}, {'entityId': 'UMLS/C0369290'}, {'entityId': 'UMLS/C1566328'}] 0.6149871349334717
# {'content': 'conjugate vaccine', 'beginOffset': 194} [{'entityId': 'UMLS/C0206515'}] 0.48033976554870605
# {'content': 'Abacavir', 'beginOffset': 212} [{'entityId': 'UMLS/C0663655'}] 0.9603832364082336
# {'content': 'Abacavir/lamivudine', 'beginOffset': 221} [{'entityId': 'UMLS/C1613391'}] 0.552099883556366
# {'content': 'Abacavir', 'beginOffset': 241} [{'entityId': 'UMLS/C0663655'}] 0.9580701589584351
# {'content': 'lamivudine', 'beginOffset': 250} [{'entityId': 'UMLS/C0209738'}] 0.8957136273384094
# {'content': 'zidovudine', 'beginOffset': 261} [{'entityId': 'UMLS/C0043474'}] 0.9415835738182068
# {'content': 'Acetylsalicylic acid/pantoprazole', 'beginOffset': 272} [{'entityId': 'UMLS/C0004057'}] 0.6609262824058533
# {'content': 'Adefovir', 'beginOffset': 306} [{'entityId': 'UMLS/C0050175'}] 0.9758250117301941
# {'content': 'lamivudine', 'beginOffset': 315} [{'entityId': 'UMLS/C0209738'}] 0.9466736316680908
# {'content': 'Albiglutide', 'beginOffset': 326} [{'entityId': 'UMLS/C2607479'}] 0.9908285737037659
# {'content': 'Albiglutide/metformin', 'beginOffset': 338} [{'entityId': 'UMLS/C2607479'}] 0.6554814577102661
# {'content': 'Alitretinoin', 'beginOffset': 372} [{'entityId': 'UMLS/C0281666'}] 0.9982038736343384
# {'content': 'Alpelisib', 'beginOffset': 385} [{'entityId': 'UMLS/C4055478'}] 0.9909002780914307
# {'content': 'Amlodipine/benazepril hcl', 'beginOffset': 395} [{'entityId': 'UMLS/C0717411'}] 0.7397399544715881
# {'content': 'Amlodipine/enalapril', 'beginOffset': 421} [{'entityId': 'UMLS/C0014025'}] 0.5489432215690613
# {'content': 'Amlodipine', 'beginOffset': 442} [{'entityId': 'UMLS/C0051696'}] 0.9745073914527893
# {'content': 'losartan', 'beginOffset': 453} [{'entityId': 'UMLS/C0126174'}] 0.9538823962211609
# {'content': 'Amlodipine', 'beginOffset': 462} [{'entityId': 'UMLS/C0051696'}] 0.9687915444374084
# {'content': 'rosuvastatin', 'beginOffset': 473} [{'entityId': 'UMLS/C0965129'}] 0.939814031124115
# {'content': 'Amoxicillin/clavulanic acid', 'beginOffset': 486} [{'entityId': 'UMLS/C0054066'}] 0.7776407599449158
# {'content': 'Artesunate', 'beginOffset': 514} [{'entityId': 'UMLS/C0052432'}] 0.946690559387207
# {'content': 'chlorproguanil', 'beginOffset': 525} [{'entityId': 'UMLS/C0055470'}] 0.9024220705032349
# {'content': 'dapsone', 'beginOffset': 540} [{'entityId': 'UMLS/C0010980'}] 0.9328754544258118
# {'content': 'Atorvastatin/glimepiride', 'beginOffset': 548} [{'entityId': 'UMLS/C0061323'}] 0.5167374014854431
# {'content': 'Batefenterol', 'beginOffset': 573} [{'entityId': 'UMLS/C4519138'}] 0.9968811273574829
# {'content': 'Belimumab', 'beginOffset': 586} [{'entityId': 'UMLS/C1723401'}] 0.9961068630218506
# {'content': 'Benzoyl peroxide', 'beginOffset': 596} [{'entityId': 'UMLS/C0005088'}] 0.9544157385826111
# {'content': 'clindamycin', 'beginOffset': 613} [{'entityId': 'UMLS/C0008947'}] 0.9513657689094543
# {'content': 'Benzoyl peroxide/clindamycin phosphate', 'beginOffset': 625} [{'entityId': 'UMLS/C1720375'}] 0.7177574634552002
# {'content': 'Benzoyl peroxide/salicylic acid', 'beginOffset': 664} [{'entityId': 'UMLS/C2929668'}] 0.8090472221374512
# {'content': 'Brinzolamide', 'beginOffset': 696} [{'entityId': 'UMLS/C0673966'}] 0.9949681162834167
# {'content': 'Brolucizumab', 'beginOffset': 709} [{'entityId': 'UMLS/C4550124'}] 0.9944244623184204
# {'content': 'Bupropion', 'beginOffset': 722} [{'entityId': 'UMLS/C0085208'}] 0.9925255179405212
# {'content': 'Cabotegravir', 'beginOffset': 732} [{'entityId': 'UMLS/C4310385'}] 0.9908441305160522
# {'content': 'Calcipotriol', 'beginOffset': 745} [{'entityId': 'UMLS/C0065767'}] 0.9488076567649841
# {'content': 'calcipotriene', 'beginOffset': 759} [{'entityId': 'UMLS/C0065767'}] 0.8957465291023254
# {'content': 'Camicinal', 'beginOffset': 773} [{'entityId': 'UMLS/C4519144'}] 0.979870617389679
# {'content': 'Canakinumab', 'beginOffset': 783} [{'entityId': 'UMLS/C2718773'}] 0.990576446056366
# {'content': 'Candesartan', 'beginOffset': 795} [{'entityId': 'UMLS/C0717550'}] 0.9891654849052429
# {'content': 'Candesartan cilexetil/hydrochlorothiazide', 'beginOffset': 807} [{'entityId': 'UMLS/C0527379'}] 0.765342116355896
# {'content': 'Carbomer and carmellose sodium gel', 'beginOffset': 849} [{'entityId': 'UMLS/C0037487'}] 0.6364884972572327
# {'content': 'Carvedilol', 'beginOffset': 884} [{'entityId': 'UMLS/C0054836'}, {'entityId': 'UMLS/C4704735'}, {'entityId': 'UMLS/C4704736'}] 0.9966771006584167
# {'content': 'Carvedilol', 'beginOffset': 895} [{'entityId': 'UMLS/C0054836'}, {'entityId': 'UMLS/C4704735'}, {'entityId': 'UMLS/C4704736'}] 0.9767431616783142
# {'content': 'lisinopril', 'beginOffset': 906} [{'entityId': 'UMLS/C0065374'}] 0.9600372910499573
# {'content': 'Cefadroxil', 'beginOffset': 928} [{'entityId': 'UMLS/C0007538'}] 0.997178852558136
# {'content': 'Cefixime', 'beginOffset': 939} [{'entityId': 'UMLS/C0060400'}] 0.9973928928375244
# {'content': 'Cefuroxime axetil', 'beginOffset': 948} [{'entityId': 'UMLS/C0055015'}] 0.6188790798187256
# {'content': 'Ceritinib', 'beginOffset': 966} [{'entityId': 'UMLS/C3818721'}] 0.9982356429100037
# {'content': 'Certolizumab', 'beginOffset': 976} [{'entityId': 'UMLS/C1872109'}] 0.9853734374046326
# {'content': 'Cilomilast', 'beginOffset': 995} [{'entityId': 'UMLS/C0968887'}] 0.9965181946754456
# {'content': 'Cilomilast/salmeterol/fluticasone propionate', 'beginOffset': 1006} [{'entityId': 'UMLS/C0968887'}] 0.7172675132751465
# {'content': 'Ciprofloxacin', 'beginOffset': 1051} [{'entityId': 'UMLS/C0008809'}] 0.9983096122741699
# {'content': 'Clobetasol', 'beginOffset': 1065} [{'entityId': 'UMLS/C0008992'}] 0.9932810068130493
# {'content': 'diphtheria', 'beginOffset': 1085} [{'entityId': 'UMLS/C0012547'}, {'entityId': 'UMLS/C0012550'}, {'entityId': 'UMLS/C0012551'}] 0.5536857843399048
# {'content': 'tetanus', 'beginOffset': 1097} [{'entityId': 'UMLS/C0305062'}] 0.8668797016143799
# {'content': 'hepatitis b', 'beginOffset': 1136} [{'entityId': 'UMLS/C0062527'}] 0.5929574966430664
# {'content': 'polio vaccine', 'beginOffset': 1175} [{'entityId': 'UMLS/C0032375'}] 0.7681716084480286
# {'content': 'tetanus', 'beginOffset': 1210} [{'entityId': 'UMLS/C0305062'}] 0.9015460014343262
# {'content': 'haemophilus influenzae type b conjugate vaccine', 'beginOffset': 1240} [{'entityId': 'UMLS/C0717811'}] 0.5091634392738342
# {'content': 'tetanus', 'beginOffset': 1309} [{'entityId': 'UMLS/C0305062'}] 0.9197308421134949
# {'content': 'haemophilus influenzae type b vaccine', 'beginOffset': 1371} [{'entityId': 'UMLS/C0062086'}] 0.749761164188385
# {'content': 'tetanus', 'beginOffset': 1430} [{'entityId': 'UMLS/C0305062'}] 0.9302862286567688
# {'content': 'haemophilus influenzae type b conjugate vaccine', 'beginOffset': 1479} [{'entityId': 'UMLS/C0717811'}] 0.6263495683670044
# {'content': 'tetanus', 'beginOffset': 1548} [{'entityId': 'UMLS/C0305062'}] 0.9007495045661926
# {'content': 'tetanus toxoid conjugate vaccine', 'beginOffset': 1622} [{'entityId': 'UMLS/C0296104'}] 0.846734344959259
# {'content': 'tetanus', 'beginOffset': 1676} [{'entityId': 'UMLS/C0305062'}] 0.9009349346160889
# {'content': 'hepatitis b vaccine', 'beginOffset': 1707} [{'entityId': 'UMLS/C0062527'}, {'entityId': 'UMLS/C2240392'}] 0.8884469270706177
# {'content': 'tetanus', 'beginOffset': 1748} [{'entityId': 'UMLS/C0305062'}] 0.8945971131324768
# {'content': 'hepatitis b', 'beginOffset': 1779} [{'entityId': 'UMLS/C0062527'}] 0.40866926312446594
# {'content': 'haemophilus influenzae type b vaccine', 'beginOffset': 1792} [{'entityId': 'UMLS/C0062086'}] 0.7805776596069336
# {'content': 'tetanus', 'beginOffset': 1851} [{'entityId': 'UMLS/C0305062'}] 0.9027326107025146
# {'content': 'hepatitis b', 'beginOffset': 1882} [{'entityId': 'UMLS/C0062527'}] 0.4114982485771179
# {'content': 'haemophilus influenzae type b vaccine', 'beginOffset': 1895} [{'entityId': 'UMLS/C0062086'}] 0.8321818709373474
# {'content': 'mumps', 'beginOffset': 1957} [{'entityId': 'UMLS/C0026782'}, {'entityId': 'UMLS/C1874704'}] 0.44157785177230835
# {'content': 'rubella', 'beginOffset': 1964} [{'entityId': 'UMLS/C0035923'}] 0.6449431777000427
# {'content': 'varicella vaccine', 'beginOffset': 1973} [{'entityId': 'UMLS/C0078048'}, {'entityId': 'UMLS/C3464497'}] 0.8526308536529541
# {'content': 'antigen', 'beginOffset': 2008} [{'entityId': 'UMLS/C0003330'}, {'entityId': 'UMLS/C0003341'}, {'entityId': 'UMLS/C0017278'}, {'entityId': 'UMLS/C0017279'}, {'entityId': 'UMLS/C0019164'}] 0.4191805124282837
# {'content': 'diphtheria', 'beginOffset': 2024} [{'entityId': 'UMLS/C0012547'}, {'entityId': 'UMLS/C0012550'}, {'entityId': 'UMLS/C0012551'}] 0.811097264289856
# {'content': 'tetanus', 'beginOffset': 2036} [{'entityId': 'UMLS/C0305062'}] 0.8751843571662903
# {'content': 'acellular pertussis vaccine', 'beginOffset': 2045} [{'entityId': 'UMLS/C0982332'}] 0.8837639689445496
# {'content': 'antigen', 'beginOffset': 2090} [{'entityId': 'UMLS/C0003330'}, {'entityId': 'UMLS/C0003341'}, {'entityId': 'UMLS/C0017278'}, {'entityId': 'UMLS/C0017279'}, {'entityId': 'UMLS/C0019164'}] 0.48854508996009827
# {'content': 'diphtheria', 'beginOffset': 2106} [{'entityId': 'UMLS/C0012547'}, {'entityId': 'UMLS/C0012550'}, {'entityId': 'UMLS/C0012551'}] 0.7520484924316406
# {'content': 'tetanus', 'beginOffset': 2118} [{'entityId': 'UMLS/C0305062'}] 0.8741714954376221
# {'content': 'polio vaccine', 'beginOffset': 2160} [{'entityId': 'UMLS/C0032375'}] 0.8275377750396729
# {'content': 'Crizanlizumab', 'beginOffset': 2174} [{'entityId': 'UMLS/C4524703'}] 0.9949004650115967
# {'content': 'Dabrafenib', 'beginOffset': 2188} [{'entityId': 'UMLS/C3467876'}] 0.9973782300949097
# {'content': 'Dabrafenib', 'beginOffset': 2199} [{'entityId': 'UMLS/C3467876'}] 0.9695357084274292
# {'content': 'trametinib', 'beginOffset': 2210} [{'entityId': 'UMLS/C2697961'}] 0.9315792322158813
# {'content': 'Danirixin', 'beginOffset': 2221} [{'entityId': 'UMLS/C4519256'}] 0.9981618523597717
# {'content': 'Daprodustat', 'beginOffset': 2231} [{'entityId': 'UMLS/C4519188'}] 0.9889805316925049
# {'content': 'Darapladib', 'beginOffset': 2243} [{'entityId': 'UMLS/C2348075'}] 0.9433040618896484
# {'content': 'Darotropium bromide', 'beginOffset': 2254} [{'entityId': 'UMLS/C2699560'}] 0.9795842170715332
# {'content': 'Darotropium bromide/vilanterol', 'beginOffset': 2274} [{'entityId': 'UMLS/C2699560'}] 0.6687807440757751
# {'content': 'Deferasirox', 'beginOffset': 2305} [{'entityId': 'UMLS/C1619629'}] 0.986588716506958
# {'content': 'Degarelix acetate', 'beginOffset': 2317} [{'entityId': 'UMLS/C2718533'}] 0.9340160489082336
# {'content': 'Denagliptin', 'beginOffset': 2335} [{'entityId': 'UMLS/C2699586'}] 0.9979739189147949
# {'content': 'Digoxin', 'beginOffset': 2390} [{'entityId': 'UMLS/C0012265'}] 0.9965978860855103
# {'content': 'Dilmapimod', 'beginOffset': 2398} [{'entityId': 'UMLS/C3272846'}] 0.9883127212524414
# {'content': 'Diphtheria', 'beginOffset': 2409} [{'entityId': 'UMLS/C0012547'}, {'entityId': 'UMLS/C0012550'}, {'entityId': 'UMLS/C0012551'}] 0.9008921980857849
# {'content': 'tetanus', 'beginOffset': 2421} [{'entityId': 'UMLS/C0305062'}] 0.8904125690460205
# {'content': 'acellular pertussis vaccine', 'beginOffset': 2430} [{'entityId': 'UMLS/C0982332'}] 0.8254204988479614
# {'content': 'Dolutegravir', 'beginOffset': 2467} [{'entityId': 'UMLS/C3253985'}] 0.989474356174469
# {'content': 'Dolutegravir/abacavir/lamivudine', 'beginOffset': 2480} [{'entityId': 'UMLS/C1613391'}] 0.5278786420822144
# {'content': 'Dolutegravir', 'beginOffset': 2513} [{'entityId': 'UMLS/C3253985'}] 0.9465277791023254
# {'content': 'lamivudine', 'beginOffset': 2526} [{'entityId': 'UMLS/C0209738'}] 0.9344323873519897
# {'content': 'Dolutegravir', 'beginOffset': 2537} [{'entityId': 'UMLS/C3253985'}] 0.9702891111373901
# {'content': 'rilpivirine', 'beginOffset': 2550} [{'entityId': 'UMLS/C1566826'}] 0.9632143974304199
# {'content': 'Donepezil', 'beginOffset': 2562} [{'entityId': 'UMLS/C0527316'}] 0.9978075623512268
# {'content': 'Dutasteride', 'beginOffset': 2572} [{'entityId': 'UMLS/C0754659'}] 0.9980650544166565
# {'content': 'Dutasteride', 'beginOffset': 2584} [{'entityId': 'UMLS/C0754659'}] 0.9506256580352783
# {'content': 'tamsulosin', 'beginOffset': 2596} [{'entityId': 'UMLS/C0257343'}] 0.9457529187202454
# {'content': 'Eltrombopag', 'beginOffset': 2607} [{'entityId': 'UMLS/C1831905'}] 0.9952731132507324
# {'content': 'Elubrixin', 'beginOffset': 2619} [{'entityId': 'UMLS/C4519321'}] 0.997005045413971
# {'content': 'Enzalutamide', 'beginOffset': 2629} [{'entityId': 'UMLS/C3496793'}] 0.9980428814888
# {'content': 'Epelsiban', 'beginOffset': 2642} [{'entityId': 'UMLS/C3274566'}] 0.9774683713912964
# {'content': 'Epoprostenol', 'beginOffset': 2652} [{'entityId': 'UMLS/C0033567'}] 0.992821216583252
# {'content': 'Eribulin mesilate', 'beginOffset': 2665} [{'entityId': 'UMLS/C2608038'}] 0.9561359286308289
# {'content': 'Erlotinib', 'beginOffset': 2683} [{'entityId': 'UMLS/C1135135'}] 0.9445253610610962
# {'content': 'Everolimus', 'beginOffset': 2693} [{'entityId': 'UMLS/C0541315'}] 0.986271858215332
# {'content': 'Exenatide', 'beginOffset': 2704} [{'entityId': 'UMLS/C0167117'}] 0.9827603101730347
# {'content': 'Fevipiprant', 'beginOffset': 2714} [{'entityId': 'UMLS/C4076895'}] 0.9916226863861084
# {'content': 'Fiboflapon', 'beginOffset': 2726} [{'entityId': 'UMLS/C4550339'}] 0.964216947555542
# {'content': 'Fidaxomicin', 'beginOffset': 2737} [{'entityId': 'UMLS/C0065023'}] 0.9977651238441467
# {'content': 'Fingolimod', 'beginOffset': 2749} [{'entityId': 'UMLS/C1699926'}] 0.9822161197662354
# {'content': 'Fluticasone', 'beginOffset': 2760} [{'entityId': 'UMLS/C0082607'}] 0.9368850588798523
# {'content': 'Fluticasone furoate', 'beginOffset': 2772} [{'entityId': 'UMLS/C1948374'}] 0.7802206873893738
# {'content': 'Fluticasone furoate', 'beginOffset': 2792} [{'entityId': 'UMLS/C1948374'}] 0.825867235660553
# {'content': 'levocabastine', 'beginOffset': 2812} [{'entityId': 'UMLS/C0064870'}] 0.8391091227531433
# {'content': 'Fluticasone furoate', 'beginOffset': 2826} [{'entityId': 'UMLS/C1948374'}] 0.6405181884765625
# {'content': 'Fluticasone furoate', 'beginOffset': 2867} [{'entityId': 'UMLS/C1948374'}] 0.7858442664146423
# {'content': 'vilanterol', 'beginOffset': 2887} [{'entityId': 'UMLS/C2935023'}] 0.6889325380325317
# {'content': 'Fluticasone furoate/vilanterol trifenatate', 'beginOffset': 2898} [{'entityId': 'UMLS/C4020624'}] 0.6038270592689514
# {'content': 'Fluticasone furoate', 'beginOffset': 2941} [{'entityId': 'UMLS/C1948374'}] 0.7401180267333984
# {'content': 'vilanterol', 'beginOffset': 2961} [{'entityId': 'UMLS/C2935023'}] 0.5823512673377991
# {'content': 'umeclidinium bromid', 'beginOffset': 2972} [{'entityId': 'UMLS/C3661274'}] 0.4523383378982544
# {'content': 'Fluticasone furoate', 'beginOffset': 2992} [{'entityId': 'UMLS/C1948374'}] 0.7949733138084412
# {'content': 'vilanterol', 'beginOffset': 3012} [{'entityId': 'UMLS/C2935023'}] 0.6665496230125427
# {'content': 'umeclidinium bromide', 'beginOffset': 3023} [{'entityId': 'UMLS/C3709474'}] 0.6399412155151367
# {'content': 'Fluticasone propionate', 'beginOffset': 3044} [{'entityId': 'UMLS/C0117996'}] 0.8514478802680969
# {'content': 'Fluticasone propionate/salmeterol', 'beginOffset': 3067} [{'entityId': 'UMLS/C1622832'}] 0.687676191329956
# {'content': 'Fondaparinux sodium', 'beginOffset': 3101} [{'entityId': 'UMLS/C1099664'}] 0.928261399269104
# {'content': 'Foretinib', 'beginOffset': 3121} [{'entityId': 'UMLS/C2973987'}] 0.9955807328224182
# {'content': 'Formoterol fumarate', 'beginOffset': 3131} [{'entityId': 'UMLS/C0771469'}] 0.8797258734703064
# {'content': 'Fosamprenavir', 'beginOffset': 3151} [{'entityId': 'UMLS/C1176315'}] 0.9965381622314453
# {'content': 'Fosdevirine', 'beginOffset': 3165} [{'entityId': 'UMLS/C4550352'}] 0.9936097264289856
# {'content': 'Fremanezumab', 'beginOffset': 3177} [{'entityId': 'UMLS/C4549503'}] 0.9968881011009216
# {'content': 'Gepotidacin', 'beginOffset': 3190} [{'entityId': 'UMLS/C4309999'}] 0.9962320923805237
# {'content': 'Gilteritinib fumarate', 'beginOffset': 3202} [{'entityId': 'UMLS/C3896946'}] 0.6414188742637634
# {'content': 'Glatiramer acetate', 'beginOffset': 3224} [{'entityId': 'UMLS/C0289884'}] 0.9743452072143555
# {'content': 'Glimepiride/metformin', 'beginOffset': 3243} [{'entityId': 'UMLS/C0061323'}] 0.620337188243866
# {'content': 'Glycerol and niacinamide', 'beginOffset': 3265} [{'entityId': 'UMLS/C0028027'}] 0.6745595335960388
# {'content': 'serum', 'beginOffset': 3302} [{'entityId': 'UMLS/C0003372'}, {'entityId': 'UMLS/C0003442'}, {'entityId': 'UMLS/C0017649'}, {'entityId': 'UMLS/C0020960'}, {'entityId': 'UMLS/C0029297'}] 0.5458800196647644
# {'content': 'Glycopyrronium', 'beginOffset': 3319} [{'entityId': 'UMLS/C3814772'}] 0.9906001687049866
# {'content': 'Glycopyrronium bromide', 'beginOffset': 3334} [{'entityId': 'UMLS/C4082411'}] 0.9880608320236206
# {'content': 'Griseofulvin', 'beginOffset': 3357} [{'entityId': 'UMLS/C0018242'}] 0.9960930943489075
# {'content': 'pandemic influenza vaccine', 'beginOffset': 3375} [{'entityId': 'UMLS/C2981835'}] 0.8367303013801575
# {'content': 'pandemic influenza vaccine', 'beginOffset': 3407} [{'entityId': 'UMLS/C2981835'}] 0.836798369884491
# {'content': 'pre-pandemic influenza vaccine', 'beginOffset': 3439} [{'entityId': 'UMLS/C0021403'}, {'entityId': 'UMLS/C0770694'}] 0.8188977241516113
# {'content': 'Haemophilus influenzae type b vaccine', 'beginOffset': 3470} [{'entityId': 'UMLS/C0062086'}] 0.8871932625770569
# {'content': 'tetanus toxoid conjugate vaccine', 'beginOffset': 3561} [{'entityId': 'UMLS/C0296104'}] 0.8899776339530945
# {'content': 'Haemophilus influenzae type b', 'beginOffset': 3594} [{'entityId': 'UMLS/C0062086'}] 0.43954649567604065
# {'content': 'c-tetanus toxoid conjugate vaccine', 'beginOffset': 3639} [{'entityId': 'UMLS/C0296104'}] 0.6253381967544556
# {'content': 'Hepatitis a', 'beginOffset': 3674} [{'entityId': 'UMLS/C0795623'}] 0.4355539083480835
# {'content': 'hepatitis b (recombinant) vaccine', 'beginOffset': 3701} [{'entityId': 'UMLS/C0034862'}] 0.48959213495254517
# {'content': 'Hepatitis a vaccine', 'beginOffset': 3735} [{'entityId': 'UMLS/C0170300'}, {'entityId': 'UMLS/C0795623'}] 0.9391796588897705
# {'content': 'Hepatitis b vaccine', 'beginOffset': 3768} [{'entityId': 'UMLS/C0062527'}, {'entityId': 'UMLS/C2240392'}] 0.893013060092926
# {'content': 'Herpes simplex vaccine', 'beginOffset': 3801} [{'entityId': 'UMLS/C0770688'}] 0.8675031065940857
# {'content': 'Herpes zoster subunit', 'beginOffset': 3824} [{'entityId': 'UMLS/C3272332'}] 0.8011014461517334
# {'content': 'hz/su) vaccine', 'beginOffset': 3847} [{'entityId': 'UMLS/C3272332'}] 0.5117989182472229
# {'content': 'Ibandronic acid', 'beginOffset': 3907} [{'entityId': 'UMLS/C0379200'}] 0.9575732350349426
# {'content': 'Imatinib mesilate', 'beginOffset': 3935} [{'entityId': 'UMLS/C0935989'}] 0.8867392539978027
# {'content': 'Inclisiran', 'beginOffset': 3953} [{'entityId': 'UMLS/C4307388'}] 0.9930282235145569
# {'content': 'Indacaterol', 'beginOffset': 3964} [{'entityId': 'UMLS/C1722260'}] 0.9882010817527771
# {'content': 'Indacaterol acetate', 'beginOffset': 3976} [{'entityId': 'UMLS/C1722260'}] 0.9171545505523682
# {'content': 'mometasone furoate', 'beginOffset': 3996} [{'entityId': 'UMLS/C0066700'}] 0.8603166937828064
# {'content': 'Indacaterol maleate', 'beginOffset': 4015} [{'entityId': 'UMLS/C2920417'}] 0.826621413230896
# {'content': 'glycopyrronium bromide', 'beginOffset': 4035} [{'entityId': 'UMLS/C4082411'}] 0.9481526613235474
# {'content': 'Indacaterol', 'beginOffset': 4058} [{'entityId': 'UMLS/C1722260'}] 0.9463547468185425
# {'content': 'glycopyrrolate', 'beginOffset': 4071} [{'entityId': 'UMLS/C0017970'}] 0.8035086989402771
# {'content': 'Indacaterol/mometasone furoate', 'beginOffset': 4086} [{'entityId': 'UMLS/C0066700'}] 0.6215846538543701
# {'content': 'Infanrix', 'beginOffset': 4117} [{'entityId': 'UMLS/C0728745'}] 0.930935800075531
# {'content': 'penta', 'beginOffset': 4126} [{'entityId': 'UMLS/C0701492'}] 0.7404435873031616
# {'content': 'infanrix hexa / pediarix', 'beginOffset': 4132} [{'entityId': 'UMLS/C0728745'}] 0.7527446150779724
# {'content': 'Influenza vaccine', 'beginOffset': 4157} [{'entityId': 'UMLS/C0021403'}, {'entityId': 'UMLS/C0770694'}] 0.8864563703536987
# {'content': 'Influenza vaccine', 'beginOffset': 4175} [{'entityId': 'UMLS/C0021403'}, {'entityId': 'UMLS/C0770694'}] 0.8968987464904785
# {'content': 'quadrivalent', 'beginOffset': 4194} [{'entityId': 'UMLS/C4290039'}, {'entityId': 'UMLS/C5392198'}, {'entityId': 'UMLS/C5447997'}] 0.7135156393051147
# {'content': 'Influenza vaccine', 'beginOffset': 4208} [{'entityId': 'UMLS/C0021403'}, {'entityId': 'UMLS/C0770694'}] 0.8859615921974182
# {'content': 'Influenza vaccine', 'beginOffset': 4254} [{'entityId': 'UMLS/C0021403'}, {'entityId': 'UMLS/C0770694'}] 0.8901162147521973
# {'content': 'Ipragliflozin', 'beginOffset': 4310} [{'entityId': 'UMLS/C3492889'}] 0.9915145635604858
# {'content': 'Isavuconazonium sulfate', 'beginOffset': 4324} [{'entityId': 'UMLS/C4018470'}] 0.9760355353355408
# {'content': 'Ketoconazole', 'beginOffset': 4348} [{'entityId': 'UMLS/C0022625'}] 0.9985841512680054
# {'content': 'Lamivudine', 'beginOffset': 4361} [{'entityId': 'UMLS/C0209738'}] 0.9985739588737488
# {'content': 'Lamotrigine', 'beginOffset': 4372} [{'entityId': 'UMLS/C0064636'}] 0.9980254769325256
# {'content': 'Lapatinib', 'beginOffset': 4384} [{'entityId': 'UMLS/C1506770'}] 0.995078444480896
# {'content': 'Lapatinib', 'beginOffset': 4394} [{'entityId': 'UMLS/C1506770'}] 0.9944517016410828
# {'content': 'capecitabine', 'beginOffset': 4409} [{'entityId': 'UMLS/C0671970'}] 0.9945825338363647
# {'content': 'Lenvatinib', 'beginOffset': 4422} [{'entityId': 'UMLS/C2986924'}] 0.9978205561637878
# {'content': 'Letrozole', 'beginOffset': 4433} [{'entityId': 'UMLS/C0246421'}] 0.9978802800178528
# {'content': 'Leuprorelin acetate', 'beginOffset': 4443} [{'entityId': 'UMLS/C0700596'}] 0.9288356900215149
# {'content': 'Levocetirizine', 'beginOffset': 4463} [{'entityId': 'UMLS/C1174893'}] 0.9977890253067017
# {'content': 'Licarbazepine', 'beginOffset': 4478} [{'entityId': 'UMLS/C1567854'}] 0.9978728294372559
# {'content': 'Linaclotide', 'beginOffset': 4492} [{'entityId': 'UMLS/C2000261'}] 0.9974240064620972
# {'content': 'Linerixibat', 'beginOffset': 4504} [{'entityId': 'UMLS/C5238076'}] 0.9961070418357849
# {'content': 'Linsitinib', 'beginOffset': 4516} [{'entityId': 'UMLS/C2987649'}] 0.9943121075630188
# {'content': 'Lisinopril', 'beginOffset': 4527} [{'entityId': 'UMLS/C0065374'}] 0.9975483417510986
# {'content': 'Losmapimod', 'beginOffset': 4538} [{'entityId': 'UMLS/C3272847'}] 0.9776480793952942
# {'content': 'Mapatumumab', 'beginOffset': 4549} [{'entityId': 'UMLS/C1665688'}] 0.9876067042350769
# {'content': 'Maraviroc', 'beginOffset': 4561} [{'entityId': 'UMLS/C1667052'}] 0.9054915904998779
# {'content': 'Measles', 'beginOffset': 4571} [{'entityId': 'UMLS/C0025010'}] 0.5906996130943298
# {'content': 'rubella vaccine', 'beginOffset': 4587} [{'entityId': 'UMLS/C0035923'}] 0.875996470451355
# {'content': 'Meloxicam', 'beginOffset': 4603} [{'entityId': 'UMLS/C0083381'}] 0.9593340754508972
# {'content': 'Melrilimab', 'beginOffset': 4613} [{'entityId': 'UMLS/C5421171'}] 0.9800481796264648
# {'content': 'Meningococcal group-b vaccine', 'beginOffset': 4624} [{'entityId': 'UMLS/C3859491'}] 0.8515680432319641
# {'content': 'rdna', 'beginOffset': 4655} [{'entityId': 'UMLS/C0012933'}] 0.798207700252533
# {'content': 'b vaccine', 'beginOffset': 4719} [{'entityId': 'UMLS/C0062527'}, {'entityId': 'UMLS/C2240392'}, {'entityId': 'UMLS/C3859491'}] 0.7660290598869324
# {'content': 'Meningococcal vaccine', 'beginOffset': 4780} [{'entityId': 'UMLS/C0700144'}] 0.9386469721794128
# {'content': 'Mepolizumab', 'beginOffset': 4802} [{'entityId': 'UMLS/C0969324'}] 0.9952759146690369
# {'content': 'Metformin', 'beginOffset': 4814} [{'entityId': 'UMLS/C0025598'}] 0.9973008632659912
# {'content': 'Methylphenidate', 'beginOffset': 4824} [{'entityId': 'UMLS/C0025810'}] 0.996552050113678
# {'content': 'Micafungin', 'beginOffset': 4840} [{'entityId': 'UMLS/C1120386'}] 0.9975098371505737
# {'content': 'Midostaurin', 'beginOffset': 4851} [{'entityId': 'UMLS/C0526371'}] 0.9971917271614075
# {'content': 'Milveterol', 'beginOffset': 4863} [{'entityId': 'UMLS/C2698231'}] 0.9908953905105591
# {'content': 'Mirabegron', 'beginOffset': 4874} [{'entityId': 'UMLS/C2983812'}] 0.9947254061698914
# {'content': 'Molibresib', 'beginOffset': 4885} [{'entityId': 'UMLS/C4682384'}] 0.9947100281715393
# {'content': 'Montelukast', 'beginOffset': 4896} [{'entityId': 'UMLS/C0298130'}] 0.995193600654602
# {'content': 'Nabumetone', 'beginOffset': 4908} [{'entityId': 'UMLS/C0068334'}] 0.9960864186286926
# {'content': 'Nadroparin calcium', 'beginOffset': 4919} [{'entityId': 'UMLS/C0206232'}] 0.9881209135055542
# {'content': 'Naquotinib mesilate', 'beginOffset': 4938} [{'entityId': 'UMLS/C4519293'}] 0.8343229293823242
# {'content': 'Naratriptan', 'beginOffset': 4958} [{'entityId': 'UMLS/C0540623'}] 0.9556552767753601
# {'content': 'Nemiralisib', 'beginOffset': 4970} [{'entityId': 'UMLS/C5197976'}] 0.9920881986618042
# {'content': 'Nepafenac', 'beginOffset': 4982} [{'entityId': 'UMLS/C0961209'}] 0.8611318469047546
# {'content': 'Nicotine', 'beginOffset': 5020} [{'entityId': 'UMLS/C0028040'}] 0.9932270050048828
# {'content': 'Nicotine polacrilex', 'beginOffset': 5029} [{'entityId': 'UMLS/C0068722'}] 0.9196259379386902
# {'content': 'Nicotine polacrilex', 'beginOffset': 5049} [{'entityId': 'UMLS/C0068722'}] 0.8354406952857971
# {'content': 'Nilotinib', 'beginOffset': 5091} [{'entityId': 'UMLS/C1721377'}] 0.9972332119941711
# {'content': 'Nivolumab', 'beginOffset': 5101} [{'entityId': 'UMLS/C3657270'}] 0.9964921474456787
# {'content': 'Octreotide', 'beginOffset': 5111} [{'entityId': 'UMLS/C0028833'}] 0.9967744946479797
# {'content': 'Ofatumumab', 'beginOffset': 5122} [{'entityId': 'UMLS/C1832027'}] 0.994989812374115
# {'content': 'Oligofructose', 'beginOffset': 5133} [{'entityId': 'UMLS/C0907858'}] 0.9955904483795166
# {'content': 'Olodanrigan', 'beginOffset': 5147} [{'entityId': 'UMLS/C5420974'}] 0.9978374242782593
# {'content': 'Olopatadine hydrochloride', 'beginOffset': 5159} [{'entityId': 'UMLS/C0771892'}] 0.9729667901992798
# {'content': 'Omalizumab', 'beginOffset': 5185} [{'entityId': 'UMLS/C0966225'}] 0.9943327307701111
# {'content': 'Omega-3-acid ethyl esters', 'beginOffset': 5196} [{'entityId': 'UMLS/C1532673'}] 0.8952974677085876
# {'content': 'Omipalisib', 'beginOffset': 5222} [{'entityId': 'UMLS/C4519177'}] 0.9980157613754272
# {'content': 'Onabotulinumtoxina', 'beginOffset': 5233} [{'entityId': 'UMLS/C2719767'}] 0.996061384677887
# {'content': 'Onasemnogene abeparvovec xioi', 'beginOffset': 5252} [{'entityId': 'UMLS/C5140521'}] 0.665737509727478
# {'content': 'Onasemnogene abeparvovec-xioi', 'beginOffset': 5282} [{'entityId': 'UMLS/C5140521'}] 0.8119324445724487
# {'content': 'Otelixizumab', 'beginOffset': 5312} [{'entityId': 'UMLS/C2935224'}] 0.9976483583450317
# {'content': 'Otilimab', 'beginOffset': 5325} [{'entityId': 'UMLS/C4731002'}] 0.9960305690765381
# {'content': 'Oxcarbazepine', 'beginOffset': 5334} [{'entityId': 'UMLS/C0069751'}] 0.9970958232879639
# {'content': 'Oxytocin', 'beginOffset': 5348} [{'entityId': 'UMLS/C0030095'}, {'entityId': 'UMLS/C1704206'}, {'entityId': 'UMLS/C4082165'}] 0.9963372349739075
# {'content': 'Panobinostat', 'beginOffset': 5357} [{'entityId': 'UMLS/C1998098'}] 0.9890652298927307
# {'content': 'Paroxetine', 'beginOffset': 5370} [{'entityId': 'UMLS/C0070122'}] 0.9974746704101562
# {'content': 'Pazopanib', 'beginOffset': 5381} [{'entityId': 'UMLS/C1831796'}] 0.9966356158256531
# {'content': 'Pectin', 'beginOffset': 5391} [{'entityId': 'UMLS/C0030744'}, {'entityId': 'UMLS/C0070203'}, {'entityId': 'UMLS/C0135827'}] 0.9854919910430908
# {'content': 'Peficitinib hydrobromide', 'beginOffset': 5398} [{'entityId': 'UMLS/C5418498'}] 0.8927221298217773
# {'content': 'Perampanel', 'beginOffset': 5423} [{'entityId': 'UMLS/C2698764'}] 0.9983965158462524
# {'content': 'Pneumococcal polysaccharide conjugate vaccine', 'beginOffset': 5434} [{'entityId': 'UMLS/C0305065'}] 0.8925729990005493
# {'content': 'Poliomyelitis vaccine', 'beginOffset': 5491} [{'entityId': 'UMLS/C0042210'}] 0.9121752381324768
# {'content': 'Polysaccharide typhoid vaccine', 'beginOffset': 5527} [{'entityId': 'UMLS/C3273244'}] 0.9522693753242493
# {'content': 'Potassium nitrate/sodium fluoride', 'beginOffset': 5558} [{'entityId': 'UMLS/C2929521'}] 0.852921187877655
# {'content': 'Propafenone', 'beginOffset': 5592} [{'entityId': 'UMLS/C0033429'}] 0.9971715211868286
# {'content': 'Pyrimethamine', 'beginOffset': 5604} [{'entityId': 'UMLS/C0034283'}] 0.9901679754257202
# {'content': 'Rabeprazole', 'beginOffset': 5618} [{'entityId': 'UMLS/C0378482'}] 0.9939078092575073
# {'content': 'Ranibizumab', 'beginOffset': 5630} [{'entityId': 'UMLS/C1566537'}] 0.995755672454834
# {'content': 'Raxibacumab', 'beginOffset': 5642} [{'entityId': 'UMLS/C2717174'}] 0.9916556477546692
# {'content': 'Refanezumab', 'beginOffset': 5654} [{'entityId': 'UMLS/C4726669'}] 0.9845833778381348
# {'content': 'Regadenoson', 'beginOffset': 5666} [{'entityId': 'UMLS/C1698215'}] 0.9938703775405884
# {'content': 'Relacatib', 'beginOffset': 5678} [{'entityId': 'UMLS/C1700101'}] 0.990551769733429
# {'content': 'Remifentanil', 'beginOffset': 5688} [{'entityId': 'UMLS/C0246631'}] 0.9957122802734375
# {'content': 'Reslizumab', 'beginOffset': 5701} [{'entityId': 'UMLS/C1869620'}] 0.9899922013282776
# {'content': 'Resveratrol', 'beginOffset': 5712} [{'entityId': 'UMLS/C0073096'}] 0.9699739217758179
# {'content': 'Retapamulin', 'beginOffset': 5724} [{'entityId': 'UMLS/C1703334'}] 0.9902732372283936
# {'content': 'Retigabine', 'beginOffset': 5736} [{'entityId': 'UMLS/C0530684'}] 0.9896216988563538
# {'content': 'Retigabine', 'beginOffset': 5747} [{'entityId': 'UMLS/C0530684'}] 0.9572384357452393
# {'content': 'ezogabine', 'beginOffset': 5759} [{'entityId': 'UMLS/C0530684'}] 0.956464409828186
# {'content': 'Retosiban', 'beginOffset': 5769} [{'entityId': 'UMLS/C2699069'}] 0.9877128601074219
# {'content': 'Ribavirin', 'beginOffset': 5779} [{'entityId': 'UMLS/C0035525'}] 0.9956194758415222
# {'content': 'Rilapladib', 'beginOffset': 5789} [{'entityId': 'UMLS/C2699087'}] 0.9951384663581848
# {'content': 'Rilpivirine', 'beginOffset': 5800} [{'entityId': 'UMLS/C1566826'}] 0.9979620575904846
# {'content': 'Rivastigmine', 'beginOffset': 5812} [{'entityId': 'UMLS/C0649350'}] 0.998006284236908
# {'content': 'Ronacaleret', 'beginOffset': 5825} [{'entityId': 'UMLS/C2825588'}] 0.9965878129005432
# {'content': 'Ropinirole', 'beginOffset': 5837} [{'entityId': 'UMLS/C0244821'}] 0.9948678016662598
# {'content': 'Rosiglitazone', 'beginOffset': 5848} [{'entityId': 'UMLS/C0289313'}] 0.995415449142456
# {'content': 'Rosiglitazone', 'beginOffset': 5862} [{'entityId': 'UMLS/C0289313'}] 0.9694667458534241
# {'content': 'glimepiride', 'beginOffset': 5876} [{'entityId': 'UMLS/C0061323'}] 0.9335206747055054
# {'content': 'Rosiglitazone', 'beginOffset': 5888} [{'entityId': 'UMLS/C0289313'}] 0.9640135169029236
# {'content': 'metformin', 'beginOffset': 5902} [{'entityId': 'UMLS/C0025598'}] 0.9374737739562988
# {'content': 'Rosiglitazone', 'beginOffset': 5912} [{'entityId': 'UMLS/C0289313'}] 0.9701204299926758
# {'content': 'simvastatin', 'beginOffset': 5926} [{'entityId': 'UMLS/C0074554'}] 0.9345037937164307
# {'content': 'Rotavirus vaccine', 'beginOffset': 5938} [{'entityId': 'UMLS/C0597418'}] 0.8364715576171875
# {'content': 'Rts,s vaccine', 'beginOffset': 5956} [{'entityId': 'UMLS/C1528874'}] 0.49856725335121155
# {'content': 'Rufinamide', 'beginOffset': 5970} [{'entityId': 'UMLS/C0213404'}] 0.9959844350814819
# {'content': 'Ruxolitinib', 'beginOffset': 5981} [{'entityId': 'UMLS/C2931926'}] 0.9951747059822083
# {'content': 'Sacubitril', 'beginOffset': 5993} [{'entityId': 'UMLS/C4033447'}] 0.9324200749397278
# {'content': 'valsartan', 'beginOffset': 6004} [{'entityId': 'UMLS/C0216784'}] 0.9033716320991516
# {'content': 'Salbutamol', 'beginOffset': 6014} [{'entityId': 'UMLS/C0001927'}] 0.9978551864624023
# {'content': 'Salmeterol', 'beginOffset': 6025} [{'entityId': 'UMLS/C0073992'}] 0.9807164072990417
# {'content': 'Sargramostim', 'beginOffset': 6036} [{'entityId': 'UMLS/C0216231'}] 0.9918403029441833
# {'content': 'Secukinumab', 'beginOffset': 6049} [{'entityId': 'UMLS/C3179547'}] 0.9940128326416016
# {'content': 'Serelaxin', 'beginOffset': 6061} [{'entityId': 'UMLS/C3700393'}] 0.9981289505958557
# {'content': 'Siponimod', 'beginOffset': 6071} [{'entityId': 'UMLS/C3657824'}] 0.9719973802566528
# {'content': 'Solcitinib', 'beginOffset': 6081} [{'entityId': 'UMLS/C4726763'}] 0.9969138503074646
# {'content': 'Solifenacin succinate', 'beginOffset': 6092} [{'entityId': 'UMLS/C1509436'}] 0.9682176113128662
# {'content': 'Solifenacin succinate', 'beginOffset': 6114} [{'entityId': 'UMLS/C1509436'}] 0.8968349099159241
# {'content': 'tamsulosin', 'beginOffset': 6138} [{'entityId': 'UMLS/C0257343'}] 0.9311388731002808
# {'content': 'Sumatriptan', 'beginOffset': 6149} [{'entityId': 'UMLS/C0075632'}] 0.977503776550293
# {'content': 'Sumatriptan/naproxen', 'beginOffset': 6161} [{'entityId': 'UMLS/C2343923'}] 0.6840144395828247
# {'content': 'Tacrolimus', 'beginOffset': 6182} [{'entityId': 'UMLS/C0085149'}] 0.99776291847229
# {'content': 'Tacrolimus', 'beginOffset': 6193} [{'entityId': 'UMLS/C0085149'}] 0.9955951571464539
# {'content': 'Tafenoquine', 'beginOffset': 6221} [{'entityId': 'UMLS/C0903411'}] 0.9980453252792358
# {'content': 'Talnetant', 'beginOffset': 6233} [{'entityId': 'UMLS/C1701942'}] 0.9908660650253296
# {'content': 'Tamsulosin hcl', 'beginOffset': 6243} [{'entityId': 'UMLS/C0257343'}] 0.9733049273490906
# {'content': 'Tapentadol', 'beginOffset': 6258} [{'entityId': 'UMLS/C2001271'}] 0.998272180557251
# {'content': 'Tapinarof', 'beginOffset': 6269} [{'entityId': 'UMLS/C4541381'}] 0.9954392910003662
# {'content': 'Tazarotene', 'beginOffset': 6279} [{'entityId': 'UMLS/C0288792'}] 0.9984155893325806
# {'content': 'Tenofovir disoproxil fumarate', 'beginOffset': 6290} [{'entityId': 'UMLS/C1099776'}] 0.8358394503593445
# {'content': 'Tisagenlecleucel', 'beginOffset': 6320} [{'entityId': 'UMLS/C4529946'}] 0.9971392154693604
# {'content': 'Tositumomab', 'beginOffset': 6337} [{'entityId': 'UMLS/C0879399'}] 0.9764229655265808
# {'content': 'Trametinib', 'beginOffset': 6349} [{'entityId': 'UMLS/C2697961'}] 0.9940565824508667
# {'content': 'Travoprost', 'beginOffset': 6360} [{'entityId': 'UMLS/C0937916'}] 0.8865504860877991
# {'content': 'Triclabendazole', 'beginOffset': 6391} [{'entityId': 'UMLS/C0077071'}] 0.993418276309967
# {'content': 'Trivalent group b streptococcus vaccine', 'beginOffset': 6407} [{'entityId': 'UMLS/C0887906'}] 0.6007178425788879
# {'content': 'Twinrix', 'beginOffset': 6447} [{'entityId': 'UMLS/C0593953'}] 0.9404133558273315
# {'content': 'Umeclidinium bromide', 'beginOffset': 6455} [{'entityId': 'UMLS/C3709474'}] 0.9150251150131226
# {'content': 'Umeclidinium bromide', 'beginOffset': 6476} [{'entityId': 'UMLS/C3709474'}] 0.8630450367927551
# {'content': 'vilanterol', 'beginOffset': 6497} [{'entityId': 'UMLS/C2935023'}] 0.8023387789726257
# {'content': 'Valaciclovir', 'beginOffset': 6508} [{'entityId': 'UMLS/C0249458'}] 0.997771143913269
# {'content': 'Valsartan', 'beginOffset': 6521} [{'entityId': 'UMLS/C0216784'}] 0.9968550205230713
# {'content': 'Varicella vaccine', 'beginOffset': 6531} [{'entityId': 'UMLS/C0078048'}, {'entityId': 'UMLS/C3464497'}] 0.8622279763221741
# {'content': 'Vercirnon', 'beginOffset': 6549} [{'entityId': 'UMLS/C3713948'}] 0.9807651042938232
# {'content': 'Vestipitant', 'beginOffset': 6559} [{'entityId': 'UMLS/C2607417'}] 0.7892804145812988
# {'content': 'Vestipitant', 'beginOffset': 6571} [{'entityId': 'UMLS/C2607417'}] 0.7119989991188049
# {'content': 'paroxetine', 'beginOffset': 6583} [{'entityId': 'UMLS/C0070122'}] 0.9081679582595825
# {'content': 'Vilanterol', 'beginOffset': 6594} [{'entityId': 'UMLS/C2935023'}] 0.9333327412605286
# {'content': 'Vilanterol/darotropium bromide', 'beginOffset': 6605} [{'entityId': 'UMLS/C2699560'}] 0.7581656575202942
# {'content': 'Vildagliptin', 'beginOffset': 6636} [{'entityId': 'UMLS/C1570906'}] 0.9955388307571411
# {'content': 'Zanamivir', 'beginOffset': 6649} [{'entityId': 'UMLS/C0216660'}] 0.9964957237243652
# {'content': 'Zoledronic acid', 'beginOffset': 6659} [{'entityId': 'UMLS/C0257685'}] 0.9730226397514343
# {'content': 'indacaterol', 'beginOffset': 6675} [{'entityId': 'UMLS/C1722260'}] 0.9945102334022522
# {'content': 'lanadelumab', 'beginOffset': 6687} [{'entityId': 'UMLS/C4505508'}] 0.9941532611846924
# {'content': 'pazopanib', 'beginOffset': 6699} [{'entityId': 'UMLS/C1831796'}] 0.9807900190353394

# %%
with open('medicine_gcp_ner.jsonl', 'w') as f:
    f.write(content)

# %%
medicine_gcp_nlp = {}

with open('medicine_gcp_ner.jsonl', 'r') as json_file:
    for line in json_file.readlines():
        obj = json.loads(line)
        medicine_gcp_nlp[list(obj.keys())[0]] = list(obj.values())[0]

len(medicine_gcp_nlp)
# Out:
# 286

# %%
trial_medicines = []
medicine_nodes = {}
trial_cryptic_drugs = []

for i, row in clinical_trials.iterrows():
    for x in str(row["Medicine or Vaccine (generic name)"]).split("; "):
        x = x.strip().lower().capitalize()

        for gsk in x.split("/"):
            if gsk.strip() in cryptic_drugs:
                trial_cryptic_drugs.append((row["Posting ID"], gsk.strip()))

        query = ""
        if x in medicine_abnornaml_list_mapping:
            if medicine_abnornaml_list_mapping[x] != "":
                query = medicine_abnornaml_list_mapping[x]
        else:
            query = x

        if query in medicine_gcp_nlp:
            for entity in medicine_gcp_nlp[query]:
                if "entityids" in entity:
                    trial_medicines.append((row["Posting ID"], entity["entityids"]))

                    medicine_nodes[entity["entityids"]] = {"name": entity["preferredTerms"], "HPO": entity["HPO"], "MSH": entity["MSH"], "RXNORM": entity["RXNORM"]}

# %%
trial_cryptic_drugs
content = "from\tto\n"
for row in trial_cryptic_drugs:
    content += f"{row[0]}\t{row[1]}\n"

with open(f"trial_cryptic_drugs.tsv", "w") as f:
    f.write(content)

# %%
content = "from\tto\n"
for row in trial_medicines:
    content += f"{row[0]}\t{row[1]}\n"

# %%
with open(f"{output_folder}/trial_medicines.tsv", "w") as f:
    f.write(content)

# %%
content = "UMLS\tname\tHPO\tMSH\tRXNORM\tother_name\n"
for c in medicine_nodes:
    content += f"{c}\t{medicine_nodes[c]['name']}\t{'|'.join(medicine_nodes[c]['HPO'])}\t{'|'.join(medicine_nodes[c]['MSH'])}\t{'|'.join(medicine_nodes[c]['RXNORM'])}\t\n"

with open(f"{output_folder}/medicines.tsv", "w") as f:
    f.write(content)

# %%
clinical_trials["Sponsor"].unique()
# Out:
# array(['GSK', 'ViiV', 'Novartis', 'Astellas', 'Eisai', 'Grunenthal',
#        'Teva', 'Ono'], dtype=object)

# %%
sponsors = set()

trial_sponsors = []

for i, row in clinical_trials.iterrows():
    sponsor = str(row["Sponsor"])

    sponsors.add(sponsor)

    trial_sponsors.append((row["Posting ID"], sponsor))

content = "from\tto\n"
for row in trial_sponsors:
    content += f"{row[0]}\t{row[1]}\n"

with open(f"{output_folder}/trial_sponsors.tsv", "w") as f:
    f.write(content)

content = "name\n"
for s in sponsors:
    content += f"{s}\n"

with open(f"{output_folder}/sponsors.tsv", "w") as f:
    f.write(content)
