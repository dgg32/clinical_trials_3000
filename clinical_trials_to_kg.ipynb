# %%
import pandas as pd
import numpy as np
import re

# %%
clinical_trials = pd.read_csv('clinical_study_data_request_com_all_sponsor.tsv', sep="\t")

# %%
clinical_trials.head()
# Out:
#    Posting ID Sponsor                                        Study Title  \
# 0           1     GSK  U0289-401: An Evaluator Blinded, 8 Week, Split...
# 1           3     GSK  GSK1550188, A randomised, single-blind, placeb...
# 2           4     GSK  A Multicenter, Randomized, Double-Blind, Phase...
# 3           8     GSK  Two-week Study to Determine and Compare the To...
# 4           9     GSK  A single-blind, randomized, comparative split-...
#
#        Medicine or Vaccine (generic name) Sponsor Identification Number  \
# 0         benzoyl peroxide/salicylic acid                     STF114550
# 1                               belimumab                     BEL114243
# 2             calcipotriol, calcipotriene                     STF114741
# 3  benzoyl peroxide/clindamycin phosphate                     STF114546
# 4  benzoyl peroxide/clindamycin phosphate                     STF114547
#
#               Medical Condition    Phase  \
# 0                 Acne Vulgaris  Phase 4
# 1  Systemic Lupus Erythematosus  Phase 1
# 2                     Psoriasis  Phase 3
# 3                 Acne Vulgaris  Phase 4
# 4                 Acne Vulgaris  Phase 4
#
#                       Link to Sponsor Study Registry  \
# 0  https://www.gsk-studyregister.com/en/trial-det...
# 1  https://www.gsk-studyregister.com/en/trial-det...
# 2  https://www.gsk-studyregister.com/en/trial-det...
# 3  https://www.gsk-studyregister.com/en/trial-det...
# 4  https://www.gsk-studyregister.com/en/trial-det...
#
#   Link to study details on ClinicalTrials.gov (if available)  \
# 0         http://clinicaltrials.gov/show/NCT01706250
# 1         http://clinicaltrials.gov/show/NCT01381536
# 2         http://clinicaltrials.gov/show/NCT00688519
# 3         http://clinicaltrials.gov/show/NCT01015638
# 4         http://clinicaltrials.gov/show/NCT00964223
#
#   Link to study details on EudraCT (if available) Analysis-ready dataset  \
# 0                                             NaN                      N
# 1                                             NaN                      N
# 2                                             NaN                      Y
# 3                                             NaN                      N
# 4                                             NaN                      Y
#
#   Annotated case report form Clinical study report Dataset specifications  \
# 0                          Y                     Y                      Y
# 1                          Y                     Y                      Y
# 2                          Y                     Y                      Y
# 3                          N                     Y                      Y
# 4                          Y                     Y                      Y
#
#   Protocol with any amendments Raw dataset Reporting and analysis plan  \
# 0                            N           Y                           N
# 1                            N           Y                           Y
# 2                            Y           Y                           Y
# 3                            Y           Y                           N
# 4                            Y           N                           Y
#
#   Additional Information about the data and documents available for this study  \
# 0  An analysis-ready dataset and a reporting and ...
# 1  An analysis-ready dataset is not available for...
# 2                                                NaN
# 3  An analysis-ready dataset and reporting and an...
# 4     A raw dataset is not available for this study.
#
#   Date Added to this Site
# 0              1-Aug-2015
# 1              1-Jul-2015
# 2              1-Jul-2015
# 3              1-Aug-2014
# 4              1-Aug-2014

# %%
len(clinical_trials["Medicine or Vaccine (generic name)"].unique())
# Out:
# 485

# %%
len(clinical_trials["Medical Condition"].unique())
# Out:
# 402

# %%
condition_abnornaml_list_mapping = {"Alzheimers disease": "Alzheimer's disease",
                                    "Dementia with parkinson’s disease": "Parkinson's disease dementia", 
                                    "Dementia with lewy bodies": "Dementia",
                                    "Renal cell carcinoma (rcc)": "Renal cell carcinoma",
                                    "Influenza, human": "Influenza",
                                    "Healthy subjects": "",
                                    "Healthy volunteers": "",
                                    "Anklyosing spondylitis": "Ankylosing spondylitis",
                                    "Antifungal agents": "",
                                    "Partial-onset seizures": "Partial onset seizures",
                                    "Relapse-remitting multiple sclerosis": "Multiple sclerosis",
                                    "Relapsing remitting multiple sclerosis": "Multiple sclerosis",
                                    "Relapsing multiple sclerosis": "Multiple sclerosis",
                                    "Relapsing-remitting multiple sclerosis": "Multiple sclerosis",
                                    "Skin care": "",
                                    "Solid tumors": "Solid tumours",
                                    "Aids": "AIDS",
                                    "Nutritional status": "",					
                                    "Nutritional supplement": ""
                                    }

# %%
conditions = []

for combination in clinical_trials["Medical Condition"].unique():
    for x in combination.split("; "):
        x = x.strip().lower().capitalize()
        if x in condition_abnornaml_list_mapping:
            if condition_abnornaml_list_mapping[x] != "":
                conditions.append(condition_abnornaml_list_mapping[x])
        elif "transplant" in x:
            pass
        else:
            conditions.append(x)

conditions = sorted(list(set(conditions)))

content = ""
for c in conditions:
    content += c + "\n"

with open("conditions.txt", "w") as f:
    f.write(content)

# %% [markdown]
# Here, we need to head to gcp and do some ner. healthcare_nlp_experiment.ipynb

# %% [markdown]
# GCP healthcare NLP requires at least 10 characters

# %%
condition_gcp_nlp = pd.read_csv("condition_gcp_ner.tsv", sep="\t")
condition_gcp_nlp.head()
# Out:
#                       text                                      preferredTerm  \
# 0                     AIDS  Acquired Immunodeficiency Syndrome;AID - Artif...
# 1      Acellular pertussis                                          Pertussis
# 2            Acne vulgaris                                      Acne Vulgaris
# 3  Acute coronary syndrome                            Acute Coronary Syndrome
# 4   Acute myeloid leukemia                        Leukemia, Myelocytic, Acute
#
#                       entityId  confidence             HPO  \
# 0  UMLS/C0001175;UMLS/C0021588    0.824860             NaN
# 1                UMLS/C0043167    0.988182             NaN
# 2                UMLS/C0001144    0.970287             NaN
# 3                UMLS/C0948089    0.891674  HPO/HP:0033678
# 4                UMLS/C0023467    0.834782  HPO/HP:0004808
#
#                        MSH
# 0  MSH/D000163;MSH/D007316
# 1              MSH/D014917
# 2              MSH/D000152
# 3              MSH/D054058
# 4              MSH/D015470

# %%
import math

condition_nlp_mapping = {}
for i, row in condition_gcp_nlp.iterrows():
    temp = {}
    for h in ["preferredTerm", "entityId", "HPO", "MSH"]:
        if ";" in str(row[h]):
            temp[h] = row[h].split(";")[0]
        else:
            temp[h] = str(row[h])
    condition_nlp_mapping[row["text"]] = temp

# %%
condition_nlp_mapping
# Out:
# {'AIDS': {'preferredTerm': 'Acquired Immunodeficiency Syndrome',
#   'entityId': 'UMLS/C0001175',
#   'HPO': 'nan',
#   'MSH': 'MSH/D000163'},
#  'Acellular pertussis': {'preferredTerm': 'Pertussis',
#   'entityId': 'UMLS/C0043167',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014917'},
#  'Acne vulgaris': {'preferredTerm': 'Acne Vulgaris',
#   'entityId': 'UMLS/C0001144',
#   'HPO': 'nan',
#   'MSH': 'MSH/D000152'},
#  'Acute coronary syndrome': {'preferredTerm': 'Acute Coronary Syndrome',
#   'entityId': 'UMLS/C0948089',
#   'HPO': 'HPO/HP:0033678',
#   'MSH': 'MSH/D054058'},
#  'Acute myeloid leukemia': {'preferredTerm': 'Leukemia, Myelocytic, Acute',
#   'entityId': 'UMLS/C0023467',
#   'HPO': 'HPO/HP:0004808',
#   'MSH': 'MSH/D015470'},
#  'Adrenocortical carcinoma': {'preferredTerm': 'Adrenocortical carcinoma',
#   'entityId': 'UMLS/C0206686',
#   'HPO': 'HPO/HP:0006744',
#   'MSH': 'MSH/D018268'},
#  'Advanced breast cancer': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Alcoholism': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Allergic conjunctivitis': {'preferredTerm': 'Allergic Conjunctivitis',
#   'entityId': 'UMLS/C0009766',
#   'HPO': 'HPO/HP:0007879',
#   'MSH': 'MSH/D003233'},
#  'Alopecia': {'preferredTerm': 'Alopecia',
#   'entityId': 'UMLS/C0002170',
#   'HPO': 'HPO/HP:0001596',
#   'MSH': 'MSH/D000505'},
#  "Alzheimer's disease": {'preferredTerm': "Alzheimer's Disease",
#   'entityId': 'UMLS/C0002395',
#   'HPO': 'HPO/HP:0002511',
#   'MSH': 'MSH/D000544'},
#  'Amyloidosis': {'preferredTerm': 'Amyloidosis',
#   'entityId': 'UMLS/C0002726',
#   'HPO': 'HPO/HP:0011034',
#   'MSH': 'MSH/D000686'},
#  'Anaemia': {'preferredTerm': 'Anemia',
#   'entityId': 'UMLS/C0002871',
#   'HPO': 'HPO/HP:0001903',
#   'MSH': 'MSH/D000740'},
#  'Analgesia': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Ankylosing spondylitis': {'preferredTerm': 'Ankylosing spondylitis',
#   'entityId': 'UMLS/C0038013',
#   'HPO': 'nan',
#   'MSH': 'MSH/D013167'},
#  'Anxiety disorders': {'preferredTerm': 'Anxiety Disorders',
#   'entityId': 'UMLS/C0003469',
#   'HPO': 'nan',
#   'MSH': 'MSH/D001008'},
#  'Arrhythmia, cardiac': {'preferredTerm': 'Cardiac Arrhythmia',
#   'entityId': 'UMLS/C0003811',
#   'HPO': 'HPO/HP:0011675',
#   'MSH': 'MSH/D001145'},
#  'Arthritis, rheumatoid': {'preferredTerm': 'Arthritis',
#   'entityId': 'UMLS/C0003864',
#   'HPO': 'HPO/HP:0001369',
#   'MSH': 'MSH/D001168'},
#  'Asthma': {'preferredTerm': 'Asthma',
#   'entityId': 'UMLS/C0004096',
#   'HPO': 'HPO/HP:0002099',
#   'MSH': 'MSH/D001249'},
#  'Asthma and rhinitis': {'preferredTerm': 'Asthma',
#   'entityId': 'UMLS/C0004096',
#   'HPO': 'HPO/HP:0002099',
#   'MSH': 'MSH/D001249'},
#  'Atherosclerosis': {'preferredTerm': 'Atherosclerosis',
#   'entityId': 'UMLS/C0004153',
#   'HPO': 'HPO/HP:0002621',
#   'MSH': 'MSH/D050197'},
#  'Atrophy, geographic': {'preferredTerm': 'Atrophic',
#   'entityId': 'UMLS/C0333641',
#   'HPO': 'nan',
#   'MSH': 'MSH/D001284'},
#  'Atrophy, muscular': {'preferredTerm': 'Atrophic',
#   'entityId': 'UMLS/C0333641',
#   'HPO': 'nan',
#   'MSH': 'MSH/D001284'},
#  'Attention deficit hyperactivity disorder (adhd)': {'preferredTerm': 'Attention deficit hyperactivity disorder',
#   'entityId': 'UMLS/C1263846',
#   'HPO': 'HPO/HP:0007018',
#   'MSH': 'MSH/D001289'},
#  'Autoimmune diseases': {'preferredTerm': 'Autoimmune Diseases',
#   'entityId': 'UMLS/C0004364',
#   'HPO': 'HPO/HP:0002960',
#   'MSH': 'MSH/D001327'},
#  'B-cell acute lymphoblastic leukemia, relapsed b-cell acute lymphoblastic leukemia, refractory b-cell acute lymphoblastic leukemia': {'preferredTerm': 'Precursor B-cell lymphoblastic leukemia',
#   'entityId': 'UMLS/C1292769',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Bipolar disorder': {'preferredTerm': 'Bipolar Disorder',
#   'entityId': 'UMLS/C0005586',
#   'HPO': 'HPO/HP:0007302',
#   'MSH': 'MSH/D001714'},
#  'Bipolar i disorder': {'preferredTerm': 'Mixed bipolar I disorder',
#   'entityId': 'UMLS/C0236780',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Bladder pain': {'preferredTerm': 'Pain',
#   'entityId': 'UMLS/C0030193',
#   'HPO': 'HPO/HP:0012531',
#   'MSH': 'MSH/D010146'},
#  'Breast cancer': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Breast neoplasms': {'preferredTerm': 'Neoplasms',
#   'entityId': 'UMLS/C0027651',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Bronchiectasis': {'preferredTerm': 'Bronchiectasis',
#   'entityId': 'UMLS/C0006267',
#   'HPO': 'HPO/HP:0002110',
#   'MSH': 'MSH/D001987'},
#  'Bronchitis, chronic': {'preferredTerm': 'Bronchitis',
#   'entityId': 'UMLS/C0006277',
#   'HPO': 'HPO/HP:0012387',
#   'MSH': 'MSH/D001991'},
#  'Bronchospasm': {'preferredTerm': 'Bronchospasm',
#   'entityId': 'UMLS/C0006266',
#   'HPO': 'HPO/HP:0025428',
#   'MSH': 'MSH/D001986'},
#  'Cachexia': {'preferredTerm': 'Cachexia',
#   'entityId': 'UMLS/C0006625',
#   'HPO': 'HPO/HP:0004326',
#   'MSH': 'MSH/D002100'},
#  'Cancer': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Cancer, advanced gastric': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Cancer, breast': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Cancer|neoplasms': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Carcinoid tumor': {'preferredTerm': 'Carcinoid Tumor',
#   'entityId': 'UMLS/C0007095',
#   'HPO': 'HPO/HP:0100570',
#   'MSH': 'MSH/D002276'},
#  'Carcinoma, hepatocellular': {'preferredTerm': 'Carcinoma',
#   'entityId': 'UMLS/C0007097',
#   'HPO': 'HPO/HP:0030731',
#   'MSH': 'MSH/D002277'},
#  'Carcinoma, midline': {'preferredTerm': 'Carcinoma',
#   'entityId': 'UMLS/C0007097',
#   'HPO': 'HPO/HP:0030731',
#   'MSH': 'MSH/D002277'},
#  'Carcinoma, renal cell': {'preferredTerm': 'Carcinoma',
#   'entityId': 'UMLS/C0007097',
#   'HPO': 'HPO/HP:0030731',
#   'MSH': 'MSH/D002277'},
#  'Carcinoma, small cell': {'preferredTerm': 'Carcinoma',
#   'entityId': 'UMLS/C0007097',
#   'HPO': 'HPO/HP:0030731',
#   'MSH': 'MSH/D002277'},
#  'Cardiovascular disease': {'preferredTerm': 'Cardiovascular Diseases',
#   'entityId': 'UMLS/C0007222',
#   'HPO': 'HPO/HP:0001626',
#   'MSH': 'MSH/D002318'},
#  'Cataract': {'preferredTerm': 'Bilateral cataracts (disorder)',
#   'entityId': 'UMLS/C0521707',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Cerebrovascular accident': {'preferredTerm': 'Cerebrovascular accident',
#   'entityId': 'UMLS/C0038454',
#   'HPO': 'HPO/HP:0001297',
#   'MSH': 'MSH/D020521'},
#  'Cervical intraepithelial neoplasia': {'preferredTerm': 'Cervical Intraepithelial Neoplasia',
#   'entityId': 'UMLS/C0206708',
#   'HPO': 'HPO/HP:0032242',
#   'MSH': 'MSH/D018290'},
#  'Cholestasis': {'preferredTerm': 'Cholestasis',
#   'entityId': 'UMLS/C0008370',
#   'HPO': 'HPO/HP:0001396',
#   'MSH': 'MSH/D002779'},
#  'Cholestasis, intrahepatic': {'preferredTerm': 'Cholestasis',
#   'entityId': 'UMLS/C0008370',
#   'HPO': 'HPO/HP:0001396',
#   'MSH': 'MSH/D002779'},
#  'Chronic constipation': {'preferredTerm': 'Constipation',
#   'entityId': 'UMLS/C0009806',
#   'HPO': 'HPO/HP:0002019',
#   'MSH': 'MSH/D003248'},
#  'Chronic idiopathic urticaria (ciu)': {'preferredTerm': 'Idiopathic urticaria',
#   'entityId': 'UMLS/C0157741',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Chronic lymphocytic leukemia (cll)': {'preferredTerm': 'Lymphoid leukemia',
#   'entityId': 'UMLS/C0023448',
#   'HPO': 'HPO/HP:0005526',
#   'MSH': 'MSH/D007945'},
#  'Chronic myelogenous leukemia': {'preferredTerm': 'Myeloid Leukemia',
#   'entityId': 'UMLS/C0023470',
#   'HPO': 'HPO/HP:0012324',
#   'MSH': 'MSH/D007951'},
#  'Chronic myeloid leukemia (cml)': {'preferredTerm': 'Myeloid Leukemia',
#   'entityId': 'UMLS/C0023470',
#   'HPO': 'HPO/HP:0012324',
#   'MSH': 'MSH/D007951'},
#  'Chronic obstructive pulmonary disease (copd)': {'preferredTerm': 'Chronic Obstructive Airway Disease',
#   'entityId': 'UMLS/C0024117',
#   'HPO': 'HPO/HP:0006510',
#   'MSH': 'MSH/D029424'},
#  'Chronic plaque psoriasis': {'preferredTerm': 'Psoriasis',
#   'entityId': 'UMLS/C0033860',
#   'HPO': 'HPO/HP:0003765',
#   'MSH': 'MSH/D011565'},
#  'Clostridium difficile infection': {'preferredTerm': 'Clostridium difficile infection',
#   'entityId': 'UMLS/C0343386',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003015'},
#  'Cognitive disorders': {'preferredTerm': 'Cognition Disorders',
#   'entityId': 'UMLS/C0009241',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003072'},
#  'Colitis, ulcerative': {'preferredTerm': 'Colitis',
#   'entityId': 'UMLS/C0009319',
#   'HPO': 'HPO/HP:0002583',
#   'MSH': 'MSH/D003092'},
#  'Constriction, bronchial': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Coronary artery disease': {'preferredTerm': 'Coronary Artery Disease',
#   'entityId': 'UMLS/C1956346',
#   'HPO': 'HPO/HP:0001677',
#   'MSH': 'MSH/D003324'},
#  'Corticosteroid refractory acute graft vs host disease': {'preferredTerm': 'Graft-vs-Host Disease',
#   'entityId': 'UMLS/C0018133',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006086'},
#  'Cough': {'preferredTerm': 'Coughing',
#   'entityId': 'UMLS/C0010200',
#   'HPO': 'HPO/HP:0012735',
#   'MSH': 'MSH/D003371'},
#  "Crohn's disease": {'preferredTerm': 'Crohn Disease',
#   'entityId': 'UMLS/C0010346',
#   'HPO': 'HPO/HP:0100280',
#   'MSH': 'MSH/D003424'},
#  'Cystic fibrosis': {'preferredTerm': 'Cystic Fibrosis',
#   'entityId': 'UMLS/C0010674',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003550'},
#  'Dementia': {'preferredTerm': 'Dementia',
#   'entityId': 'UMLS/C0497327',
#   'HPO': 'HPO/HP:0000726',
#   'MSH': 'MSH/D003704'},
#  'Dentin sensitivity': {'preferredTerm': 'Dentin Sensitivity',
#   'entityId': 'UMLS/C0011432',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003807'},
#  'Denture retention': {'preferredTerm': 'Denture Retention',
#   'entityId': 'UMLS/C0011397',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003781'},
#  'Depressive disorder': {'preferredTerm': 'Depressive disorder',
#   'entityId': 'UMLS/C0011581',
#   'HPO': 'HPO/HP:0000716',
#   'MSH': 'MSH/D003866'},
#  'Depressive disorder and anxiety disorders': {'preferredTerm': 'Depressive disorder',
#   'entityId': 'UMLS/C0011581',
#   'HPO': 'HPO/HP:0000716',
#   'MSH': 'MSH/D003866'},
#  'Depressive disorder, major': {'preferredTerm': 'Depressive disorder',
#   'entityId': 'UMLS/C0011581',
#   'HPO': 'HPO/HP:0000716',
#   'MSH': 'MSH/D003866'},
#  'Dermatitis, atopic': {'preferredTerm': 'Dermatitis',
#   'entityId': 'UMLS/C0011603',
#   'HPO': 'HPO/HP:0011123',
#   'MSH': 'MSH/D003872'},
#  'Dermatitis, chronic': {'preferredTerm': 'Dermatitis',
#   'entityId': 'UMLS/C0011603',
#   'HPO': 'HPO/HP:0011123',
#   'MSH': 'MSH/D003872'},
#  'Dermatitis, seborrheic': {'preferredTerm': 'Dermatitis',
#   'entityId': 'UMLS/C0011603',
#   'HPO': 'HPO/HP:0011123',
#   'MSH': 'MSH/D003872'},
#  'Diabetes mellitus': {'preferredTerm': 'Diabetes Mellitus',
#   'entityId': 'UMLS/C0011849',
#   'HPO': 'HPO/HP:0000819',
#   'MSH': 'MSH/D003920'},
#  'Diabetes mellitus, type 1': {'preferredTerm': 'Diabetes Mellitus, Insulin-Dependent',
#   'entityId': 'UMLS/C0011854',
#   'HPO': 'HPO/HP:0100651',
#   'MSH': 'MSH/D003922'},
#  'Diabetes mellitus, type 2': {'preferredTerm': 'Diabetes Mellitus, Non-Insulin-Dependent',
#   'entityId': 'UMLS/C0011860',
#   'HPO': 'HPO/HP:0005978',
#   'MSH': 'MSH/D003924'},
#  'Diabetic kidney disease': {'preferredTerm': 'Diabetic Nephropathy',
#   'entityId': 'UMLS/C0011881',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003928'},
#  'Diabetic macular edema': {'preferredTerm': 'Macular edema due to diabetes mellitus',
#   'entityId': 'UMLS/C0730285',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Diabetic neuropathic pain': {'preferredTerm': 'Diabetic Neuralgia',
#   'entityId': 'UMLS/C0751074',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003929'},
#  'Diphtheria': {'preferredTerm': 'Diphtheria',
#   'entityId': 'UMLS/C0012546',
#   'HPO': 'nan',
#   'MSH': 'MSH/D004165'},
#  'Drug-related side effects and adverse reactions': {'preferredTerm': 'Adverse reaction to drug',
#   'entityId': 'UMLS/C0041755',
#   'HPO': 'HPO/HP:0020172',
#   'MSH': 'MSH/D064420'},
#  'Dysentery, bacillary': {'preferredTerm': 'Dysentery',
#   'entityId': 'UMLS/C0013369',
#   'HPO': 'nan',
#   'MSH': 'MSH/D004403'},
#  'Dyslipidaemias': {'preferredTerm': 'Dyslipidemias',
#   'entityId': 'UMLS/C0242339',
#   'HPO': 'HPO/HP:0003119',
#   'MSH': 'MSH/D050171'},
#  'Eczema': {'preferredTerm': 'Eczema',
#   'entityId': 'UMLS/C0013595',
#   'HPO': 'HPO/HP:0000964',
#   'MSH': 'MSH/D004485'},
#  'Embolism, pulmonary': {'preferredTerm': 'Embolism',
#   'entityId': 'UMLS/C0013922',
#   'HPO': 'nan',
#   'MSH': 'MSH/D004617'},
#  'Embryo transfer': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Endometriosis': {'preferredTerm': 'Endometriosis',
#   'entityId': 'UMLS/C0014175',
#   'HPO': 'HPO/HP:0030127',
#   'MSH': 'MSH/D004715'},
#  'Eosinophilic asthma': {'preferredTerm': 'Asthma',
#   'entityId': 'UMLS/C0004096',
#   'HPO': 'HPO/HP:0002099',
#   'MSH': 'MSH/D001249'},
#  'Epilepsy': {'preferredTerm': 'Epilepsy',
#   'entityId': 'UMLS/C0014544',
#   'HPO': 'HPO/HP:0001250',
#   'MSH': 'MSH/D004827'},
#  'Epilepsy, partial': {'preferredTerm': 'Epilepsy',
#   'entityId': 'UMLS/C0014544',
#   'HPO': 'HPO/HP:0001250',
#   'MSH': 'MSH/D004827'},
#  'Epilepsy, tonic-clonic': {'preferredTerm': 'Epilepsy',
#   'entityId': 'UMLS/C0014544',
#   'HPO': 'HPO/HP:0001250',
#   'MSH': 'MSH/D004827'},
#  'Episodic migraine headache': {'preferredTerm': 'Migraine Disorders',
#   'entityId': 'UMLS/C0149931',
#   'HPO': 'HPO/HP:0002076',
#   'MSH': 'MSH/D008881'},
#  'Esophageal cancer': {'preferredTerm': 'Esophageal carcinoma',
#   'entityId': 'UMLS/C0152018',
#   'HPO': 'HPO/HP:0011459',
#   'MSH': 'MSH/D004938'},
#  'Fasciolasis': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Fibrillation, atrial': {'preferredTerm': 'Atrial Fibrillation',
#   'entityId': 'UMLS/C0004238',
#   'HPO': 'HPO/HP:0005110',
#   'MSH': 'MSH/D001281'},
#  'Fibromyalgia syndrome, primary': {'preferredTerm': 'Fibromyalgia',
#   'entityId': 'UMLS/C0016053',
#   'HPO': 'nan',
#   'MSH': 'MSH/D005356'},
#  'Focal infection, dental': {'preferredTerm': 'Focal Infection',
#   'entityId': 'UMLS/C0016397',
#   'HPO': 'nan',
#   'MSH': 'MSH/D005490'},
#  'Fracture healing': {'preferredTerm': 'Fracture',
#   'entityId': 'UMLS/C0016658',
#   'HPO': 'HPO/HP:0020110',
#   'MSH': 'MSH/D050723'},
#  'Gastrointestinal diseases': {'preferredTerm': 'Gastrointestinal Diseases',
#   'entityId': 'UMLS/C0017178',
#   'HPO': 'HPO/HP:0011024',
#   'MSH': 'MSH/D005767'},
#  'Gastrointestinal motility': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Gastroparesis': {'preferredTerm': 'Gastroparesis',
#   'entityId': 'UMLS/C0152020',
#   'HPO': 'HPO/HP:0002578',
#   'MSH': 'MSH/D018589'},
#  'Gonorrhea': {'preferredTerm': 'Gonorrhea',
#   'entityId': 'UMLS/C0018081',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006069'},
#  'Haemophilus influenzae type b': {'preferredTerm': 'Haemophilus influenzae type b',
#   'entityId': 'UMLS/C0121772',
#   'HPO': 'nan',
#   'MSH': 'MSH/D019741'},
#  'Heart failure': {'preferredTerm': 'Heart failure',
#   'entityId': 'UMLS/C0018801',
#   'HPO': 'HPO/HP:0001635',
#   'MSH': 'MSH/D006333'},
#  'Heart failure with preserved ejection fraction': {'preferredTerm': 'Heart failure',
#   'entityId': 'UMLS/C0018801',
#   'HPO': 'HPO/HP:0001635',
#   'MSH': 'MSH/D006333'},
#  'Heart failure, chronic (chf)': {'preferredTerm': 'Heart failure',
#   'entityId': 'UMLS/C0018801',
#   'HPO': 'HPO/HP:0001635',
#   'MSH': 'MSH/D006333'},
#  'Heart failure, congestive': {'preferredTerm': 'Heart failure',
#   'entityId': 'UMLS/C0018801',
#   'HPO': 'HPO/HP:0001635',
#   'MSH': 'MSH/D006333'},
#  'Heart failure, congestive and microalbuminuria': {'preferredTerm': 'Heart failure',
#   'entityId': 'UMLS/C0018801',
#   'HPO': 'HPO/HP:0001635',
#   'MSH': 'MSH/D006333'},
#  'Hepatitis a': {'preferredTerm': 'Hepatitis A',
#   'entityId': 'UMLS/C0019159',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006506'},
#  'Hepatitis b': {'preferredTerm': 'Hepatitis B',
#   'entityId': 'UMLS/C0019163',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006509'},
#  'Hepatitis b, chronic': {'preferredTerm': 'Hepatitis B',
#   'entityId': 'UMLS/C0019163',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006509'},
#  'Hepatitis c': {'preferredTerm': 'Hepatitis C',
#   'entityId': 'UMLS/C0019196',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006526'},
#  'Hepatitis c, chronic': {'preferredTerm': 'Hepatitis C',
#   'entityId': 'UMLS/C0019196',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006526'},
#  'Hepatocellular carcinoma (hcc)': {'preferredTerm': 'Liver carcinoma',
#   'entityId': 'UMLS/C2239176',
#   'HPO': 'HPO/HP:0001402',
#   'MSH': 'MSH/D006528'},
#  'Her2-negative metastatic breast cancer': {'preferredTerm': 'Neoplasm Metastasis',
#   'entityId': 'UMLS/C0027627',
#   'HPO': 'nan',
#   'MSH': 'MSH/D009362'},
#  'Her2/neu over-expressing locally advanced breast cancer or metastatic breast cancer': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Hereditary periodic fevers': {'preferredTerm': 'Fever',
#   'entityId': 'UMLS/C0015967',
#   'HPO': 'HPO/HP:0001945',
#   'MSH': 'MSH/D005334'},
#  'Herpes genitalis': {'preferredTerm': 'Genital Herpes',
#   'entityId': 'UMLS/C0019342',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006558'},
#  'Herpes labialis': {'preferredTerm': 'Herpes Labialis',
#   'entityId': 'UMLS/C0019345',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006560'},
#  'Herpes simplex': {'preferredTerm': 'Herpes Simplex Infections',
#   'entityId': 'UMLS/C0019348',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006561'},
#  'Herpes zoster': {'preferredTerm': 'Herpes zoster disease',
#   'entityId': 'UMLS/C0019360',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006562'},
#  'Hip fracture': {'preferredTerm': 'Fracture',
#   'entityId': 'UMLS/C0016658',
#   'HPO': 'HPO/HP:0020110',
#   'MSH': 'MSH/D050723'},
#  'Hiv infections': {'preferredTerm': 'HIV Infections',
#   'entityId': 'UMLS/C0019693',
#   'HPO': 'nan',
#   'MSH': 'MSH/D015658'},
#  'Huntington disease': {'preferredTerm': 'Huntington Disease',
#   'entityId': 'UMLS/C0020179',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006816'},
#  'Hypercholesterolemia': {'preferredTerm': 'Hypercholesterolemia',
#   'entityId': 'UMLS/C0020443',
#   'HPO': 'HPO/HP:0003124',
#   'MSH': 'MSH/D006937'},
#  'Hypereosinophilic syndrome': {'preferredTerm': 'Hypereosinophilic syndrome',
#   'entityId': 'UMLS/C1540912',
#   'HPO': 'nan',
#   'MSH': 'MSH/D017681'},
#  'Hyperhidrosis': {'preferredTerm': 'Hyperhidrosis disorder',
#   'entityId': 'UMLS/C0020458',
#   'HPO': 'HPO/HP:0000975',
#   'MSH': 'MSH/D006945'},
#  'Hyperreactivity, bronchial': {'preferredTerm': 'Hyperreactivity',
#   'entityId': 'UMLS/C4693174',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Hypertension': {'preferredTerm': 'Hypertensive disease',
#   'entityId': 'UMLS/C0020538',
#   'HPO': 'HPO/HP:0000822',
#   'MSH': 'MSH/D006973'},
#  'Hypertension, pulmonary': {'preferredTerm': 'Hypertensive disease',
#   'entityId': 'UMLS/C0020538',
#   'HPO': 'HPO/HP:0000822',
#   'MSH': 'MSH/D006973'},
#  'Hypertriglyceridemia': {'preferredTerm': 'Hypertriglyceridemia',
#   'entityId': 'UMLS/C0020557',
#   'HPO': 'HPO/HP:0002155',
#   'MSH': 'MSH/D015228'},
#  'Hypertrophy, left ventricular': {'preferredTerm': 'Hypertrophy',
#   'entityId': 'UMLS/C0020564',
#   'HPO': 'nan',
#   'MSH': 'MSH/D006984'},
#  'Hypogonadism, male': {'preferredTerm': 'Hypogonadism',
#   'entityId': 'UMLS/C0020619',
#   'HPO': 'HPO/HP:0000135',
#   'MSH': 'MSH/D007006'},
#  'Idiopathic pulmonary fibrosis': {'preferredTerm': 'Idiopathic Pulmonary Fibrosis',
#   'entityId': 'UMLS/C1800706',
#   'HPO': 'nan',
#   'MSH': 'MSH/D054990'},
#  'Idiopathic thrombocytopenic purpura': {'preferredTerm': 'Immune thrombocytopenic purpura',
#   'entityId': 'UMLS/C0398650',
#   'HPO': 'HPO/HP:0001973',
#   'MSH': 'MSH/D016553'},
#  'Impetigo': {'preferredTerm': 'Impetigo',
#   'entityId': 'UMLS/C0021099',
#   'HPO': 'nan',
#   'MSH': 'MSH/D007169'},
#  'Infection, human immunodeficiency virus': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infection, human immunodeficiency virus i': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, bacterial': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, herpesviridae': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, human immunodeficiency virus and herpesviridae': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, meningococcal': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, papillomavirus': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, respiratory syncytial virus': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, respiratory tract': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, rotavirus': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, staphylococcal': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Infections, streptococcal': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Inflammatory bowel diseases': {'preferredTerm': 'Inflammatory Bowel Diseases',
#   'entityId': 'UMLS/C0021390',
#   'HPO': 'HPO/HP:0002037',
#   'MSH': 'MSH/D015212'},
#  'Influenza': {'preferredTerm': 'Influenza',
#   'entityId': 'UMLS/C0021400',
#   'HPO': 'nan',
#   'MSH': 'MSH/D007251'},
#  'Influenza a virus, h1n1 subtype': {'preferredTerm': 'influenza A virus',
#   'entityId': 'UMLS/C0029347',
#   'HPO': 'nan',
#   'MSH': 'MSH/D009980'},
#  'Insulin resistance': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Invasive aspergillosis / invasive mucormycosis': {'preferredTerm': 'Aspergillosis, Nervous System Invasive',
#   'entityId': 'UMLS/C0752341',
#   'HPO': 'nan',
#   'MSH': 'MSH/D020953'},
#  'Invasive candidiasis': {'preferredTerm': 'Invasive Candidiasis',
#   'entityId': 'UMLS/C1609535',
#   'HPO': 'nan',
#   'MSH': 'MSH/D058365'},
#  'Invasive fungal infection': {'preferredTerm': 'Invasive Fungal Infections',
#   'entityId': 'UMLS/C1262313',
#   'HPO': 'HPO/HP:0020101',
#   'MSH': 'MSH/D000072742'},
#  'Invasive fungal infections': {'preferredTerm': 'Invasive Fungal Infections',
#   'entityId': 'UMLS/C1262313',
#   'HPO': 'HPO/HP:0020101',
#   'MSH': 'MSH/D000072742'},
#  'Irritable bowel syndrome': {'preferredTerm': 'Irritable Bowel Syndrome',
#   'entityId': 'UMLS/C0022104',
#   'HPO': 'nan',
#   'MSH': 'MSH/D043183'},
#  'Ischaemic attack, transient': {'preferredTerm': 'Transient Ischemic Attack',
#   'entityId': 'UMLS/C0007787',
#   'HPO': 'HPO/HP:0002326',
#   'MSH': 'MSH/D002546'},
#  'Juvenile psoriatic arthritis, enthesitis-related arthritis': {'preferredTerm': 'Arthritis, Psoriatic',
#   'entityId': 'UMLS/C0003872',
#   'HPO': 'nan',
#   'MSH': 'MSH/D015535'},
#  'Lennox-gastaut syndrome': {'preferredTerm': 'Lennox-Gastaut syndrome',
#   'entityId': 'UMLS/C0238111',
#   'HPO': 'nan',
#   'MSH': 'MSH/D065768'},
#  'Leukaemia, lymphocytic, chronic': {'preferredTerm': 'leukemia',
#   'entityId': 'UMLS/C0023418',
#   'HPO': 'HPO/HP:0001909',
#   'MSH': 'MSH/D007938'},
#  'Leukaemia, myelocytic, acute': {'preferredTerm': 'leukemia',
#   'entityId': 'UMLS/C0023418',
#   'HPO': 'HPO/HP:0001909',
#   'MSH': 'MSH/D007938'},
#  'Liver diseases': {'preferredTerm': 'Disease',
#   'entityId': 'UMLS/C0012634',
#   'HPO': 'nan',
#   'MSH': 'MSH/D004194'},
#  'Lower urinary tract symptoms / benign prostatic hyperplasia': {'preferredTerm': 'Symptoms',
#   'entityId': 'UMLS/C1457887',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Lung cancer, non-small cell': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Lung injury, acute': {'preferredTerm': 'Traumatic injury',
#   'entityId': 'UMLS/C3263723',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014947'},
#  'Lung injury, acute and respiratory distress syndrome, adult': {'preferredTerm': 'Traumatic injury',
#   'entityId': 'UMLS/C3263723',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014947'},
#  'Lupus erythematosus, cutaneous': {'preferredTerm': 'Lupus Erythematosus',
#   'entityId': 'UMLS/C0409974',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Lupus nephritis': {'preferredTerm': 'Lupus Nephritis',
#   'entityId': 'UMLS/C0024143',
#   'HPO': 'HPO/HP:0033726',
#   'MSH': 'MSH/D008181'},
#  'Lymphoma, follicular': {'preferredTerm': 'Lymphoma',
#   'entityId': 'UMLS/C0024299',
#   'HPO': 'HPO/HP:0002665',
#   'MSH': 'MSH/D008223'},
#  'Lymphoma, mantle-cell': {'preferredTerm': 'Lymphoma',
#   'entityId': 'UMLS/C0024299',
#   'HPO': 'HPO/HP:0002665',
#   'MSH': 'MSH/D008223'},
#  'Lymphoma, non-hodgkin': {'preferredTerm': 'Lymphoma',
#   'entityId': 'UMLS/C0024299',
#   'HPO': 'HPO/HP:0002665',
#   'MSH': 'MSH/D008223'},
#  'Malaria': {'preferredTerm': 'Malaria',
#   'entityId': 'UMLS/C0024530',
#   'HPO': 'nan',
#   'MSH': 'MSH/D008288'},
#  'Malaria, falciparum': {'preferredTerm': 'Malaria',
#   'entityId': 'UMLS/C0024530',
#   'HPO': 'nan',
#   'MSH': 'MSH/D008288'},
#  'Malaria, vivax': {'preferredTerm': 'Malaria',
#   'entityId': 'UMLS/C0024530',
#   'HPO': 'nan',
#   'MSH': 'MSH/D008288'},
#  'Mastocytosis': {'preferredTerm': 'Mastocytosis',
#   'entityId': 'UMLS/C0024899',
#   'HPO': 'HPO/HP:0100495',
#   'MSH': 'MSH/D008415'},
#  'Measles': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Measles, mumps, rubella': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Melanoma': {'preferredTerm': 'melanoma',
#   'entityId': 'UMLS/C0025202',
#   'HPO': 'HPO/HP:0002861',
#   'MSH': 'MSH/D008545'},
#  'Meningitis, meningococcal': {'preferredTerm': 'Meningitis',
#   'entityId': 'UMLS/C0025289',
#   'HPO': 'HPO/HP:0001287',
#   'MSH': 'MSH/D008581'},
#  'Meningococcal disease': {'preferredTerm': 'Meningococcal Infections',
#   'entityId': 'UMLS/C0025303',
#   'HPO': 'nan',
#   'MSH': 'MSH/D008589'},
#  'Mental disorders': {'preferredTerm': 'Mental disorders',
#   'entityId': 'UMLS/C0004936',
#   'HPO': 'nan',
#   'MSH': 'MSH/D001523'},
#  'Metabolic syndrome x': {'preferredTerm': 'Metabolic Syndrome X',
#   'entityId': 'UMLS/C0524620',
#   'HPO': 'nan',
#   'MSH': 'MSH/D024821'},
#  'Metastases, brain': {'preferredTerm': 'Neoplasm Metastasis',
#   'entityId': 'UMLS/C0027627',
#   'HPO': 'nan',
#   'MSH': 'MSH/D009362'},
#  'Metastatic breast cancer': {'preferredTerm': 'Malignant neoplasm of breast',
#   'entityId': 'UMLS/C0006142',
#   'HPO': 'HPO/HP:0003002',
#   'MSH': 'MSH/D001943'},
#  'Metastatic melanoma': {'preferredTerm': 'Metastatic melanoma',
#   'entityId': 'UMLS/C0278883',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Metastatic renal cell carcinoma': {'preferredTerm': 'Metastatic Renal Cell Carcinoma',
#   'entityId': 'UMLS/C4721698',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Metastatic triple-negative breast cancer': {'preferredTerm': 'Triple Negative Breast Neoplasms',
#   'entityId': 'UMLS/C3539878',
#   'HPO': 'nan',
#   'MSH': 'MSH/D064726'},
#  'Migraine': {'preferredTerm': 'Migraine Disorders',
#   'entityId': 'UMLS/C0149931',
#   'HPO': 'HPO/HP:0002076',
#   'MSH': 'MSH/D008881'},
#  'Migraine disorders': {'preferredTerm': 'Migraine Disorders',
#   'entityId': 'UMLS/C0149931',
#   'HPO': 'HPO/HP:0002076',
#   'MSH': 'MSH/D008881'},
#  'Migraine disorders and premenstrual syndrome': {'preferredTerm': 'Migraine Disorders',
#   'entityId': 'UMLS/C0149931',
#   'HPO': 'HPO/HP:0002076',
#   'MSH': 'MSH/D008881'},
#  'Migraine, without aura': {'preferredTerm': 'Migraine Disorders',
#   'entityId': 'UMLS/C0149931',
#   'HPO': 'HPO/HP:0002076',
#   'MSH': 'MSH/D008881'},
#  'Mild asthma and allergic rhinitis': {'preferredTerm': 'Asthma',
#   'entityId': 'UMLS/C0004096',
#   'HPO': 'HPO/HP:0002099',
#   'MSH': 'MSH/D001249'},
#  'Moderate to severe acute pain': {'preferredTerm': 'Pain',
#   'entityId': 'UMLS/C0030193',
#   'HPO': 'HPO/HP:0012531',
#   'MSH': 'MSH/D010146'},
#  'Moderate to severe acute post-operative pain': {'preferredTerm': 'Pain',
#   'entityId': 'UMLS/C0030193',
#   'HPO': 'HPO/HP:0012531',
#   'MSH': 'MSH/D010146'},
#  'Moderate to severe chronic plaque-type psoriasis': {'preferredTerm': 'Psoriasis',
#   'entityId': 'UMLS/C0033860',
#   'HPO': 'HPO/HP:0003765',
#   'MSH': 'MSH/D011565'},
#  'Moderate to severe scalp psoriasis': {'preferredTerm': 'Psoriasis',
#   'entityId': 'UMLS/C0033860',
#   'HPO': 'HPO/HP:0003765',
#   'MSH': 'MSH/D011565'},
#  'Mood disorders': {'preferredTerm': 'Mood Disorders',
#   'entityId': 'UMLS/C0525045',
#   'HPO': 'nan',
#   'MSH': 'MSH/D019964'},
#  'Multiple myeloma (mm)': {'preferredTerm': 'Multiple Myeloma',
#   'entityId': 'UMLS/C0026764',
#   'HPO': 'HPO/HP:0006775',
#   'MSH': 'MSH/D009101'},
#  'Multiple sclerosis': {'preferredTerm': 'Multiple Sclerosis',
#   'entityId': 'UMLS/C0026769',
#   'HPO': 'nan',
#   'MSH': 'MSH/D009103'},
#  'Multiple sclerosis, relapsing-remitting': {'preferredTerm': 'Multiple Sclerosis',
#   'entityId': 'UMLS/C0026769',
#   'HPO': 'nan',
#   'MSH': 'MSH/D009103'},
#  'Mumps': {'preferredTerm': 'Mumps',
#   'entityId': 'UMLS/C0026780',
#   'HPO': 'nan',
#   'MSH': 'MSH/D009107'},
#  'Muscle atrophy': {'preferredTerm': 'Atrophic',
#   'entityId': 'UMLS/C0333641',
#   'HPO': 'nan',
#   'MSH': 'MSH/D001284'},
#  'Myasthenia gravis': {'preferredTerm': 'Myasthenia Gravis',
#   'entityId': 'UMLS/C0026896',
#   'HPO': 'nan',
#   'MSH': 'MSH/D009157'},
#  'Mycoses': {'preferredTerm': 'Mycoses',
#   'entityId': 'UMLS/C0026946',
#   'HPO': 'nan',
#   'MSH': 'MSH/D009181'},
#  'Myelodysplastic syndrome (mds)': {'preferredTerm': 'MYELODYSPLASTIC SYNDROME',
#   'entityId': 'UMLS/C3463824',
#   'HPO': 'HPO/HP:0002863',
#   'MSH': 'MSH/D009190'},
#  'Myelofibrosis': {'preferredTerm': 'Primary Myelofibrosis',
#   'entityId': 'UMLS/C0001815',
#   'HPO': 'HPO/HP:0011974',
#   'MSH': 'MSH/D055728'},
#  'Myocardial perfusion imaging': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Nausea and vomiting, chemotherapy-induced': {'preferredTerm': 'Nausea',
#   'entityId': 'UMLS/C0027497',
#   'HPO': 'HPO/HP:0002018',
#   'MSH': 'MSH/D009325'},
#  'Nausea and vomiting, postoperative': {'preferredTerm': 'Nausea',
#   'entityId': 'UMLS/C0027497',
#   'HPO': 'HPO/HP:0002018',
#   'MSH': 'MSH/D009325'},
#  'Neisseria meningitidis': {'preferredTerm': 'Neisseria meningitidis',
#   'entityId': 'UMLS/C0027575',
#   'HPO': 'nan',
#   'MSH': 'MSH/D009345'},
#  'Neoplasms': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Neoplasms, breast': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Neoplasms, colorectal': {'preferredTerm': 'Neoplasms',
#   'entityId': 'UMLS/C0027651',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Neoplasms, gastrointestinal tract': {'preferredTerm': 'Neoplasms',
#   'entityId': 'UMLS/C0027651',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Neoplasms, head and neck': {'preferredTerm': 'Neoplasms',
#   'entityId': 'UMLS/C0027651',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Neoplasms, ovarian': {'preferredTerm': 'Neoplasms',
#   'entityId': 'UMLS/C0027651',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Neoplasms, prostate': {'preferredTerm': 'Neoplasms',
#   'entityId': 'UMLS/C0027651',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Neoplasms|lung neoplasms': {'preferredTerm': 'Neoplasms',
#   'entityId': 'UMLS/C0027651',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Neovascular age-related macular degeneration': {'preferredTerm': 'Macular degeneration',
#   'entityId': 'UMLS/C0024437',
#   'HPO': 'HPO/HP:0000608',
#   'MSH': 'MSH/D008268'},
#  'Neuralgia, postherpetic': {'preferredTerm': 'Neuralgia',
#   'entityId': 'UMLS/C0027796',
#   'HPO': 'HPO/HP:0033345',
#   'MSH': 'MSH/D009437'},
#  'Neuroendocrine tumors (net)': {'preferredTerm': 'Neuroendocrine Tumors',
#   'entityId': 'UMLS/C0206754',
#   'HPO': 'HPO/HP:0100634',
#   'MSH': 'MSH/D018358'},
#  'Neurogenic detrusor overactivity': {'preferredTerm': 'Overactive Detrusor',
#   'entityId': 'UMLS/C0268849',
#   'HPO': 'nan',
#   'MSH': 'MSH/D053201'},
#  'Neuropathy, diabetic': {'preferredTerm': 'Neuropathy',
#   'entityId': 'UMLS/C0442874',
#   'HPO': 'HPO/HP:0009830',
#   'MSH': 'nan'},
#  'Non-radiographic spondyloarthritis': {'preferredTerm': 'Spondylarthritis',
#   'entityId': 'UMLS/C0949690',
#   'HPO': 'nan',
#   'MSH': 'MSH/D025241'},
#  'Non-small cell lung cancer': {'preferredTerm': 'Non-Small Cell Lung Carcinoma',
#   'entityId': 'UMLS/C0007131',
#   'HPO': 'HPO/HP:0030358',
#   'MSH': 'MSH/D002289'},
#  'Non-small cell lung carcinoma (nsclc)': {'preferredTerm': 'Non-Small Cell Lung Carcinoma',
#   'entityId': 'UMLS/C0007131',
#   'HPO': 'HPO/HP:0030358',
#   'MSH': 'MSH/D002289'},
#  'Obesity': {'preferredTerm': 'Obesity',
#   'entityId': 'UMLS/C0028754',
#   'HPO': 'HPO/HP:0001513',
#   'MSH': 'MSH/D009765'},
#  'Obsessive-compulsive disorder': {'preferredTerm': 'Obsessive-Compulsive Disorder',
#   'entityId': 'UMLS/C0028768',
#   'HPO': 'HPO/HP:0000722',
#   'MSH': 'MSH/D009771'},
#  'Obsessive-compulsive disorder and depressive disorder': {'preferredTerm': 'Obsessive-Compulsive Disorder',
#   'entityId': 'UMLS/C0028768',
#   'HPO': 'HPO/HP:0000722',
#   'MSH': 'MSH/D009771'},
#  'Obstetric labour, premature': {'preferredTerm': 'Anesthesia, Obstetrical',
#   'entityId': 'UMLS/C0002922',
#   'HPO': 'nan',
#   'MSH': 'MSH/D000773'},
#  'Ocular hypertension': {'preferredTerm': 'Ocular Hypertension',
#   'entityId': 'UMLS/C0028840',
#   'HPO': 'HPO/HP:0007906',
#   'MSH': 'MSH/D009798'},
#  'Oedema, pulmonary': {'preferredTerm': 'Edema',
#   'entityId': 'UMLS/C0013604',
#   'HPO': 'HPO/HP:0000969',
#   'MSH': 'MSH/D004487'},
#  'Oesophagitis, eosinophilic': {'preferredTerm': 'Esophagitis',
#   'entityId': 'UMLS/C0014868',
#   'HPO': 'HPO/HP:0100633',
#   'MSH': 'MSH/D004941'},
#  'Open-angle glaucoma': {'preferredTerm': 'Glaucoma, Open-Angle',
#   'entityId': 'UMLS/C0017612',
#   'HPO': 'HPO/HP:0012108',
#   'MSH': 'MSH/D005902'},
#  'Osteoarthritis': {'preferredTerm': 'Degenerative polyarthritis',
#   'entityId': 'UMLS/C0029408',
#   'HPO': 'HPO/HP:0002758',
#   'MSH': 'MSH/D010003'},
#  'Osteopenia': {'preferredTerm': 'Osteopenia',
#   'entityId': 'UMLS/C0029453',
#   'HPO': 'HPO/HP:0000938',
#   'MSH': 'MSH/D001851'},
#  'Osteoporosis': {'preferredTerm': 'Osteoporosis',
#   'entityId': 'UMLS/C0029456',
#   'HPO': 'HPO/HP:0000939',
#   'MSH': 'MSH/D010024'},
#  'Osteoporosis, male': {'preferredTerm': 'Osteoporosis',
#   'entityId': 'UMLS/C0029456',
#   'HPO': 'HPO/HP:0000939',
#   'MSH': 'MSH/D010024'},
#  'Osteoporosis, postmenopausal': {'preferredTerm': 'Osteoporosis',
#   'entityId': 'UMLS/C0029456',
#   'HPO': 'HPO/HP:0000939',
#   'MSH': 'MSH/D010024'},
#  'Otitis media': {'preferredTerm': 'Otitis Media',
#   'entityId': 'UMLS/C0029882',
#   'HPO': 'HPO/HP:0000388',
#   'MSH': 'MSH/D010033'},
#  'Ovarian cancer': {'preferredTerm': 'Malignant neoplasm of ovary',
#   'entityId': 'UMLS/C1140680',
#   'HPO': 'HPO/HP:0100615',
#   'MSH': 'MSH/D010051'},
#  'Ovarian neoplasms|neoplasms|solid tumor|hepatic impairment': {'preferredTerm': 'ovarian neoplasm',
#   'entityId': 'UMLS/C0919267',
#   'HPO': 'HPO/HP:0100615',
#   'MSH': 'MSH/D010051'},
#  'Pain, inflammatory': {'preferredTerm': 'Pain',
#   'entityId': 'UMLS/C0030193',
#   'HPO': 'HPO/HP:0012531',
#   'MSH': 'MSH/D010146'},
#  'Pain, neuropathic': {'preferredTerm': 'Pain',
#   'entityId': 'UMLS/C0030193',
#   'HPO': 'HPO/HP:0012531',
#   'MSH': 'MSH/D010146'},
#  'Pancreatic neuroendocrine tumor (pnet)': {'preferredTerm': 'Well Differentiated Pancreatic Endocrine Tumor',
#   'entityId': 'UMLS/C1337011',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Pancreatitis, acute necrotizing': {'preferredTerm': 'Pancreatitis',
#   'entityId': 'UMLS/C0030305',
#   'HPO': 'HPO/HP:0001733',
#   'MSH': 'MSH/D010195'},
#  'Panic disorder': {'preferredTerm': 'Panic Disorder',
#   'entityId': 'UMLS/C0030319',
#   'HPO': 'nan',
#   'MSH': 'MSH/D016584'},
#  'Parkinson disease': {'preferredTerm': 'Parkinson Disease',
#   'entityId': 'UMLS/C0030567',
#   'HPO': 'HPO/HP:0001300',
#   'MSH': 'MSH/D010300'},
#  "Parkinson's disease dementia": {'preferredTerm': 'Parkinson Disease',
#   'entityId': 'UMLS/C0030567',
#   'HPO': 'nan',
#   'MSH': 'MSH/D010300'},
#  'Partial onset seizures': {'preferredTerm': 'Seizures',
#   'entityId': 'UMLS/C0036572',
#   'HPO': 'HPO/HP:0001250',
#   'MSH': 'MSH/D012640'},
#  'Peripheral neuropathic pain': {'preferredTerm': 'Neuralgia',
#   'entityId': 'UMLS/C0027796',
#   'HPO': 'HPO/HP:0033345',
#   'MSH': 'MSH/D009437'},
#  'Peripheral neuropathies': {'preferredTerm': 'Peripheral Neuropathy',
#   'entityId': 'UMLS/C0031117',
#   'HPO': 'HPO/HP:0009830',
#   'MSH': 'MSH/D010523'},
#  'Persistent asthma': {'preferredTerm': 'Asthma',
#   'entityId': 'UMLS/C0004096',
#   'HPO': 'HPO/HP:0002099',
#   'MSH': 'MSH/D001249'},
#  'Pertussis': {'preferredTerm': 'Pertussis',
#   'entityId': 'UMLS/C0043167',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014917'},
#  'Philadelphia chromosome positive acute lymphoblastic leukemia (ph+ all)': {'preferredTerm': 'Acute lymphocytic leukemia',
#   'entityId': 'UMLS/C0023449',
#   'HPO': 'HPO/HP:0006721',
#   'MSH': 'MSH/D054198'},
#  'Plaque psoriasis': {'preferredTerm': 'Psoriasis',
#   'entityId': 'UMLS/C0033860',
#   'HPO': 'HPO/HP:0003765',
#   'MSH': 'MSH/D011565'},
#  'Pneumonia, community-acquired': {'preferredTerm': 'Pneumonia',
#   'entityId': 'UMLS/C0032285',
#   'HPO': 'HPO/HP:0002090',
#   'MSH': 'MSH/D011014'},
#  'Poliomyelitis': {'preferredTerm': 'Poliomyelitis',
#   'entityId': 'UMLS/C0032371',
#   'HPO': 'nan',
#   'MSH': 'MSH/D011051'},
#  'Polyps, nasal': {'preferredTerm': 'Multiple polyps',
#   'entityId': 'UMLS/C0334108',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Post-polycythemia vera myelofibrosis (ppv-mf)': {'preferredTerm': 'Post-polycythemia vera myelofibrosis',
#   'entityId': 'UMLS/C3805232',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Post-traumatic stress disorder': {'preferredTerm': 'Post-Traumatic Stress Disorder',
#   'entityId': 'UMLS/C0038436',
#   'HPO': 'HPO/HP:0033676',
#   'MSH': 'MSH/D013313'},
#  'Postherpetic neuralgia (phn)': {'preferredTerm': 'Postherpetic neuralgia',
#   'entityId': 'UMLS/C0032768',
#   'HPO': 'nan',
#   'MSH': 'MSH/D051474'},
#  'Postpartum hemorrhage': {'preferredTerm': 'Postpartum Hemorrhage',
#   'entityId': 'UMLS/C0032797',
#   'HPO': 'HPO/HP:0011891',
#   'MSH': 'MSH/D006473'},
#  'Premature ejaculation': {'preferredTerm': 'Premature Ejaculation',
#   'entityId': 'UMLS/C0033038',
#   'HPO': 'HPO/HP:0012876',
#   'MSH': 'MSH/D061686'},
#  'Premenstrual syndrome': {'preferredTerm': 'Premenstrual syndrome',
#   'entityId': 'UMLS/C0033046',
#   'HPO': 'nan',
#   'MSH': 'MSH/D011293'},
#  'Prostate cancer': {'preferredTerm': 'Malignant neoplasm of prostate',
#   'entityId': 'UMLS/C0376358',
#   'HPO': 'HPO/HP:0012125',
#   'MSH': 'MSH/D011471'},
#  'Prostatic hyperplasia': {'preferredTerm': 'Prostatic Hyperplasia',
#   'entityId': 'UMLS/C2937421',
#   'HPO': 'nan',
#   'MSH': 'MSH/D011470'},
#  'Psoriasis': {'preferredTerm': 'Psoriasis',
#   'entityId': 'UMLS/C0033860',
#   'HPO': 'HPO/HP:0003765',
#   'MSH': 'MSH/D011565'},
#  'Psoriasis, nail': {'preferredTerm': 'Psoriasis',
#   'entityId': 'UMLS/C0033860',
#   'HPO': 'HPO/HP:0003765',
#   'MSH': 'MSH/D011565'},
#  'Psoriasis, palmoplantar': {'preferredTerm': 'Psoriasis',
#   'entityId': 'UMLS/C0033860',
#   'HPO': 'HPO/HP:0003765',
#   'MSH': 'MSH/D011565'},
#  'Psoriatic arthritis': {'preferredTerm': 'Arthritis, Psoriatic',
#   'entityId': 'UMLS/C0003872',
#   'HPO': 'nan',
#   'MSH': 'MSH/D015535'},
#  'Pulmonary arterial hypertension': {'preferredTerm': 'Pulmonary arterial hypertension',
#   'entityId': 'UMLS/C2973725',
#   'HPO': 'HPO/HP:0002092',
#   'MSH': 'MSH/D000081029'},
#  'Pulmonary disease, chronic obstructive': {'preferredTerm': 'Lung diseases',
#   'entityId': 'UMLS/C0024115',
#   'HPO': 'HPO/HP:0002088',
#   'MSH': 'MSH/D008171'},
#  'Refractory partial seizures': {'preferredTerm': 'Seizures, Focal',
#   'entityId': 'UMLS/C0751495',
#   'HPO': 'HPO/HP:0007359',
#   'MSH': 'MSH/D012640'},
#  'Renal cell carcinoma': {'preferredTerm': 'Renal Cell Carcinoma',
#   'entityId': 'UMLS/C0007134',
#   'HPO': 'HPO/HP:0005584',
#   'MSH': 'MSH/D002292'},
#  'Respiratory disorders': {'preferredTerm': 'Respiration Disorders',
#   'entityId': 'UMLS/C0035204',
#   'HPO': 'nan',
#   'MSH': 'MSH/D012120'},
#  'Respiratory syncytial virus infections': {'preferredTerm': 'Respiratory Syncytial Virus Infections',
#   'entityId': 'UMLS/C0035235',
#   'HPO': 'nan',
#   'MSH': 'MSH/D018357'},
#  'Restless legs syndrome': {'preferredTerm': 'Restless Legs Syndrome',
#   'entityId': 'UMLS/C0035258',
#   'HPO': 'HPO/HP:0012452',
#   'MSH': 'MSH/D012148'},
#  'Retinal diseases': {'preferredTerm': 'Retinal Diseases',
#   'entityId': 'UMLS/C0035309',
#   'HPO': 'HPO/HP:0000479',
#   'MSH': 'MSH/D012164'},
#  'Retinopathy of prematurity': {'preferredTerm': 'Retinopathy of Prematurity',
#   'entityId': 'UMLS/C0035344',
#   'HPO': 'HPO/HP:0500049',
#   'MSH': 'MSH/D012178'},
#  'Retinopathy, diabetic': {'preferredTerm': 'Diabetic Retinopathy',
#   'entityId': 'UMLS/C0011884',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003930'},
#  'Rheumatoid arthritis': {'preferredTerm': 'Rheumatoid Arthritis',
#   'entityId': 'UMLS/C0003873',
#   'HPO': 'HPO/HP:0001370',
#   'MSH': 'MSH/D001172'},
#  'Rhinitis': {'preferredTerm': 'Rhinitis',
#   'entityId': 'UMLS/C0035455',
#   'HPO': 'HPO/HP:0012384',
#   'MSH': 'MSH/D012220'},
#  'Rhinitis, allergic, perennial': {'preferredTerm': 'Rhinitis',
#   'entityId': 'UMLS/C0035455',
#   'HPO': 'HPO/HP:0012384',
#   'MSH': 'MSH/D012220'},
#  'Rhinitis, allergic, perennial and seasonal': {'preferredTerm': 'Rhinitis',
#   'entityId': 'UMLS/C0035455',
#   'HPO': 'HPO/HP:0012384',
#   'MSH': 'MSH/D012220'},
#  'Rhinitis, allergic, seasonal': {'preferredTerm': 'Rhinitis',
#   'entityId': 'UMLS/C0035455',
#   'HPO': 'HPO/HP:0012384',
#   'MSH': 'MSH/D012220'},
#  'Rhinitis, vasomotor': {'preferredTerm': 'Rhinitis',
#   'entityId': 'UMLS/C0035455',
#   'HPO': 'HPO/HP:0012384',
#   'MSH': 'MSH/D012220'},
#  'Rubella': {'preferredTerm': 'Rubella',
#   'entityId': 'UMLS/C0035920',
#   'HPO': 'nan',
#   'MSH': 'MSH/D012409'},
#  'Sarcoma, soft tissue': {'preferredTerm': 'Sarcoma',
#   'entityId': 'UMLS/C1261473',
#   'HPO': 'HPO/HP:0100242',
#   'MSH': 'MSH/D012509'},
#  'Schizophrenia': {'preferredTerm': 'Schizophrenia',
#   'entityId': 'UMLS/C0036341',
#   'HPO': 'HPO/HP:0100753',
#   'MSH': 'MSH/D012559'},
#  'Scleroderma, systemic': {'preferredTerm': 'Scleroderma',
#   'entityId': 'UMLS/C0011644',
#   'HPO': 'HPO/HP:0100324',
#   'MSH': 'MSH/D012594'},
#  'Secondary prevention of thromboembolic events': {'preferredTerm': 'Thromboembolism',
#   'entityId': 'UMLS/C0040038',
#   'HPO': 'HPO/HP:0001907',
#   'MSH': 'MSH/D013923'},
#  'Seizure disorder generalized tonic clonic': {'preferredTerm': 'Epilepsy',
#   'entityId': 'UMLS/C0014544',
#   'HPO': 'HPO/HP:0001250',
#   'MSH': 'MSH/D004827'},
#  'Seizure, absence': {'preferredTerm': 'Seizures',
#   'entityId': 'UMLS/C0036572',
#   'HPO': 'HPO/HP:0001250',
#   'MSH': 'MSH/D012640'},
#  'Seizures': {'preferredTerm': 'Seizures',
#   'entityId': 'UMLS/C0036572',
#   'HPO': 'HPO/HP:0001250',
#   'MSH': 'MSH/D012640'},
#  'Sepsis': {'preferredTerm': 'Septicemia',
#   'entityId': 'UMLS/C0036690',
#   'HPO': 'HPO/HP:0100806',
#   'MSH': 'MSH/D018805'},
#  'Shigella sonnei infection': {'preferredTerm': 'Shigella sonnei',
#   'entityId': 'UMLS/C0036960',
#   'HPO': 'nan',
#   'MSH': 'MSH/D012764'},
#  'Sickle cell disease': {'preferredTerm': 'Anemia, Sickle Cell',
#   'entityId': 'UMLS/C0002895',
#   'HPO': 'nan',
#   'MSH': 'MSH/D000755'},
#  'Sinusitis': {'preferredTerm': 'Sinusitis',
#   'entityId': 'UMLS/C0037199',
#   'HPO': 'HPO/HP:0000246',
#   'MSH': 'MSH/D012852'},
#  'Sinusitis, acute': {'preferredTerm': 'Sinusitis',
#   'entityId': 'UMLS/C0037199',
#   'HPO': 'HPO/HP:0000246',
#   'MSH': 'MSH/D012852'},
#  "Sjoegren's syndrome": {'preferredTerm': 'Adie Syndrome',
#   'entityId': 'UMLS/C0001519',
#   'HPO': 'HPO/HP:0000717',
#   'MSH': 'MSH/D000270'},
#  'Skin diseases': {'preferredTerm': 'Disease',
#   'entityId': 'UMLS/C0012634',
#   'HPO': 'nan',
#   'MSH': 'MSH/D004194'},
#  'Skin infections, bacterial': {'preferredTerm': 'Communicable Diseases',
#   'entityId': 'UMLS/C0009450',
#   'HPO': 'nan',
#   'MSH': 'MSH/D003141'},
#  'Sleep disorders': {'preferredTerm': 'Sleep Disorders',
#   'entityId': 'UMLS/C0851578',
#   'HPO': 'nan',
#   'MSH': 'MSH/D012893'},
#  'Sleep initiation and maintenance disorders': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Sma - spinal muscular atrophy': {'preferredTerm': 'Spinal Muscular Atrophy',
#   'entityId': 'UMLS/C0026847',
#   'HPO': 'HPO/HP:0007269',
#   'MSH': 'MSH/D009134'},
#  'Smoking cessation': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Social phobia': {'preferredTerm': 'Phobic anxiety disorder',
#   'entityId': 'UMLS/C0349231',
#   'HPO': 'nan',
#   'MSH': 'MSH/D010698'},
#  'Soft tissue sarcoma': {'preferredTerm': 'Sarcoma',
#   'entityId': 'UMLS/C1261473',
#   'HPO': 'HPO/HP:0100242',
#   'MSH': 'MSH/D012509'},
#  'Solid tumor cancer with bone metastases': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Solid tumours': {'preferredTerm': 'Neoplasms',
#   'entityId': 'UMLS/C0027651',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Spasticity, post-stroke': {'preferredTerm': 'Muscle Spasticity',
#   'entityId': 'UMLS/C0026838',
#   'HPO': 'HPO/HP:0001257',
#   'MSH': 'MSH/D009128'},
#  'Spondylitis, ankylosing': {'preferredTerm': 'Spondylitis',
#   'entityId': 'UMLS/C0038012',
#   'HPO': 'HPO/HP:0033631',
#   'MSH': 'MSH/D013166'},
#  'Spondyloarthritis': {'preferredTerm': 'Spondylarthritis',
#   'entityId': 'UMLS/C0949690',
#   'HPO': 'nan',
#   'MSH': 'MSH/D025241'},
#  'Streptococcus agalactiae': {'preferredTerm': 'Streptococcus agalactiae',
#   'entityId': 'UMLS/C0579233',
#   'HPO': 'nan',
#   'MSH': 'MSH/D013292'},
#  'Streptococcus pneumoniae': {'preferredTerm': 'Streptococcus pneumoniae',
#   'entityId': 'UMLS/C0038410',
#   'HPO': 'nan',
#   'MSH': 'MSH/D013296'},
#  'Substance dependence': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Systemic juvenile idiopathic arthritis (sjia)': {'preferredTerm': 'Juvenile arthritis',
#   'entityId': 'UMLS/C3495559',
#   'HPO': 'HPO/HP:0005681',
#   'MSH': 'MSH/D001171'},
#  'Systemic lupus erythematosus': {'preferredTerm': 'Lupus Erythematosus, Systemic',
#   'entityId': 'UMLS/C0024141',
#   'HPO': 'HPO/HP:0002725',
#   'MSH': 'MSH/D008180'},
#  'Tendon injuries': {'preferredTerm': 'Tendon Injuries',
#   'entityId': 'UMLS/C0039504',
#   'HPO': 'HPO/HP:0100550',
#   'MSH': 'MSH/D013708'},
#  'Tetanus': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Therapeutic treatment of inhalation anthrax': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Thromboembolism': {'preferredTerm': 'Thromboembolism',
#   'entityId': 'UMLS/C0040038',
#   'HPO': 'HPO/HP:0001907',
#   'MSH': 'MSH/D013923'},
#  'Thrombosis, venous': {'preferredTerm': 'Thrombosis',
#   'entityId': 'UMLS/C0040053',
#   'HPO': 'nan',
#   'MSH': 'MSH/D013927'},
#  'Thyroid cancer': {'preferredTerm': 'Malignant Neoplasms',
#   'entityId': 'UMLS/C0006826',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Tinnitus': {'preferredTerm': 'Tinnitus',
#   'entityId': 'UMLS/C0040264',
#   'HPO': 'HPO/HP:0000360',
#   'MSH': 'MSH/D014012'},
#  'Tobacco use disorder': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Tooth erosion': {'preferredTerm': 'Tooth Erosion',
#   'entityId': 'UMLS/C0040436',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014077'},
#  'Toxoplasmosis': {'preferredTerm': 'Toxoplasmosis',
#   'entityId': 'UMLS/C0040558',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014123'},
#  'Transplantation, kidney': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Transplantation, liver': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Transplantation, organ': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Tuberculosis': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Tumors characterized by genetic abnormalities of alk': {'preferredTerm': 'Neoplasms',
#   'entityId': 'UMLS/C0027651',
#   'HPO': 'HPO/HP:0002664',
#   'MSH': 'MSH/D009369'},
#  'Type 2 diabetes': {'preferredTerm': 'Diabetes Mellitus, Non-Insulin-Dependent',
#   'entityId': 'UMLS/C0011860',
#   'HPO': 'HPO/HP:0005978',
#   'MSH': 'MSH/D003924'},
#  'Typhoid fever': {'preferredTerm': 'Typhoid Fever',
#   'entityId': 'UMLS/C0041466',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014435'},
#  'Ulcers, duodenal and gastric': {'preferredTerm': 'Ulcer',
#   'entityId': 'UMLS/C0041582',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014456'},
#  'Uncontrolled asthma': {'preferredTerm': 'Asthma',
#   'entityId': 'UMLS/C0004096',
#   'HPO': 'HPO/HP:0002099',
#   'MSH': 'MSH/D001249'},
#  'Urinary bladder, overactive': {'preferredTerm': 'nan',
#   'entityId': 'nan',
#   'HPO': 'nan',
#   'MSH': 'nan'},
#  'Urinary incontinence': {'preferredTerm': 'Urinary Incontinence',
#   'entityId': 'UMLS/C0042024',
#   'HPO': 'HPO/HP:0000020',
#   'MSH': 'MSH/D014549'},
#  'Urologic diseases': {'preferredTerm': 'Urologic Diseases',
#   'entityId': 'UMLS/C0042075',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014570'},
#  'Urticaria': {'preferredTerm': 'Urticaria',
#   'entityId': 'UMLS/C0042109',
#   'HPO': 'HPO/HP:0001025',
#   'MSH': 'MSH/D014581'},
#  'Varicella': {'preferredTerm': 'Chickenpox',
#   'entityId': 'UMLS/C0008049',
#   'HPO': 'nan',
#   'MSH': 'MSH/D002644'},
#  'Vascular disease, peripheral': {'preferredTerm': 'Vascular Diseases',
#   'entityId': 'UMLS/C0042373',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014652'},
#  'Vasculitis': {'preferredTerm': 'Vasculitis',
#   'entityId': 'UMLS/C0042384',
#   'HPO': 'HPO/HP:0002633',
#   'MSH': 'MSH/D014657'},
#  'Virus diseases': {'preferredTerm': 'Virus Diseases',
#   'entityId': 'UMLS/C0042769',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014777'},
#  'Vomiting': {'preferredTerm': 'Vomiting',
#   'entityId': 'UMLS/C0042963',
#   'HPO': 'HPO/HP:0002013',
#   'MSH': 'MSH/D014839'},
#  'Wet age related macular degeneration (amd)': {'preferredTerm': 'Macular degeneration',
#   'entityId': 'UMLS/C0024437',
#   'HPO': 'HPO/HP:0000608',
#   'MSH': 'MSH/D008268'},
#  'Whole cell pertussis': {'preferredTerm': 'Pertussis',
#   'entityId': 'UMLS/C0043167',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014917'},
#  'Wound healing': {'preferredTerm': 'Injury wounds',
#   'entityId': 'UMLS/C0043250',
#   'HPO': 'nan',
#   'MSH': 'MSH/D014947'}}

# %%
trial_conditions = []

for i, row in clinical_trials.iterrows():
    for x in row["Medical Condition"].split("; "):
        x = x.strip().lower().capitalize()

        query = ""
        if x in condition_abnornaml_list_mapping:
            if condition_abnornaml_list_mapping[x] != "":
                query = condition_abnornaml_list_mapping[x]
        else:
            query = x

        if query in condition_nlp_mapping and condition_nlp_mapping[query]["entityId"] != 'nan':
            trial_conditions.append((row["Posting ID"], condition_nlp_mapping[query]["entityId"]))

# %%
content = "from\tto\n"
for row in trial_conditions:
    content += f"{row[0]}\t{row[1]}\n"

# %%
with open("trial_conditions.tsv", "w") as f:
    f.write(content)

# %%
medicine_abnornaml_list_mapping = {"Nan": ""}

# %%
rx_cryptic_drug = re.compile(r'[A-Za-z]+\d+')

# %%
medicine = []
cryptic_drugs = []

content = ""
for m in clinical_trials["Medicine or Vaccine (generic name)"].unique():
    for x in str(m).split(";"):
        x = x.strip().lower().capitalize()
        if x in medicine_abnornaml_list_mapping:
            if medicine_abnornaml_list_mapping[x] != "":
                medicine.append(medicine_abnornaml_list_mapping[x])
        else:
            if rx_cryptic_drug.match(x) is None:
                medicine.append(x)
            else:
                if "vaccine" in x:
                    medicine.append(x)
                else:
                    cryptic_drugs.append(x)

medicine = sorted(list(set(medicine)))

content = ""
for c in medicine:
    content += c + "\n"

with open("medicines.txt", "w") as f:
    f.write(content)

content = ""
for c in cryptic_drugs:
    content += c + "\n"

with open("cryptic_medicines.txt", "w") as f:
    f.write(content)

# %%
medicine_gcp_nlp = pd.read_csv("medicine_gcp_ner.tsv", sep="\t")
medicine_gcp_nlp.head()
# Out:
#                                                 text  \
# 0  10-valent pneumococcal polysaccharide and non-...
# 1  12-valent pneumococcal polysaccharide and non-...
# 2                                           Abacavir
# 3                                Abacavir/lamivudine
# 4                     Abacavir/lamivudine/zidovudine
#
#                                        preferredTerm  \
# 0  pneumococcal polysaccharide, type 37;Polyvalen...
# 1  pneumococcal polysaccharide, type 37;Polyvalen...
# 2                                           abacavir
# 3                              abacavir / lamivudine
# 4                                           abacavir
#
#                                             entityId  confidence  HPO  \
# 0  UMLS/C0245576;UMLS/C0305065;UMLS/C1098021;UMLS...    0.519008  NaN
# 1  UMLS/C0245576;UMLS/C0305065;UMLS/C1098021;UMLS...    0.609726  NaN
# 2                                      UMLS/C0663655    0.960383  NaN
# 3                                      UMLS/C1613391    0.552100  NaN
# 4                                      UMLS/C0663655    0.958070  NaN
#
#                                                MSH
# 0  MSH/C058381;MSH/D022242;MSH/C437065;MSH/C437065
# 1  MSH/C058381;MSH/D022242;MSH/C437065;MSH/C437065
# 2                                      MSH/C106538
# 3                                      MSH/C492871
# 4                                      MSH/C106538

# %%
medicine_nlp_mapping = {}
for i, row in medicine_gcp_nlp.iterrows():
    temp = {}
    for h in ["preferredTerm", "entityId", "HPO", "MSH"]:
        if ";" in str(row[h]):
            temp[h] = row[h].split(";")[0]
        else:
            temp[h] = str(row[h])
    medicine_nlp_mapping[row["text"]] = temp

# %%
trial_medicines = []

for i, row in clinical_trials.iterrows():
    for x in str(row["Medicine or Vaccine (generic name)"]).split("; "):
        x = x.strip().lower().capitalize()

        query = ""
        if x in medicine_abnornaml_list_mapping:
            if medicine_abnornaml_list_mapping[x] != "":
                query = medicine_abnornaml_list_mapping[x]
        else:
            query = x

        if query in medicine_nlp_mapping and medicine_nlp_mapping[query]["entityId"] != 'nan':
            trial_medicines.append((row["Posting ID"], medicine_nlp_mapping[query]["entityId"]))

# %%
content = "from\tto\n"
for row in trial_medicines:
    content += f"{row[0]}\t{row[1]}\n"

# %%
with open("trial_medicines.tsv", "w") as f:
    f.write(content)
