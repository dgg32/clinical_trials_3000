# %%
import pandas as pd
import numpy as np

# %%
clinical_trials = pd.read_csv('clinical_study_data_request_com_all_sponsor.tsv', sep="\t")

# %%
clinical_trials.head()
# Out:
#    Posting ID Sponsor                                        Study Title  \
# 0           1     GSK  U0289-401: An Evaluator Blinded, 8 Week, Split...
# 1           3     GSK  GSK1550188, A randomised, single-blind, placeb...
# 2           4     GSK  A Multicenter, Randomized, Double-Blind, Phase...
# 3           8     GSK  Two-week Study to Determine and Compare the To...
# 4           9     GSK  A single-blind, randomized, comparative split-...
#
#        Medicine or Vaccine (generic name) Sponsor Identification Number  \
# 0         benzoyl peroxide/salicylic acid                     STF114550
# 1                               belimumab                     BEL114243
# 2             calcipotriol, calcipotriene                     STF114741
# 3  benzoyl peroxide/clindamycin phosphate                     STF114546
# 4  benzoyl peroxide/clindamycin phosphate                     STF114547
#
#               Medical Condition    Phase  \
# 0                 Acne Vulgaris  Phase 4
# 1  Systemic Lupus Erythematosus  Phase 1
# 2                     Psoriasis  Phase 3
# 3                 Acne Vulgaris  Phase 4
# 4                 Acne Vulgaris  Phase 4
#
#                       Link to Sponsor Study Registry  \
# 0  https://www.gsk-studyregister.com/en/trial-det...
# 1  https://www.gsk-studyregister.com/en/trial-det...
# 2  https://www.gsk-studyregister.com/en/trial-det...
# 3  https://www.gsk-studyregister.com/en/trial-det...
# 4  https://www.gsk-studyregister.com/en/trial-det...
#
#   Link to study details on ClinicalTrials.gov (if available)  \
# 0         http://clinicaltrials.gov/show/NCT01706250
# 1         http://clinicaltrials.gov/show/NCT01381536
# 2         http://clinicaltrials.gov/show/NCT00688519
# 3         http://clinicaltrials.gov/show/NCT01015638
# 4         http://clinicaltrials.gov/show/NCT00964223
#
#   Link to study details on EudraCT (if available) Analysis-ready dataset  \
# 0                                             NaN                      N
# 1                                             NaN                      N
# 2                                             NaN                      Y
# 3                                             NaN                      N
# 4                                             NaN                      Y
#
#   Annotated case report form Clinical study report Dataset specifications  \
# 0                          Y                     Y                      Y
# 1                          Y                     Y                      Y
# 2                          Y                     Y                      Y
# 3                          N                     Y                      Y
# 4                          Y                     Y                      Y
#
#   Protocol with any amendments Raw dataset Reporting and analysis plan  \
# 0                            N           Y                           N
# 1                            N           Y                           Y
# 2                            Y           Y                           Y
# 3                            Y           Y                           N
# 4                            Y           N                           Y
#
#   Additional Information about the data and documents available for this study  \
# 0  An analysis-ready dataset and a reporting and ...
# 1  An analysis-ready dataset is not available for...
# 2                                                NaN
# 3  An analysis-ready dataset and reporting and an...
# 4     A raw dataset is not available for this study.
#
#   Date Added to this Site
# 0              1-Aug-2015
# 1              1-Jul-2015
# 2              1-Jul-2015
# 3              1-Aug-2014
# 4              1-Aug-2014

# %%
clinical_trials["Medicine or Vaccine (generic name)"].unique()
# Out:
# array(['benzoyl peroxide/salicylic acid', 'belimumab',
#        'calcipotriol, calcipotriene',
#        'benzoyl peroxide/clindamycin phosphate', 'carvedilol',
#        'casopitant', 'clobetasol', 'darotropium bromide',
#        'vilanterol/darotropium bromide', 'fluticasone furoate',
#        'fluticasone propionate', 'fluticasone propionate/salmeterol',
#        'fondaparinux sodium', 'GSK256066', 'GW870086', 'lamotrigine',
#        'omega-3-acid ethyl esters', 'otelixizumab', 'paroxetine',
#        'retapamulin', 'retigabine, ezogabine', 'rilapladib',
#        'ronacaleret', 'ropinirole', 'rosiglitazone', 'SB705498',
#        'sumatriptan/naproxen', 'tazarotene', 'vestipitant',
#        'Human Papillomavirus Types 16 and 18 Vaccine',
#        'Pneumococcal Polysaccharide Conjugate Vaccine (Adsorbed)',
#        'Combined Diphtheria, Tetanus, Acellular Pertussis Adsorbed, Hepatitis B (Recombinant), Inactivated Polio Vaccine',
#        'Combined Diphtheria, Tetanus, Acellular Pertussis, Hepatitis B, Inactivated Polio, Haemophilus influenzae Type b Vaccine',
#        'Diphtheria, Tetanus, Acellular Pertussis Vaccine Adsorbed',
#        'Combined Diphtheria, Tetanus, Pertussis, HepB, Polio, Hib and Neisseria meningitis serogroup C tetanus toxoid conjugate vaccine',
#        'Combined Diphtheria, Tetanus, Whole Cell Pertussis, Hepatitis B, Haemophilus influenzae Type b Vaccine (KFT)',
#        'Combined Measles, Mumps, Rubella, Varicella Vaccine',
#        'Combined Reduced Antigen Content Diphtheria, Tetanus, Acellular Pertussis Vaccine',
#        'Combined Reduced Antigen Content Diphtheria, Tetanus, Acellular Pertussis, Inactivated Polio Vaccine',
#        'Hepatitis B Vaccine, Recombinant',
#        'Influenza Vaccine (Quadrivalent)', 'GSK1388442A',
#        'H5N1 Pandemic Influenza Vaccine', 'Influenza Vaccine',
#        'H1N1 Pandemic Influenza Vaccine',
#        'Haemophilus influenzae Type b, Meningococcal C and Y-Tetanus Toxoid Conjugate Vaccine',
#        'Haemophilus influenzae Type b, Meningococcal C-Tetanus Toxoid Conjugate Vaccine',
#        'Influenza Vaccine (Split Virion, Inactivated)',
#        'Influenza Vaccine (Split Virion, Inactivated, Fluviral)',
#        'Poliomyelitis Vaccine (Inactivated)', 'Rotavirus Vaccine',
#        'zanamivir', 'GSK932121',
#        'Combined Diphtheria, Tetanus, Acellular Pertussis, Haemophilus influenzae Type b Conjugate Vaccine',
#        'Combined Diphtheria, Tetanus, Acellular Pertussis, Inactivated Polio, Haemophilus influenzae Type b Conjugate Vaccine',
#        'dutasteride', 'fluticasone furoate/vilanterol', 'GSK2018682',
#        'salmeterol', 'vilanterol', 'abacavir', 'abacavir/lamivudine',
#        'abacavir/lamivudine/zidovudine', 'dolutegravir', 'fosamprenavir',
#        'lamivudine', 'maraviroc', 'nadroparin calcium', 'fiboflapon',
#        'Hepatitis A Vaccine, Inactivated', 'salbutamol',
#        'umeclidinium bromide', 'umeclidinium bromide/vilanterol',
#        'albiglutide', nan, 'amoxicillin/clavulanic acid',
#        'carvedilol; carvedilol/lisinopril; lisinopril',
#        'fluticasone furoate; fluticasone propionate',
#        'Haemophilus influenzae Type b Vaccine', 'twinrix', 'sumatriptan',
#        'valaciclovir', 'RTS,S Vaccine', 'bupropion',
#        'Combined Diphtheria, Tetanus, Whole Cell Pertussis, Hepatitis B, Haemophilus influenzae Type b Vaccine',
#        'Meningococcal Serogroups A, C, W-135 and Y Vaccine',
#        'Varicella Vaccine', 'omalizumab', 'albiglutide/metformin',
#        'cilomilast', 'cilomilast/salmeterol/fluticasone propionate',
#        'denagliptin', 'rosiglitazone/metformin',
#        'umeclidinium bromide/vilanterol;umeclidinium bromide',
#        'vestipitant/paroxetine', 'mirabegron',
#        'solifenacin succinate + tamsulosin', 'GSK2590066A',
#        'Hepatitis A (Inactivated), Hepatitis B (Recombinant) Vaccine',
#        'rosiglitazone/glimepiride',
#        'darotropium bromide; vilanterol; darotropium bromide/vilanterol',
#        'naratriptan', 'rosiglitazone; rosiglitazone/metformin',
#        'artesunate/chlorproguanil/dapsone', 'GSK2245840', 'GW678007',
#        'milveterol', 'ipragliflozin', 'micafungin', 'regadenoson',
#        'tacrolimus extended-release',
#        'Combined Diphtheria, Tetanus, Whole Cell Pertussis, Hepatitis B Vaccine',
#        'foretinib', 'GSK159802', 'GSK2245841', 'GW597901',
#        'H5N1 Pre-pandemic Influenza Vaccine',
#        'Hepatitis A vaccine, Inactivated', 'Herpes Simplex Vaccine',
#        'Measles, Mumps, Rubella Vaccine', 'Meningococcal Vaccine',
#        'SRT501', 'darapladib', 'Fluticasone furoate',
#        'fluticasone furoate; fluticasone furoate/vilanterol',
#        'GSK2239633', 'GW766994', 'GW799943', 'ibandronic acid',
#        'ketoconazole', 'tositumomab', 'solifenacin succinate',
#        'amlodipine/losartan', 'cefuroxime axetil', 'dilmapimod',
#        'glimepiride/metformin', 'GSK1004723', 'GSK1004723; GSK835726',
#        'GSK1018921; GSK931145', 'GSK1059615', 'GSK1070806', 'GSK1292263',
#        'GSK1322322', 'GSK1322888', 'GSK1360707', 'GSK1482160',
#        'GSK1521498', 'GSK163090', 'GSK202405', 'GSK2339345', 'GSK2374697',
#        'GSK239512', 'GSK2434735', 'GSK2485852', 'refanezumab',
#        'GSK256073', 'GSK2849466', 'GSK315234', 'GSK461364', 'GSK598809',
#        'GSK618334', 'GSK679586', 'GSK704838', 'GSK835726', 'GSK958108',
#        'GW273225; lamotrigine', 'GW274150', 'GW328267', 'GW559090',
#        'GW677954', 'GW784568', 'nabumetone', 'propafenone', 'SB649868',
#        'SB756050', 'lenvatinib', 'digoxin',
#        'umeclidinium bromide; vilanterol; umeclidinium bromide/vilanterol',
#        'vercirnon', 'benzoyl peroxide/clindamycin', 'GSK1034702',
#        'GSK424887', 'Meningococcal Serogroup B Vaccine', 'resveratrol',
#        'erlotinib', 'atorvastatin/glimepiride',
#        'Fluticasone Furoate/vilanterol', 'mepolizumab',
#        'rosiglitazone/simvastatin', 'GSK2336805', 'GSK690693',
#        'metformin', 'solcitinib', 'iboctadekin', 'remifentanil',
#        'secukinumab', 'batefenterol', 'fluticasone furoate/levocabastine',
#        'GSK1362885', 'raxibacumab', 'amlodipine/enalapril',
#        'amlodipine/rosuvastatin', 'GSK2256098', 'isavuconazonium sulfate',
#        'brinzolamide', 'everolimus', 'indacaterol',
#        'indacaterol, glycopyrrolate', 'nilotinib', 'glycopyrronium',
#        'oxcarbazepine', 'sacubitril/valsartan',
#        'travoprost ophthalmic solution', 'valsartan',
#        'amlodipine/benazepril hcl', 'fingolimod', 'rivastigmine',
#        'panobinostat', 'cefadroxil', 'Fluticasone Propionate/Salmeterol',
#        'omipalisib', 'GSK2800528', 'ceritinib', 'dabrafenib',
#        'eltrombopag', 'lapatinib', 'pazopanib', 'trametinib',
#        'zoledronic acid', 'batefenterol; fluticasone furoate',
#        'fluticasone furoate/Levocabastine', 'GSK1995057',
#        'GSK2282512A; Influenza Vaccine (Quadrivalent)',
#        'Polysaccharide Typhoid Vaccine', 'alitretinoin', 'danirixin',
#        'fluticasone furoate/vilanterol trifenatate', 'gepotidacin',
#        'daprodustat', 'GSK1572932A', 'GSK2245035', 'GSK2445053',
#        'GSK356278', 'retosiban', 'camicinal', 'elubrixin', 'epelsiban',
#        'fluticasone furoate/umeclidinium bromide',
#        'fluticasone furoate/vilanterol/umeclidinium bromide',
#        'linerixibat', 'GSK2618960', 'GSK2862277', 'GSK933776',
#        'losmapimod', 'montelukast', 'olopatadine hydrochloride',
#        'candesartan', 'candesartan cilexetil/hydrochlorothiazide',
#        'GSK2189241A', 'GSK2189242A',
#        'GSK2189242A; Pneumococcal Polysaccharide Conjugate Vaccine (Adsorbed)',
#        'GSK2256294', 'nemiralisib', 'GSK2789869A', 'relacatib',
#        'tafenoquine', 'GSK1399686',
#        'Herpes Zoster subunit (HZ/su) vaccine',
#        'nepafenac ophthalmic suspension, 0.3%', 'perampanel',
#        'adefovir/lamivudine', 'GSK2647544', 'GSK3206641A', 'tapinarof',
#        'acetylsalicylic acid/pantoprazole', 'GSK2282512A',
#        'methylphenidate', 'certolizumab pegol', 'tacrolimus',
#        'rabeprazole', 'exenatide', 'GSK2132231A', 'GSK2245851',
#        'GSK2890457', 'GW824575', 'mapatumumab', 'oxytocin', 'SB249553',
#        'SB719125', 'GSK2647155A', 'GSK2231395A', 'GSK2302032A',
#        'eribulin mesilate', 'rufinamide', 'dutasteride/tamsulosin',
#        'GSK2231392A', 'GSK2302025A', 'GSK2315698/GSK2398852',
#        'GSK2654911A', 'GSK2881078',
#        'Meningococcal group-B vaccine (rDNA, component, adsorbed) rMenB+OMV NZ',
#        'GSK3050002', 'GSK2636771',
#        'Nicotine Polacrilex Lozenge 2 mg and 4 mg', 'GSK3003891A',
#        'SB692342', 'GSK2878175', 'CCI21130', 'otilimab', 'fluticasone',
#        'GSK2793660', 'GSK2849330', 'GSK3117391', 'GSK3191607',
#        'GSK369796', 'letrozole', 'ASP8477', 'fosdevirine', 'nicotine',
#        'GSK3536819A', 'INFANRIX PENTA/INFANRIX HEXA / PEDIARIX',
#        'epoprostenol', 'SB732462', 'GSK3536852A', 'GSK2130579A',
#        'SB208141', 'GSK2392102A', 'GSK3008348', 'GSK2981278',
#        'Indacterol', 'indacterol', 'seralaxin', 'meloxicam', 'SB732461',
#        'GSK2982772', 'talnetant', 'SB773812', 'GSK2330811', 'GSK2798745',
#        'GSK560417A', 'GSK2838497A', 'GSK2302024A', 'fidaxomicin',
#        'GSK3536829A',
#        'Combined Diphtheria, Tetanus, Acellular Pertussis Adsorbed, Hepatitis B (Recombinant), Inactivated Polio Vaccine; Haemophilus influenzae type b',
#        'tenofovir disoproxil fumarate', 'GSK2838232', 'GSK3179106',
#        'dolutegravir/rilpivirine', 'ciprofloxacin', 'GSK568893A',
#        'GSK560410A', 'SB513026', 'GSK3342830', 'GSK1940029', 'GSK3389404',
#        'SB209762', 'GSK3008356', 'GSK2292767', 'GSK2256098; trametinib',
#        'GSK2647153A', 'GSK3536853A', 'GSK3277511A', 'imatinib mesilate',
#        'GSK1557484A', 'GSK2830929A; GSK2830930A',
#        'GSK2231392A; SKF103860', 'SKF103860', 'GSK576389A', 'GSK1119711A',
#        'GSK3052230', 'nicotine polacrilex', 'GSK2981710', 'GSK3128349',
#        'donepezil', 'canakinumab', 'glycopyrronium bromide', 'ofatumumab',
#        'GSK3536855A', 'GSK3389245A', 'SB217744', 'GSK3536820A',
#        'GSK2879552', 'GSK2816126', 'BVS857', 'midostaurin', 'cefixime',
#        'bupropion; paroxetine', 'ASP7962', 'naquotinib mesilate',
#        'leuprorelin acetate', 'GSK3536834A', 'gilteritinib fumarate',
#        'linsitinib', 'ASP1707', 'ASP8232', 'peficitinib hydrobromide',
#        'siponimod', 'triclabendazole', 'pyrimethamine', 'enzalutamide',
#        'linaclotide', 'ASP3652', 'SB213503', 'OnabotulinumtoxinA',
#        'levocetirizine', 'GSK3390107A',
#        'Indacaterol acetate/Mometasone furoate', 'formoterol fumarate',
#        'cabotegravir', 'cabotegravir; rilpivirine',
#        'potassium nitrate/sodium fluoride', 'ribavirin', 'retigabine',
#        'ruxolitinib', 'olodanrigan', 'Oligofructose; Pectin', 'CFZ533',
#        'lanalumab', 'fluticasone furoate/vilanterol/umeclidinium bromid',
#        'deferasirox', 'alpelisib', 'fevipiprant', 'molibresib',
#        'GSK1795091', 'GSK2983559', 'ASP5878', 'GSK3730661',
#        'GI150835/GI237410/GSK3744919/glycerol',
#        'Trivalent Group B streptococcus Vaccine',
#        'indacaterol/mometasone furoate', 'ASP5094', 'tamsulosin HCl',
#        'Onasemnogene Abeparvovec-xioi', 'GSK2831781',
#        '10-valent pneumococcal polysaccharide and non-typeable Haemophilus influenzae protein D conjugate vaccine',
#        '12-valent pneumococcal polysaccharide and non-typeable Haemophilus influenzae protein D conjugate vaccine',
#        'GSK2646264', 'GSK3542503', 'dabrafenib/trametinib', 'octreotide',
#        'onasemnogene abeparvovec xioi', 'GSK3640254',
#        'Developmental Cosmetic Moisturizing Creams', 'brolucizumab',
#        'crizanlizumab', 'GSK3888550A',
#        'carbomer and carmellose sodium gel',
#        'glycerol and niacinamide face cream, serum and lotion',
#        'Dabrafenib', 'GSK1120212', 'vildagliptin', 'GSK3335065',
#        'GSK3511294', 'GSK3985771', 'SB444563', 'SB257049',
#        'GSK3536819A;GSK3536829A', 'GSK3228836', 'Tapentadol',
#        'alisporivir', 'degarelix acetate', 'CAD106', 'CNP520',
#        'GR61229;GSK3358699;GSK562554;sargramostim', 'griseofulvin',
#        'dolutegravir/lamivudine', 'dolutegravir/abacavir/lamivudine',
#        'GSK3844766A', 'Pazopanib', 'GSK3816302A', 'ASP0113',
#        'Fremanezumab', 'Glatiramer Acetate', 'Reslizumab', 'inclisiran',
#        'licarbazepine', 'indacaterol maleate/glycopyrronium bromide',
#        'lapatinib plus capecitabine', 'papzopanib', 'ranibizumab',
#        'GSK3732394', 'melrilimab', 'tisagenlecleucel', 'Nivolumab'],
#       dtype=object)
